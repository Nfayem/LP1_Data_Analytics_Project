# %% [markdown]
# # Leveraging Data-Driven Insights to Uncover Value in the Indian Ecosystem

# %% [markdown]
# ## Table of Contents
# <!-- TOC -->
#
# - [Step 1: Business Understanding](#step-1-business-understanding)
#   - [Scenario](#scenario)
#   - [Objective](#objective)
#   - [Hypothesis: Influence of Top Investors](#hypothesis-influence-of-top-investors)
#   - [Key Business Questions](#key-business-questions)
#   - [Approach](#approach)
# - [Step 2: Data Understanding](#step-2-data-understanding)
#   - [Project Initialisation](#project-initialisation)
#   - [Data Collection](#data-collection)
#     - [Access the 2020 and 2021 data from Microsoft SQL Server](#access-the-2020-and-2021-data-from-microsoft-sql-server)
#       - [Connect to the database using provided credentials](#connect-to-the-database-using-provided-credentials)
#       - [Fetch Information Schema for tables in the database](#fetch-information-schema-for-tables-in-the-database)
#       - [Load LP1\_startup\_funding2021 Data](#load-lp1_startup_funding2021-data)
#       - [Load LP1\_startup\_funding2020 Data](#load-lp1_startup_funding2020-data)
#     - [Access 2019 data from OneDrive](#access-2019-data-from-onedrive)
#     - [Access the 2018 data from GitHub Repository](#access-the-2018-data-from-github-repository)
#   - [Data Quality Considerations](#data-quality-considerations)
# - [Step 3: Data Preparation](#step-3-data-preparation)
#   - [Data Cleaning](#data-cleaning)
#   - [Data Transformation](#data-transformation)
#   - [Data Integration](#data-integration)
#
# <!-- /TOC -->

# %% [markdown]
# [Back to Top](#Table-of-Contents)
#
# ## Step 1: Business Understanding
#
# ### Background
# A "startup" is typically characterized by its age, size, and funding method, though there isn't a strict definition. Generally, a startup is a young company, only a few years old, that hasn't yet achieved consistent revenue. These companies operate on a small scale, often with just a working prototype or a paid pilot, but they have the potential for rapid growth and expansion. Initially, they are funded by the founders' personal networks, including friends and family, and they actively seek additional financing to support their growth and establish a sustainable business.
#
# As an example, the Government of India’s Startup India program defines a “startup” as a company (PIB 2017) that is:
#
#     1. Headquartered in India with not more than ten years since incorporation or registration
#
#     2. Having an annual turnover of less than INR 1 billion (roughly $14 million) (Startup India 2019)
#
# `Available:` [ADBI Working Paper Series](https://www.adb.org/publications/startup-environment-and-funding-activity-india)
#
# ### Scenario
# Your team is trying to venture into the Indian start-up ecosystem. As the data expert of the team, you are to investigate the ecosystem and propose the best course of action.
#
# ### Objective
# The primary objective is to analyse the funding landscape for start-ups in India from 2018 to 2021, focusing on identifying key trends and patterns. This analysis will provide crucial insights into the Indian start-up ecosystem, which will guide strategic decisions for entering and navigating the market effectively.
#
# ### Hypothesis: Dominance of Funding Stages
#
# **A. Rationale:**
#
# Understanding the distribution of funding across different stages of start-ups can reveal where the bulk of investments are going. This insight is valuable for new start-ups to determine their potential funding opportunities at various stages of their development.
#
# **B. Null Hypothesis (H<sub>0</sub>):**
#
# The proportion of total funding received by early-stage start-ups (seed and series A) is not significantly different from the proportion received by later-stage start-ups (series B and beyond) from 2018 to 2021.
#
# **C. Alternative Hypothesis (H<sub>1</sub>):**
#
# Early-stage start-ups (seed and series A) receive a significantly larger proportion of the total funding compared to later-stage start-ups (series B and beyond) from 2018 to 2021.
#
# ### Key Business Questions
#
# **1. Who are the most active investors in the Indian start-up ecosystem?**
#
# Identifying the most active investors helps understand the key players driving the start-up ecosystem. This information is essential for forming strategic partnerships, understanding investment patterns, and identifying potential sources of capital.
#
# i. Ranking: Rank investors based on the number of deals made.
# ii. Visualization: Use bar charts and heatmaps to visualize the most active investors and their investment patterns by year, total funding amounts and average funding amounts.
# iii. Network Analysis: Conduct a network analysis to understand the relationships and co-investment patterns among top investors.
#
# **2. Are there any geographical trends or hotspots for start-up funding in India?**
#
# Identifying geographical trends or hotspots for start-up funding helps in understanding the regional distribution of investments. This information is valuable for targeting investments, identifying regional hubs of innovation, and planning market entry strategies.
#
# i. Visualization: Use heatmaps to visualize funding concentrations across different regions.
# ii. Cluster Analysis: Perform cluster analysis to identify regions with high concentrations of start-up funding.
# iii. Comparative Analysis: Compare funding amounts across regions to highlight hotspots.
#
# **3. Are there any annual trends in start-up funding in India from 2018 to 2021?**
#
# Understanding the annual trends in start-up funding helps to assess the growth and dynamics of the start-up ecosystem over time. This information is crucial for strategic planning and forecasting future trends, providing insights into how the investment climate has evolved.
#
# i. Trend Analysis: Use line charts to visualize the year-over-year changes in total funding amounts.
# ii. Statistical Analysis: Calculate the annual growth rates and perform a trend analysis to identify any significant upward or downward patterns.
#
# **4. Which sectors received the most funding each year?**
#
# Analyzing the sectors that received the most funding can provide additional context for evaluating the influence of top investors.
#
# **5. What impact do the years of existence or age of a start-up have on investment opportunities?**
#
# Understanding how the age of a start-up influences investment opportunities can provide insights into whether start-ups funded by top investors indeed have higher subsequent funding rounds.
#
# **6. What are the funding stages (seed, series A, etc.) that received the highest investments?**
#
# Examining the funding stages that received the highest investments can offer insights into the funding patterns of top investors.
#
# ### Approach
# In conclusion, to understand the trends and patterns in start-up funding in India from 2018 to 2021, a comprehensive approach will be implemented. This will involve gathering detailed data on start-ups, funding amounts, stages, sectors, geographic locations, and investors. The collected data will be analyzed using descriptive statistics, trend analysis, visualizations, and statistical tests to derive key insights. These insights will be compiled into detailed reports and dashboards, providing actionable information and strategic recommendations. Ultimately, this analysis will offer data-driven guidance on the most promising sectors, regions, and funding stages to focus on, identify key investors for potential partnerships, and assess the overall attractiveness of the Indian start-up market for strategic entry.

# %% [markdown]
# [Back to Top](#Table-of-Contents)
#
# ## Step 2: Data Understanding
#
# `Data Collection`
#
# To effectively analyse the Indian start-up ecosystem from 2018 to 2021, comprehensive data collection is crucial. The data will be sourced from multiple datasets that detail startup funding activities within this period. Each dataset will encompass various aspects essential for a holistic understanding of the funding landscape. Specifically, the datasets will include:
#
# **A. Start-up Details:**
#
# -   Company/Brand: Name of the company/start-up
#
# -   Founded: Year start-up was founded
#
# -   Headquarters/Location: The geographical location of the start-up, including city and region.
#
# -   Sector/Industry: The industry or sector in which the start-up operates, such as healthtech, fintech, etc.
#
# -   What it does/About Company: Description about Company
#
# -   Founders: Founders of the Company
#
# **B. Funding Information:**
#
# -   Amount: The total amount of funding received by the start-up in each funding round.
#
# -   Stage/Round: Details of the funding stages such as seed, series A, series B, etc.
#
# **C. Investors' Information:**
#
# -   Investors: The names of the investors or investment firms involved.
#
# `Data Quality Considerations`
#
# Ensuring high data quality is paramount for reliable analysis and actionable insights. Key considerations for maintaining data quality include:
#
# **A. Completeness:**
#
# Ensure that all necessary fields are filled in across the datasets. This includes making sure that no critical information is missing for any of the start-ups, funding rounds, or investors.
#
# **B. Consistency:**
#
# Handle any inconsistencies in data entries. This may involve standardizing entries for sectors, locations, and investor names to ensure uniformity. For example, variations in how sectors are labeled (e.g., "Healthtech" vs. "Health Technology") should be standardized to a single format.
#
# **C. Handling Missing Data:**
#
# Identify and address missing data points. Techniques such as imputation, where appropriate, or excluding certain records if the missing data is minimal and does not impact overall analysis, will be employed.

# %% [markdown]
# ### Project Initialisation

# %%
# Importing necessary libraries
from dotenv import dotenv_values
import pyodbc
import requests
import pandas as pd
import numpy as np
from scipy.stats import skew, kurtosis
from fancyimpute import IterativeImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression
from scipy.stats import chi2_contingency
import re
import calendar
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.ticker as mtick
from matplotlib.ticker import FuncFormatter
import seaborn as sns
import networkx as nx
import warnings

# Suppressing all warnings to avoid cluttering the output
warnings.filterwarnings("ignore")

# Set display options for Pandas DataFrame
pd.set_option("display.max_rows", 100)
pd.set_option("display.max_columns", 100)

# set theme
sns.set_theme(style="dark", palette="dark", font="sans-serif", font_scale=1.5)
plt.style.use("dark_background")
custom_palette = ["cyan", "magenta", "yellow"]

# %% [markdown]
# ### Data Collection
#
# The task involves accessing three different datasets from different sources: a database, OneDrive, and a GitHub repository. Each dataset has a specific method of access, such as querying a database using ODBC or ORM library, downloading a file programmatically using the requests library from OneDrive, and cloning or downloading a file from a GitHub repository using gitpython or requests library.

# %% [markdown]
# #### Access the 2020 and 2021 data from Microsoft SQL Server

# %% [markdown]
# ##### Connect to the database using provided credentials

# %%
# Load environment variables from .env file
environment_variables = dotenv_values("LP1_DAP.env")

# Retrieve environment variables for database connection
server_name = environment_variables.get("server")
password = environment_variables.get("password")
login = environment_variables.get("login")
database_name = environment_variables.get("database")

# Create a database connection string using pyodbc
connection_string = f"DRIVER={{SQL Server}};SERVER={server_name};DATABASE={database_name};UID={login};PWD={password};"

#Establish a connection to the database
try:
    connection = pyodbc.connect(connection_string)
    print("Connection successful:", connection_string)    
except Exception as e:
    print("Connection failed:", e)
# Out:
# Connection successful: DRIVER={SQL Server};SERVER=dap-projects-database.database.windows.net;DATABASE=dapDB;UID=LP1_learner;PWD=Hyp0th3s!$T3$t!ng;

# %% [markdown]
# ##### Fetch Information Schema for tables in the database

# %%
# Define the SQL query to show specific tables in the database
db_query = """
        SELECT *
        FROM INFORMATION_SCHEMA.TABLES
        WHERE TABLE_SCHEMA = 'dbo'
        """
# Read data from the SQL query result into a DataFrame using the established database connection
schema_df = pd.read_sql(db_query, connection)

#  Check whether data has been retrieved successfully to confirm successful connection to database
try:
    schema_df = pd.read_sql(db_query, connection)    
    print("Data retrieved successfully")
    print()
    print(schema_df)    
except Exception as e:
    print("Failed to retrieve data:", e)
# Out:
# Data retrieved successfully
#
#   TABLE_CATALOG TABLE_SCHEMA               TABLE_NAME  TABLE_TYPE
# 0         dapDB          dbo  LP1_startup_funding2021  BASE TABLE
# 1         dapDB          dbo  LP1_startup_funding2020  BASE TABLE

# %% [markdown]
# ##### Load LP1_startup_funding2021 Data

# %%
# Define the SQL query to show specific tables in the database
db_query1 = """
        SELECT *
        FROM LP1_startup_funding2021        
        """
# Read data from the SQL query result into a DataFrame using the established database connection
df2021 = pd.read_sql(db_query1, connection)

# Display DataFrame Info
df2021.info()
print()

# Display the DataFrame
df2021.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1209 non-null   object
#  1   Founded        1208 non-null   float64
#  2   HeadQuarter    1208 non-null   object
#  3   Sector         1209 non-null   object
#  4   What_it_does   1209 non-null   object
#  5   Founders       1205 non-null   object
#  6   Investor       1147 non-null   object
#  7   Amount         1206 non-null   object
#  8   Stage          781 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 85.1+ KB
#     Company_Brand  Founded HeadQuarter          Sector  \
# 0  Unbox Robotics   2019.0   Bangalore      AI startup
# 1          upGrad   2015.0      Mumbai          EdTech
# 2     Lead School   2012.0      Mumbai          EdTech
# 3         Bizongo   2015.0      Mumbai  B2B E-commerce
# 4        FypMoney   2021.0    Gurugram         FinTech
#
#                                         What_it_does  \
# 0  Unbox Robotics builds on-demand AI-driven ware...
# 1     UpGrad is an online higher education platform.
# 2  LEAD School offers technology based school tra...
# 3  Bizongo is a business-to-business online marke...
# 4  FypMoney is Digital NEO Bank for Teenagers, em...
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
# 3            Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                      Kapil Banwari
#
#                                         Investor        Amount         Stage
# 0                    BEENEXT, Entrepreneur First    $1,200,000  Pre-series A
# 1       Unilazer Ventures, IIFL Asset Management  $120,000,000          None
# 2               GSV Ventures, Westbridge Capital   $30,000,000      Series D
# 3                         CDC Group, IDG Capital   $51,000,000      Series C
# 4  Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal    $2,000,000          Seed

# %% [markdown]
# ##### Load LP1_startup_funding2020 Data

# %%
# Define the SQL query to show specific tables in the database
db_query2 = """
        SELECT *
        FROM LP1_startup_funding2020        
        """
# Read data from the SQL query result into a DataFrame using the established database connection
df2020 = pd.read_sql(db_query2, connection)

# Display DataFrame Info
df2020.info()
print()

# Display the DataFrame
df2020.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1055 entries, 0 to 1054
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1055 non-null   object
#  1   Founded        842 non-null    float64
#  2   HeadQuarter    961 non-null    object
#  3   Sector         1042 non-null   object
#  4   What_it_does   1055 non-null   object
#  5   Founders       1043 non-null   object
#  6   Investor       1017 non-null   object
#  7   Amount         801 non-null    float64
#  8   Stage          591 non-null    object
#  9   column10       2 non-null      object
# dtypes: float64(2), object(8)
# memory usage: 82.5+ KB
#   Company_Brand  Founded HeadQuarter              Sector  \
# 0    Aqgromalin   2019.0     Chennai            AgriTech
# 1      Krayonnz   2019.0   Bangalore              EdTech
# 2  PadCare Labs   2018.0        Pune  Hygiene management
# 3         NCOME   2020.0   New Delhi              Escrow
# 4    Gramophone   2016.0      Indore            AgriTech
#
#                                         What_it_does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# 4  Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
#
#                               Investor    Amount     Stage column10
# 0                      Angel investors  200000.0      None     None
# 1                      GSF Accelerator  100000.0  Pre-seed     None
# 2                       Venture Center       NaN  Pre-seed     None
# 3  Venture Catalysts, PointOne Capital  400000.0      None     None
# 4  Siana Capital Management, Info Edge  340000.0      None     None

# %% [markdown]
# #### Access 2019 data from OneDrive

# %%
# Path of CSV file
file_path = '../Data/startup_funding2019.csv'

# Read the CSV file into a pandas DataFrame
df2019 = pd.read_csv(file_path)

# Display DataFrame Info
df2019.info()
print()

# Display the DataFrame
df2019.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  89 non-null     object
#  1   Founded        60 non-null     float64
#  2   HeadQuarter    70 non-null     object
#  3   Sector         84 non-null     object
#  4   What it does   89 non-null     object
#  5   Founders       86 non-null     object
#  6   Investor       89 non-null     object
#  7   Amount($)      89 non-null     object
#  8   Stage          43 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 6.4+ KB
#     Company/Brand  Founded HeadQuarter           Sector  \
# 0  Bombay Shaving      NaN         NaN        Ecommerce
# 1       Ruangguru   2014.0      Mumbai           Edtech
# 2        Eduisfun      NaN      Mumbai           Edtech
# 3        HomeLane   2014.0     Chennai  Interior design
# 4        Nu Genes   2004.0   Telangana         AgriTech
#
#                                         What it does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
# 2            It aims to make learning fun via games.
# 3              Provides interior designing solutions
# 4  It is a seed company engaged in production, pr...
#
#                                 Founders  \
# 0                     Shantanu Deshpande
# 1  Adamas Belva Syah Devara, Iman Usman.
# 2                          Jatin Solanki
# 3           Srikanth Iyer, Rama Harinath
# 4                 Narayana Reddy Punyala
#
#                                             Investor     Amount($)  \
# 0                               Sixth Sense Ventures    $6,300,000
# 1                                   General Atlantic  $150,000,000
# 2     Deepak Parekh, Amitabh Bachchan, Piyush Pandey   $28,000,000
# 3  Evolvence India Fund (EIF), Pidilite Group, FJ...   $30,000,000
# 4           Innovation in Food and Agriculture (IFA)    $6,000,000
#
#            Stage
# 0            NaN
# 1       Series C
# 2  Fresh funding
# 3       Series D
# 4            NaN

# %% [markdown]
# #### Access the 2018 data from GitHub Repository

# %%
# URL of the file to download
url = "https://github.com/Azubi-Africa/Career_Accelerator_LP1-Data_Analysis/raw/main/startup_funding2018.csv"

# Local file path where the file will be saved
local_file_path = '../Data/startup_funding2018.csv'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Write the content of the response to the specified file path
    with open(local_file_path, "wb") as f:
        f.write(response.content)
    print("File downloaded successfully")
else:
    print("Failed to download file")

# Read the downloaded CSV file into a DataFrame
df2018 = pd.read_csv(local_file_path)

# Display DataFrame Info
print()
df2018.info()
print()

# Display the DataFrame
df2018.head()
# Out:
# File downloaded successfully
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company Name   526 non-null    object
#  1   Industry       526 non-null    object
#  2   Round/Series   526 non-null    object
#  3   Amount         526 non-null    object
#  4   Location       526 non-null    object
#  5   About Company  526 non-null    object
# dtypes: object(6)
# memory usage: 24.8+ KB
#       Company Name                                           Industry  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#   Round/Series       Amount                          Location  \
# 0         Seed       250000       Bangalore, Karnataka, India
# 1         Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2     Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3        Angel      2000000       Noida, Uttar Pradesh, India
# 4         Seed            —  Hyderabad, Andhra Pradesh, India
#
#                                        About Company
# 0  TheCollegeFever is a hub for fun, fiesta and f...
# 1  A startup which aggregates milk from dairy far...
# 2          Leading Online Loans Marketplace in India
# 3  PayMe India is an innovative FinTech organizat...
# 4  Eunimart is a one stop solution for merchants ...

# %% [markdown]
# ### Data Quality Considerations
# The datasets are carefully examined to identify common data quality issues such as missing values, outliers, duplicates, inconsistencies, and errors.

# %% [markdown]
# #### Load LP1_startup_funding2021 Data

# %% [markdown]
# ##### Missing and Duplicate Data Quality Considerations

# %%
# Determine the proportion of missing values
missing_percentage_21 = (df2021.isnull().mean() * 100).round(2)

# Check for duplicated values
duplicate_count_21 = df2021.duplicated(subset=None, keep=False).sum()

# Display duplicated rows if any
duplicated_rows_21 = df2021[df2021.duplicated(subset=None, keep=False)]

# Display Results
print("Proportion of missing values in 2021 data:")
print()
print(missing_percentage_21)
print("\nNumber of duplicated rows in 2021 data:", duplicate_count_21)
print("\nDuplicated rows in 2021 data:")
duplicated_rows_21
# Out:
# Proportion of missing values in 2021 data:
#
# Company_Brand     0.00
# Founded           0.08
# HeadQuarter       0.08
# Sector            0.00
# What_it_does      0.00
# Founders          0.33
# Investor          5.13
# Amount            0.25
# Stage            35.40
# dtype: float64
#
# Number of duplicated rows in 2021 data: 38
#
# Duplicated rows in 2021 data:
#           Company_Brand  Founded             HeadQuarter  \
# 94            Curefoods   2020.0               Bangalore
# 96             Bewakoof   2012.0                  Mumbai
# 98              FanPlay   2020.0          Computer Games
# 104      Advantage Club   2014.0                  Mumbai
# 106              Ruptok   2020.0               New Delhi
# 107           Curefoods   2020.0               Bangalore
# 109            Bewakoof   2012.0                  Mumbai
# 111             FanPlay   2020.0          Computer Games
# 117      Advantage Club   2014.0                  Mumbai
# 119              Ruptok   2020.0               New Delhi
# 229            Trinkerr   2021.0               Bangalore
# 230               Zorro   2021.0                Gurugram
# 231       Ultraviolette   2021.0               Bangalore
# 232          NephroPlus   2009.0               Hyderabad
# 233             Unremot   2020.0               Bangalore
# 234         FanAnywhere   2021.0               Bangalore
# 235          PingoLearn   2021.0                    Pune
# 236                Spry   2021.0                  Mumbai
# 237             Enmovil   2015.0               Hyderabad
# 238       ASQI Advisors   2019.0                  Mumbai
# 239  Insurance Samadhan   2018.0               New Delhi
# 240     Evenflow Brands   2020.0                  Mumbai
# 241          MasterChow   2020.0        Food & Beverages
# 242  Fullife Healthcare   2009.0  Pharmaceuticals\t#REF!
# 243            Trinkerr   2021.0               Bangalore
# 244               Zorro   2021.0                Gurugram
# 245       Ultraviolette   2021.0               Bangalore
# 246          NephroPlus   2009.0               Hyderabad
# 247             Unremot   2020.0               Bangalore
# 248         FanAnywhere   2021.0               Bangalore
# 249          PingoLearn   2021.0                    Pune
# 250                Spry   2021.0                  Mumbai
# 251             Enmovil   2015.0               Hyderabad
# 252       ASQI Advisors   2019.0                  Mumbai
# 253  Insurance Samadhan   2018.0               New Delhi
# 254     Evenflow Brands   2020.0                  Mumbai
# 255          MasterChow   2020.0        Food & Beverages
# 256  Fullife Healthcare   2009.0  Pharmaceuticals\t#REF!
#
#                                                 Sector  \
# 94                                    Food & Beverages
# 96                                   Apparel & Fashion
# 98                                      Computer Games
# 104                                             HRTech
# 106                                            FinTech
# 107                                   Food & Beverages
# 109                                  Apparel & Fashion
# 111                                     Computer Games
# 117                                             HRTech
# 119                                            FinTech
# 229                                    Capital Markets
# 230                                     Social network
# 231                                         Automotive
# 232                             Hospital & Health Care
# 233                  Information Technology & Services
# 234                                 Financial Services
# 235                                         E-learning
# 236                                              Music
# 237                  Information Technology & Services
# 238                                 Financial Services
# 239                                          Insurance
# 240                                     Consumer Goods
# 241                                          Hauz Khas
# 242  Primary Business is Development and Manufactur...
# 243                                    Capital Markets
# 244                                     Social network
# 245                                         Automotive
# 246                             Hospital & Health Care
# 247                  Information Technology & Services
# 248                                 Financial Services
# 249                                         E-learning
# 250                                              Music
# 251                  Information Technology & Services
# 252                                 Financial Services
# 253                                          Insurance
# 254                                     Consumer Goods
# 255                                          Hauz Khas
# 256  Primary Business is Development and Manufactur...
#
#                                           What_it_does  \
# 94   Healthy & nutritious foods and cold pressed ju...
# 96   Bewakoof is a lifestyle fashion brand that mak...
# 98   A real money game app specializing in trivia g...
# 104  Advantage Club is India's largest employee eng...
# 106  Ruptok fintech Pvt. Ltd. is an online gold loa...
# 107  Healthy & nutritious foods and cold pressed ju...
# 109  Bewakoof is a lifestyle fashion brand that mak...
# 111  A real money game app specializing in trivia g...
# 117  Advantage Club is India's largest employee eng...
# 119  Ruptok fintech Pvt. Ltd. is an online gold loa...
# 229  Trinkerr is India's first social trading platf...
# 230               Pseudonymous social network platform
# 231  Create and Inspire the future of sustainable u...
# 232  A vision and passion of redefining healthcare ...
# 233      Unremot is a personal office for consultants!
# 234                             Celebrity NFT platform
# 235  PingoLearn offers language learning courses wi...
# 236  THE BEST ROYALTY-FREE MUSIC TO CREATE TRENDING...
# 237  Enmovil delivers a Business Intelligence Platf...
# 238  Bringing Blockchain technology intro mainstrea...
# 239  The insurance industry will help in representa...
# 240  Identify and partner with the upcoming eCommer...
# 241                A ready-to-cook Asian cuisine brand
# 242                                       Varun Khanna
# 243  Trinkerr is India's first social trading platf...
# 244               Pseudonymous social network platform
# 245  Create and Inspire the future of sustainable u...
# 246  A vision and passion of redefining healthcare ...
# 247      Unremot is a personal office for consultants!
# 248                             Celebrity NFT platform
# 249  PingoLearn offers language learning courses wi...
# 250  THE BEST ROYALTY-FREE MUSIC TO CREATE TRENDING...
# 251  Enmovil delivers a Business Intelligence Platf...
# 252  Bringing Blockchain technology intro mainstrea...
# 253  The insurance industry will help in representa...
# 254  Identify and partner with the upcoming eCommer...
# 255                A ready-to-cook Asian cuisine brand
# 256                                       Varun Khanna
#
#                                           Founders  \
# 94                                    Ankit Nagori
# 96                                Prabhkiran Singh
# 98                                          YC W21
# 104             Sourabh Deorah, Smiti Bhatt Deorah
# 106                                    Ankur Gupta
# 107                                   Ankit Nagori
# 109                               Prabhkiran Singh
# 111                                         YC W21
# 117             Sourabh Deorah, Smiti Bhatt Deorah
# 119                                    Ankur Gupta
# 229                Manvendra Singh, Gaurav Agarwal
# 230  Jasveer Singh, Abhishek Asthana, Deepak Kumar
# 231            Subramaniam Narayan, Niraj Rajmohan
# 232                                 Vikram Vuppala
# 233                            Shiju Radhakrishnan
# 234                    Varun Chaudhary, Amit Kumar
# 235             Mohit Menghani, Shubham Maheshwari
# 236                Gaurav Dagaonkar, Meghna Mittal
# 237     Ravi Bulusu, Nanda Kishore, Venkat Moganty
# 238                                  Swapnil Pawar
# 239                     Deepak Bhuvenshwari Uniyal
# 240                  Utsav Agarwal, Pulkit Chhabra
# 241                  Vidur Kataria, Sidhanth Madan
# 242             Morgan Stanley Private Equity Asia
# 243                Manvendra Singh, Gaurav Agarwal
# 244  Jasveer Singh, Abhishek Asthana, Deepak Kumar
# 245            Subramaniam Narayan, Niraj Rajmohan
# 246                                 Vikram Vuppala
# 247                            Shiju Radhakrishnan
# 248                    Varun Chaudhary, Amit Kumar
# 249             Mohit Menghani, Shubham Maheshwari
# 250                Gaurav Dagaonkar, Meghna Mittal
# 251     Ravi Bulusu, Nanda Kishore, Venkat Moganty
# 252                                  Swapnil Pawar
# 253                     Deepak Bhuvenshwari Uniyal
# 254                  Utsav Agarwal, Pulkit Chhabra
# 255                  Vidur Kataria, Sidhanth Madan
# 256             Morgan Stanley Private Equity Asia
#
#                                               Investor        Amount  \
# 94                 Iron Pillar, Nordstar, Binny Bansal     $13000000
# 96                                          InvestCorp      $8000000
# 98                         Pritesh Kumar, Bharat Gupta      Upsparks
# 104           Y Combinator, Broom Ventures, Kunal Shah      $1700000
# 106                                     Eclear Leasing      $1000000
# 107                Iron Pillar, Nordstar, Binny Bansal     $13000000
# 109                                         InvestCorp      $8000000
# 111                        Pritesh Kumar, Bharat Gupta      Upsparks
# 117           Y Combinator, Broom Ventures, Kunal Shah      $1700000
# 119                                     Eclear Leasing      $1000000
# 229                                        Accel India      $6600000
# 230  Vijay Shekhar Sharma, Ritesh Agarwal, Ankiti Bose     $32000000
# 231                                    TVS Motor, Zoho    $150000000
# 232                              IIFL Asset Management     $24000000
# 233                          Inflection Point Ventures       $700000
# 234        Oasis Capital, Scorpio VC, DeltaHub Capital  $Undisclosed
# 235  Titan Capital, Haresh Chawla, AngelList Syndicate       $200000
# 236                          9Unicorns, Ashneer Grover      $1500000
# 237                                  Anicut Angel Fund      $1300000
# 238                              Founders Room Capital      $1000000
# 239                                     9Unicorns, ZNL       $725000
# 240                                               None       $500000
# 241                                       WEH Ventures       $461000
# 242                                          $22000000      Series C
# 243                                        Accel India      $6600000
# 244  Vijay Shekhar Sharma, Ritesh Agarwal, Ankiti Bose     $32000000
# 245                                    TVS Motor, Zoho    $150000000
# 246                              IIFL Asset Management     $24000000
# 247                          Inflection Point Ventures       $700000
# 248        Oasis Capital, Scorpio VC, DeltaHub Capital  $Undisclosed
# 249  Titan Capital, Haresh Chawla, AngelList Syndicate       $200000
# 250                          9Unicorns, Ashneer Grover      $1500000
# 251                                  Anicut Angel Fund      $1300000
# 252                              Founders Room Capital      $1000000
# 253                                     9Unicorns, ZNL       $725000
# 254                                               None       $500000
# 255                                       WEH Ventures       $461000
# 256                                          $22000000      Series C
#
#             Stage
# 94           None
# 96           None
# 98       $1200000
# 104          None
# 106          None
# 107          None
# 109          None
# 111      $1200000
# 117          None
# 119          None
# 229      Series A
# 230          Seed
# 231      Series C
# 232      Series E
# 233          Seed
# 234          Seed
# 235          None
# 236          Seed
# 237  Pre-series A
# 238  Pre-series A
# 239  Pre-series A
# 240          None
# 241          Seed
# 242          None
# 243      Series A
# 244          Seed
# 245      Series C
# 246      Series E
# 247          Seed
# 248          Seed
# 249          None
# 250          Seed
# 251  Pre-series A
# 252  Pre-series A
# 253  Pre-series A
# 254          None
# 255          Seed
# 256          None

# %% [markdown]
# ##### Unique values Data Quality Considerations

# %%
# List all elements in the columns
for i, column in enumerate(df2021.columns):
    print(f'Column-{i + 1}: {column}: {len(df2021[column].unique())}\n', df2021[column].unique())
    print('_'*100)
    print()
# Out:
# Column-1: Company_Brand: 1033
#  ['Unbox Robotics' 'upGrad' 'Lead School' ... 'Gigforce' 'Vahdam' 'WeRize']
# ____________________________________________________________________________________________________
#
# Column-2: Founded: 31
#  [2019. 2015. 2012. 2021. 2014. 2018. 2016. 2020. 2010. 2017. 1993. 2008.
#  2013. 1999. 1989. 2011.   nan 2009. 2002. 1994. 2006. 2000. 2007. 1978.
#  2003. 1998. 1991. 1984. 2004. 2005. 1963.]
# ____________________________________________________________________________________________________
#
# Column-3: HeadQuarter: 71
#  ['Bangalore' 'Mumbai' 'Gurugram' 'New Delhi' 'Hyderabad' 'Jaipur'
#  'Ahmadabad' 'Chennai' None 'Small Towns, Andhra Pradesh' 'Goa'
#  'Rajsamand' 'Ranchi' 'Faridabad, Haryana' 'Gujarat' 'Pune' 'Thane'
#  'Computer Games' 'Cochin' 'Noida' 'Chandigarh' 'Gurgaon' 'Vadodara'
#  'Food & Beverages' 'Pharmaceuticals\t#REF!' 'Gurugram\t#REF!' 'Kolkata'
#  'Ahmedabad' 'Mohali' 'Haryana' 'Indore' 'Powai' 'Ghaziabad' 'Nagpur'
#  'West Bengal' 'Patna' 'Samsitpur' 'Lucknow' 'Telangana' 'Silvassa'
#  'Thiruvananthapuram' 'Faridabad' 'Roorkee' 'Ambernath' 'Panchkula'
#  'Surat' 'Coimbatore' 'Andheri' 'Mangalore' 'Telugana' 'Bhubaneswar'
#  'Kottayam' 'Beijing' 'Panaji' 'Satara' 'Orissia' 'Jodhpur' 'New York'
#  'Santra' 'Mountain View, CA' 'Trivandrum' 'Jharkhand' 'Kanpur' 'Bhilwara'
#  'Guwahati' 'Online Media\t#REF!' 'Kochi' 'London'
#  'Information Technology & Services' 'The Nilgiris' 'Gandhinagar']
# ____________________________________________________________________________________________________
#
# Column-4: Sector: 254
#  ['AI startup' 'EdTech' 'B2B E-commerce' 'FinTech' 'Home services'
#  'HealthTech' 'Tech Startup' 'E-commerce' 'B2B service' 'Helathcare'
#  'Renewable Energy' 'Electronics' 'IT startup' 'Food & Beverages'
#  'Aeorspace' 'Deep Tech' 'Dating' 'Gaming' 'Robotics' 'Retail' 'Food'
#  'Oil and Energy' 'AgriTech' 'Telecommuncation' 'Milk startup'
#  'AI Chatbot' 'IT' 'Logistics' 'Hospitality' 'Fashion' 'Marketing'
#  'Transportation' 'LegalTech' 'Food delivery' 'Automotive' 'SaaS startup'
#  'Fantasy sports' 'Video communication' 'Social Media' 'Skill development'
#  'Rental' 'Recruitment' 'HealthCare' 'Sports' 'Computer Games'
#  'Consumer Goods' 'Information Technology' 'Apparel & Fashion'
#  'Logistics & Supply Chain' 'Healthtech' 'Healthcare' 'SportsTech'
#  'HRTech' 'Wine & Spirits' 'Mechanical & Industrial Engineering'
#  'Spiritual' 'Financial Services' 'Industrial Automation' 'Health'
#  'Lifestyle' 'IoT' 'Banking' 'Computer software' 'Tech startup'
#  'Digital mortgage' 'Information Technology & Services' 'Furniture'
#  'B2B marketplace' 'Healtcare' 'Location Analytics' 'Media'
#  'Consumer Electronics' 'Tobacco' 'Deeptech' 'Insuretech' 'MLOps platform'
#  'Venture Capital' 'Pet care' 'Drone' 'Wholesale' 'Construction'
#  'E-learning' 'Consumer Services' 'Venture Capital & Private Equity'
#  'Health, Wellness & Fitness' 'OTT' 'Education Management'
#  'Computer Software' 'Insurance' 'Software Startup'
#  'Computer & Network Security' 'Capital Markets' 'Social network'
#  'Hospital & Health Care' 'Music' 'Hauz Khas'
#  'Primary Business is Development and Manufacturing of Novel Healthcare Products in Effervescent forms using imported propriety ingredients.'
#  "MoEVing is India's only Electric Mobility focused Technology Platform with a vision to accelerate EV adoption in India."
#  'Cosmetics' 'Mobility' 'Social media' 'Real Estate' 'Digital platform'
#  'B2B Ecommerce' 'Online Media' 'Social commerce' 'Mobile Games'
#  'Food Production' 'Podcast' 'HeathTech' 'Battery' 'Content publishing'
#  'Water purification' 'Content commerce' 'Innovation Management'
#  'Software company' 'Automation' 'Food Industry' 'Celebrity Engagement'
#  'Trading platform' 'Personal Care' 'Cannabis startup' 'Blogging'
#  'Consulting' 'BioTechnology' 'B2B Marketplace' 'Health care'
#  'Social audio' 'Fashion and lifestyle' 'Delivery service'
#  'B2B Manufacturing' 'Home Decor' 'Solar' 'TaaS startup' 'EV startup'
#  'HR Tech' 'Blockchain startup' 'Food and Beverages' 'Beverages'
#  'Manufacturing startup' 'Cryptocurrency' 'Vehicle repair startup'
#  'Advisory firm' 'Legaltech' 'Pollution control equiptment'
#  'Fashion & Lifestyle' 'Blockchain' 'Fitness' 'D2C' 'Automobile'
#  'Environmental Services' 'Merchandise' 'Facilities Services'
#  'Marketing & Advertising' 'Human Resources' 'Eyewear' 'D2C Business'
#  'Biotechnology' 'Farming' 'NFT Marketplace' 'Internet' 'SpaceTech'
#  'Consumer software' 'Social community' 'Fishery'
#  'Renewables & Environment' 'Online storytelling' 'Aviation' 'IT company'
#  'Environmental service' 'Job discovery platform' 'D2C Fashion'
#  'Heathcare' 'CRM' 'Software' 'Nutrition' 'D2C startup'
#  'Innovation management' 'Community platform' 'Venture capitalist'
#  'Networking' 'Commercial Real Estate' 'AR startup' 'Consumer service'
#  'Consumer goods' 'MarTech' 'Advertisement' 'Content creation'
#  'Augmented reality' 'Rental space' 'Bike Rental' 'Beauty products'
#  'Tourism' 'FemTech' 'Cultural' 'Co-working' 'InsureTech'
#  'Supply chain platform' 'Social platform' 'CleanTech' 'Real estate'
#  'AI company' 'Sports startup' 'Matrimony' 'Crypto' 'Clothing' 'Analytics'
#  'Finance' 'IoT platform' 'Commerce' 'Defense & Space' 'Entertainment'
#  'Business Supplies & Equipment' 'NFT' 'Oil & Energy' 'EV'
#  'Company-as-a-Service' 'Textiles' 'Professional Training & Coaching'
#  'Maritime' 'Housing Marketplace' 'Furniture Rental' 'Telecommunications'
#  'Equity Management' 'Cloud kitchen' 'Nanotechnology' 'Community'
#  'Higher Education' 'B2B' 'Mechanical Or Industrial Engineering'
#  'D2C jewellery' 'Sales and Distribution' 'SaaS' 'Information Services'
#  'Translation & Localization' 'Investment Banking' 'Femtech' 'sports'
#  'Foootwear' 'Legal Services' 'Veterinary' 'Arts & Crafts'
#  'Investment Management' 'Education' 'Management Consulting' 'B2B startup'
#  'Sochcast is an Audio experiences company that give the listener and creators an Immersive Audio experience'
#  'Design' 'B2B Travel' 'Interior Design' 'Manchester, Greater Manchester'
#  'Product studio' 'Aviation & Aerospace' 'Staffing & Recruiting']
# ____________________________________________________________________________________________________
#
# Column-5: What_it_does: 1143
#  ['Unbox Robotics builds on-demand AI-driven warehouse robotics solutions, which can be deployed using limited foot-print, time, and capital.'
#  'UpGrad is an online higher education platform.'
#  'LEAD School offers technology based school transformation system that assures excellent learning for every child.'
#  ... 'International education loans for high potential students.'
#  'Collegedekho.com is Student’s Partner, Friend & Confidante, To Help Him Take a Decision and Move On to His Career Goals.'
#  'India’s first socially distributed full stack financial services platform for small town India']
# ____________________________________________________________________________________________________
#
# Column-6: Founders: 1096
#  ['Pramod Ghadge, Shahid Memon'
#  'Mayank Kumar, Phalgun Kompalli, Ravijot Chugh, Ronnie Screwvala'
#  'Smita Deorah, Sumeet Mehta' ... 'Bala Sarda'
#  'Arnav Kumar, Vaibhav Singh' 'Vishal Chopra, Himanshu Gupta']
# ____________________________________________________________________________________________________
#
# Column-7: Investor: 938
#  ['BEENEXT, Entrepreneur First' 'Unilazer Ventures, IIFL Asset Management'
#  'GSV Ventures, Westbridge Capital' 'CDC Group, IDG Capital'
#  'Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal' 'Vy Capital'
#  'CIIE.CO, KIIT-TBI' 'Inflection Point Ventures' 'Inflexor Ventures' None
#  '9Unicorns Accelerator Fund, Metaform Ventures'
#  'SucSEED Indovation, IIM Calcutta Innovation Park' 'Safe Planet Medicare'
#  'Impact Partners, C4D Partners'
#  'Tiger Global Management, InnoVen Capital' 'Novo Tellus Capital'
#  'Raintree Family Office, ADB arm' 'Mumbai Angels, Narendra Shyamsukha'
#  'Paradigm, Kunal Shah' 'Matrix Partners India, GIC'
#  'Chiratae Ventures, JAFCO Asia' 'Mumbai Angels Network, Expert DOJO'
#  'GVFL' 'Kotak Mahindra Bank, FMO' 'Kalaari Capital'
#  'NB Ventures, IAN Fund' 'Sequoia Capital India, Hummingbird Ventures'
#  'Gaurav Munjal, Snehil Khanor' 'JITO Angel Network, SOSV'
#  'Chiratae Ventures, YourNest Venture Capital' 'STRIVE VC'
#  'Venture Catalysts' 'Jaipuria Family Office' 'Amazon' 'Riso Capital'
#  'MTG Ventures' 'Qualcomm Ventures, Warburg Pincus' '9Unicorns'
#  'Morgan Stanley' 'Alfa Ventures, Agility Venture Partners'
#  'Stellaris Venture Partners, Ramakant Sharma' 'Spanache'
#  'DSG Consumer Partners, Saama Capital' 'Hindustan Media Ventures'
#  'Stellaris Venture Partners, Omidyar Network India, Flourish Ventures'
#  'Angelbay Holdings, Faad Network' 'Alteria Capital, Chiratae Ventures'
#  'WaterBridge Ventures, Info Edge' 'Carmignac, Falcon Edge Capital'
#  'Vaibhav Domkundwar, Kunal Shah'
#  'Chiratae Ventures, Bharat Innovation Fund'
#  'Acko Technology, Services, LetsVenture'
#  'Bertelsmann India Investments, Fullerton Financial Holdings'
#  'Dragoneer Investment Group, Tiger Global Management' 'http://100x.vc/'
#  'TPG Growth, Caisse de Depot et Placement du Quebec'
#  'Centrum Financial Services' 'Chiratae Ventures, BEENEXT' 'Harsha Bhogle'
#  'GetVantage, Prakash Katama'
#  'Tiger Global Management, Y Combinator Continuity Fund'
#  'Michael & Susan Dell Foundation' 'Marquee fintech founders'
#  'Falcon Edge India, Norwest Venture Partners'
#  'SOSV, Omphalos Ventures India' 'Twitter Ventures, Pawan Munjal'
#  'CitiusTech' 'Arena Holdings, Think Investments'
#  'T Choithrams BVI, Ardor' 'Kogta Financial India Limited, ICICI Bank'
#  'SucSEED Venture Partners, TMT Connekt' 'SAIF Partners, Venture Highway'
#  'Global Founders Capital' 'JAFCO Asia, Chiratae Ventures' 'Y Combinator'
#  'Artha Venture Fund' 'Jitendra Gupta, Amrish Rau'
#  'FJ Labs, Brian Norgard' 'Indian Angel Network'
#  'Jitendra Gupta, Harsh Shah' 'Elevation Partners, Emergent Ventures'
#  'Kalaari Capital, Dream Capital' 'Lumikai' 'Matrix Partners India'
#  'C4D Partners' 'Bertelsmann India' 'Iron Pillar, Nordstar, Binny Bansal'
#  'FMC, Omnivore, Blume Ventures' 'InvestCorp'
#  'Pritesh Kumar, Bharat Gupta' 'Y Combinator, 9Unicorns, Titan Capital'
#  'Unicorn India Ventures, SEA Fund, Devdatt Shah'
#  'Matrix Partners India, Elevation Capital'
#  'Avaana Capital, Orios Ventures' 'Punit Balan'
#  'Y Combinator, Broom Ventures, Kunal Shah'
#  'Skycatcher, AET Fund, BAce Capital, Dream Incubator, 1Up Ventures'
#  'Eclear Leasing' 'First Cheque, Letsventure'
#  'Sequoia Capital India, BEENEXT' 'Velocity'
#  'Tribe Capital, Moore Strategic Ventures (MSV)' 'Fireside Ventures'
#  'Inflection Point Ventures, ONGC' 'Y Combinator, Incubate Fund India'
#  'Titan Capital, Rockstud Capital,  John Abraham, WEH Ventures'
#  'Info Edge Ventures' 'NB Ventures' 'Accel' 'Binny Bansal, Kunal Shah'
#  'TradeCred' 'Unicorn India Ventures'
#  'UC Inclusive Credit, Western Capital'
#  'IIFL India Private Equity Fund, Smiti Holding & Trading Company'
#  'Faering Capital' 'responsAbility Investments, Blue Orchard'
#  'Sanchit Agarwal, Sujan Sinha, Michael Cooke'
#  'CRV, Nexus Venture Partners'
#  'Salesforce Ventures, Sierra Ventures, Sequoia Capital India’s Surge'
#  'Micelio Fund, growX ventures'
#  'IIFL Wealth, Asset Management, Northern Arc Capital'
#  'Better Capital, Ashish Achrekar' 'IAN' 'Alpha Wave Incubation'
#  'Point One Capital, Yatra Angel Network (YAN), Opus Consulting, Manipal Technologies.'
#  'Microsoft' 'Shell Ventures, Yamaha, Kunal Shah' 'We Founder Circle'
#  'Saama Capital, DSG Consumer Partners, Sharrp Ventures'
#  'Tiger Global’s Scott Schleifer' 'Elevation Capital'
#  'Venture Catalysts, Auxano Capital, Venture Garage, Yoga Capital, Ah!Ventures, Lead Angels'
#  'Sixth Sense Ventures' '9Unicorns, Sequoia Capital India’s Surge'
#  'Anicut Angel Fund, 9 Unicorns' 'Info Edge, FalconEdge'
#  'WestCap Group, Tomales Bay Capital' 'Chiratae Ventures, Better Capital'
#  'Siguler Guff, Baillie Gifford'
#  'IIFL AMC, Mankind Pharma Family Office, Aroa Ventures'
#  'ITI Growth Opportunities' 'Amrac Investment Trust' 'Bhavin Turakhia'
#  'Amara Raja Batteries' 'India Infoline Finance' 'Venture Highway'
#  'BEENEXT, Orios' 'Axilor' 'Westbridge Capital, Tanglin Venture Partners'
#  '100X.VC\ufeff,\ufeff Titan Capital, Rahul Mathur, Gaurav Mandlecha'
#  'IIFL, Amicus Capital, Ananta Capital' 'Venture Highway, Endiya Partners'
#  'Verlinvest, Sequoia Capital India' 'Anicut Angel Fund' 'Tiger Global'
#  'Alphabit Fund, Fulgur Ventures, Stacks Accelerator, SBX Capital'
#  'Roots Ventures, Velo Partners' 'Nexus Venture Partners'
#  'Mumbai Angels Network, Huddle, Lumis Partners' 'SucSEED Indovation Fund'
#  'Potencia Ventures, Bisk Ventures, LetsVenture, Ronnie Screwvala, Arihant Patni'
#  'Better Capital, First Cheque, Titan Capital' 'Evolvence Capital'
#  'SARA ELGI'
#  'Nubank, Global Founders Capital, Sequoia Capital India, Matrix Partners India'
#  'ah! Ventures High Tables'
#  'Eight Roads Ventures, Think Investments, Mankekar Family Office'
#  'A91 Partners' 'Chiratae Ventures' 'Sequoia’s Surge'
#  'Lead Angels, Titan Capital, Pravega Ventures'
#  'Accel Partners, Elevation Capital'
#  'Inflection Point Ventures, Rockstud Capital, FirstPort Capital, Bliss Flow Investments Pvt Ltd'
#  'Anicut Angel Fund, Axilor Ventures' 'Ecosystem Ventures, CMM group'
#  'Mumbai Angels Network, Social Alpha' 'Disrupt ADQ, QIC'
#  'Valar Ventures, IA Ventures' 'Sequoia Capital India' 'Zomato'
#  'Lightspeed, Times Group, Tanglin Venture Partners'
#  'Binny Bansal, Deep Kalra, Dr Ashish Gupta, Gokul Rajaram, Shirish Nadkarni'
#  'Tuscan Ventures, Ohm Stock Brokers, Artha Venture Fund'
#  'Signal Peak Ventures' 'Evolvence, Hero Enterprise'
#  'BlueOrchard Impact Investment Managers' 'Steadview Capital'
#  'MassMutual Ventures' 'YourNest VC' 'Accel India'
#  'Vijay Shekhar Sharma, Ritesh Agarwal, Ankiti Bose' 'TVS Motor, Zoho'
#  'IIFL Asset Management' 'Oasis Capital, Scorpio VC, DeltaHub Capital'
#  'Titan Capital, Haresh Chawla, AngelList Syndicate'
#  '9Unicorns, Ashneer Grover' 'Founders Room Capital' '9Unicorns, ZNL'
#  'WEH Ventures' '$22000000' '$5000000'
#  'Kunal Shah, Deepinder Goyal, Abhiraj Singh Bhal'
#  'Guild Capital, RPSG Capital Ventures'
#  'General Catalyst, Eight Roads Ventures, Elevation Capital'
#  'NB Ventures, Earlsfield Capital' 'Varun Alagh, Sahil Barua'
#  'SoftBank Vision Fund 2' 'Tribe Capital, Prime Venture Partners'
#  'Jungle Ventures' 'Marquee international institutional investors'
#  'Alkeon Capital' 'Y Combinator, Harvard Management'
#  'Y Combinator\ufeff, \ufeffGoodwater Capital'
#  'Shrishti Sahu, Umang Vohra' 'Astra Ventures, Gaurav Jaitly'
#  'Capital A, Collective Artists Network' 'Aditya Singhal, Nishant Sinha'
#  'Pentathlon Ventures'
#  'Alpha Wave Ventures II, Tiger Global Management, SoftBank Vision Fund II'
#  'KRAFTON' 'Chiratae Ventures, Lenskart Vision Fund' 'Recur Club'
#  'DevX Venture Fund' 'DevX Venture Fund, Blume Founder Fund'
#  'Ajith Daneil' 'Aurum Proptech' 'Y-Combinator' 'The Good Glamm Group'
#  'Invus' 'Tiger Global, Prosus Ventures'
#  'Shuru Up, Ankit Kedia, Arun Gupta' 'Ankit Mehrotra, Saurabh Aggarwal'
#  'Sauce.vc' '3one4 Capital, Sixth Sense Ventures'
#  'YCombinator, Justin Mateen, Pioneer Fund'
#  'Sojitz Corporation, Stride Ventures'
#  'IIFL Wealth, TPG Growth, Norwest Venture Partners'
#  'Nabventures, Avaana Capital' 'Fluid Ventures, Mulberry Silks'
#  'Rajesh Rajendran' 'Mike Novogratz, Neeraj Arora'
#  'Reliance Digital Health' 'Ritu Marya Family Office.' 'Ten Innovate'
#  'Tiger Global, Sequoia Capital' 'Shark Tank India'
#  'Premji Invest, Steadview Capital' 'Sequoia' 'Apis Insurtech Fund I'
#  'SK Tripathi, Sanjeev Gupta' 'Hardcastle Petrofer'
#  'Ocean View Investment, QED Fund' 'Omidyar Network, Tencent Holdings'
#  'ITI Growth Opportunities Fund, Unit-E Ventures'
#  'InnoVen Capital, Nexus Venture Partners' 'CIIE.CO'
#  'Orios Venture Partners' 'Omidyar Network India'
#  'Wipro venture capital arm' 'Yuj Ventures, Sixth Sense Ventures'
#  'Premji Invest, Mirae Asset Naver Asia Growth Fund, Alpine Capital'
#  'Inflection Point Ventures, SucSEED Venture Partners'
#  'Anas Rahman Junaid, Vinod Jose' 'Capital One, Arrowroot Capital'
#  'YourNest Venture Capital' 'Incubate Fund India' 'Kunal Shah, Greg Kidd'
#  'InnoVen Capital, TEAMFund'
#  'Venture Catalysts, 9Unicorns Accelerator Fund'
#  'Venture Highway, Rohit Bansal' 'Fresco Capital, Social Starts'
#  'Y Combinator, Rebright Partners' 'Rohit Goutamchand, India CXO Fund'
#  'Rajasthan Venture Capital Fund, ACPL Exports' 'Amplo, Insight Partners'
#  'Better Capital' 'Justin Mateen' 'View Trade Holding Corp'
#  'InnoVen Capital, Bertelsmann India Investments' 'ScoopWhoop'
#  'Canaan Valley Capital, Glade Brook Capital Partners'
#  'Vijay Shekhar Sharma, Dr Ritesh Malik' 'RTP Global, Harshil Mathur'
#  'Paragon Partners, NABVENTURES' 'EXPERT DOJO'
#  'Saama Capital, India Quotient'
#  'InCred Financial Services, Vivriti Capital, Northern Arc Capital'
#  'ah! Ventures' 'Somak Ghosh, M V Nair' 'Wurk'
#  'Plutus Wealth Management, Turtle Entertainment'
#  'Ambiga Subramanian, Goutham Ekollu' 'Accel, Owl Ventures' 'Rajan Anadan'
#  'Jesse Lucas' 'IDFC Private Equity, Bessemer Venture Partners'
#  'Sequoia Capital India, Accel' 'Venture Catalysts, Tahseen Consulting'
#  'Equanimity Ventures' 'BlueOrchard Finance S A, Gojo & Company'
#  'Better Capital, Titan Capital' 'Gojo & Company' 'Mumbai Angels'
#  'Pegasus Tech Ventures, Base Partners' '3one4 Capital, Accel'
#  'Hitesh Oberoi, Lightbox' 'YES Bank' 'Campus Fund'
#  'Hyperplane Venture Capital' 'Matrix Partners India, RTP Global'
#  'Info Edge, Ruizheng Investment' 'Quess Corp India'
#  'Sunil Kumar Singhvi, 9Unicorns Accelerator Fund'
#  'India Accelerator’s Angel Investor Network' 'Shell Foundation'
#  'Jimmy Singh' 'Kunal Shah, Deepak Abbot' 'Accel, Nexus Venture'
#  'Singapore Angel Network, Artha India Ventures'
#  'Starfish Growth Partners, Investpad' 'Hashed' 'Titan Capital'
#  "Zerodha's Rainmatter Capital, Better Capital"
#  'Sixth Sense Ventures, Colgate Palmolive'
#  'Lightbox, Evolvence India Fund' 'Tomorrow Capital'
#  'Inflection Point Ventures, DLabs' 'InnoVen Capital, Steadview Capital'
#  'BlackSoil Capital' 'PointOne Capital, Core91 VC'
#  'A91 Partners, Faering Capital' 'Blockchain Capital, SBI Ven Capital'
#  'Baring Private Equity Partners India, Talbros'
#  'Sequoia Capital India, 3one4 Capital' 'Prosus Ventures, RTP Global'
#  'U.S. International Development Finance Corp, responsAbility'
#  'Binance Labs, Zee Prime Capital' 'RP-Sanjiv Goenka Group'
#  'IvyCap Ventures' 'Zone Startups In' 'Blue Ashva Capital'
#  'Ribbit Capital, Kunal Shah' 'Ecom Express' 'InnoVen Capital'
#  'Satish Grampurohit' 'Amit Singhal, Raine Ventures'
#  'Octahedron Capital, Moonstone Capital'
#  'Tiger Global, Dragoneer Investment Group, Steadview Capital, General Atlantic'
#  'CDC Group, Aavishkaar Venture Capital' 'GSF, Pras Hanuma'
#  'Ajat Hukkoo, Piyush Chaplot' 'Mumbai Angels, Amitesh Pandey'
#  'Think Investments'
#  'Nexus Venture Partners, 23 High Networth Individuals (HNIs)'
#  'Yatra Angel Network, BEENEXT'
#  'Orios Venture Partners, Matrix Partners India' 'Trishneet Arora'
#  'ContCentric' 'Siana Capital' 'DST Global, General Catalyst'
#  'Anthill Ventures' 'InnoVen Capital, InnoVen Capita'
#  '3one4 Capital, DSP Group' 'Enzia Ventures, AngelList'
#  'Steadview Capital, Insight Partners'
#  'Invested Development, Pratithi Investment Trust'
#  'Dhianu Das, Agility Venture Partners' 'Hindustan Media Venture'
#  'Omnivore' 'Awign Enterprises' 'Siddharth Bhaskar Shah, Upsparks'
#  'S Chand' 'Goldman Sachs, Tata Capital'
#  'growX ventures, Venture Gurukool' 'Mount Judi India Growth Fund'
#  'GEF Capital’s South Asia Fund'
#  'Sunil Sethia, Sunil Kumar Singhvi, Manish Mardia' 'Sequoia Capital'
#  'Mechanism Capital, DACM'
#  'Northern Arc Capital, Niyogin Fintech Limited, Credit Saison India, Vivriti Capital'
#  'Pearl Investment LLC' '021 Capital, Sparrow Capital'
#  'Kotak Investment Advisors Limited, Gruhas Proptech' 'VANS Group'
#  'Sachin Tendulkar' 'Xentel Investments' 'Accel Partners'
#  'Waterbridge, Lumikai' 'Auxano, Falcon5' 'Infoedge ventures'
#  'JITO Angel Network' 'Jupiter' 'Unitus Ventures' 'GIC, Infoedge'
#  'pi Ventures' 'Northern Arc, Caspian Impact Investments'
#  'Sofina Ventures SA' 'Tiger Global, Flipkart Ventures'
#  'Inflection Point Ventures, Rockstud Capital, Pentathlon Ventures, Prophetic Ventures syndicate'
#  'Prime VP' 'Tribe Capital, IFC Emerging Asia Fund, VEF'
#  'Sequoia’s Surge, Y Combinator' 'Endiya Partners'
#  'Gokul Rajaram, Pureland Venture, Wavemaker Partners' 'Callapina Capital'
#  'Khosla Ventures' 'Accel Partners, Matrix India'
#  'Omidyar Network India, Innoven Capital' 'Temasek, Falcon Edge'
#  'Deep Kalra, Ashish Kashyap, Rajesh Magow'
#  'IAN, Social Alpha, Startup Oasis' 'Capital India'
#  'FirstCry, Lightspeed Venture Partners' 'Accel, LetsVenture, 1Crowd'
#  'SAB Holdings' 'Lightspeed Venture Partners, Elevation Capital'
#  'Mumbai Angels Network' 'Jayanti Kanani' 'LeapFrog, Khosla Ventures'
#  'Ananta Capital' 'Northern Arc, Vivriti Capital' 'TATA Cleantech Capital'
#  'Aqua-Spark' 'Climate Angels Fund'
#  'Sequoia’s Surge, Nexus Venture Partners'
#  'Entrepreneur First (EF), GrowX Ventures' 'Zephyr Peacock' 'ADM Capital'
#  'SoftBank Vision Fund, Hindustan Media Venture' '100x Entrepreneurs'
#  'Healthcare veterans, PIEDS' 'Bank of Baroda' 'YCombinator' 'IAN Fund'
#  'Vishal Gupta' 'Mirae Asset, H&M' 'Kotak Securities' 'Klub'
#  'Balaji Srinivasan' '$1000000' 'BASF Venture Capital GmbH'
#  'Rebright Partners, Flourish Ventures' 'Sequoia Surge'
#  'Titan Capital, Sequoia Capital' 'Parthiv Group'
#  'Omkar Pandharkame, Ketaki Ogale'
#  'GetVantage, Velocity, Shiprocket Capital' 'Krafton Inc, Omidyar'
#  'Blume Ventures, Exfinity Venture Partners'
#  'Beyond Next Ventures, M Venture Partners' 'AdvantEdge Founders'
#  'Faering Capital, Sequoia Capital India, IIFL Alternate Asset Managers'
#  'Sixth Sense Ventures, NABVENTURES' 'Temasek, Multiples PE'
#  'Griffin Gaming Partners' 'Zinnia Global' 'InfoEdge Ventures, IAN Fund'
#  'IIFL, Mumbai Angels' 'BEENEXT, Sequoia’s Surge' 'Antler India'
#  'Bharat Inclusion' 'Fidelity, BlackRock' 'Blacksoil' 'Speciale Invest'
#  'Canbank Venture Capital Fund' 'W Health Ventures'
#  '021 Capital, Y Combinator' 'Anand Prakash Sharma' 'Axilor Ventures'
#  'velocity.in' 'March Capital, Tribe Capital' 'Learn Capital' 'RTP Global'
#  'IAN, Yuj Ventures' 'Sequoia’s Surge, Accel Partners' 'Uday Sodhi'
#  'Fidelity, GIC' 'Auxano' 'Angelist India'
#  'Stanford Angels and Entrepreneurs India, Anjali Bansal'
#  'Vy Capital, Wellington Management' 'Avon Cycles'
#  'Matrix Partners India, 021 Capital' 'HNIs, Angels'
#  'NewQuest Capital Partners, Motilal Oswal Private Equity' 'Lasons India'
#  'Pankaj Chaddah, Srivatsan Rajan' 'Paytm'
#  'BlackSoil, CLSA Capital Partners' 'Saama, Whiteboard Capital'
#  'Indian Angel Network, Titan Capital, Lead Angels' 'The Chennai Angels'
#  'Venture Highway, Stellaris Venture Partners'
#  'State Bank of India, Y Combinator' 'Sanjay Baldwa, Ajay Jain' 'InfoEdge'
#  'Nitin Passi, Ruchirans Jaipuria' 'Stride Ventures, InnoVen Capital'
#  'Venture Catalysts, Jeevak Gupta'
#  'Triodos Investment Management, SAIF Partners' 'N+1 Capital'
#  'DST Global, RTP Global' 'Amit Singal, Manish Aggarwal'
#  'Trifecta Capital Advisors, Blume Ventures' 'Kumar Aakash, Amit Singhal'
#  'growX ventures' 'Shaival Desai, Alkemi Venture Partners'
#  'Aavishkaar Venture Capital, YWC Venture Capital' 'Alteria Capital'
#  'Tiga Investments, Baron Capital' 'Venture Catalysts, 9unicorns'
#  'Qualgro' 'Amit Lakhotia, Pravin Jadhav' 'Pravega Ventures'
#  'Greenoaks Capital, Elevation Capital'
#  'Sequoia Capital India, rocketship.vc' 'BLinC Invest'
#  'Spring Marketing Capital' 'Chaitanya Kalipatnapu, Kedar Gavane'
#  'Roha Investment Managers, angel investor Saumil Shah'
#  'TNF Ventures, Razorpay' 'Lok Capital, IIFL Asset Management'
#  'Nvidia Inception' 'Tiger Global Management, DST Global'
#  'Marquee investors' 'Ashish Hemrajani, Parikshit Dar'
#  'India Accelerator, Lyxel&Flamingo' 'Roshan Abbas, Ritesh Malik'
#  'Goat Capital, JAM Fund' 'General Catalyst, Jungle Ventures'
#  'Blackstone Group, ADQ' 'GoAhead Ventures'
#  'Paradigm Shift Capital, AngelList India' 'Arali Ventures'
#  'Anup Kumar Yama' 'Aryaman Vir' 'iSeed, Titan Capital'
#  'Research Innovation Incubation Design Labs' 'Sushil Agarwal'
#  'IvyCap Ventures, Endiya Partners' 'GUSEC Seed Fund, DeVX Venture Fund'
#  'Tiger Global, Sequoia' 'Quadria Capital'
#  'Blume Ventures, Whiteboard Capital' 'Ashwini Kakkar. 9Unicorns'
#  'Ashish Shah' 'Faad Network' 'Paragon Partners, Aavishkaar Capital'
#  'Krafton, Lumikai' 'Indovation Fund, Mumbai Angels'
#  'Gunosy, Blume Ventures' 'Edge Ventures, Elevation Capital' 'CDC Group'
#  'Titan Capital, Kunal Shah'
#  'Yamaha Motors, Omidyar Network India, Eight Roads Ventures'
#  'Norfund, The Rise Fund' 'Siti Cable' 'Crossbeam Venture Partners'
#  'Aavishkaar Capital' 'Mapmyindia' 'Jyoti Bansal' 'Accor'
#  'SRI Capital, Picus Capital, Alkemi Capital'
#  'Saama Capital, DSG Consumer Partners' 'Valar Ventures'
#  'Addition, SIG Global India Fund'
#  '9Unicorns Accelerator Fund, Indian Angel Network' 'Alfa Ventures'
#  '1Crowd' 'TCV, D1 Capital Partners, Falcon Edge.'
#  'BanyanTree Finance Pvt. Ltd.' 'EXPERT DOJO, Mumbai Angels'
#  'Quona Capital' 'Ashv Finance, BlackSoil Capital'
#  'WaterBridge Ventures, SAIF Partners'
#  'Sweta Rau, 9Unicorns Accelerator Fund' 'Omnivore, Strive Ventures'
#  'Rajesh Sud, KULDEEP JAIN' 'PayU, Google'
#  'Sundi Natarajan, Srinivas Anumolu' 'Titan Capital, First Cheque'
#  'TPG Capital Asia, Epiq Capital' 'MaGEHold Pte. Ltd.'
#  'BlackRock, Owl Ventures'
#  'Asian Development Bank, Oman India Joint Investment Fund'
#  'JSW Ventures, Kalaari Capital' 'Unitus Ventures, Omidyar Network India'
#  'IvyCap Ventures, Pratithi Investment Trust'
#  'ACPI Investments, AdvantEdge Founders'
#  'RouteOne, Mankekar Family Office' 'India Quotient'
#  'TCN International Commerce' 'Alpine Capital, PremjiInvest'
#  'Bon Angels Venture Partners, Daesung Private Equity'
#  'Spring Marketing Capital, Verlinvest' 'Bain Capital'
#  'F-Prime Capital, Eight Roads Ventures India'
#  'Mumbai Angels, DNA Entertainment Networks'
#  'Hornbill Capital Advisers, Plutus Wealth Management'
#  'ADB Ventures, Jetty Ventures' 'Techstars, Ryan Johnson'
#  'Bessemer Venture Partners'
#  'Titan Capital, iSeed, First Cheque, 3.0 Fund.'
#  'Falcon Edge Capital, White Oak Global Advisors' 'Angel investors'
#  'Akya Ventures' 'Kayenne Ventures, Nordic Microfinance Initiative'
#  'Kae Capital, Pi Ventures' 'Elevar Equity, Accel India'
#  'Titan Capital, Y Combinator' 'Jitendra Gupta, Better Capital'
#  'Radiant Life Care Private Ltd, Life Healthcare'
#  'Mount Judi Ventures, growX Ventures, Season Two Ventures'
#  'Richard Rekhy' 'GAWA Capital, Gaja Capital'
#  'Better Capital, Bharat Inclusion Seed Fund' 'Krafton'
#  'Eight Roads Ventures India, Nexus Venture Partners'
#  'CDC Group, Partners Group' 'Matrix Partners India, Ankur Capital'
#  'U.S. International Development Finance Corp, Asian Development Bank'
#  'Hungama, Hindustan Talkies' 'Agility Venture Partners'
#  'Speciale Invest, Farid Ahsan'
#  'Bessemer Venture Partners, CDH Investments'
#  'Sequoia Capital India, Matrix Partners India'
#  'Chiratae Ventures, AET Fund' 'Omidyar Network, Falcon Edge Capital'
#  'Jetty Ventures, Srinivas Anumolu' 'Avendus' 'YourNest'
#  'National Skill Development Corporation, Rianta Capital'
#  'Sequoia Capital India, Rocketship.vc' 'Infosys, Qualcomm Ventures'
#  'Real Estate Accelerator Program (REAP), AngelList'
#  'Asian Development Bank, U.S. International Development Finance Corp'
#  'Kohlberg Kravis Roberts, Temasek Holdings'
#  'Shireen Rangaswamy, Dilesh Gathani'
#  'Rebright Partners, Wadhwani Foundation' 'Dinesh Godara, Aditya Talwar'
#  'Sistema Asia Capital, Evolvence India Fund'
#  'Rajesh Agarwal, Nandkishore Mundada' 'Kallol Banerjee, Jaydeep Barman'
#  'JITO Angel Network, LetsVenture' 'MyAsia VC, Orios Venture Partners'
#  'W Health Ventures, Pi Ventures' 'Artha India Ventures, Sriram Krishnan'
#  'GSV, Multiply Ventures' 'WorldBusiness Capital, Northern Arc'
#  'Tanglin Ventures, Better Capital, Whiteboard Capital'
#  'Y Combinator, Rehan A Khan' 'Balaji Srinivasan, Naval Ravikant'
#  'Devesh Sachdev, Bhavesh Manglani' 'Pradeep K Jaisingh, Jayant Mehrotra'
#  'Varun Alagh, Harish Daiya' 'IAN Fund, World Startup Factory'
#  'Omidyar Network India, Avaana Capital' 'Brex, Y-Combinator'
#  'Mark Cuban, MiH Ventures' 'IvyCap Ventures, IAN Fund'
#  'Gurj Aujla, Ashik K' 'Dream Sports'
#  'The Chatterjee Group, Prophetic Ventures' 'Harsh Jain, Lalit Keshre'
#  'Supriya Kumari, Premanshu Singh'
#  '9Unicorns Accelerator Fund, Sunder Nookala'
#  'Accel Partners, Falcon Edge Capital, Norwest Venture Partners'
#  'Pravesh Mehta' 'Gaurav Gupta, Vivek Srivatsav' 'Lead Angels'
#  'Induslaw, Reddy Futures' 'Yuj Ventures' 'Geekster'
#  'Manish Subramaniam, Upaya Social Ventures' 'Eaglewings Ventures'
#  'Appit Simple Infotek' 'Beyond Next Ventures'
#  'Ramakant Sharma, Elevation Capital'
#  'Keiretsu Forum, SucSEED Venture Partners'
#  'Lightspeed India Partners, CM Ventures'
#  'Skycatcher, Nexus Venture Partners'
#  'Avataar Venture Partners, Kalaari Capital'
#  'Alteria Capital, Matrix Partners India'
#  'Raghav Kapur, Indian Angel Network' 'GSF Accelerator'
#  'Rishi Kumar Bagla, Krishen Lal Khanna'
#  'Glade Brook Capital, Nexus, Y Combinator' 'Capital Group, Falcon Edge'
#  'Dinesh Agarwal, Amarjit Batra' 'Arcilla, Samir Khosla'
#  'SUNiCON Ventures, Shubhkam Ventures, Jito Angel network, FAAD Network'
#  'Baring PE India' 'Manuvel Malabar Jewellers' 'Nabventures'
#  'Y Combinator, Jetty Ventures, Earlsfield Capital, SMC Advisors, Kunal Shah'
#  'Kunal Shah, Snehal Fulzele' 'SternAegis Ventures'
#  'Blume Ventures, Orios Ventures' 'Warburg Pincus\ufeff, Prosus Ventures'
#  'BlackSoil'
#  'Akash Prakash, Madhu Jayakumar, Dipinder Sandhu, Shagun Khandelwal'
#  'OAKS Asset Management' 'Titan Capital, LetsVenture'
#  'Incofin, NabVentures, Orios' 'BEENEXT' 'SIG'
#  'Blume Ventures, Micelio Fund'
#  'CDC Group, Jungle Ventures, March Capital, Marshall Wace'
#  'Ashish Jain, Ajay Surana' 'We Founder Circle, Appyhigh, Mumbai Angels'
#  'Aroa Ventures, GVFL, Udaan' 'Investcorp, Omidyar Network' '2000000'
#  'Riteesh Mohan Bakshi, Raghav Mohan Bakshi, Achin Kochar'
#  'Info Edge Ventures, Omnivore' 'Sequoia Capital , Together Fund'
#  'Alpha Wave Ventures, Falcon Edge Capital'
#  'Vivek Vaidya, Kevin Donlon, Ayush Singh'
#  'Kieretsu Forum, Lets Venture, Shell'
#  'Sixth Sense Ventures, Godrej Family office, Malpani Group'
#  'Y-Combinator, AME Cloud Ventures, Gokul Rajaram' 'Smallcase'
#  'The StarupLab, AngelBay' 'Dallas Venture Capital, Mars Growth Capital'
#  'Raj Nair, Gopinath Latpate'
#  'Y Combinator, Goat VC, JAM Fund, Goodwater Capital'
#  'Binny Bansal, General Catalyst'
#  'General Atlantic, Tiger Global, Moore Strategic Ventures'
#  'Ascent Capital' 'Northern Arc, Arthmate, Shine Star, E clear, Hinduja'
#  'Family Office of Kantamaneni, IIM Calcutta Innovation Park'
#  'Saama Capital\ufeff, \ufeffTitan Capital\ufeff, DSG Consumer Partners'
#  'Omidyar Network, Flourish Ventures, Elevar Equity, Accel'
#  'ah! Ventures, We Founder Circle' 'Sequoia Capital, Matrix Partners'
#  'Falcon Edge, DST Global, D1 Capital, Redbird Capital, Tiger Global'
#  'Abu Dhabi Growth Fund, Tiger Global' 'Accel, Bain Capital'
#  'Tiger Global, Insight Partners' 'Ronnie Screwvala' 'WestBridge Capital'
#  'Elevation, General Catalyst' 'Equanimity Ventures, 9Unicorns' 'Nueva'
#  'Blume Ventures, Nexus Venture Partners'
#  'Apoorva Sharma, The Chennai Angels, Karthik Bhat'
#  'Gokul Rajaram, Venture Catalysts' 'Kvanto Payment Services'
#  'Siana Capital, Inflexor Ventures, Stride Ventures'
#  'Oxshott Capital Partners, XN Exponent, Edelweiss'
#  'Kunal Shah, Better Capital' 'Lightrock India, Filter Capital' 'EKKI'
#  'Stakeboat Capital' 'Coinbase Ventures, Andreessen Horowitz'
#  'BEENEXT, 3one4 Capital' 'Let’s Venture, Better Capital'
#  'International Finance Corporation'
#  'Alia Bhatt, IAN Fund, Social Alpha, Draper Richards Kaplan Foundation'
#  'Sequoia Capital India, ICONIQ Capital, Perceptive Advisors'
#  'LetsVenture' 'India Accelerator' 'Qatar Investment Authority'
#  'Netcore Cloud, Vallabh Bhansali, Jimmy Mahtani' 'Petronas Ventures'
#  'Solana' 'Falcon Edge, Softbank' 'Enzia Ventures, Kunal Shah'
#  'Auxano Capital' 'Prashant Pansare, Supermorpheus'
#  'Docprime Technologies' 'LC Nueva AIF' 'Nitish Mittersain, Gaurav Munjal'
#  '9Unicorns, Venture Catalysts, Sandeep Singhal'
#  'Temasek, Google, SBI Investment' 'Elevar Equity' 'Aroa Ventures'
#  '9Unicorns, Symphony International Holdings Limited, Value Quest'
#  'Republic Crypto, Woodstock, DCG, Sahil Lavingia' 'Data Point Capital'
#  'Momentum 6, Basics Capital, Krypital Capital, Shima Capital, Magnus Capital'
#  'Norwest Venture Partners' 'Sabre Partners' 'Vertex Ventures, Omnivore'
#  'Base 10 Partners, Eight Roads Ventures' 'enture Catalyst, IPV'
#  'Tiger Global, Falcon Edge'
#  'BAce Capital, Heritas Capital, 3Lines Venture Capital'
#  'Leo Capital, Mayfield Fund' 'Plutus Wealth, Oaks Asset Management'
#  'Anil Thadani, Ashutosh Sinha, Roy van Leeuwen'
#  'Pi Ventures LLP, Tanas Capital, Prodapt Holdings' 'Vitol'
#  'Ruchirans Jaipuria, Rishi Kajaria' 'Manish Choksi, Varun Vakil'
#  'Nadir B Godrej' 'Celesta Capital' 'TransUnion, Blume Ventures'
#  'Blume, Alpha Wave Incubation' 'Habitat for Humanity International'
#  'Global Founders Capital, Enzia Ventures, Better Capital'
#  'Kora Capital, Stripe, Alua Capital' 'Iconiq Growth'
#  'Rukam Capital, DSG Consumer Partners, The Chennai Angels'
#  'MAS Financial Services' 'Rocketship.vc, Vulcan Capital'
#  'Tiger Global, Vitruvian Partners' 'Think Investments, Venture Highway'
#  'Alok Kohli, Sanjeev Bhargava' 'Venture Catalysts, Gruhas Proptech'
#  "LetsVenture, AngelList India, Founder's Room Circle"
#  'Dinesh Godara, Anuj Ahuja, Aditya' 'Z3Partners'
#  'Celesta Capital, Omidyar Network India' 'Pavestone Ventures'
#  'LetsVenture, Paradigm Shift VC, Binny Bansal'
#  'Sofina, Lightrock India, Temasek' 'Dia Mirza' 'DST Global'
#  'Pritt Investment Partners, 9Unicorns' 'Darq Capital, Jagadeesh Atukuri'
#  'Stellaris Venture Partners' 'StartupXseed Ventures'
#  'Xponentia Capital Partners' 'General Atlantic, Multiples'
#  'Vulcan Capital' 'InCorp India'
#  'Oikocredit, Nomura, The Bill & Melinda Gates Foundation' 'Kedaara'
#  'Moore Strategic Ventures, BEENEXT'
#  'Kalaari Capital, Incubate Fund India'
#  'Sequoia Capital, Lightspeed, TVS Capital Funds' 'ABC World Asia'
#  'IIFL AMC, Sistema Asia Fund, CX Partners, Singularity Growth Opportunities Fund'
#  'Prime Securities Limited' 'Fidelity, B Capital'
#  '9Unicorns, Varanium NexGen Fund' 'Sequoia Capital, Sandeep Nailwal'
#  'Old Fashion Research, Nothing Research, Tenzor capital'
#  'Aavishkaar Capital, Rajiv Dadlani Group' 'NEVF, AccelNest'
#  'The Treasury' '9Unicorns, Spearhead Capital, Venture Catalysts'
#  'Ramp, Rainfall Ventures, Roka Works, Y Combinator' 'India Angel Network'
#  'Responsibility, Blue Ashva Capital, Pravega Ventures'
#  'Dream Capital, Elysian Park Ventures' 'CDC Group, Creaegis'
#  'Lee Fixel’s venture capital firm, Addition'
#  'Y Combinator, JAFCO Asia, Incubate Fund India, marquee angels'
#  'The Xander Group' 'Aarin Capital' 'James Milner, Adam Lallana'
#  'LetsVenture, Ajay Garg, Tarun Sharma' 'Kunal Sarkar'
#  'Morgan Stanley Private Equity Asia' 'Westbridge Capital'
#  'Lightrock India' '$Undisclosed' 'JAM, Better Tomorrow Ventures'
#  'SOSV, Venture Catalysts' 'Incofin’s India Progress Fund'
#  '9Unicorns, Anthill Ventures' 'Jani Ventures INC'
#  'CreedCap Asia Advisors' 'Joseph Joy'
#  'DST Global, Falcon Edge, SoftBank Vision Fund 2' 'Trifecta Capital'
#  "Titan Capital, AngelList's syndicate"
#  'Vineet Singh, Krishna D, Deependra Bisht, Alan Aim'
#  'Westbridge Capital, Sixth Sense Ventures' 'MaGEHold'
#  'Season Two Ventures, IndiaMart' 'Kunal Shah, Anant Maheshwari'
#  'WaterBridge Ventures, Enzia Ventures' 'Tree Line Investment Management'
#  'Orbimed Asia Partners' 'Zip Co' 'Eight Roads Ventures, GSV'
#  'Kunal Shah, Krishna Kumar'
#  'Vijay Shekhar Sharma, Rohit Kapoor, Amanpreet Bajaj, Lalit Singh'
#  'Stellaris Venture Partners, Chiratae Ventures' 'Lightspeed, Sequioa'
#  'TheVentures' 'Titan Capital, Archana Priyadarshini, Gaurav Ahuja'
#  'Jungle Ventures, CX Partners'
#  'Cygnus Medicare Group, Probal Ghoshal, Shuchin Bajaj' 'M2P Fintech'
#  'SucSEED  Indovation Fund, Uincept, Palimala Ventures'
#  'Anicut Angel Fund, Sauce.VC' 'Omidyar Network India, Chiratae Ventures'
#  'Elevation Capital, Accel India' 'Legatum Capital' 'Navneet Education'
#  '1000000\t#REF!' 'Sonu Nigam, Whiteboard Capital' 'Aditya Duggar'
#  'Vertex Ventures, Stellaris Venture Partners' 'Omnivore, India Quotient'
#  'We Founder Circle, Dexter Angels'
#  'IIFL\ufeff, \ufeffAnicut Angel Fund\ufeff, \ufeffKae Capital\ufeff, TradeCred'
#  'Indian Angel Network, Axilor' 'Invesco Developing Markets Fund'
#  'Cholamandalam' 'Curesense Therapeutics' 'Ka Enterprises'
#  'IAN Fund, Malabar Angel Network, Native Angel Network'
#  'DSG Consumer Partners, Titan Capital'
#  'Sujeet Kumar, SucSEED Indovation Fund' 'Ameba Capital, 9Unicorns'
#  'Susquehanna International Group, Bessemer Venture Partners'
#  'IIFL AMC, Oman India Joint Investment Fund' 'Unilazer Ventures'
#  'Tribe Capital, Arkam Ventures, WEH, Kunal Shah'
#  'Venture Catalysts, Indian Angel Network'
#  'Elevation Capital, Matrix Partners India' 'Ashok Goyal'
#  'Cure.fit, Endiya Partners, Tanglin Venture'
#  'HOF Capital, Old Well Ventures, LetsVenture, 9Unicorns'
#  'Jinisha Sharma, Aditya Agarwal, Victoria, Abhishek Shroff'
#  'LetsVenture, 2am VC, magic.fund'
#  'Arvind Venugopal Nair, Amritendu Mukherjee'
#  'Rajasthan Venture Capital Fund'
#  'Covalent, Double Peak, GenBlock Capital, Ledger Prime, MEXC Global, Synaps'
#  'Vijayan' 'Gokul Rajaram, JPIN, Venture Catalysts UK, AngelList'
#  'Rachit Poddar, Rajesh Gupta'
#  'Virenxia Group, Rajesh Jain, Nitin Agarwal' 'Addition' 'Prashasta Seth'
#  'Matrix Partners India, Jitendra Gupta, RTP Global'
#  'Shaival Desai, Flowstate Ventures' 'Zoho' 'Transworld Group' 'IIFL AMC'
#  'Owl Ventures' 'Winter Capital, ETS, Man Capital'
#  '3one4 Capital, Kalaari Capital']
# ____________________________________________________________________________________________________
#
# Column-8: Amount: 279
#  ['$1,200,000' '$120,000,000' '$30,000,000' '$51,000,000' '$2,000,000'
#  '$188,000,000' '$200,000' 'Undisclosed' '$1,000,000' '$3,000,000'
#  '$100,000' '$700,000' '$9,000,000' '$40,000,000' '$49,000,000' '$400,000'
#  '$300,000' '$25,000,000' '$160,000,000' '$150,000' '$1,800,000'
#  '$5,000,000' '$850,000' '$53,000,000' '$500,000' '$1,100,000'
#  '$6,000,000' '$800,000' '$10,000,000' '$21,000,000' '$7,500,000'
#  '$26,000,000' '$7,400,000' '$1,500,000' '$600,000' '$800,000,000'
#  '$17,000,000' '$3,500,000' '$15,000,000' '$215,000,000' '$2,500,000'
#  '$350,000,000' '$5,500,000' '$83,000,000' '$110,000,000' '$500,000,000'
#  '$65,000,000' '$150,000,000,000' '$300,000,000' '$2,200,000'
#  '$35,000,000' '$140,000,000' '$4,000,000' '$13,000,000' None
#  '$Undisclosed' '$2000000' '$800000' '$6000000' '$2500000' '$9500000'
#  '$13000000' '$5000000' '$8000000' '$1000000' 'Upsparks' '$200000'
#  '$12000000' '$1500000' '$1700000' '$5500000' '$400000' '$150000000'
#  '$4000000' '$100000000' '$500000' '$15000000' '$10000000' '$40000000'
#  '$225000000' '$6700000' '$1300000' '$20000000' '$250000' '$21000000'
#  '$1200000' '$52000000' '$3800000' '$17500000' '$42000000' '$2300000'
#  '$7000000' '$30000000' '$450000000' '$28000000' '$300000' '$3500000'
#  '$8500000' '$25000000' '$3000000' '$37000000' '$370000000' '$700000'
#  '$16000000' '$100000' '$44000000' '$770000' '$125000000' '$35000000'
#  '$50000000' '$4900000' '$145000000' '$22000000' '$70000000' '$6600000'
#  '$32000000' '$24000000' '$725000' '$461000' 'Series C' 'Seed' '$96000000'
#  '$60000000' '$500000000' '$266000000' '$4500000' '$325000000' '$6500000'
#  '$1600000' '$150000' '$225000' '$85000000' '$235000' '$260000' '$2900000'
#  '$53000000' '$1100000' '$86000000' '$130000' '$$100,00' '$111000000'
#  '$265000' '$76000000' '$100,000,000' '$75,000,000' '$3,800,000'
#  '$12,000,000' '$1,600,000' '$260,000' '$1,000,000,000' '$18,000,000'
#  '$20,000,000' '$350,000' '$95,000,000' '$4,100,000' '$5,200,000'
#  '$8,000,000' '$1,400,000' '$2,600,000' '$900,000' '$250,000'
#  '$16,000,000' '$7,000,000' '$11,000,000' '$280,000,000' '$50,000,000'
#  '$14,300,000' '$81,000,000' '$1,300,000' '$8,200,000' '$70,000,000'
#  '$720,000' '$600000' '$9000000' '$1800000' '$330000' '$undisclosed'
#  '$200000000' '$36000000' '$67000000' '$10200000' '$220000000'
#  '$108000000' '$75000000' '$450000' '$660000000' 'ah! Ventures'
#  '$45000000' '$3200000' '$370000' 'Pre-series A'
#  'ITO Angel Network, LetsVenture' '$48000000' '$3600000' '$11000000'
#  '$192000000' '$65000000' '$1400000' '$1900000' '$41000000' '$144000000'
#  '$5200000' '$270000000' '$140000' '$250000000' '$320000' '$350000000'
#  '$4800000' '$38000000' '$125000' '$26000000' '$64000000' '$620000'
#  '$900000' 'JITO Angel Network, LetsVenture' '$2600000' '$1,250,000'
#  '$400,000,000' '$1,700,000' '$27,000,000' '$234,000,000' '$460,000,000'
#  '$13,500,000' '$5,100,000' '$195,000,000' '$125,000' '$45,000,000'
#  '$200,000,000' '$7,300,000' '$6,300,000' '$12,500,000' '$24,000,000'
#  '$140,000' '$16,500,000' '$340,000' '$43,000,000' '$150,000,000'
#  '$3300000' '$92000000' '$17000000' '$135000000' '$$1,55,000' '$2100000'
#  '$840000000' '$248000000' '$4300000' '$570000' '$2200000' '$4700000'
#  '$300000000' '$260000000' '$140000000' '$175000000' '$19000000' '$810000'
#  '$7500000' '$600000000' '$90000000' '$5700000' '$6750000' '$78000000'
#  '$5400000' '$115000000' '$255000000' '$18000000' '$570000000' '$550000'
#  '$2700000' '$4200000' '$31000000' '$540000' '$14000000' '$340000' '$'
#  '$6200000' '$750000' '$6300000' '$23000000' '$55000000']
# ____________________________________________________________________________________________________
#
# Column-9: Stage: 32
#  ['Pre-series A' None 'Series D' 'Series C' 'Seed' 'Series B' 'Series E'
#  'Pre-seed' 'Series A' 'Pre-series B' 'Debt' '$1200000' 'Bridge' 'Seed+'
#  'Series F2' 'Series A+' 'Series G' 'Series F' 'Series H' 'Series B3' 'PE'
#  'Series F1' 'Pre-series A1' '$300000' 'Early seed' 'Series D1' '$6000000'
#  '$1000000' 'Seies A' 'Pre-series' 'Series A2' 'Series I']
# ____________________________________________________________________________________________________

# %% [markdown]
# ##### Identifying Odd Entries in Each Column

# %% [markdown]
# **Column-1: Company_Brand: 1033**
#
# In the context of identifying odd entries in a list of startup names, duplicates are considered odd because they deviate from the expectation that each entry should be unique. In order to identify duplicate startups the following steps are carried out:
#
# 1.  Identify key features that represent the core information of a startup
#
# 2.  Filter duplicates in the dataset based on these key features

# %%
# Define key columns to identify duplicates
key_columns = ['Company_Brand', 'Founded', 'HeadQuarter', 'Sector', 'What_it_does', 'Founders']

# Check for number of duplicated values within the 'Company_Brand' column
dup21_count = df2021.duplicated(subset=key_columns, keep=False).sum()

# Identify duplicate entries in the 'Company_Brand' column
dup_c1_21 = df2021[df2021.duplicated(subset=key_columns, keep=False)]

# Extract the list of duplicated company brands
unidup_c1_21 = dup_c1_21['Company_Brand'].unique()

# Display results
print(f"Number of duplicated values in 'Company_Brand' column: {dup21_count}")
print("\nList of duplicated company brands:")
print(unidup_c1_21)
dup_c1_21
# Out:
# Number of duplicated values in 'Company_Brand' column: 77
#
# List of duplicated company brands:
# ['DealShare' 'Curefoods' 'TartanSense' 'Bewakoof' 'Kirana247' 'FanPlay'
#  'NeoDocs' 'IsGoingOnline' 'Camp K12' 'Elda Health' 'Sporjo'
#  'Advantage Club' 'SuperGaming' 'Ruptok' 'Trinkerr' 'Zorro'
#  'Ultraviolette' 'NephroPlus' 'Unremot' 'FanAnywhere' 'PingoLearn' 'Spry'
#  'Enmovil' 'ASQI Advisors' 'Insurance Samadhan' 'Evenflow Brands'
#  'MasterChow' 'Fullife Healthcare' 'BharatPe' 'Nazara Technologies' 'MPL'
#  'Spinny' 'KreditBee' "BYJU'S" 'Euler Motors' 'Northern Arc' 'Delhivery']
#             Company_Brand  Founded             HeadQuarter  \
# 14              DealShare   2018.0                  Jaipur
# 94              Curefoods   2020.0               Bangalore
# 95            TartanSense   2015.0               Bangalore
# 96               Bewakoof   2012.0                  Mumbai
# 97              Kirana247   2018.0               New Delhi
# 98                FanPlay   2020.0          Computer Games
# 99                NeoDocs   2020.0                  Mumbai
# 100         IsGoingOnline   2015.0                  Cochin
# 101              Camp K12   2010.0                Gurugram
# 102           Elda Health   2020.0               Bangalore
# 103                Sporjo   2020.0                  Mumbai
# 104        Advantage Club   2014.0                  Mumbai
# 105           SuperGaming   2017.0                    Pune
# 106                Ruptok   2020.0               New Delhi
# 107             Curefoods   2020.0               Bangalore
# 108           TartanSense   2015.0               Bangalore
# 109              Bewakoof   2012.0                  Mumbai
# 110             Kirana247   2018.0               New Delhi
# 111               FanPlay   2020.0          Computer Games
# 112               NeoDocs   2020.0                  Mumbai
# 113         IsGoingOnline   2015.0                  Cochin
# 114              Camp K12   2010.0                Gurugram
# 115           Elda Health   2020.0               Bangalore
# 116                Sporjo   2020.0                  Mumbai
# 117        Advantage Club   2014.0                  Mumbai
# 118           SuperGaming   2017.0                    Pune
# 119                Ruptok   2020.0               New Delhi
# 229              Trinkerr   2021.0               Bangalore
# 230                 Zorro   2021.0                Gurugram
# 231         Ultraviolette   2021.0               Bangalore
# 232            NephroPlus   2009.0               Hyderabad
# 233               Unremot   2020.0               Bangalore
# 234           FanAnywhere   2021.0               Bangalore
# 235            PingoLearn   2021.0                    Pune
# 236                  Spry   2021.0                  Mumbai
# 237               Enmovil   2015.0               Hyderabad
# 238         ASQI Advisors   2019.0                  Mumbai
# 239    Insurance Samadhan   2018.0               New Delhi
# 240       Evenflow Brands   2020.0                  Mumbai
# 241            MasterChow   2020.0        Food & Beverages
# 242    Fullife Healthcare   2009.0  Pharmaceuticals\t#REF!
# 243              Trinkerr   2021.0               Bangalore
# 244                 Zorro   2021.0                Gurugram
# 245         Ultraviolette   2021.0               Bangalore
# 246            NephroPlus   2009.0               Hyderabad
# 247               Unremot   2020.0               Bangalore
# 248           FanAnywhere   2021.0               Bangalore
# 249            PingoLearn   2021.0                    Pune
# 250                  Spry   2021.0                  Mumbai
# 251               Enmovil   2015.0               Hyderabad
# 252         ASQI Advisors   2019.0                  Mumbai
# 253    Insurance Samadhan   2018.0               New Delhi
# 254       Evenflow Brands   2020.0                  Mumbai
# 255            MasterChow   2020.0        Food & Beverages
# 256    Fullife Healthcare   2009.0  Pharmaceuticals\t#REF!
# 339              BharatPe   2018.0               New Delhi
# 359   Nazara Technologies   2000.0                  Mumbai
# 372                   MPL   2018.0               Bangalore
# 394                   MPL   2018.0               Bangalore
# 401              BharatPe   2018.0               New Delhi
# 407              BharatPe   2018.0               New Delhi
# 448              BharatPe   2018.0               New Delhi
# 511                Spinny   2015.0                Gurugram
# 605             KreditBee   2018.0               Bangalore
# 638                BYJU'S   2011.0               Bangalore
# 736                BYJU'S   2011.0               Bangalore
# 746             KreditBee   2018.0               Bangalore
# 755   Nazara Technologies   2000.0                  Mumbai
# 756          Euler Motors   2018.0               New Delhi
# 788          Northern Arc   2008.0                 Chennai
# 796             DealShare   2018.0                  Jaipur
# 797          Euler Motors   2018.0               New Delhi
# 805          Northern Arc   2008.0                 Chennai
# 862                BYJU'S   2011.0               Bangalore
# 936                Spinny   2015.0                Gurugram
# 1089            Delhivery   2011.0                Gurugram
# 1195            Delhivery   2011.0                Gurugram
#
#                                                  Sector  \
# 14                                           E-commerce
# 94                                     Food & Beverages
# 95                               Information Technology
# 96                                    Apparel & Fashion
# 97                             Logistics & Supply Chain
# 98                                       Computer Games
# 99                                           Healthtech
# 100                                              Retail
# 101                                              EdTech
# 102                                          Healthcare
# 103                                          SportsTech
# 104                                              HRTech
# 105                                              Gaming
# 106                                             FinTech
# 107                                    Food & Beverages
# 108                              Information Technology
# 109                                   Apparel & Fashion
# 110                            Logistics & Supply Chain
# 111                                      Computer Games
# 112                                          Healthtech
# 113                                              Retail
# 114                                              EdTech
# 115                                          Healthcare
# 116                                          SportsTech
# 117                                              HRTech
# 118                                              Gaming
# 119                                             FinTech
# 229                                     Capital Markets
# 230                                      Social network
# 231                                          Automotive
# 232                              Hospital & Health Care
# 233                   Information Technology & Services
# 234                                  Financial Services
# 235                                          E-learning
# 236                                               Music
# 237                   Information Technology & Services
# 238                                  Financial Services
# 239                                           Insurance
# 240                                      Consumer Goods
# 241                                           Hauz Khas
# 242   Primary Business is Development and Manufactur...
# 243                                     Capital Markets
# 244                                      Social network
# 245                                          Automotive
# 246                              Hospital & Health Care
# 247                   Information Technology & Services
# 248                                  Financial Services
# 249                                          E-learning
# 250                                               Music
# 251                   Information Technology & Services
# 252                                  Financial Services
# 253                                           Insurance
# 254                                      Consumer Goods
# 255                                           Hauz Khas
# 256   Primary Business is Development and Manufactur...
# 339                                             FinTech
# 359                                              Gaming
# 372                                              Gaming
# 394                                              Gaming
# 401                                             FinTech
# 407                                             FinTech
# 448                                             FinTech
# 511                                          Automotive
# 605                                             FinTech
# 638                                              EdTech
# 736                                              EdTech
# 746                                             FinTech
# 755                                              Gaming
# 756                                          Automotive
# 788                                             FinTech
# 796                                          E-commerce
# 797                                          Automotive
# 805                                             FinTech
# 862                                              EdTech
# 936                                          Automotive
# 1089                           Logistics & Supply Chain
# 1195                           Logistics & Supply Chain
#
#                                            What_it_does  \
# 14               DealShare is a Social Commerce Startup
# 94    Healthy & nutritious foods and cold pressed ju...
# 95    TartanSense unlocks value for small farm holde...
# 96    Bewakoof is a lifestyle fashion brand that mak...
# 97    An on-demand FMCG supply chain company leverag...
# 98    A real money game app specializing in trivia g...
# 99    Neodocs is a part of India's prominent Social ...
# 100   Kochi-based digital catalogue and marketplace ...
# 101   Camp K12 is a global online school for 21st ce...
# 102   Elda Health is a digital wellness platform tha...
# 103   A one stop destination to build a successful c...
# 104   Advantage Club is India's largest employee eng...
# 105   At SuperGaming, building India's best gaming c...
# 106   Ruptok fintech Pvt. Ltd. is an online gold loa...
# 107   Healthy & nutritious foods and cold pressed ju...
# 108   TartanSense unlocks value for small farm holde...
# 109   Bewakoof is a lifestyle fashion brand that mak...
# 110   An on-demand FMCG supply chain company leverag...
# 111   A real money game app specializing in trivia g...
# 112   Neodocs is a part of India's prominent Social ...
# 113   Kochi-based digital catalogue and marketplace ...
# 114   Camp K12 is a global online school for 21st ce...
# 115   Elda Health is a digital wellness platform tha...
# 116   A one stop destination to build a successful c...
# 117   Advantage Club is India's largest employee eng...
# 118   At SuperGaming, building India's best gaming c...
# 119   Ruptok fintech Pvt. Ltd. is an online gold loa...
# 229   Trinkerr is India's first social trading platf...
# 230                Pseudonymous social network platform
# 231   Create and Inspire the future of sustainable u...
# 232   A vision and passion of redefining healthcare ...
# 233       Unremot is a personal office for consultants!
# 234                              Celebrity NFT platform
# 235   PingoLearn offers language learning courses wi...
# 236   THE BEST ROYALTY-FREE MUSIC TO CREATE TRENDING...
# 237   Enmovil delivers a Business Intelligence Platf...
# 238   Bringing Blockchain technology intro mainstrea...
# 239   The insurance industry will help in representa...
# 240   Identify and partner with the upcoming eCommer...
# 241                 A ready-to-cook Asian cuisine brand
# 242                                        Varun Khanna
# 243   Trinkerr is India's first social trading platf...
# 244                Pseudonymous social network platform
# 245   Create and Inspire the future of sustainable u...
# 246   A vision and passion of redefining healthcare ...
# 247       Unremot is a personal office for consultants!
# 248                              Celebrity NFT platform
# 249   PingoLearn offers language learning courses wi...
# 250   THE BEST ROYALTY-FREE MUSIC TO CREATE TRENDING...
# 251   Enmovil delivers a Business Intelligence Platf...
# 252   Bringing Blockchain technology intro mainstrea...
# 253   The insurance industry will help in representa...
# 254   Identify and partner with the upcoming eCommer...
# 255                 A ready-to-cook Asian cuisine brand
# 256                                        Varun Khanna
# 339   BharatPe develops a QR code-based payment app ...
# 359   Nazara Technologies develops mobile content su...
# 372   Mobile Premier League is a skill-based eSports...
# 394   Mobile Premier League is a skill-based eSports...
# 401   BharatPe develops a QR code-based payment app ...
# 407   BharatPe develops a QR code-based payment app ...
# 448   BharatPe develops a QR code-based payment app ...
# 511   Spinny is a new age used car end-to-end platfo...
# 605   KreditBee is a digital lending platform develo...
# 638   BYJU'S is an educational technology company th...
# 736   BYJU'S is an educational technology company th...
# 746   KreditBee is a digital lending platform develo...
# 755   Nazara Technologies develops mobile content su...
# 756                   Electric Light Commercial Vehicle
# 788   Northern Arc Capital (Formerly known as IFMR C...
# 796              DealShare is a Social Commerce Startup
# 797                   Electric Light Commercial Vehicle
# 805   Northern Arc Capital (Formerly known as IFMR C...
# 862   BYJU'S is an educational technology company th...
# 936   Spinny is a new age used car end-to-end platfo...
# 1089  Delhivery is a leading logistics and supply ch...
# 1195  Delhivery is a leading logistics and supply ch...
#
#                                                Founders  \
# 14            Sankar Bora, Sourjyendu Medda, Vineet Rao
# 94                                         Ankit Nagori
# 95                                         Jaisimha Rao
# 96                                     Prabhkiran Singh
# 97                  Tarun Jiwarajka, Pankhuri Jiwarajka
# 98                                               YC W21
# 99           Nikunj Malpani, Anurag Meena, Pratik Lodha
# 100                                          Eobin Alex
# 101                                        Anshul Bhagi
# 102    Swathi Kulkarni, Sindhuri Ananth, Shubham Sharma
# 103                                       G Srinivvasan
# 104                  Sourabh Deorah, Smiti Bhatt Deorah
# 105          Roby John, Sanket Nadhani, Navneet Waraich
# 106                                         Ankur Gupta
# 107                                        Ankit Nagori
# 108                                        Jaisimha Rao
# 109                                    Prabhkiran Singh
# 110                 Tarun Jiwarajka, Pankhuri Jiwarajka
# 111                                              YC W21
# 112          Nikunj Malpani, Anurag Meena, Pratik Lodha
# 113                                          Eobin Alex
# 114                                        Anshul Bhagi
# 115    Swathi Kulkarni, Sindhuri Ananth, Shubham Sharma
# 116                                       G Srinivvasan
# 117                  Sourabh Deorah, Smiti Bhatt Deorah
# 118          Roby John, Sanket Nadhani, Navneet Waraich
# 119                                         Ankur Gupta
# 229                     Manvendra Singh, Gaurav Agarwal
# 230       Jasveer Singh, Abhishek Asthana, Deepak Kumar
# 231                 Subramaniam Narayan, Niraj Rajmohan
# 232                                      Vikram Vuppala
# 233                                 Shiju Radhakrishnan
# 234                         Varun Chaudhary, Amit Kumar
# 235                  Mohit Menghani, Shubham Maheshwari
# 236                     Gaurav Dagaonkar, Meghna Mittal
# 237          Ravi Bulusu, Nanda Kishore, Venkat Moganty
# 238                                       Swapnil Pawar
# 239                          Deepak Bhuvenshwari Uniyal
# 240                       Utsav Agarwal, Pulkit Chhabra
# 241                       Vidur Kataria, Sidhanth Madan
# 242                  Morgan Stanley Private Equity Asia
# 243                     Manvendra Singh, Gaurav Agarwal
# 244       Jasveer Singh, Abhishek Asthana, Deepak Kumar
# 245                 Subramaniam Narayan, Niraj Rajmohan
# 246                                      Vikram Vuppala
# 247                                 Shiju Radhakrishnan
# 248                         Varun Chaudhary, Amit Kumar
# 249                  Mohit Menghani, Shubham Maheshwari
# 250                     Gaurav Dagaonkar, Meghna Mittal
# 251          Ravi Bulusu, Nanda Kishore, Venkat Moganty
# 252                                       Swapnil Pawar
# 253                          Deepak Bhuvenshwari Uniyal
# 254                       Utsav Agarwal, Pulkit Chhabra
# 255                       Vidur Kataria, Sidhanth Madan
# 256                  Morgan Stanley Private Equity Asia
# 339                    Ashneer Grover, Shashvat Nakrani
# 359                                   Nitish Mittersain
# 372              Sai Srinivas Kiran G, Shubham Malhotra
# 394              Sai Srinivas Kiran G, Shubham Malhotra
# 401                    Ashneer Grover, Shashvat Nakrani
# 407                    Ashneer Grover, Shashvat Nakrani
# 448                    Ashneer Grover, Shashvat Nakrani
# 511           Niraj Singh, Mohit Gupta, Ramanshu Mahaur
# 605   Karthikeyan Krishnaswamy, Madhusudan Ekambaram...
# 638                    Byju Raveendran, Divya Gokulnath
# 736                    Byju Raveendran, Divya Gokulnath
# 746   Karthikeyan Krishnaswamy, Madhusudan Ekambaram...
# 755                                   Nitish Mittersain
# 756                                        Saurav Kumar
# 788                                    Kshama Fernandes
# 796           Sankar Bora, Sourjyendu Medda, Vineet Rao
# 797                                        Saurav Kumar
# 805                                    Kshama Fernandes
# 862                    Byju Raveendran, Divya Gokulnath
# 936           Niraj Singh, Mohit Gupta, Ramanshu Mahaur
# 1089                                        Sahil Barua
# 1195                                        Sahil Barua
#
#                                                Investor        Amount  \
# 14             Tiger Global Management, InnoVen Capital    $9,000,000
# 94                  Iron Pillar, Nordstar, Binny Bansal     $13000000
# 95                        FMC, Omnivore, Blume Ventures      $5000000
# 96                                           InvestCorp      $8000000
# 97                                                 None      $1000000
# 98                          Pritesh Kumar, Bharat Gupta      Upsparks
# 99               Y Combinator, 9Unicorns, Titan Capital  $Undisclosed
# 100      Unicorn India Ventures, SEA Fund, Devdatt Shah       $200000
# 101            Matrix Partners India, Elevation Capital     $12000000
# 102                      Avaana Capital, Orios Ventures      $1500000
# 103                                         Punit Balan      $2000000
# 104            Y Combinator, Broom Ventures, Kunal Shah      $1700000
# 105   Skycatcher, AET Fund, BAce Capital, Dream Incu...      $5500000
# 106                                      Eclear Leasing      $1000000
# 107                 Iron Pillar, Nordstar, Binny Bansal     $13000000
# 108                       FMC, Omnivore, Blume Ventures      $5000000
# 109                                          InvestCorp      $8000000
# 110                                                None      $1000000
# 111                         Pritesh Kumar, Bharat Gupta      Upsparks
# 112              Y Combinator, 9Unicorns, Titan Capital  $Undisclosed
# 113      Unicorn India Ventures, SEA Fund, Devdatt Shah       $200000
# 114            Matrix Partners India, Elevation Capital     $12000000
# 115                      Avaana Capital, Orios Ventures      $1500000
# 116                                         Punit Balan      $2000000
# 117            Y Combinator, Broom Ventures, Kunal Shah      $1700000
# 118   Skycatcher, AET Fund, BAce Capital, Dream Incu...      $5500000
# 119                                      Eclear Leasing      $1000000
# 229                                         Accel India      $6600000
# 230   Vijay Shekhar Sharma, Ritesh Agarwal, Ankiti Bose     $32000000
# 231                                     TVS Motor, Zoho    $150000000
# 232                               IIFL Asset Management     $24000000
# 233                           Inflection Point Ventures       $700000
# 234         Oasis Capital, Scorpio VC, DeltaHub Capital  $Undisclosed
# 235   Titan Capital, Haresh Chawla, AngelList Syndicate       $200000
# 236                           9Unicorns, Ashneer Grover      $1500000
# 237                                   Anicut Angel Fund      $1300000
# 238                               Founders Room Capital      $1000000
# 239                                      9Unicorns, ZNL       $725000
# 240                                                None       $500000
# 241                                        WEH Ventures       $461000
# 242                                           $22000000      Series C
# 243                                         Accel India      $6600000
# 244   Vijay Shekhar Sharma, Ritesh Agarwal, Ankiti Bose     $32000000
# 245                                     TVS Motor, Zoho    $150000000
# 246                               IIFL Asset Management     $24000000
# 247                           Inflection Point Ventures       $700000
# 248         Oasis Capital, Scorpio VC, DeltaHub Capital  $Undisclosed
# 249   Titan Capital, Haresh Chawla, AngelList Syndicate       $200000
# 250                           9Unicorns, Ashneer Grover      $1500000
# 251                                   Anicut Angel Fund      $1300000
# 252                               Founders Room Capital      $1000000
# 253                                      9Unicorns, ZNL       $725000
# 254                                                None       $500000
# 255                                        WEH Ventures       $461000
# 256                                           $22000000      Series C
# 339                             Amplo, Insight Partners  $100,000,000
# 359      Plutus Wealth Management, Turtle Entertainment   $10,000,000
# 372                Pegasus Tech Ventures, Base Partners   $95,000,000
# 394                Pegasus Tech Ventures, Base Partners    $5,000,000
# 401                  InnoVen Capital, Steadview Capital    $6,000,000
# 407                  InnoVen Capital, Steadview Capital   $10,000,000
# 448                 Steadview Capital, Insight Partners    $8,200,000
# 511                                        Tiger Global    $108000000
# 605   NewQuest Capital Partners, Motilal Oswal Priva...      $8000000
# 638                     Tiga Investments, Baron Capital    $350000000
# 736                             BlackRock, Owl Ventures  $460,000,000
# 746                        Alpine Capital, PremjiInvest   $75,000,000
# 755   Hornbill Capital Advisers, Plutus Wealth Manag...   $30,000,000
# 756                        ADB Ventures, Jetty Ventures    $2,600,000
# 788   U.S. International Development Finance Corp, A...   $10,000,000
# 796                Omidyar Network, Falcon Edge Capital    $3,000,000
# 797                    Jetty Ventures, Srinivas Anumolu    $4,000,000
# 805   Asian Development Bank, U.S. International Dev...   $50,000,000
# 862                     Tiga Investments, Baron Capital  $150,000,000
# 936                 Abu Dhabi Growth Fund, Tiger Global    $248000000
# 1089         Lee Fixel’s venture capital firm, Addition    $125000000
# 1195                                           Addition     $76000000
#
#              Stage
# 14            None
# 94            None
# 95            None
# 96            None
# 97            None
# 98        $1200000
# 99            None
# 100           None
# 101           None
# 102           None
# 103           None
# 104           None
# 105           None
# 106           None
# 107           None
# 108       Series A
# 109           None
# 110   Pre-series A
# 111       $1200000
# 112       Pre-seed
# 113   Pre-series A
# 114       Series A
# 115           Seed
# 116   Pre-series A
# 117           None
# 118       Series A
# 119           None
# 229       Series A
# 230           Seed
# 231       Series C
# 232       Series E
# 233           Seed
# 234           Seed
# 235           None
# 236           Seed
# 237   Pre-series A
# 238   Pre-series A
# 239   Pre-series A
# 240           None
# 241           Seed
# 242           None
# 243       Series A
# 244           Seed
# 245       Series C
# 246       Series E
# 247           Seed
# 248           Seed
# 249           None
# 250           Seed
# 251   Pre-series A
# 252   Pre-series A
# 253   Pre-series A
# 254           None
# 255           Seed
# 256           None
# 339       Series D
# 359           None
# 372           None
# 394           None
# 401           Debt
# 407           Debt
# 448           Debt
# 511       Series D
# 605           None
# 638           None
# 736       Series F
# 746           Seed
# 755           None
# 756       Series A
# 788           Debt
# 796           Debt
# 797       Series A
# 805           Debt
# 862           None
# 936       Series E
# 1089          None
# 1195      Series I

# %% [markdown]
# **Column-2: Founded: 31**
#
# To identify odd entries in the column that identifies the year in which startup companies in India were founded, we need to focus on identifying entries that deviate from the expected range or format. Specifically, we should consider:
#
# 1. Missing or NaN values.
#
# 2. Years that are unusually old for a startup context.
#      -  The range of 1980 to 2024 encompasses a period marked by significant technological innovation, economic dynamism, cultural shifts, and global connectivity, making it reasonable to classify companies founded within this timeframe as startups [United Nations DESA](https://econpapers.repec.org/scripts/redir.pf?u=http%3A%2F%2Fwww.un.org%2Fesa%2Fdesa%2Fpapers%2F2019%2Fwp158_2019.pdf;h=repec:une:wpaper:158), [WEForum](https://www.weforum.org/agenda/2024/01/9-forces-reshaping-the-global-business-landscape/#:~:text=URL%3A%20https%3A%2F%2Fwww.weforum.org%2Fagenda%2F2024%2F01%2F9), [Mercatus Center](https://www.mercatus.org/research/research-papers/technological-innovation-and-economic-growth), [MDPI - Sustainability 2020](https://doi.org/10.3390/su12208323).
#
#      -  [Go to Definition of an Indian Startup](#background)
#
#
#
# 3. Non-numeric values or invalid year formats.

# %%
# Define criteria for odd entries in the 'Founded' column
def is_odd_year(year):
    """
    Function to identify odd entries in the 'Founded' column based on specified criteria.

    Parameters:
        year (int or float): The founding year of a startup.

    Returns:
        bool: True if the year is considered odd, False otherwise.
    """
    # Criteria for odd entries:
    # - Missing values
    # - Years that are unusually old for a startup context
    # - Non-numeric values or invalid year formats
    
    # Check for missing values
    if pd.isnull(year):
        return True
    
    # Check if the year is not numeric
    if not isinstance(year, (int, float)):
        return True
    
    # Assuming startups would not be founded before 1980 or after 2024
    if year < 1980 or year > 2024:  
        return True
    
    # If the year passes all criteria, it's not considered odd
    return False

# Filter odd entries in the 'Founded' column
odde_c2_21 = df2021[df2021['Founded'].apply(is_odd_year)]['Founded']

# Calculate the number of unique odd entries
oddn_c2_21 = odde_c2_21.unique()

# Print the number of odd entries and their details
print(f"Number of odd entries in 'Founded' column: {len(oddn_c2_21)}")
print('\nOdd entries:')
for entry in oddn_c2_21:
    print(entry)
# Out:
# Number of odd entries in 'Founded' column: 3
#
# Odd entries:
# nan
# 1978.0
# 1963.0

# %% [markdown]
# **Column-3: HeadQuarter: 71**
#
# To identify odd entries in the column that lists headquarters or locations in India where startup companies are found, we need to identify entries that do not fit the typical format of Indian city names or locations. Odd entries might include:
#
# 1. Missing or NaN values
#
# 2. Locations outside India.
#
# 3. Non-geographical entities.
#
# 4. Entries with noticeable errors or typographical mistakes.

# %%
# list of Indian cities
indian_cities = [
    'Ahmedabad', 'Ambernath', 'Andaman and Nicobar Islands', 'Andhra Pradesh', 'Andheri',
    'Arunachal Pradesh', 'Assam', 'Bangalore', 'Belgaum', 'Bengaluru', 'Bihar', 'Bhilwara',
    'Bhopal', 'Bhubaneswar', 'Chandigarh', 'Chennai', 'Chhattisgarh', 'Coimbatore', 'Cochin', 'Dehradun',
    'Delhi', 'Dhingsara', 'Faridabad', 'Ghaziabad', 'Gandhinagar', 'Goa', 'Gujarat', 'Gurgaon', 'Gurugram', 'Guwahati',
    'Haryana', 'Himachal Pradesh', 'Hyderabad', 'Indore', 'Jaipur', 'Jammu and Kashmir',
    'Jharkhand', 'Jodhpur', 'Kanpur', 'Karnataka', 'Kerala', 'Kochi', 'Kolkata', 'Kottayam',
    'Lucknow', 'Ludhiana', 'Madhya Pradesh', 'Maharashtra', 'Mangalore', 'Mohali', 'Mumbai',
    'Nagaland', 'Nagpur', 'New Delhi', 'Noida', 'Odisha', 'Orissia', 'Panchkula', 'Panaji', 'Patna',
    'Puducherry', 'Powai', 'Pune', 'Rajsamand', 'Rajasthan', 'Ranchi', 'Roorkee', 'Samastipur',
    'Satara', 'Samsitpur', 'Silvassa', 'Sikkim', 'Surat', 'Tamil Nadu', 'Telangana', 'Telugana',
    'Thane', 'Thiruvananthapuram', 'The Nilgiris', 'Tirunelveli', 'Trivandrum', 'Tumkur', 
    'Uttar Pradesh', 'Uttarakhand', 'Vadodara', 'Warangal', 'West Bengal',
    'Kalkaji', 'Hubli', 'Azadpur', 'Kota', 'Anand', 'Bangalore City', 'Margão', 'Alwar', 'Kannur',
    'Ernakulam', 'Kormangala', 'Mylapore', 'Guntur', 'Kalpakkam', 'Worli', 'Alleppey', 'Guindy'
]


# Identifying odd entries
def is_odd_location(location):
    """
    Function to identify odd entries in the 'HeadQuarter' column.

    Parameters:
        location (str): The location entry to be evaluated.

    Returns:
        bool: True if the location is considered odd, False otherwise.
    """
    # Criteria for odd entries:
    # - Missing values
    # - Locations outside India
    # - Non-geographical entities
    # - Entries with noticeable errors or typos
    
    # Check for missing values
    if pd.isnull(location):
        return True
    
    # Check for None values
    if location is None:
        return True
    
    # Strip leading and trailing spaces
    location = location.strip()

    # Check for empty strings
    if len(location) == 0:
        return True
    
    # Define non-geographical keywords
    non_geographical_keywords = ['computer games', 'food & beverages', 'online media', 'information technology & services']

    # Check if the lowercase input string contains any of the lowercase non-geographical keywords
    if any(keyword.lower() in location.lower() for keyword in non_geographical_keywords):
        return True

    # Check for special characters indicating errors or typos
    if '\t#REF!' in location:
        return True
    
    # Check for numeric characters within the location
    if any(non_alpha for non_alpha in location if non_alpha.isdigit()):
        return True
    
    # Check for comma-separated entries
    if ',' in location:
        parts = location.split(',')
        # Check for irregularities in comma-separated entries
        if len(parts) > 2 or any(len(part.strip()) == 0 for part in parts):
            return True
        # Check if the second part contains non-alphabetical characters
        if not parts[1].strip().replace(" ", "").isalpha():
            return True 
    
    # Check if the location is not among the predefined list of Indian locations
    return location not in indian_cities



# Filter odd entries in the 'HeadQuarter' column
odde_c3_21 = df2021[df2021['HeadQuarter'].apply(is_odd_location)]['HeadQuarter']

# Extract unique odd entries
oddn_c3_21 = odde_c3_21.unique()

# Print the number of odd entries and their details
print(f"Number of odd entries in 'HeadQuarter' column: {len(oddn_c3_21)}")
print('\nOdd entries:')
for entry in oddn_c3_21:
    print(entry)
# Out:
# Number of odd entries in 'HeadQuarter' column: 15
#
# Odd entries:
# Ahmadabad
# None
# Small Towns, Andhra Pradesh
# Faridabad, Haryana
# Computer Games
# Food & Beverages
# Pharmaceuticals	#REF!
# Gurugram	#REF!
# Beijing
# New York
# Santra
# Mountain View, CA
# Online Media	#REF!
# London
# Information Technology & Services

# %% [markdown]
# `Comment`
#
# Non-geographical descrepancies will be updated to 'Not filled', and any potential geographical discrepancies will be corrected accordingly. International geographical entries with minimal occurrences will be removed if their exclusion does not compromise data integrity.

# %% [markdown]
# **Column-4: Sector: 254**
#
# To identify odd entries in the given list of sectors of startups in India, we need to consider entries that do not align with typical startup sectors or contain errors. Odd entries might include:
#
# 1. Missing or NaN values
#
# 2. Location entries
#
# 3. Sectors with more than 5 words
#
# 4. Typos or mispellings
#
# 5. Uncommon abbreviations
#
# 6. Inconsistent formatting
#
# 7. Non-industry terms and unusaul sectors

# %%
def is_odd_sector(sector):
    """
    Function to identify odd entries in the list of startup sectors.

    Parameters:
        sector (str): The sector of a startup.

    Returns:
        bool: True if the sector is considered odd, False otherwise.
    """
    # Criteria for odd entries:
    # - Missing values
    # - Location entries
    # - Sectors with more than 5 words
    # - Typos or mispellings
    # - Uncommon abbreviations
    # - Inconsistent formatting
    # - Non-industry terms and unusaul sectors
    
    # Check for missing values
    if pd.isnull(sector):
        return True    

    # Strip leading and trailing spaces
    sector = sector.strip()

    # Check for empty strings
    if len(sector) == 0:
        return True
    
    # Check for location entries
    if ',' in sector:
        return True
    
    # Check for sectors with more than 5 words
    if len(sector.split()) > 5:
        return True
    
    # Check for typos or misspellings
    if 'Helathcare' in sector or 'equiptment' in sector:
        return True
    
    # Check for numeric values within the sector
    if re.search(r'\d', sector):
        return True
    
    # Check for inconsistent formatting
    special_characters = [
        '&', '@', '#', '$', '%', '^', '*', '!', '?', '(', ')', '-', '_', '=', '+',
        '{', '}', '[', ']', '|', '\\', ':', ';', '"', "'", '<', '>', ',', '.', '/',
        '~', '`'
    ]
    if any(char in sector for char in special_characters):
        return True
    
    # Check for Non-industry terms and unusual sectors
    non_industry_terms = ['hauz khas', 'music', 'manchester', 'sochcast', 'matrimony', 'company-as-a-service', 'startup']
    if any(term.lower() in sector.lower() for term in non_industry_terms):
        return True
    
    return False

# Filter odd entries in the 'Sector' column
odde_c4_21 = df2021['Sector'].apply(is_odd_sector)
oddn_c4_21 = df2021[odde_c4_21]['Sector'].unique()

# Print the number of odd entries and their details
print(f"Number of odd entries in 'Sector' column: {len(oddn_c4_21)}")
print('\nOdd entries:')
for entry in oddn_c4_21:
    print(entry)
# Out:
# Number of odd entries in 'Sector' column: 63
#
# Odd entries:
# AI startup
# B2B E-commerce
# Tech Startup
# E-commerce
# B2B service
# Helathcare
# IT startup
# Food & Beverages
# Milk startup
# SaaS startup
# Apparel & Fashion
# Logistics & Supply Chain
# Wine & Spirits
# Mechanical & Industrial Engineering
# Tech startup
# Information Technology & Services
# B2B marketplace
# E-learning
# Venture Capital & Private Equity
# Health, Wellness & Fitness
# Software Startup
# Computer & Network Security
# Hospital & Health Care
# Music
# Hauz Khas
# Primary Business is Development and Manufacturing of Novel Healthcare Products in Effervescent forms using imported propriety ingredients.
# MoEVing is India's only Electric Mobility focused Technology Platform with a vision to accelerate EV adoption in India.
# B2B Ecommerce
# Cannabis startup
# B2B Marketplace
# B2B Manufacturing
# TaaS startup
# EV startup
# Blockchain startup
# Manufacturing startup
# Vehicle repair startup
# Pollution control equiptment
# Fashion & Lifestyle
# D2C
# Marketing & Advertising
# D2C Business
# Renewables & Environment
# D2C Fashion
# D2C startup
# AR startup
# Co-working
# Sports startup
# Matrimony
# Defense & Space
# Business Supplies & Equipment
# Oil & Energy
# Company-as-a-Service
# Professional Training & Coaching
# B2B
# D2C jewellery
# Translation & Localization
# Arts & Crafts
# B2B startup
# Sochcast is an Audio experiences company that give the listener and creators an Immersive Audio experience
# B2B Travel
# Manchester, Greater Manchester
# Aviation & Aerospace
# Staffing & Recruiting

# %% [markdown]
# `Comments`
#
# The 'Sector' column contains numerous unique values, many of which are worded differently despite having the same meaning. There are two approaches to address this column:
#
# **1. Maintaining Current Granularity:** This approach involves standardizing the terminology by assigning a single term to synonymous entries and replacing odd or inconsistent entries with either a suitable existing term or 'Not filled'.
#
# **2. Defining Descriptive and Collective Bins:** This method involves categorizing the sectors into broader, descriptive bins. These bins can be defined within the existing 'Sector' column or by creating a new column named 'Sector_Category'. The proposed bins include, but are not limited to, the following categories:
#
#    - Technology & Innovation
#
#    - Health & Wellness
#
#    - Finance & Commerce
#
#    - Consumer Goods & Services
#
#    - Media & Marketing
#
#    - Transportation & Mobility
#
#    - Industrial & Manufacturing
#
#    - Legal & Professional Services
#
#    - Art & Design
#
#    - Education & Training
#
#    - Environmental & Renewable Energy
#
#    - Real Estate & Construction
#
#    - Food & Beverage Industry
#
#    - Social & Community Services

# %% [markdown]
# **Column-5: What_it_does: 1143**
#
# To identify odd entries in the given list of what startups do in India, we need to consider entries that might include:
#
# 1. Missing or NaN values
#
# 2. Entries containing unusual special characters and a word count less than 5
#
# 3. Entries that include a string pattern like $xxxxxxxxxxxx

# %%
def is_odd_activity(activity):
    """
    Function to identify odd entries in the list of startup activities.

    Parameters:
        activity (str): What a startup does.

    Returns:
        bool: True if the activity is considered odd, False otherwise.
    """
    # Criteria for odd entries:
    # - Missing values
    # - Entries containing unusual special characters and a word count less than 5
    # - Entries that include a string pattern like $xxxxxxxxxxxx
    
    # Check for missing values
    if pd.isnull(activity):
        return True    

    # Strip leading and trailing spaces
    activity = activity.strip()

    # Check for empty strings
    if len(activity) == 0:
        return True  
     
    # Check for strings like $xxxxxxxxxxxx
    if re.match(r'^\$[0-9]{1,}$', activity):
        return True
    
    # Check for entries containing unusual special characters and a word count less than 5
    # List of special characters
    special_characters = [
        '&', '@', '#', '$', '%', '^', '*', '!', '?', '(', ')', '-', '_', '=', '+',
        '{', '}', '[', ']', '|', '\\', ':', ';', '"', "'", '<', '>', ',', '.', '/',
        '~', '`'
    ]
    if any(char in activity for char in special_characters) and len(activity.split()) < 5:
        return True
    
    return False

# Filter odd entries in the 'What_it_does' column
odde_c5_21 = df2021['What_it_does'].apply(is_odd_activity)
oddn_c5_21 = df2021[odde_c5_21]['What_it_does'].unique()

# Print the number of odd entries and their details
print(f"Number of odd entries in 'What_it_does' column: {len(oddn_c5_21)}")
print('\nOdd entries:')
for entry in oddn_c5_21:
    print(entry)
# Out:
# Number of odd entries in 'What_it_does' column: 13
#
# Odd entries:
# Tata Digital-backed Curefit
# Vikash Mishra, Mragank Jain
# Plant-based nutraceutical firm
# India's First Icepops Brand
# Small businesses-focused non-banking lender
# Video integrated social-gaming platform
# 24*7 convenience store
# Video-based social commerce startup
# 100% Natural Dog Treats.
# Sustainability for the future.
# World's first cross-border Neobank
# Just-in-time Sales Enablement Platform
# A gig/on-demand staffing company.

# %% [markdown]
# **Column-6: Founders: 1096**
#
# To identify odd entries in the given list of founders of startups in India, we need to consider entries that might include:
#
# 1. Missing or NaN values
#
# 2. Entries containing unusual special characters and a word count less than 2
#
# 3. Entries that include a string pattern like $xxxxxxxxxxxx

# %%
def is_odd_founder(founder):
    """
    Function to identify odd entries in the list of startup founders.

    Parameters:
        founder (str): The name of a startup founder.

    Returns:
        bool: True if the founder entry is considered odd, False otherwise.
    """
    # Criteria for odd entries:
    # - Missing values
    # - Entries containing unusual special characters and a word count less than 2
    # - Entries that include a string pattern like $xxxxxxxxxxxx
    
    # Check for missing values
    if pd.isnull(founder):
        return True    

    # Strip leading and trailing spaces
    founder = founder.strip()

    # Check for empty strings
    if len(founder) == 0:
        return True  
     
    # Check for strings like $xxxxxxxxxxxx
    if re.match(r'^\$[0-9]{1,}$', founder):
        return True
    

    # Check for entries containing unusual special characters and a word count less than 2
    # List of special characters
    special_characters = [
        '&', '@', '#', '$', '%', '^', '*', '!', '?', '(', ')', '-', '_', '=', '+',
        '{', '}', '[', ']', '|', '\\', ':', ';', '"', "'", '<', '>', ',', '.', '/',
        '~', '`'
    ]
    if any(char in founder for char in special_characters) and len(founder.split()) < 2:
        return True
    
    return False

# Filter odd entries in the 'Founders' column
odde_c6_21 = df2021['Founders'].apply(is_odd_founder)
oddn_c6_21 = df2021[odde_c6_21]['Founders'].unique()

# Print the number of odd entries and their details
print(f"Number of odd entries in 'Founders' column: {len(oddn_c6_21)}")
print('\nOdd entries:')
for entry in oddn_c6_21:
    print(entry)
# Out:
# Number of odd entries in 'Founders' column: 1
#
# Odd entries:
# None

# %% [markdown]
# **Column-7: Investor: 938**
#
# To identify odd entries in the given list of investors of startups in India, we need to consider entries that might include:
#
# 1. Missing or NaN values
#
# 2. Entries containing unusual special characters and a word count less than 2
#
# 3. Entries that include a string pattern like $xxxxxxxxxxxx

# %%
def is_odd_investor(investor):
    """
    Function to identify odd entries in the list of investors for startups.

    Parameters:
        investor (str): The investor of a startup.

    Returns:
        bool: True if the investor is considered odd, False otherwise.
    """
    # Criteria for odd entries:
    # - Missing values
    # - Entries containing unusual special characters and a word count less than 2
    # - Entries that include a string pattern like $xxxxxxxxxxxx
    
    # Check for missing values
    if pd.isnull(investor):
        return True    

    # Strip leading and trailing spaces
    investor = investor.strip()

    # Check for empty strings
    if len(investor) == 0:
        return True  
    
    # Check for entries containing unusual special characters and a word count less than 2
    special_characters = [
        '&', '@', '#', '$', '%', '^', '*', '!', '?', '(', ')', '-', '_', '=', '+',
        '{', '}', '[', ']', '|', '\\', ':', ';', '"', "'", '<', '>', ',', '.', '/',
        '~', '`'
    ]
    if any(char in investor for char in special_characters) and len(investor.split()) < 3:
        return True
    
    # Check for entries that include a string pattern like $xxxxxxxxxxxx
    if re.match(r'^\$[0-9]{1,}$', investor):
        return True
    
    return False

# Filter odd entries in the 'Founders' column
odde_c7_21 = df2021['Investor'].apply(is_odd_investor)
oddn_c7_21 = df2021[odde_c7_21]['Investor'].unique()

# Print the number of odd entries and their details
print(f"Number of odd entries in 'Investor' column: {len(oddn_c7_21)}")
print('\nOdd entries:')
for entry in oddn_c7_21:
    print(entry)
# Out:
# Number of odd entries in 'Investor' column: 28
#
# Odd entries:
# CIIE.CO, KIIT-TBI
# None
# http://100x.vc/
# BEENEXT, Orios
# 9Unicorns, ZNL
# $22000000
# $5000000
# Y-Combinator
# Sauce.vc
# CIIE.CO
# ah! Ventures
# Waterbridge, Lumikai
# Auxano, Falcon5
# GIC, Infoedge
# Aqua-Spark
# $1000000
# Fidelity, BlackRock
# velocity.in
# Fidelity, GIC
# HNIs, Angels
# N+1 Capital
# Krafton, Lumikai
# PayU, Google
# Brex, Y-Combinator
# NEVF, AccelNest
# $Undisclosed
# Lightspeed, Sequioa
# 1000000	#REF!

# %% [markdown]
# **Column-8: Amount: 279**
#
# To identify the odd entries in the list of funding amounts to startups in India, we need to consider entries that meet the criteria described below:
#
# 1. Format inconsistency
#
# 2. Non-numeric values
#
# 3. Unusual symbols or standalone special characters

# %%
def odd_amount(amount):
    """
    Function to identify odd entries in the list of funding amounts given to startups.

    Parameters:
        amount (str): The funding amount given to a startup.

    Returns:
        bool: True if the amount is considered odd, False otherwise.
    """
    # Criteria for odd entries:
    # - Format inconsistency
    # - Non-numeric values
    # - Unusual symbols or standalone special characters

    if pd.isnull(amount):
        return True    

    # Strip leading and trailing spaces
    amount = amount.strip()

    # Check for empty strings
    if len(amount) == 0:
        return True
    
    # Check if the amount contains only text and/or special characters
    if re.match(r'^[^\d,]+$', str(amount)):
        return True

    # Check for entries that include a string pattern like $xxxxxxxxxxxx
    if re.match(r'^\$[0-9]{1,}$', str(amount)):
        return True

        # Check for entries that include a string pattern like $x,xxx,xxx,xxx
    if re.match(r'^\$\d{1,3}(,\d{3})*(\.\d+)?$', str(amount)):
        return True

    return False

# Apply the odd_amount function to each element in the 'Amount' column of df2021
odde_c8_21 = df2021['Amount'].apply(odd_amount)

# Filter the DataFrame to get only the rows where 'Amount' column has odd entries
oddn_c8_21 = df2021[odde_c8_21]['Amount'].unique()

# Print the number of odd entries and their details
print(f"Number of odd entries in 'Amount' column: {len(oddn_c8_21)}")
print('\nOdd entries:')
for entry in oddn_c8_21:
    print(entry)
# Out:
# Number of odd entries in 'Amount' column: 275
#
# Odd entries:
# $1,200,000
# $120,000,000
# $30,000,000
# $51,000,000
# $2,000,000
# $188,000,000
# $200,000
# Undisclosed
# $1,000,000
# $3,000,000
# $100,000
# $700,000
# $9,000,000
# $40,000,000
# $49,000,000
# $400,000
# $300,000
# $25,000,000
# $160,000,000
# $150,000
# $1,800,000
# $5,000,000
# $850,000
# $53,000,000
# $500,000
# $1,100,000
# $6,000,000
# $800,000
# $10,000,000
# $21,000,000
# $7,500,000
# $26,000,000
# $7,400,000
# $1,500,000
# $600,000
# $800,000,000
# $17,000,000
# $3,500,000
# $15,000,000
# $215,000,000
# $2,500,000
# $350,000,000
# $5,500,000
# $83,000,000
# $110,000,000
# $500,000,000
# $65,000,000
# $150,000,000,000
# $300,000,000
# $2,200,000
# $35,000,000
# $140,000,000
# $4,000,000
# $13,000,000
# None
# $Undisclosed
# $2000000
# $800000
# $6000000
# $2500000
# $9500000
# $13000000
# $5000000
# $8000000
# $1000000
# Upsparks
# $200000
# $12000000
# $1500000
# $1700000
# $5500000
# $400000
# $150000000
# $4000000
# $100000000
# $500000
# $15000000
# $10000000
# $40000000
# $225000000
# $6700000
# $1300000
# $20000000
# $250000
# $21000000
# $1200000
# $52000000
# $3800000
# $17500000
# $42000000
# $2300000
# $7000000
# $30000000
# $450000000
# $28000000
# $300000
# $3500000
# $8500000
# $25000000
# $3000000
# $37000000
# $370000000
# $700000
# $16000000
# $100000
# $44000000
# $770000
# $125000000
# $35000000
# $50000000
# $4900000
# $145000000
# $22000000
# $70000000
# $6600000
# $32000000
# $24000000
# $725000
# $461000
# Series C
# Seed
# $96000000
# $60000000
# $500000000
# $266000000
# $4500000
# $325000000
# $6500000
# $1600000
# $150000
# $225000
# $85000000
# $235000
# $260000
# $2900000
# $53000000
# $1100000
# $86000000
# $130000
# $111000000
# $265000
# $76000000
# $100,000,000
# $75,000,000
# $3,800,000
# $12,000,000
# $1,600,000
# $260,000
# $1,000,000,000
# $18,000,000
# $20,000,000
# $350,000
# $95,000,000
# $4,100,000
# $5,200,000
# $8,000,000
# $1,400,000
# $2,600,000
# $900,000
# $250,000
# $16,000,000
# $7,000,000
# $11,000,000
# $280,000,000
# $50,000,000
# $14,300,000
# $81,000,000
# $1,300,000
# $8,200,000
# $70,000,000
# $720,000
# $600000
# $9000000
# $1800000
# $330000
# $undisclosed
# $200000000
# $36000000
# $67000000
# $10200000
# $220000000
# $108000000
# $75000000
# $450000
# $660000000
# ah! Ventures
# $45000000
# $3200000
# $370000
# Pre-series A
# $48000000
# $3600000
# $11000000
# $192000000
# $65000000
# $1400000
# $1900000
# $41000000
# $144000000
# $5200000
# $270000000
# $140000
# $250000000
# $320000
# $350000000
# $4800000
# $38000000
# $125000
# $26000000
# $64000000
# $620000
# $900000
# $2600000
# $1,250,000
# $400,000,000
# $1,700,000
# $27,000,000
# $234,000,000
# $460,000,000
# $13,500,000
# $5,100,000
# $195,000,000
# $125,000
# $45,000,000
# $200,000,000
# $7,300,000
# $6,300,000
# $12,500,000
# $24,000,000
# $140,000
# $16,500,000
# $340,000
# $43,000,000
# $150,000,000
# $3300000
# $92000000
# $17000000
# $135000000
# $2100000
# $840000000
# $248000000
# $4300000
# $570000
# $2200000
# $4700000
# $300000000
# $260000000
# $140000000
# $175000000
# $19000000
# $810000
# $7500000
# $600000000
# $90000000
# $5700000
# $6750000
# $78000000
# $5400000
# $115000000
# $255000000
# $18000000
# $570000000
# $550000
# $2700000
# $4200000
# $31000000
# $540000
# $14000000
# $340000
# $
# $6200000
# $750000
# $6300000
# $23000000
# $55000000

# %% [markdown]
# **Column-9: Stage: 32**
#
# To identify the odd entries in the 'Stage' column, we need to determine which entries deviate from typical startup funding stages. Odd entries might include:
#
# 1. Missing or NaN Values
#
# 2. Non standard startup funding stages
#
# 3. Special characters or symbols
#
# 4. Unsual naming conventions

# %%
def odd_stage(stages):
    """
    Function to identify odd entries in the list of funding stages of startups.

    Parameters:
        stages (list): List of funding stages of startups.

    Returns:
        list: A list of odd entries in the funding stages.
    """
    # Criteria for odd entries:
    # - Missing or NaN Values
    # - Non standard startup funding stages
    # - Special characters or symbols
    # - Unsual naming conventions
    
    odd_entries = []
    
    
    valid_stages = [
    'Pre-series A', 'Pre-series', 'Series A', 'Seed', 'Series B', 'Series C', 'Series D', 'Series E', 'Series F', 
    'Series G', 'Series H', 'Series I', 'Series F1', 'Series F2', 'Series A+', 'Series B3', 'Early seed', 'Pre-seed', 
    'Pre-series', 'Pre-series A1', 'Pre-series B', 'Series D1', 'Series A2', 'Seed+', 'Post series A', 'Series B+', 
    'Series A-1', 'Series C, D', 'Pre-series C', 'Seed Funding', 'Angel Round', 'Pre series A', 'Pre series B', 
    'Seed round', 'Pre-seed Round', 'Seed Round', 'Series B2', 'Pre- series A', 'Bridge Round', 'Pre-Series B', 
    'Series E2', 'Seed Investment', 'Mid series', 'Pre series C', 'Seed Round & Series A', 'Seed A', 'Pre Series A', 
    'Pre series A1', 'Pre seed round', 'Pre-Seed', 'Seed funding', 'Pre seed Round', 'Seed fund'
        ]


    for stage in stages:
        # Check for missing values
        if pd.isnull(stage):
            odd_entries.append(stage)
        elif stage not in valid_stages:
            odd_entries.append(stage)
    return odd_entries

# Identify odd entries in 'Stage' column of df2021
odde_c9_21 = odd_stage(df2021['Stage'])

# Get unique odd entries
oddn_c9_21 = set(odde_c9_21)

# Print the number of odd entries and their details
print(f"Number of odd entries in 'Stage' column: {len(oddn_c9_21)}")
print('\nOdd entries:')
for entry in oddn_c9_21:
    print(entry)
# Out:
# Number of odd entries in 'Stage' column: 9
#
# Odd entries:
# $6000000
# $1000000
# Bridge
# $1200000
# PE
# Debt
# Seies A
# $300000
# None

# %% [markdown]
# #### Load LP1_startup_funding2020 Data

# %% [markdown]
# ##### Missing and Duplicate Data Quality Considerations

# %%
# Determine the proportion of missing values
missing_percentage_20 = (df2020.isnull().mean() * 100).round(2)

# Check for duplicated values
duplicate_count_20 = df2020.duplicated(subset=None, keep=False).sum()

# Display duplicated rows if any
duplicated_rows_20 = df2020[df2020.duplicated(subset=None, keep=False)]

# Display Results
print("Proportion of missing values in 2020 data:")
print()
print(missing_percentage_20)
print("\nNumber of duplicated rows in 2020 data:", duplicate_count_20)
print("\nDuplicated rows in 2020 data:")
duplicated_rows_20
# Out:
# Proportion of missing values in 2020 data:
#
# Company_Brand     0.00
# Founded          20.19
# HeadQuarter       8.91
# Sector            1.23
# What_it_does      0.00
# Founders          1.14
# Investor          3.60
# Amount           24.08
# Stage            43.98
# column10         99.81
# dtype: float64
#
# Number of duplicated rows in 2020 data: 6
#
# Duplicated rows in 2020 data:
#     Company_Brand  Founded HeadQuarter                 Sector  \
# 120         Nykaa   2012.0      Mumbai              Cosmetics
# 129     Krimanshi   2015.0     Jodhpur  Biotechnology company
# 145     Krimanshi   2015.0     Jodhpur  Biotechnology company
# 205         Nykaa   2012.0      Mumbai              Cosmetics
# 326        Byju’s   2011.0   Bangalore                 EdTech
# 362        Byju’s   2011.0   Bangalore                 EdTech
#
#                                           What_it_does         Founders  \
# 120  Nykaa is an online marketplace for different b...    Falguni Nayar
# 129  Krimanshi aims to increase rural income by imp...     Nikhil Bohra
# 145  Krimanshi aims to increase rural income by imp...     Nikhil Bohra
# 205  Nykaa is an online marketplace for different b...    Falguni Nayar
# 326  An Indian educational technology and online tu...  Byju Raveendran
# 362  An Indian educational technology and online tu...  Byju Raveendran
#
#                                            Investor       Amount Stage  \
# 120                        Alia Bhatt, Katrina Kaif          NaN  None
# 129  Rajasthan Venture Capital Fund, AIM Smart City     600000.0  Seed
# 145  Rajasthan Venture Capital Fund, AIM Smart City     600000.0  Seed
# 205                        Alia Bhatt, Katrina Kaif          NaN  None
# 326           Owl Ventures, Tiger Global Management  500000000.0  None
# 362           Owl Ventures, Tiger Global Management  500000000.0  None
#
#     column10
# 120     None
# 129     None
# 145     None
# 205     None
# 326     None
# 362     None

# %% [markdown]
# ##### Unique values Data Quality Considerations

# %%
# List all elements in the columns
for i, column in enumerate(df2020.columns):
    print(f'Column-{i + 1}: {column}: {len(df2020[column].unique())}\n', df2020[column].unique())
    print('_'*100)
    print()
# Out:
# Column-1: Company_Brand: 905
#  ['Aqgromalin' 'Krayonnz' 'PadCare Labs' 'NCOME' 'Gramophone' 'qZense'
#  'MyClassboard' 'Metvy' 'Rupeek' 'Gig India' 'Slurrp Farm' 'Medfin'
#  'MasterG' 'Brila 91' 'FoodyBuddy' 'Zomato' 'OurEye.ai' 'Shiprocket'
#  'Pine Labs' 'Moneyboxx Finance' 'EWar' 'SucSEED Indovation'
#  'TaxBuddy.com' 'Awign Enterprises' 'Circle of Angels' 'CoinDCX' 'Glance'
#  'VerSe Innovation' 'Voosh' 'Delhivery' 'Arya' 'Pickrr' 'PhonePe'
#  'Countingwell' 'Callify.ai' 'Hudle' 'Cover it Up' 'BiteSpeed' 'WakeFit'
#  'Sreyas Holistic Remedies' 'Fleeca India' 'M1xchange' 'Exotel'
#  'PagarBook' 'PointOne Capital' 'Ayana' 'Fisdom' 'Tinker Coders'
#  'Infinite Uptime' 'HappyLocate' 'Loop Health' 'NeoDocs' 'The ePlane'
#  'TagMango' 'The New Shop' 'MobiKwik' 'DebugsBunny' 'BHIVE Investech'
#  'Rivigo' 'ZipLoan' 'Swipez' 'Humus' 'Artivatic.ai' 'Prescinto' 'Toppeq'
#  'Bolo Indya' 'Bombay Play' 'FreshToHome' 'KIKO TV'
#  'Atomberg Technologies' 'DealShare' 'Smallcase' 'CueMath' 'Gamerji'
#  '5C Network' 'Ethereum Push Notification Service' 'Mihup' 'RuralBasket'
#  'WayCool Foods' 'Infra.Market' 'Info Edge Venture' 'Clovia' 'Codingal'
#  'CRED' 'Vistaar Finance' "Let's Dive" 'Habitat' 'SAWO Labs' 'Signzy'
#  'KopyKitab' 'Kyt' 'Raskik' 'GetWork' 'Mobile Premier League (MPL)'
#  'Pravasirojgar' 'Omatra Hotels' 'Awign' 'NewsReach' 'Cashfree'
#  'Credgenics' 'GeoIQ' 'Country Delight' 'Quintype' 'CARS24'
#  'Astrogate Labs' 'Power Gummies' 'Cityflo' 'AlgoBulls' 'Inntot'
#  'Ensuredit' 'Shipsy' 'ERPNext' 'LightSpeedAI' 'Grip Invest' 'Unacademy'
#  'Yellow Classes' 'Plum' 'STAGE' 'Nykaa' 'Kaagaz Scanner' 'NIRA' 'Prolixr'
#  "Byju's" 'DaMENSCH' 'SignalX' 'Lancify' 'Krimanshi' 'Instoried'
#  'PlayerzPot' 'Instamojo' 'Turtlemint' 'Arata' 'MPL' 'True Balance'
#  'Thrive' 'Kitchens Centre' 'Prescribe' 'Nepra' 'inFeedo'
#  'Shilpa Sciences' 'Arzooo' 'MindTickle' 'Slice' 'Rapawalk' "Oga Fit's"
#  'LAVAL' 'Stride Ventures' 'BlackSoil' 'Biocon' 'Clientjoy' 'Xpressbees'
#  'GalaxyCard' 'Wellness Forever' 'MoooFarm' 'BitClass' 'Gonuts' 'Uolo'
#  'Kirana King' 'Jade Forest' 'iKure' 'FrontRow' 'Reliance Retail' 'TUBBR'
#  'Ather Energy' 'Routematic' 'LivFin' 'Universal Sportsbiz Pvt Ltd'
#  'Lattu Kids' 'Eggoz' 'Steradian Semiconductors' 'CHARGE+ZONE'
#  'Stones2milestones' 'Udacity' 'AjnaLens' 'Gully Network' 'TurboHire'
#  'Traya' 'Charcoal Eats' 'Mitron TV' 'Svami' 'Dhurnia' 'Expertrons'
#  'Leena AI' 'Bizlog' 'Tamasha.live' 'Fedo' 'FabHotels' 'Freshokartz'
#  'FlexiLoans' 'Agrix' 'BharatAgri' 'FreshtoHome' 'Credable' 'Railofy'
#  'Finova Capital' 'Teachmint' 'Peel-Works' 'Janani' 'Finelistings'
#  'Wellversed' 'Jumbotail' 'Winzo' 'mCaffeine' 'Pocket FM' 'Snackible'
#  'TagZ Foods' 'Genius Teacher' 'Krimanshi Feeds' 'Origo' 'GetVantage'
#  'Betterplace' 'Biddano' 'InVideo' 'Hubilo' 'BASIC Home Loan' 'Ketos'
#  'SUGAR cosmetics' 'Ahaguru' 'Tekion' 'Brighteye Ventures' 'EzeRx'
#  'VitalTech' 'Ultraviolette Automotive' 'Tring' 'Rare Planet' 'GoodGamer'
#  'InnAccel' 'Tiliter' 'Slintel' 'SoOLEGAL' 'HobSpace' 'Supplynote'
#  'Hire Me Car' 'ShopUp' 'Harmonizer India' 'Dukaan' 'CredR' 'Satyukt'
#  'RACEnergy' 'TREAD' 'Anveshan' 'TeaMonk' 'Fleetx' 'ReNEWate' 'Tango Eye'
#  'Avataa Me' 'Arrival' 'Cover Genius' 'Phononic Vibes' 'MikeLegal' 'Clair'
#  'Gourmet Garden' 'Miko' 'Razorpay' 'Ninjacart' 'Wow! Momo'
#  'Pepper Content' 'LIVSPACE' 'Acculi Labs' 'Your MD' 'Antaios' 'Unnati'
#  'Disprz' 'Uni' 'Credit Wise Capital' 'Chargebee'
#  'Reliance Retail Ventures Ltd' 'Winuall' 'Genrobotics' 'Livve' 'Ergos'
#  'Krishitantra' 'PakkaProfile' 'Monet Networks' 'Unocoin' 'Pesto'
#  'NirogStreet' 'Bambrew' 'Omnify' 'Fanball XI' 'Treebo Hotels'
#  'GPS Renewables' 'Public' 'Legal Salah' 'FanPlay' 'ECOSTP' 'Coralogix'
#  'Equiwatt' 'Reliance Retail Ventures' 'Zhangmen' 'AgroWave'
#  'Sapio Analytics' 'Taimei' 'Avanse Financial Services' 'Industry Buying'
#  'Hopscotch' 'Pristyn Care' 'WoodenStreet' 'ACKO' 'Farmers Fresh Zone'
#  'Invento' 'Infurnia' "AnalytIQSports's SuperCric" 'Snowflake' 'GenieTalk'
#  'Classplus' 'Mobile Premier League' 'Fourth Partner Energy' 'Flipkart'
#  'Vivriti Capital' 'InsuranceDekho' 'BestDoc' 'Byju’s' 'Melorra'
#  'Reliance' 'Inflexor Ventures' 'Pandorum' 'SpeakIn' 'LetsUp' 'Newsreach'
#  'Dream11' 'JetSynthesys' 'Vesta Space Technology' 'Dozee' 'Rebel Foods'
#  'Ketto' 'Suryoday' 'SucSEED' 'Strata' '3one4 Capital' 'WE-Hub' 'Vicara'
#  'Gaana' 'EM3 Agri' 'Odwen' 'Fasal' 'Trukky' 'BankBazaar' 'Specsmakers'
#  'Grinntech' 'CreditMantri' 'Chai Waale' 'Deepsync' 'ConnectedH' 'QShala'
#  'Pitstop' 'Customfit ai' 'Nirmata' 'Oga Fit' 'ShipsKart' 'SquadStack'
#  'Financepeer' 'Cashify' 'Etrio' 'Codeyoung' 'StayQrious'
#  'Sunstone Eduversity' 'Infilect' 'MobiGarage' 'Samunnati'
#  'WeInnovate Biosolutions' 'Yummy Corp' 'Clairvolex' 'Assiduus' 'Brinton'
#  'AFK Gaming' 'Infarm' 'Zuper' 'Origa' 'GullyBuy Software' 'Recordent'
#  'Penny' 'Onsitego' 'Precily' 'SmartClean' 'ClanConnect' 'Servify'
#  'ShareChat' 'Rephrase.ai' 'EkAnek' 'Cub McPaws' 'Zimyo' 'PumPumPum'
#  'Burgerama' 'Moms Co' 'DillyHub' 'FPL Technologies' 'FITTR' 'Illumnus'
#  'CashKaro' 'Newton School' 'Airmeet' 'Observe ai' 'InCred' 'Toppr'
#  'CarTrade' 'LEAD School' 'Lido Learning' 'Apna.co'
#  'Quintype Technologies' 'Dunzo' 'Entropik' 'Livspace' 'WinZO' 'SenseHawk'
#  'Eloelo' 'Aibono' 'BuildPan' 'Homelane' 'MyGlamm' 'Aviom' 'Flinto'
#  'WayCool' 'YAP' 'Big Bang Boom Solutions' 'GUVI' 'BluSmart'
#  'Cell Propulsion' 'Spoonshot' 'Pulse' 'Groww' 'i3 Systems' 'SOAL'
#  'OckyPocky' 'Hippo Video' 'Hasura' 'Qapita' 'Sunday' 'Gamezop' 'Phool.co'
#  'Chiratae Ventures' 'MedLife' 'IDfy' 'Bira91' 'Max wholesale'
#  'Craftsvilla' 'MechMocha' 'Mindhouse' 'DeepSync' 'Eruditus' 'Gradeup'
#  'Tracxn' 'Purple Style Labs' 'ProPhysio' 'Flickstree' 'Settl' 'Fanspole'
#  'Sarva' 'Univ.ai' 'PurohitJi' 'CredoLab' 'Brick&Bolt' '6Degree' 'Exprs'
#  'Bikayi' 'Virtual Forest' 'The Health company' 'TrulyMadly Matchmakers'
#  'TrueFan' 'Avail Finance' 'The Money Club' 'Virohan' 'OneCode'
#  'Verloop.io' 'Otipy' 'Evage' 'Trell' 'Captain Fresh' 'Pixxel'
#  'Habbit Health' 'SmarterBiz' 'Able Jobs' 'Vieroots' 'Stack Finance'
#  'Masai School' 'Mitron' 'Daalchini' 'Suno India' 'LendingKart'
#  'Text Mercato' 'Eden Smart Homes' 'GrayQuest' 'BigHaat' 'CityCash'
#  'HomeLane' 'HungerBox' 'DaveAI' 'Eduvanz' 'DocSumo' 'CUSMAT' 'Chingari'
#  'Data Sutram' 'Wobot Intelligence' 'DrinkPrime' 'Infeedo'
#  'Probus Smart Things' 'CrowdPouch' 'Hevo' 'BigSpoon Foods' 'DatStop'
#  'IPHM Services' 'Wellcure' 'VilCart' 'Firescore' 'BulBul'
#  'Pickright Technologies' 'Muse Wearables' 'SATYA Microcapital'
#  'WYN Studio' 'Entri' 'Snack Amor' 'MPowered' 'Leap Club' 'Gigforce'
#  'Vegrow' 'Finn' 'Bijnis' 'iNurture' 'StyleDotMe' 'Ripsey' 'ThriveFNC'
#  'Vedantu' 'Magicpin' 'Procol' 'Yumlane' 'Crio' 'Openapp'
#  'uFony Services Pvt ltd' 'Protinus Fashion Networking Pvt Ltd' 'Uable'
#  'ParkSmart' 'IncNut Digital' 'GigIndia' 'Specsmaker' 'Piggy Ride' 'NOTO'
#  'Cuemath' 'Cars24' 'Earth Energy EV' 'Green Cure' 'Blue Sky Analytics'
#  'Edhusk' 'Decentro' 'Zolostays' 'Frontier Markets' 'Brainwired'
#  'Aye Finance' 'Paper Boat' 'Ken42' 'Forbidden Foods'
#  'Universal Sportsbiz' 'Gobbly' 'Aerostrovilos' 'Bulk MRO' 'Inspektlabs'
#  'Zetwerk' 'ChitMonks' 'Walrus' 'Arth Designbuild' 'goDutch' 'Rusk Media'
#  'Bold Care' 'Samosa Party' 'High Street Essentials' 'Fullife' 'Oziva'
#  'Aether Biomedical' '91springboard' 'Yulu' 'Milkbasket' 'MergerDomo'
#  'GoMechanic' 'Milk Mantra' 'Myglamm' 'Drishti Technologies' 'Instasolv'
#  'GoldenPi' 'Peppermint' 'Jai Kisan' 'Agro2o' 'LetsTransport'
#  'GabbarDeals' 'Crimson Healthcare' 'Biomoneta' 'Edvizo' 'Drum Food'
#  'Innoviti' 'Jiffy ai' 'Postman' 'F5' 'Waycool' 'Myelin Foundry'
#  'Ameliorate Biotech' 'Hapramp' 'MyKaam' 'HealthPlix' 'YoloBus'
#  'iNurture Education' 'Pocket52' 'QuaQua' 'Crofarm' 'Timios'
#  'Wooden Street' 'Rentmojo' 'Credgencies' 'Knorish' 'Vahak' 'Nutrova'
#  'Cube Wealth' 'IVF Access' 'Hoi Foods' 'Ola Financial Services' 'Awifs'
#  'Swiflearn' 'Remedo' 'Blowhorn' 'Toch' 'Gram Cover' 'Coin DCX'
#  'HomeCapital' 'Euler Motors' 'Riskcovry'
#  'NWNT (No Worry No Tension Healthcare)' 'Voicezen' 'Credit Mantri'
#  'Xtracap' 'Vakilsearch' 'Khatabook' 'Indian School Finance Company'
#  'Juicy Chemistry' 'DeepTek' 'Stepathlon Lifestyle' 'Sindhuja Microcredit'
#  'Tesco Charge Zone' 'Intello Labs' 'SirionLabs' 'GroCurv' 'Refrens'
#  'Spyne' 'Docsapp' 'Phable' 'Generic Aadhaar' 'Nium' 'Mintoak' 'VestSpace'
#  'Blackbuck' 'Vernacular ai' 'Clover' 'Varthana' 'Codeninja'
#  'MetaMerphoSys' 'Rooter' 'Aker Foods' 'Sascan Meditech pvt ltd'
#  'DailyHunt' 'Pratilipi' 'Biryani By Kilo' 'Consure Medical' 'Tessol'
#  'News Reach' 'RoomSoom' 'Pedagogy' 'Medlife' 'Qin1' 'MYSUN' 'ShopX'
#  'NewsBytes' 'Wagonfly' 'Convosight' 'Fittr' 'AsknBid'
#  'Finaureus Technologies' 'Daily Ninja' 'Guvi Geek Network Pvt Ltd'
#  'LoadShare' 'Indusface' 'DMI Group' 'Spintly' 'Credr' 'Bijak' 'Bugworks'
#  'Yap' 'UzhavarBumi' 'Tattva' 'Pariksha' 'NoBroker' 'Box8' 'Capital Float'
#  'ITILITE' 'Morning Context' 'Aavenir' 'Savvy Co op' 'BLive'
#  'Yellow Messenger' 'Ewar' 'Setu' 'Wellthy Therapeutics' 'Locale ai'
#  'FarEye' 'Porter' 'SugarBox' 'Big Basket' 'Amica' 'Fingerlix' 'Plop'
#  'Zupee' 'DeHaat' 'Swiggy' 'Akna Medical' 'RaRa Delivery' 'JusPay'
#  'Obviously AI' 'Fingpay' 'Recko' 'Furlenco' 'Mera Cashier' 'Camp K12'
#  'MedGenome' 'Samadhan' 'SaScan' 'CureFit' 'Nimesa' 'Design X'
#  'Driftly Electric' 'Imstrong' 'Rupifi' 'SnackAmor' 'Zealthy' 'NuNu TV'
#  'QTalk' 'Shadez' 'Excess2Sell' 'Stanplus' 'Univariety' 'Peel Works'
#  'CoreStack' 'Agnikul' 'Fintso' 'Smart Coin' 'ZunRoof' 'Shop101'
#  'OM Bhakti' 'Lal10' 'Anaxee Digital Runner' 'CollegeKhabri'
#  'Ola Electric' 'Multi Living' 'FamPay' 'UnboxRobotics Labs' 'Karbon Card'
#  'Innerchef' 'Epigamia' 'StyleNook' 'Callido Learning' 'Soxytoes'
#  'Salesken' 'Leap Finance' 'Sleepy Owl' 'Tricog' 'GogoBus'
#  'Spaciya Consultants' 'Bounce' 'Neeman' 'Chqbook' 'SMEcorner' 'Oda Class'
#  'Spinny' 'goStops' 'Umeed Housing' 'Vogo' 'Flick Stree' 'Qure ai'
#  'MinionLabs' 'Josh Talks' 'PhoneParLoan' 'RailYatri' 'Pepper' 'iMerit'
#  'BharatPe' 'Invideo' 'AvalonMeta' 'Near Store' 'ElecTorq'
#  'Prayaan Capital' 'Sanfe' 'Go Desi' 'Whatfix' 'Zvesta' 'Digit Insurance'
#  'Yolo' 'SmartVizX' 'MaxWholesale' 'Carbon Clean' 'Genius Corner'
#  'PlanetSpark' 'CamCom' 'Simsim' 'Shuttl' 'HooLiv' 'ClassMonitor' 'Friyey'
#  'Oga' 'CYFIRMA' 'Paytm money' 'Nova Credit' 'CodingNinjas' 'HempStreet'
#  'MoEngage' 'Chaayos' 'PetPooja' 'Altor' 'Pepperfry' 'FirstCry' 'Byju'
#  'WorkIndia' 'Qyuki' 'Leap India' 'Picxy' 'NEETprep' 'Dot Pvt. Ltd'
#  'Kuku FM' 'SuperMoney' 'AlphaVector' 'Fox Capital' 'Tribe Theory'
#  'Embibe' 'Oye! Rickshaw' 'Seal Professional' 'Sprinng Foods' '1MG'
#  'Aagey' 'Doubtnut' 'AdonMo' 'Kisan Network' 'Unotech' 'CureSkin'
#  'WizKlub' 'Interviewbit' 'MoneyTap' 'Uniplatform Tech' 'INdwealth'
#  'Bizongo' 'AppsFlyer' 'Konfinity' 'Nupay' 'LogiNext' 'Samosa Singh'
#  'Crysta' 'Eupheus Learning' 'Park+' 'Goodmylk' 'SmartKarrot' 'Skylo'
#  'Tea Trunk' 'Zoomcar' 'Samya AI' 'Kristal AI' 'Invento Robotics'
#  'Sabse Sasta Dukaan' 'Fitphilia' 'Medicus' 'Monech' 'Teach Us' 'Dealberg'
#  'Phenom People' 'Extra Edge' 'Capital Quotient' 'Karfa' 'Zinier'
#  'ProEves' 'Toddle' 'Aesthetic Nutrition' 'TechnifyBiz' 'Wysh' 'Keito'
#  'Klub' 'Aadhar' 'IncubateHub' 'Rage Coffee' 'Skilancer'
#  'Harappa Education' 'Rheo' 'Axio Biosolutions' 'Techbooze' 'PayMart'
#  'Testbook' 'FabAlley' 'HaikuJAM' 'Mamaearth' 'Rentomojo' 'Generico'
#  'HighRadius' 'Chai Kings' 'Shiksha' 'Super Surfaces' 'Quicko'
#  'Satin Creditcare' 'XpressBees' 'FarmERP' 'Wealth Bucket' 'Fashor'
#  'Leverage Edu' 'EpiFi' 'Purplle' 'Pando']
# ____________________________________________________________________________________________________
#
# Column-2: Founded: 27
#  [2019. 2018. 2020. 2016. 2008. 2015. 2017. 2014. 1998. 2007. 2011. 1982.
#  2013. 2009. 2012. 1995. 2010. 2006. 1978.   nan 1999. 1994. 2005. 1973.
#  2002. 2004. 2001.]
# ____________________________________________________________________________________________________
#
# Column-3: HeadQuarter: 78
#  ['Chennai' 'Bangalore' 'Pune' 'New Delhi' 'Indore' 'Hyderabad' 'Gurgaon'
#  'Belgaum' 'Noida' 'Mumbai' 'Andheri' 'Jaipur' 'Ahmedabad' 'Kolkata'
#  'Tirunelveli, Tamilnadu' 'Thane' None 'Singapore' 'Gurugram' 'Gujarat'
#  'Haryana' 'Kerala' 'Jodhpur' 'Jaipur, Rajastan' 'Delhi'
#  'Frisco, Texas, United States' 'California' 'Dhingsara, Haryana'
#  'New York, United States' 'Patna'
#  'San Francisco, California, United States' 'San Francisco, United States'
#  'San Ramon, California' 'Paris, Ile-de-France, France'
#  'Plano, Texas, United States' 'Sydney'
#  'San Francisco Bay Area, Silicon Valley, West Coast' 'Bangaldesh'
#  'London, England, United Kingdom' 'Sydney, New South Wales, Australia'
#  'Milano, Lombardia, Italy' 'Palmwoods, Queensland, Australia' 'France'
#  'San Francisco Bay Area, West Coast, Western US'
#  'Trivandrum, Kerala, India' 'Cochin' 'Samastipur, Bihar'
#  'Irvine, California, United States' 'Tumkur, Karnataka'
#  'Newcastle Upon Tyne, Newcastle upon Tyne, United Kingdom'
#  'Shanghai, China' 'Jiaxing, Zhejiang, China' 'Rajastan' 'Kochi'
#  'Ludhiana' 'Dehradun' 'San Franciscao' 'San Francisco'
#  'Tangerang, Jawa Barat, Indonesia' 'Berlin' 'Seattle' 'Riyadh' 'Seoul'
#  'New York' 'Bangkok' 'Kanpur' 'Chandigarh' 'Warangal' 'Hyderebad'
#  'Odisha' 'Bihar' 'Goa' 'Tamil Nadu' 'Uttar Pradesh' 'Bhopal' 'Banglore'
#  'Coimbatore' 'Bengaluru']
# ____________________________________________________________________________________________________
#
# Column-4: Sector: 303
#  ['AgriTech' 'EdTech' 'Hygiene management' 'Escrow' 'Networking platform'
#  'FinTech' 'Crowdsourcing' 'Food & Bevarages' 'HealthTech'
#  'Fashion startup' 'Food Industry' 'Food Delivery'
#  'Virtual auditing startup' 'E-commerce' 'Gaming' 'Work fulfillment'
#  'AI startup' 'Telecommunication' 'Logistics' 'Tech Startup' 'Sports'
#  'Retail' 'Medtech' 'Tyre management' 'Cloud company' 'Software company'
#  'Venture capitalist' 'Renewable player' 'IoT startup' 'SaaS startup'
#  'Aero company' 'Marketing company' 'Retail startup' 'Co-working Startup'
#  'Finance company' 'Tech company' 'Solar Monitoring Company'
#  'Video sharing platform' 'Gaming startup' 'Video streaming platform'
#  'Consumer appliances' 'Blockchain startup' 'Conversational AI platform'
#  'Real Estate' 'SaaS platform' 'AI platform' 'Fusion beverages' 'HR Tech'
#  'Job portal' 'Hospitality' 'Digital Media' 'Dairy startup'
#  'Content management' 'Spacetech' 'Transportation' 'Trading platform'
#  'AI Company' 'Photonics startup' 'Entertainment' 'Cosmetics'
#  'Scanning app' 'Skincare startup' 'Food and Beverages'
#  'Biotechnology company' 'FoodTech' 'Proptech' 'CleanTech'
#  'Fitness startup' 'Healthcare' 'PaaS startup' 'Beverages' 'Social Media'
#  'Automobiles' 'Deeptech' 'EV startup' 'AR/VR startup'
#  'Recruitment startup' 'QSR startup' 'Video platform' 'Edtech'
#  'Fertility tech' 'Luxury car startup' 'FM' 'Food' 'Nutrition sector'
#  'Tech platform' 'Video' 'Retail Tech' 'HeathTech' 'Sles and marketing'
#  'LegalTech' 'Car Service' 'Bike marketplace' 'Agri tech' 'Reatil startup'
#  'AR platform' 'Consumer Goods' 'Content marketplace' 'Interior Design'
#  'Rental space' 'Soil-Tech' 'Ayurveda tech' 'Packaging solution startup'
#  'Cleantech' 'Sanitation solutions' 'HealthCare' 'Home Design'
#  'InsureTech' 'AI Startup' 'Solar solution' 'Jewellery startup'
#  'Multinational conglomerate company' 'Deeptech startup' 'Social Network'
#  'Publication' 'Tech' 'Fashion' 'Finance' 'Venture capital'
#  'Entreprenurship' 'Food devlivery' 'Warehouse' 'Online financial service'
#  'Eyeglasses' 'Battery design' 'Online credit management startup'
#  'Beverage' 'TravelTech' 'Agriculture' 'Startup laboratory'
#  'Personal care startup' 'Customer service company' 'SaaS\xa0\xa0startup'
#  'Marketing startup' 'Service industry' 'Social media' 'AI' 'Jewellery'
#  'AR startup' 'HR Tech startup' 'Automotive Startup' 'Food Startup'
#  'EdTech Startup' 'Car Trade' 'EdtTech' 'Manufacturing' 'AI Platform'
#  'Automation' 'Solar SaaS' 'WL & RAC protection' 'Social commerce'
#  'Home interior services' 'Agritech startup' 'API platform' 'Deep Tech'
#  'Electricity' 'Automotive company' 'FMCG' 'Insurance Tech'
#  'Video personalization' 'Software Company' 'Biomaterial startup' 'Health'
#  'IT' 'Craft Beer' 'Healthtech' 'Education' 'Investment'
#  'Linguistic Spiritual' 'Construction' 'Battery manufacturer'
#  'Nano Distribution Network' 'AI health' 'Dating app' 'Media' 'Fintech'
#  'Healthcare/Edtech' 'Social Commerce' 'Agritech/Commerce' 'Mobility tech'
#  'Social e-commerce' 'Food & Logistics' 'SpaceTech' 'Nutrition Tech' 'HR'
#  'IoT' None 'Agritech' 'Interior design' 'Foodtech' 'AR/VR' 'Appliance'
#  'HR tech' 'Food tech' 'Mental Health' 'Ecommerce' 'Solar Solution' 'SaaS'
#  'Automobile' 'B2B marketplace' 'Fashion Tech' 'Nutrition tech'
#  'Health & Wellness' 'Cloud Kitchen' 'IoT/Automobile' 'Eye Wear'
#  'Digital tech' 'Data Intelligence' 'Co-living' 'Food & Beverages'
#  'Automotive' 'B2B' 'Defense tech' 'Marketplace' 'Construction tech'
#  'Nutrition' 'Coworking' 'Micro-mobiity' 'Auto-tech' 'Beauty' 'Robotics'
#  'Yoga & wellness' 'Logitech' 'Med Tech' 'Life sciences'
#  'Retail Aggregator' 'Deep Tech AI' 'Biotech' 'Blockchain' 'HrTech'
#  'Mobility/Transport' 'Travel' 'Rental' 'AI & Debt' 'SaaS/Edtech'
#  'Transport' 'Co-working' 'Insurtech' 'Cryptocurrency' 'Automotive tech'
#  'Legal' 'Fitness' 'EV' 'Supply chain, Agritech' 'Pharma'
#  'Insurance technology' 'Foodtech & Logistics' 'Housing' 'Pharmaceutical'
#  'Data Analytics' 'Investment Tech' 'Financial Services' 'Biopharma'
#  'Dairy' 'Beauty & wellness' 'Travel & SaaS' 'Tourism & EV' 'Media Tech'
#  'Location Analytics' 'E store' 'Data Science' 'Insurance'
#  'Health and Fitness' 'Technology' 'Interior & decor' 'eMobility'
#  'Automation tech' 'Media & Networking' 'E-market' 'AI & Data science'
#  'Travel tech' 'Automotive and Rentals' 'E-tail' 'Accomodation'
#  'AI & Media' 'Machine Learning' 'Content Marktplace' 'Visual Media'
#  'Hygiene' 'VR & SaaS' 'Sales & Services' 'AI & Deep learning'
#  'Housing & Rentals' 'Estore' 'Marketing' 'E tailor' 'E-mobility'
#  'Ad-tech' 'Neo-banking' 'Transport Automation' 'Techonology'
#  'Transport & Rentals' 'AI Robotics' 'Preschool Daycare' 'Food diet'
#  'B2B Agritech' 'E-connect' 'Tech hub' 'Consultancy' 'Pharmacy'
#  'Deisgning' 'Taxation' 'Automobile Technology']
# ____________________________________________________________________________________________________
#
# Column-5: What_it_does: 990
#  ['Cultivating Ideas for Profit'
#  'An academy-guardian-scholar centric ecosystem which provides state of the art technological solutions.'
#  'Converting bio-hazardous waste to harmless waste'
#  'Escrow-as-a-service platform'
#  'Gramophone is an AgTech platform enabling access to agri inputs and powering efficient farm management.'
#  'qZense Labs is building the next-generation IoT solution for fresh food quality assessment and management.'
#  'MyClassboard is a full-fledged School / College Management Software.'
#  'AI driven networking platform for individuals and organisations which aims to provided a seamless end to end networking experience.'
#  'Rupeek is an online lending platform that specializes in credit risk, gold loans, and personal loans.'
#  'GigIndia is a marketplace that provides on-demand work completion for companies through a gig workforce of jobseekers.'
#  'Slurrp Farm is a children health food brand.'
#  'Medfin is a Discovery platform for medical procedures and financing.'
#  'MasterG is a design and skill development organisation.'
#  'Bira 91 is a craft beer company.'
#  'FoodyBuddy is a online food delivery portal'
#  'Zomato is a food delivery and restaurant discovery site that provides information and reviews about restaurants'
#  'Video intelligence solution for Enterprise Standard Operating Procedures Monitoring and Quality Control, leveraging CCTV infrastructure.'
#  'Shiprocket helps online retailers simplify their shipping by providing a delightful post purchase experience to their consumers.'
#  'A merchant platform company that provides financing and last-mile retail transaction technology to merchants.'
#  'MONEYBOXX FINANCE LTD is committed to providing easy access to financing to the deserving micro enterprises in the tier 2 and tier 3 cities of India'
#  'EWar Games is a e-sports and real-time gaming start-up.'
#  'SucSEED INDOVATION FACILITATES ACCESS TO CAPITAL FOR DEEP TECH STARTUPS TO INNOVATE, SCALE & GROW'
#  'TaxBuddy for any tax related issues.'
#  'Operations and manpower outsourcing startup'
#  'Circles of Angels aims to solve this issue through the creation of a funding network that makes impact funding accessible to everyone.'
#  'CoinDCX is a company that specializes in crypto-enabled financial services.'
#  'Glance is a screen zero platform that consumers use across connected devices to experience the Internet.'
#  'Owner of Dailyhunt App and I-Pay'
#  "Building India's largest digital food service brand"
#  'Delhivery is a supply chain services company that provides products and services to build trust and improve the lives of consumers.'
#  '"Simplifying Agribusiness" Throughout Agri-Supply chain, FPO Market Linkages, Market Research, Implementation'
#  'Pickrr is an on-demand first mile logistics company'
#  'PhonePe is a mobile payment application that enables users to transfer money instantly.'
#  'An interactive Maths app, Countingwell breaks Maths concepts into short, simple modules that get kids learning with the least amount of screen time.'
#  'Callify.ai is a Voice-Based Candidate Screening & Engagement platform for Talent Acquisition teams.'
#  'Hudle is a sports & fitness discovery & booking platform with 300+ sports venues and sports events/tournaments available for booking.'
#  'Online portal that churns out high quality products'
#  'Chat-based commerce for E-commerce brands'
#  'Wakefitkart is a mattress manufacturing company'
#  'Sreyas Holistic Remedies operates a chain of dermatologist clinics under the brand name of Oliva'
#  'FLEECA is a Tyre Care Provider company.'
#  'M1 an online exchange for TReDS set up under the approval RBI to facilitate discounting of invoices on a PAN India basis.'
#  'Exotel provides cloud telephony services such as virtual phone numbers and telephony applications for small and medium enterprises in India.'
#  "Staff's Salary, Work & Attendance Management Application"
#  'Pre-seed/Seed focussed VC investor'
#  'Ayana Renewable Power is an Indian renewable energy platform'
#  'Fisdom is a fintech company that offers investment advisory services through an application.'
#  'Tinker Coder is a LIVE Online Platform through which kids will learn the art of coding'
#  'The industrial Internet platform that harnesses the power of big data & predictive analytics for data-driven decision making.'
#  "HappyLocate is India's first One Stop Relocation Platform, transforming the way Employee Relocations are managed"
#  'PhonePe is a mobile payments application that allows the user to transfer money instantly.'
#  'Loop Health is bringing ease and choice to patients seeking major medical treatments.'
#  'Neodocs analyses medical reports and provides personalised health recommendations remotely.'
#  'Transforming the mobility landscape using aerial transport.'
#  'TagMango is a marketing and advertising app that helps influencer, and brands to partner with individuals.'
#  'The New Shop is a chain of high speed retail stores'
#  'MobiKwik is India’s leading fintech platform, operating businesses in consumer payments, payment gateway, and financial services.'
#  'DebugsBunny is the best Kids Coding Platform where kids are taught to code online by our expert teachers.'
#  "BHIVE is Bangalore's (India) largest Coworking space that allows entrepreneurs to take their ideas to the next level."
#  'Rivigo is a technology-enabled logistics platform provider that offers transport services.'
#  'ZipLoan is a online lending platform'
#  'Swipez is a payment collection platform.'
#  'Farmgate to Retail outlet Agri-Fresh produce supply chain'
#  "Artivatic's patent pending technology solves complex problems in Insurance for On-boarding, Fraud, Risk Profiling, Underwriting & claims."
#  'Prescinto provides solutions for solar monitoring and analytics solutions.'
#  'SaaS-based equity management platform'
#  'Bolo Indya is a short video & commerce platform. It allows users to create, watch and share videos & discover and avail services.'
#  'Bombay Play is a Card and Toy Company Making games for India.'
#  'Freshtohome is an e-commerce platform for fresh and chemical-free seafood.'
#  'KIKO TV is an AI-based short live video e-commerce platform.'
#  'Atomberg Technology aspires to be the "Tesla" of the world of household appliances'
#  'DealShare is a Social Commerce Startup'
#  'Changing how India invests in equities'
#  'Cuemath is an engaging ‘learning-by-doing’ methodology for students with face-to-face sessions from highly-trained Cuemath teachers.'
#  'Gamerji is an online esports gaming platform where tournaments are created for different games such as PUBG, COD, Free Fire etc.'
#  "5C is India's first Diagnostics Network, making Radiodiagnosis more Accessible, Affordable and Accurate"
#  'EPNS is a decentralized notification protocol'
#  'Intelligence-based personal mobile assistant app'
#  'Naturally grown and healthy products directly from farmers.'
#  'WayCool has adopted a tech-enabled supply chain approach to produce staples like rice, dairy, and value added products.'
#  'Hella Infra Market develops an online procurement marketplace intended to serve the real estate and construction materials industry.'
#  'Info Edge provides online recruitment, matrimonial and real estate classifieds, and related services.'
#  'Clovia is the online lingerie retailer'
#  'Coding education platform for K-12 students'
#  'CRED is a members-only app that rewards the user with exclusive rewards for paying credit card bills.'
#  'The preferred full range Financial Services provider to the Small Business segment focused on rural and semi urban markets.'
#  'A platform for remote employee engagement and building team culture'
#  'Habitat, a social learning edtech platform for civil service aspirants'
#  'Providing Secure Authentication solutions to Apps and Websites. Eliminating Passwords and OTPs for a seamless User Experience.'
#  "Signzy are creating 'building blocks for a Digital Trust system."
#  'Kopykitab is an India-based digital library that provides eBooks, and digital content in school and higher education.'
#  'Holistic education for every child | Individual and small group live classes for ages 5 - 15 years'
#  "All new fusion-flavour fruit juices with the goodness of coconut and taste of India's finest fruits."
#  'GetWork is a campus recruiting platform to post your jobs and hire across dozens of colleges at once.'
#  'Mobile Premier League is a skill-based eSports platform used to offer cash prizes while playing games.'
#  'Initiative for blue-collar job workers'
#  'Omatra is very new hotel management firm recently registered as Omatra Hospitality Services Private Limited.'
#  'NewsReach India offers partner publications a digital footprint and monetisation of their content via advertisements.'
#  'Cashfree is a payments and banking technology company that enables businesses in India to collect payments online and make payouts.'
#  'Credgenics is a tech-enabled platform backed by Titan Capital, helping fintech lenders and Banks in their critical NPA reduction'
#  'Map-based intelligent platform with single-click access to street-level location data - demographics, competitions, movements - for retail.'
#  'Country Delight produces and distributes milk intended to provide good quality and unadulterated milk at doorstep.'
#  'A technology company that focus on building a suite of digital publishing solutions to simplify content creation, distribution, audience engagement'
#  'CARS24 is an India-based platform for selling used cars.'
#  'Astrogate Labs provides high-quality products related to space infrastructure.'
#  'Power Gummies are a team of passionate givers who are dedicated to catering nutritional supplements'
#  'Cityflo is an urban transportation app that provides comfortable and economical buses for daily commute.'
#  'Algobulls is a state-of-the-art Trading Platform where customers are provided with Fully Automated Algorithmic Trading'
#  'Inntot Technologies, is a technology driven company.'
#  'ENSUREDIT enables and empowers end customers and Insurance Intermediaries with AI-based product platforms for transformational customer experience.'
#  "Shipsy's platform enables data driven decision making enhancing visibility and operational efficiency for Supply Chain industry"
#  'ERPNext is an Open Source, Online ERP solution which includes Accounting, CRM, Inventory, Purchasing, HR, Support and a lot more.'
#  'Developer of an optoelectronic processor designed to accelerate AI computations.'
#  'Grip is an investment platform that allows retail investors to make small ticket investments in physical assets that earn lease income.'
#  'Unacademy is an online learning platform providing educational content such as video lectures and examinations.'
#  'New-age fun-learning platform for kids.'
#  'High quality health insurance and health benefits'
#  'STAGE is an Indian language content platform for artist-led entertainment.'
#  'Nykaa is an online marketplace for different beauty and wellness products.'
#  'Kaagaz Scanner is the Indian replacement to banned Cam Scanner App.'
#  'NIRA promotes financial inclusion by creating simple, transparent products that empower individuals to live a life of choice and freedom.'
#  'A premium skincare brand committed towards building innovative skin care wellness.'
#  "BYJU'S is an educational technology company that develops personalized learning programs for K-12 students."
#  "DaMENSCH is a designer and seller of men's apparel."
#  'SignalX offers an artificial intelligence-powered SaaS platform'
#  "Lancify is building the world's strongest young workforce"
#  'Krimanshi aims to increase rural income by improving the productivity of Indian cattle with better quality feed.'
#  'Instoried is an augmented writing platform which improves customer interest and engagement.'
#  'Favorite fantasy cricket, football & kabaddi leagues online to win daily cash and prizes'
#  'Instamojo is an on-demand payments platform that enables entrepreneurs to build, manage, and grow their business online.'
#  'Turtlemint has built Indian personalized insurance platform'
#  'Arata is an e-commerce site for beauty products and cosmetics.'
#  'True Balance is a digital wallet that enables users to access utility bill payment and other financial products.'
#  'Thrive is all-in-one restaurant ordering suite for table ordering, pickup, and delivery with marketing in-built.'
#  'Kitchens Centre offers turnkey solutions to cloud kitchens.'
#  'Provide online services to patients by leveraging WhatsApp.'
#  'NEPRA Resource Management provides waste management solutions in India.'
#  'inFeedo is a predictive people analytics company helping 300,000+ employees in 100+ companies make their voice feel heard and valued.'
#  'Shilps Sciences is a healthtech platform that claims to have solved gene editing by accelerating single gene cell applications.'
#  'B2B retail tech platform transforming 300,000+ SMEs in electronics space with its flagship "Go Store" product'
#  "MindTickle offers the industry's most comprehensive sales readiness solution for closing knowledge and skill gaps in customer-facing teams."
#  'Slice is a card for first-time credit card users. They are inventing the future of finance for young Indians'
#  'Rapawalk is an online brand that offers a personalized service of creating your own shoes.'
#  'The new-age home workout app that gives you an unmatched boutique digital fitness studio experience.'
#  'Laval Cosmetics, affordable makeup for all ages'
#  'Stride Ventures is a venture capital firm in India which aims to invest in innovative startups across the country.'
#  'Blacksoil Advisory is an independent boutique advisory firm.'
#  'Biocon is a healthcare and technology, company focused on biotechnology.'
#  'Client Management Software For Modern Agencies.'
#  'Xpressbees is an e-commerce logistics company that provides reliable logistics solutions to its partners.'
#  'Mobile based Instant credit card. | Easiest way to get a credit card. Get one in 3 minutes'
#  'Wellness Forever is the one-stop destination for wellness'
#  'MoooFarm is an information technology company that bridges the technology gap to help marginalized dairy farmers.'
#  'BitClass is a PaaS solution which helps teachers set up their independent live classes'
#  'Personalised Video shoutouts from favourite celebrity.'
#  'Uolo Technology is founded by paranoid parents who want to make a difference to preschool experience.'
#  'A revolutionary idea of standardization, digitization & centralization to traditional Grocery system.'
#  'NATURALLY THE BEST From zero artificial ingredients in our drinks to the way they make you feel, we bring you a bespoke range of natural mixers.'
#  'iKure is a social enterprise that delivers primary healthcare and wellness & prevention services to communities in India'
#  'Comprehensive courses, taught by idols.'
#  'Reliance Retail Ventures Limited is a subsidiary company of Reliance Industries Limited.'
#  "World's First Personal Social Network"
#  'Ather Energy is a manufacturer of electric scooters.'
#  'Vision is to enable a safer and more comfortable commute to work for employees of India Inc.'
#  'LivFin is a non-banking financial company registered with the Reserve Bank of India (RBI)'
#  'A fashion startup based in Bengaluru.'
#  'Lattu kids is an edutainment platform for preschool kids.'
#  'Eggoz is a brand of fresh and chemical-free eggs, produced in tech-enabled & nutrition-engineered deep integration partnership with farmers.'
#  'Semiconductor company focused on CMOS millimeter wave products for Radar.'
#  'Charge+Zone provides services in renewable energy solutions, product development, and software engineering company.'
#  'Stones2milestones is India (Delhi) Based EdTech Company'
#  'Udacity develops an online learning platform offering programs in artificial intelligence, machine learning, and robotics sector.'
#  'AjnaLens develops AR/VR wearables primarily for the Defence, Education and enterprise customers.'
#  'Gully Network is a tech-enabled network of mid-sized grocery stores.'
#  'Talent Intelligence Platform for enterprises that helps recruiters discover the right candidates for a job using a Human-like AI'
#  'work with our customers closely to get their hair health sorted for long-term effective results'
#  'In the last five years, have served over 1.5 million orders and enjoy high customer satisfaction.'
#  'Mitron is a free short videoplatform for next generation'
#  'Svami is the result of three seasoned drinkers extending their love for libations to the larger world of drinks.'
#  'Developer of an online learning platform intended for various competitive exam preparations.'
#  'Expertrons is an AI video bot platform created to help students and professionals prepare for interviews.'
#  'Leena AI offers a human resource management platform that transforms employee experience with conversational AI.'
#  'Bizlog Value Chain enables re-commerce and circular economy through unique REVERSE LOGISTICS engine.'
#  'Tamasha offers a platform for influencers to host live, video based, real money contests and games.'
#  'Artificial Intelligence based Credit Score for Health'
#  'Fabhotels is the online aggregator for hotel rooms. It aims to provide standardized services at economical budgets.'
#  'Freshokartz provides soil data based crop and fertilisers recommendation to farmers and delivery seeds, pesticides'
#  'an online lending platform started with an endeavour to solve the problem that SMEs face in accessing Quick, Flexible and Adequate funds for growing their Businesses.'
#  'Farming-as-a-service (covering farm machinery and agri input services) and provides market linkages, especially for fragmented farm owners.'
#  'A Smart Farming Technology Platform for Indian Farmers'
#  'CredAble provides working capital & supply chain finance programs for large enterprises and their suppliers and distributors.'
#  'Railofy is a WL & RAC protection that enables waitlisted passengers to reach their destination at the lowest possible price.'
#  'Finova Capital is a non-banking financial company.'
#  'Teachmint is an easy to use platform for tutors to conduct unlimited live classes and manage their classrooms'
#  'Peel-Works is a tech and data analytics company specializing in e-commerce for corner stores.'
#  'Janani aims to make the process of infertility treatment and assisted fertilisation easier'
#  'A Used Luxury Car Marketplace'
#  'Wellversed Health enables production of customised clinical food products specific to health requirements of a demography or an individual.'
#  'Jumbotail is solving an important problem of organising food and grocery ecosystem in India through technology, data science and design.'
#  'WinZO is a mobile e-sports social gaming platform that offers monetary benefits and prizes to players.'
#  'MCaffeine is a personal care brand that offers caffein-infused face, body, and hair care products.'
#  'Pocket FM is an audiobook & podcast app that brings you over 10K+ popular audiobooks.'
#  'Snackible operates a health-food production company designed to sell healthy snack food via online and offline channels.'
#  'Jumbotail is solving an important problem of organising food and grocery ecosystem in India'
#  'TagZ Foods is a supplier of snacks and food products.'
#  'Genius Teacher creates engaging educational content, delivers fun learning experience to the students'
#  'Provider of marketing and warehousing services for agricultural commodities.'
#  "GetVantage is India and Southeast Asia's first fintech enabled Revenue-based financing platform."
#  'Developer of a digital verification platform designed to manage the semi-formal workforce.'
#  "India's 1st tech-enabled healthcare logistics platform."
#  'InVideo enables you to transform your content into great videos.'
#  'Retail tech platform empowering 300,000+ small retailers in electronics space to compete with big organised players and increase sales'
#  'World’s smartest virtual event platform that brings Experience & Intelligence together'
#  'A platform for automating home loans for middle and low-income households in India,'
#  'KETOS provides hardware and software analytics solutions and real-time data for usage and flow across water systems.'
#  'It is a cruelty-free makeup brand providing cosmetics that is high on style and higher on performance.'
#  "It is creating 'building blocks for a Digital Trust system."
#  'It is conducting IIT JEE Coach for Physics, Math and Chemistry easily.'
#  'It is a cloud-built platform with advanced machine learning and AI capabilities for a personalized and seamless consumer experience.'
#  'Education technology venture capital firm.'
#  'Developer and manufacturer of medical devices'
#  'VitalTech is a develop technologies that empower patients to better care for their safety,'
#  'Ultraviolette Automotive is a technology startup working on electric two-wheelers and energy infrastructure.'
#  'Tring is a celebrity engagement platform, for all occasions including birthday, anniversaries, get well soon messages.'
#  'Rare Planet sells handicrafts made by local artisans.'
#  "GoodGamer is India's first Daily Fantasy Sports and true Esports gaming platform."
#  'A building a portfolio of novel medical devices designed, engineered, and priced for global Emerging Markets.'
#  'Software that uses computer vision to recognise products without barcodes'
#  'Slintel, a leader in capturing technographics-powered buying intent, helps companies uncover the 3% of active buyers in their target market.'
#  'SoOLEGAL is a global integrated directory of lawyers, legal aid organizations, and Law firms.'
#  "India's Activity Hub for Kids"
#  "Supplynote is India's leading procurement platform with a unique stack of SAAS and E-commerce to solve the procurement problem"
#  "India's largest cloud based digital discovery and services provisioning platform for the taxi rental"
#  'ShopUp provides easy access to B2B sourcing, last-mile logistics, digital credit, and business management solutions to small businesses.'
#  'Energy-efficient solutions based on the Artificial Intelligence, Machine Learning and Internet of Things technology,'
#  'Zomato is a food delivery and restaurant discovery site that provides information and reviews about restaurants.'
#  'Developer of an android application designed for businesses to sell online.'
#  'India’s Only 100% Inspected and Certified Used Bikes Marketplace.'
#  'An agritech company that provides business to business (B2B) agricultural data'
#  'RACEnergy builds and deploys battery swapping infrastructure for use in various segments of vehicles.'
#  "A homegrown fitness startup that aims to advance the 'Fit India' initiative by offering holistic and affordable workouts."
#  'Provide quality and healthy food products'
#  "India's Finest Specialty Tea company."
#  'Fleetx is an intelligent data platform which uses AI, machine learning, sensors and predictive analytics to help fleet owners.'
#  'Tech platform helping millions of renovation contractors, property improvement professionals and businesses manage their business digitally.'
#  'Retail Video Analytics SaaS product'
#  'AVATAAR.ME is a deep-tech 3D AR platform which delivers personalized fashion discovery experience to users on mobile devices.'
#  'Arrival is a technology company that specializes in developing electric vehicles.'
#  'Cover Genius provides an insurance distribution platform designed to protect the customers of e-commerce companies'
#  'Phononic Vibes introduces a new patented technology for vibration and noise control and isolation, with a circular economy approach.'
#  'MikeLegal is an AI powered legal associate that aims to build an ecosystem of legal tools'
#  'Clair is a social fintech that provides Instant Pay Access as a Service for human capital management and gig platforms.'
#  'Gourmet Garden is a global market leader in chilled convenient packaged herbs.'
#  'Miko is an advanced robotics startup founded by three IIT Bombay post-graduates on the pillars of robotics, AI & IoT.'
#  'Razorpay is a platform that enables businesses to accept, process, and disburse payments.'
#  'Ninjacart is a business-to-business fresh produce supply chain that connects farmers, manufactures, and brands to retailers directly.'
#  'Wow! Momo is a chain of fast-food restaurants that specializes in momos.'
#  'Pepper Content is a Content-Mediation Platform that connects talented writers to organisations that require content.'
#  'Livspace is an interior design startup that offers a platform that connects people to designers, services, and products.'
#  'Acculi Labs is a clinical grade smartphone based diagnostic tool'
#  'Your.MD is a platform committed to helping a billion people find their health by unlocking self-care with digital technology.'
#  'Developer of memory-based technology intended to solve issues of advanced computing.'
#  'A helping hand to the farming community through Artificial Intelligence'
#  'Disprz is a one-of-its-kind “knowledge-tech” start-up that strives to make people knowledgeable, productive and smarter at what they do.'
#  'The team aims to bridge the gap for credit cards and make them more accessible for people across different regions.'
#  'CreditWise Capital is a consumer finance company.'
#  'Chargebee is a PCI Level 1 certified subscription and recurring billing system for SaaS and subscription based eCommerce businesses'
#  'Reliance Retail offers online shopping and a chain of neighborhood stores, supermarkets, and wholesale/specialty stores.'
#  'Winuall specializes in the fields of E-learning, online quizzes, and tests, study material for competitive exams.'
#  'GenRobotic specializes in powered robotic exoskeletons with RC controlled humanoid robotic systems and Artificial Intelligence.'
#  'An online platform where both owners and tenants find help in making sure their rental transaction are safe and secure.'
#  'Ergos is building an integrated supply chain by setting up micro warehouses.'
#  'Krishi-Tantra is an Agri-IoT startup building farm automation for controlled agricultural environment.'
#  'PakkaProfile bridges the gap between companies and the workforce by making better, unbiased decisions with the help of psychometric games'
#  'Monet Networks Using sentiment and non verbal cues analysis for increased engagement and real time content feedback.'
#  'Unocoin is an Indian bitcoin processor that enables users to buy, sell, store, use, and accept bitcoins.'
#  'Pesto is a career accelerator for software engineers with the mission to take opportunities to places where talent exists.'
#  'NirogStreet is an Ayurvedic doctor discovery and appointment booking platform where patients can easily find doctors and fix consultation.'
#  'Bambrew is an online shop for reusable bamboo straws.'
#  'Omnify is a Global SaaS platform for Small Services Business'
#  'The gaming company mostly focused on fantasy football games'
#  "Treebo is India's tech-enabled, asset-light affordable accommodation brand."
#  'To solve the urban waste problem by utilising local technologies and business models.'
#  'Video-led social app Public provides users with a platform to share and view important hyperlocal videos'
#  'Legal Salah is bringing the provision of imparting value based legal and consultancy services to the user.'
#  'FanPlay Technologies operates as a real-money gaming startup.'
#  'Eco friendly zero power zero maintenance sewage treatment plant in India.'
#  'Coralogix is a log analytics SaaS platform that improves the delivery and maintenance process for software providers.'
#  'Equiwatt is a digital platform enabling households to get paid for saving energy at peak times.'
#  'Zhangmen is an online tutoring platform provides tutoring courses to students.'
#  'Agrowave engages in transforming agriculture supply chain by connecting farms to businesses.'
#  'Sapio Analytics provides AI-powered policymaking solutions for government institutions.'
#  'Taimei Technology provides a cloud platform for clinical research collaboration.'
#  'Avanse, regulated by the Reserve Bank of India, is an education finance company that operates as a non-banking finance company (NBFC).'
#  "India's largest industrial ecommerce platform"
#  'Hopscotch provides an insider access to international brands for babies, kids, and moms.'
#  'Pristyn Care is Health Care Startup that is disrupting Day Care Procedures.'
#  'Wooden Street is a online furniture platform that provides custom made & ready to order furniture.'
#  'Acko General Insurance is a private sector general insurance company in India.'
#  'FarmersFZ is an online venture for fresh and safe vegetables and agri products.'
#  'Invento Robotics specializes in developing service robots intended for customer interactions.'
#  'Infurnia Technologies is an eponymous cloud-based architecture design software platform.'
#  "SuperCric is India's first strategy Cricket Manager simulation game"
#  'Snowflake is a cloud data platform that provides a data warehouse-as-a-service designed for the cloud.'
#  'GenieTalk as a virtual assistant uses AI to bring conversation commerce with a personalised experience on the app.'
#  'Classplus offers a mobile-first SaaS platform for 3000+ tutors to offer their curriculum and operations completely online.'
#  'Mobile Premier League(MPL) is a skill based E-Sports platform where you can play your favourite mobile games'
#  'Fourth Partner Energy provides turnkey rooftop solar energy solutions for customers in India.'
#  'Flipkart is an e-commerce marketplace that offers over 30 million products cross 70+ categories.'
#  'Vivriti Capital is a marketplace for small enterprises and individuals that lack efficient access to financial services.'
#  'The funding for branding and marketing activities as well as strengthening the product and technology teams'
#  'An Intelligent Patient Relationship Management (PRM) system for hospitals and other healthcare providers in India.'
#  'An Indian educational technology and online tutoring firm'
# ...
#  'Pearl Brook Holdings Ltd, Al Nour International Holdings Co.'
#  'Rocketship' 'Nadir Godrej, Individual Investors' 'Pawan Munjal'
#  'US International Development Finance Corporation'
#  'Tano India, L’Occitane, Bessemer' 'Sozo Ventures' 'Undisclosed'
#  'Rainmatter Capital' 'Venture Catalysts, Naveen Kshatriya,'
#  'Shikhar Dhawan' 'Arkam Ventures, Nabventures'
#  'Beyond Next Ventures, ArthaVida Ventures, Dr Aniruddha Malpani'
#  'Iron Pillar, Blume Ventures' 'Danone Manifesto, Mousse Partners'
#  'Entrepreneurial Development Bank, Bessemer Venture Partners'
#  'Insight Partners' 'Induslnd Bank' 'Pratithi'
#  'PadUp, Villgro USA, Vinners, LetsVenture, SINE IIT Bombay, DERBI'
#  'Dr Apoorva Ranjan Sharma, Mrunal Jhaveri, Nirav Panchmatia, Vikas Kapoor, Karan Garg'
#  'JSW Ventures, Chiratae Ventures, Kalaari Capital' 'Kimera Ltd'
#  'Gameskraft' 'Anthill Ventures' 'Smile group' 'Rangsons Technologies'
#  'WSV Capital' 'Gautam Dalmia, Pratithi Investment Trust, Shri Investment'
#  '100x VC' 'Black Soil'
#  'Leo Capaitals, Amit Gupta, Abhishek Goyal, Ramakant Sharma, Harsh Pokhran'
#  'Beenext, Asuka Holding' 'Vertex Ventures SEA & India' 'Crowd Fund'
#  'Bisque Limited, Link Investment Trust.'
#  'Stellaris Venture Partners, Venture Highway'
#  'River Rock Ventures. Inflection Point Ventures'
#  'Chinaccelerator, 9 Unicorns Fund, Inflection Point Ventures'
#  'EMVC, Flourish, Omidyar Network India' 'Polychain Capital'
#  'Varanium NexGen Fund' 'Inventus III India Fund'
#  'Bharat Inclusion Seed Fund, Varanium Capital, and Better Capital'
#  'Amit Burman' 'Bharti Airtel'
#  'Whiteboard Capital, FirstCheque, Artha India Ventures, Sweta Rau, Deepak Abbot, Amrish Rau, Harpreet Singh Grover'
#  'IDG Ventures, Elevar Equity, Accion' 'Angel Investors'
#  'Kalyan Krishnamurthy, Sujeet Kumar, Keshav Sanghi, Roman Saini, Sumit Jain, Hemesh Singh'
#  'Sujeet Kumar' 'B Capital Group' 'Angel investors. HNI' 'Innoven Capital'
#  'Tracxn Labs, Angellist, Tri-Deep Capital' 'Ankit Bhati, Nitin Gupta'
#  'Gray Matters Capital' 'Akya Ventures' 'GHV Accelerator'
#  'Josh Liberman, Mark Adams' 'Nordic Microfinance Initiative'
#  'Chiratae Ventures, Accel Partners, BCIP Venture Associates, Bain Capital, Renaud Laplanche'
#  'Saama Capital' 'Tiger Global, Avatar Growth Capital'
#  'Lightspeed Venture Partners' 'Unicorn Investments Pte Ltd'
#  'Vijay Shekhar Sharma, Anupam Mittal'
#  'Tribe Capital, Innoven Capital, BII'
#  'Angellist, Smile Group, Manish Amin, Anil Goel, Anubhav Sonthalia, Deepak Mittal'
#  'Steadview capital'
#  'Bessemer Venture Partners India, Fusian Capital, Rebright Partners, Milliways Fund LLC'
#  'Ratan Tata' 'VisaVentures, BRI Ventures' 'Next Capital'
#  'Trifecta Venture' 'Exfinity Ventures, IAN Fund' 'Alteria Capital'
#  'ChrysCapital' 'Hari Balasubramanian, EaSyndicate'
#  'Paytm, leAD Sports, Rockstud Capital, Founder Bank Capital' 'Lupa India'
#  'Tencent'
#  'Devanshu Dolat Desai, Anand M Khatau, Debasish Priyadarshi Purohit, Kaushik Shanghvi'
#  'Accel Partners, Jungle Ventures' 'Barkawi' '1Funds Domestic Scheme'
#  'RiverRock Ventures' 'RTP Global' 'Hero Fincorp' 'Li and Fung'
#  'Mantra Capital, Patni Family'
#  'Nikhil Vora, Iceland Venture Studio, LetsVenture, Samyakth Capital'
#  'North Base Media' 'Investment Trust of India'
#  'IvyCap Ventures, Sequoia Capital'
#  'Sequoia Capital Surge, Better Capital'
#  'Ravikanth Reddy & Mumbai Angel Network' 'Sequoia Capital, Sofina'
#  'Pinetree Capital' 'Big Basket' 'Education Catalyst Fund' 'CDC Group'
#  'KB Global Platform Firm' 'Tata Capital Growth Fund II' 'NXC Corporation'
#  'Saltwater Venture Sparks'
#  'University of Tokyo Edge Capital, Global Brain Corporation'
#  'Abhishek Goyal, Bharat Jaisinghani, FirstCheque' 'BeeNext'
#  'Angel Network' 'Sukhbir Singh, Rakhee Singal'
#  'INSEAD Angels, IIT Kanpur Angels, Sixth Sense Ventures, Saahil Bhatia'
#  'Bytedance, Falcon Edge, Goldman Sachs, Advent Management'
#  'General Atlantic' 'IIFL Seed Ventures Fund, Menlo park'
#  'Ribbit Capital, SAIF Partners, Sequoia Capital India, Amazon'
#  'Greenoaks Capital, Vy Capital. Matrix Partners India' 'Accel' 'Indie VC'
#  'Lightspeed Venture Partners, Lightspeed India Partners.'
#  'Lightspeed Venture, Falcon Edge, Bharat Inclusive Technologies Seed Fund.'
#  'M12, Honeywell venture capital, Eight Roads Venture'
#  'Amazon, Sequoia, Walden SKT Venture Fund' 'Lightstone Global Funds'
#  'Zee Entertainment Enterprises Limited' 'Amazon Inc`, Dinesh J Hinduja'
#  'Alibaba Holdings' 'Hummingbird Ventures, Bedrock Capital'
#  'Legend Capital' 'Accel, Zephyr Peacock, Swiggy, RB Investments.'
#  'Better Capital, LetsVenture, Rohit Chanana, Jayant Kadambi, Sunil Kumar Singhvi'
#  'Bace Capital'
#  'Tencent, Ark Impact, Korea Investment Partners, Samsung Ventures, Mirae Asset Capital Markets'
#  'LGT Lightstone Aspada' 'Pacific Horizon' 'Der Shing Lim, 500 startups'
#  'Vostok Emerging Finance' 'Arka Venture Labs' 'IvyCap Ventures'
#  'Vertex Ventures' 'Chowdry Associates, Lightbox'
#  'Sukhbir Singh, India Accelerator, Boudhik Ventures, Shankar Nath, Shaurya Garg'
#  'Matrix Partners, SAIF Partners' 'LeapFrog Investments'
#  'Aavishkar Capital' 'Unicorn India ventures'
#  'Pecus Capital, Madhur Deora' 'Temasek' 'Ideaspring capital'
#  'ThinkNext LLC' 'MG Motor India'
#  'Ashneer Grover, Kunal Shah, Ramakant Sharma'
#  'KYT Ventures, First Cheque, AngelList'
#  'Polychain Capital, Bain Capital Ventures, HDR Group'
#  'Risers Accelerators' 'Accel India, Lightspeed Venture Partners'
#  'Gautham Madhavan' 'Pegasus FinInvest' 'TPG-backed Group Landmark'
#  'CESC Ventures' 'Naya Ventures' 'pi Ventures'
#  'Rajeev Juneja, Pratul Shroff, Dilip Khandelwal, Piyush Gupta'
#  'Mahendra Singh Dhoni' 'LGT LightstoneAspada' 'Godrej Investments'
#  'Stellaris Venture Partners, Unilever Ventures, Kalaari Capital, Vy Capital'
#  'Sorenson Impact' 'Vishal Dixit' 'Pawan Munjal Family Trust Fund'
#  'Lodha Ventures'
#  'Y Combinator, Venture Highway, Sequoia India, Global Founders Capital'
#  'Arali Ventures, CIIE.CO' 'Kunal Shah, Amrish Rau, Jitendra Gupta'
#  'Accel India' 'Mistletoe' 'KA Enterprise'
#  'Lead Angels Network, Stanford Angels' 'Angel network'
#  'LetsVenture investors'
#  'Advent Management, A91 Emerging Fund, Trifecta Venture'
#  'SAIF Partners, Mayfield India' 'Rukam Capital'
#  'UTEC-The University of Tokyo Edge Capital, Aflac Ventures, LLC, Dream Incubator, TeamFund'
#  'Ixigo' 'Sequoia’s Surge, Fosun RZ' 'Alok Garg' 'InnoVen Capital'
#  'Anicut Angel Fund' 'Aavishkaar Capital' 'Paragon Partners' 'Yuanfudao'
#  'Nandan Nilekani, Sanjeev Aggarwal' 'Atraxn Partners.'
#  'Morgan Stanley Private Equity Asia' 'Lightstone Aspada'
#  'Samsung Venture Investment' 'Indian Angel Network'
#  'Media Development Investment Fund' 'Accelerator MOX'
#  'Nandan Nilekani, Samsung Venture Investment Corporation'
#  'Maharashtra Defence, Aerospace Venture Fund (MDAVF)'
#  'Kunal Bahl, Rohit Bansal'
#  'GGV Capital, Bertelsmann India Investments, Binny Bansal, Sequoia India, Accel Partners'
#  'CDC Group Plc' 'Ribbit Capital' 'Sequoia Capital’s Surge' 'Peerplays'
#  'Sauce.vc' 'AdvantEdge' 'Accion Venture Lab'
#  'SucSEED Venture Partners, BIRAC, Elixir Pharma, Titan Capital'
#  'Prosus N.V'
#  'Facebook, General Atlantic, Sequoia India, Nexus Venture Partners, Steadview Capital, Blume Ventures'
#  'Hindustan Media Ventures' 'Virat Kohli, Anushka Sharma'
#  'Rockstud Capital' 'IAN Fund-I,\xa0\xa0Al Falaj Investment Company (AFI)'
#  'WAVE Equity Partners, Chevron Technology Ventures, Marubeni Corporation.'
#  'Zodius Growth Fund'
#  'Mahesh Mohta, Jyoti Arora, Nachu Subramanian, Srivats'
#  'Indian Angel Network, Lead Angels, Hyderabad Angels'
#  'Triton Investment Advisors,'
#  'Accel Partners, Shunwei Capital, Good Capital' 'SIG Global India Fund'
#  'Kolte-Patil Family Office' 'Ashwin Khorana' 'Tarun Bhalla' 'Z3 Partners'
#  'One97 Communications' 'GGV Capital'
#  'Amrish Rau, Kunal Shah, Jitendra Gupta'
#  'Omnivore, Accel Partners, Mayfield'
#  'Kleiner Perkins, Canapi Ventures, Index Ventures, Nyca Partners, General Catalyst.'
#  'Info Edge Ltd' 'Chowdry Associates' 'Pharmacon Holdings'
#  'Blume Ventures, Sequoia' 'Think Investment' 'Udaan'
#  'Pidilite Industries' 'Softbank’s Vision Fund' 'LightBox Ventures'
#  'Xiaomi' 'Info Edge Venture Fund' 'Neev Fund'
#  'FirstCheque, Angellist India, Aakrit Vaish, Ranjith Radhakrishnan'
#  'Arunachal Pradesh Social Entrepreneurship Meet' 'IndiaQuotient'
#  'PayU, Fosun RZ Capital' 'Unitus Ventures.'
#  'Avaana Capital, Titan Capital' 'Institutional Investors' 'Tim Draper'
#  'Beenext' 'Reliance Industries Limited (RIL)' 'Equanimity Ventures'
#  'Mistletoe, Info Edge Asia' 'Bill & Melinda Gates Foundation'
#  'JITO Angel Network, Ketan Kothari, Girish Jain, Sunil Singhvi, Vinay Jain'
#  'Ant Financial' 'GrowX ventures, Prophetic Ventures' 'Atsushi Taira'
#  'Manish Choksi' 'InnoVen capital' 'SenseAI Ventures'
#  'Tiger Global Management, Sequoia Capital India, Singapore’s Economic Development Board (EBD)'
#  'Aquiline Technology Growth (ATG), RTP Global, Sequoia India'
#  'Frontline Strategy Finds, SucSEED Venture Partners LLP'
#  'Tiger Global, Steadview Capital, DF International Private Partners'
#  'Schroder Adveq' 'A91 Partners, Faering Capital, TVS Capital'
#  'Tahoe Investment Group, Mercer Investment' 'Mastercard'
#  'SOSV, Chinaccelerator' 'Tiger Global, Steadview Capital' 'She Capital'
#  'Green Shots Capital, Alfa Ventures, Real Time Venture, Petrotech, Steel City Securities, Lalit Wadhwa, Dr Kriti Maroli'
#  'Yuj Ventures' 'Accel Partners, B Capital'
#  'Sequoia Capital, Matrix Partners India'
#  'Ginni International, Elisa Khong, Sandeep Singh, VegInvest'
#  'SoftBank Group' 'Sony Innovation Fund' 'Amit Singal, Manish Aggarwal'
#  'Windrose Capital, ITI Growth Opportunities Venture Fund'
#  'Yatra Angel Network (YAN)' 'WestBridge Capital'
#  'Sprout Venture Partners, Indian Angel Network' 'La Gajjar Group'
#  'ICONIQ Capital' 'Matrix Partners India'
#  'Sequoia Capital, Ribbit Capital, Amazon, Saif Partners'
#  'Flipkart India, Singapore-based GEC3'
#  'Omnivore, Insitor Impact Asia Fund' 'Kalaari Capital'
#  'Suma Soft Pvt Ltd'
#  'Sprout Venture Partners, JITO Angel Network, LetsVenture'
#  'Refex Capital' 'James Murdoch-led Lupa Systems'
#  'Lightspeed Venture Partners, Sequoia Surge' 'Omidyar Network India'
#  'Space Capital'
#  'IIM Ahmedabad’s incubator (CIIE.CO),Chandigarh Angels Network'
#  'Iron Pillar' 'Lightbox. Social Capital, Dunce Capital'
#  'GMO Payment Gateway' 'Tiger Global' 'The Chennai Angels (TCA)'
#  'HNIs in India, Japan, and the US' 'Vishnu Reddy'
#  'Zerodha fintech fund, Rainmatter' 'Austrian Bank' 'Alibaba' 'TechnoGen'
#  'NorthStar, Vinod Khatumal'
#  'Chiratae Ventures, Sequoia Capital, Orios Venture Partners'
#  'Sprout venture partners' 'DSG Consumer Partners, Blume Ventures'
#  'Sequoia India, Ribbit Capital' 'Verlinvest' 'SIG Global India Fund LLP.']
# ____________________________________________________________________________________________________
#
# Column-8: Amount: 301
#  [2.0000000e+05 1.0000000e+05           nan 4.0000000e+05 3.4000000e+05
#  6.0000000e+05 4.5000000e+07 1.0000000e+06 2.0000000e+06 1.2000000e+06
#  6.6000000e+08 1.2000000e+05 7.5000000e+06 5.0000000e+06 5.0000000e+05
#  3.0000000e+06 1.0000000e+07 1.4500000e+08 1.0000000e+08 2.1000000e+07
#  4.0000000e+06 2.0000000e+07 5.6000000e+05 2.7500000e+05 4.5000000e+06
#  1.5000000e+07 3.9000000e+08 7.0000000e+06 5.1000000e+06 7.0000000e+08
#  2.3000000e+06 7.0000000e+05 1.9000000e+07 9.0000000e+06 4.0000000e+07
#  7.5000000e+05 1.5000000e+06 7.8000000e+06 5.0000000e+07 8.0000000e+07
#  3.0000000e+07 1.7000000e+06 2.5000000e+06 4.0000000e+04 3.3000000e+07
#  3.5000000e+07 3.0000000e+05 2.5000000e+07 3.5000000e+06 2.0000000e+08
#  6.0000000e+06 1.3000000e+06 4.1000000e+06 5.7500000e+05 8.0000000e+05
#  2.8000000e+07 1.8000000e+07 3.2000000e+06 9.0000000e+05 2.5000000e+05
#  4.7000000e+06 7.5000000e+07 8.0000000e+06 1.2100000e+08 5.5000000e+07
#  3.3000000e+06 1.1000000e+07 1.6000000e+07 5.4000000e+06 1.5000000e+08
#  4.2000000e+06 2.2000000e+07 5.2000000e+07 1.1000000e+06 1.1800000e+08
#  1.6000000e+06 1.8500000e+07 7.0000000e+10 8.0000000e+08 4.0000000e+08
#  1.5000000e+05 1.7600000e+08 6.0000000e+07 4.7000000e+05 2.4000000e+05
#  3.0000000e+09 7.4000000e+07 6.2000000e+07 2.1000000e+06 5.0000000e+08
#  1.2500000e+07 2.2000000e+09 5.0600000e+06 2.2500000e+08 2.4700000e+07
#  7.7000000e+06 1.9067328e+07 5.1000000e+07 1.1500000e+05 5.4000000e+04
#  2.0000000e+04 8.0314600e+05 2.3800000e+05 1.0220000e+07 1.0200000e+06
#  1.2000000e+07 1.3400000e+07 1.7000000e+08 2.9000000e+06 5.4300000e+05
#  9.0000000e+07 3.4000000e+06 2.3000000e+07 8.0900000e+06 1.0300000e+06
#  5.0400000e+06 3.6000000e+05 1.4000000e+06 6.5000000e+05 5.4000000e+07
#  4.2500000e+07 1.1370000e+07 3.2500000e+05 4.1000000e+05 4.5000000e+05
#  6.8200000e+05 4.0500000e+06 1.0500000e+06 1.0800000e+06 4.3000000e+06
#  6.8000000e+06 2.1100000e+06 7.6400000e+05 6.0300000e+05 4.0900000e+05
#  2.9200000e+05 2.8600000e+05 1.3600000e+05 5.4600000e+05 8.8700000e+05
#  4.3000000e+04 4.0900000e+04 2.2000000e+06 5.6600000e+06 3.5000000e+05
#  1.1000000e+05 1.2200000e+08 1.1635000e+07 2.8000000e+06 1.0650000e+06
#  6.6900000e+05 1.6076000e+07 6.4960000e+05 6.7000000e+06 2.2000000e+05
#  2.6650000e+05 2.8790000e+06 2.6500000e+07 3.5100000e+05 4.6761000e+07
#  1.7500000e+05 1.1241000e+07 8.0400000e+05 1.3400000e+06 4.6700000e+05
#  1.3300000e+05 3.8230000e+06 9.3400000e+05 2.9300000e+05 1.9800000e+05
#  9.2700000e+05 9.7100000e+05 3.0600000e+06 1.8620000e+06 2.3200000e+05
#  2.8880000e+06 1.3280000e+06 1.5500000e+07 5.6000000e+07 2.2500000e+06
#  1.6753000e+07 3.7000000e+06 1.4700000e+06 5.3000000e+05 2.6700000e+05
#  3.3440000e+06 7.2000000e+06 2.7430000e+06 6.0820000e+06 6.6090000e+06
#  2.7700000e+07 5.9400000e+06 3.9640000e+06 5.5000000e+06 1.9700000e+05
#  4.3270000e+06 4.5900000e+05 3.9370000e+06 1.3135000e+06 2.2980000e+05
#  5.3050000e+06 2.6400000e+05 1.7500000e+06 5.9670000e+06 2.9800000e+06
#  3.2300000e+05 1.3260000e+06 2.7000000e+07 5.2000000e+06 2.5300000e+06
#  7.9200000e+05 1.1363000e+07 1.7150000e+06 3.2900000e+05 5.2710000e+06
#  8.7000000e+06 3.2260000e+06 5.9000000e+06 4.4000000e+07 3.8790000e+06
#  1.3000000e+07 8.8000000e+06 9.5000000e+06 9.2000000e+05 3.5600000e+07
#  9.4000000e+06 7.9000000e+05 4.8000000e+05 1.6000000e+05 8.2000000e+06
#  4.2570000e+06 1.4100000e+06 3.4980000e+05 7.8600000e+05 2.0040000e+06
#  1.2300000e+08 2.4800000e+05 2.4000000e+07 1.4259000e+07 2.4500000e+07
#  3.8000000e+06 1.8370000e+07 6.8525000e+07 4.8000000e+06 1.8340000e+06
#  2.3850000e+07 4.3000000e+07 2.1600000e+07 4.5980000e+06 1.3137000e+07
#  1.1500000e+08 3.9000000e+06 6.7000000e+05 8.5000000e+06 3.1480000e+06
#  2.6000000e+06 4.0495000e+06 1.0500000e+07 6.5000000e+06 4.3700000e+07
#  1.3800000e+07 3.0690000e+05 4.2000000e+05 6.2730000e+05 1.1300000e+08
#  3.2000000e+07 1.1000000e+08 1.3970000e+06 4.4850000e+05 7.9757000e+06
#  3.3000000e+05 5.6000000e+06 1.4020000e+06 2.1500000e+07 2.9600000e+08
#  4.9000000e+06 1.4024000e+06 1.2618300e+07 9.9000000e+06 9.8253000e+05
#  7.0185200e+07 2.1000000e+08 8.4000000e+07 3.9000000e+07 2.7000000e+06
#  1.4034000e+06 1.0500000e+08 1.0300000e+08 2.8130000e+05 1.2700000e+04
#  2.5000000e+04 9.7500000e+07 5.0700000e+05 8.4000000e+06 1.8300000e+07
#  1.2500000e+08 1.8100000e+05 2.8000000e+05 1.4700000e+07 1.3200000e+07
#  8.0430000e+06]
# ____________________________________________________________________________________________________
#
# Column-9: Stage: 43
#  [None 'Pre-seed' 'Seed' 'Pre-series A' 'Pre-series' 'Series C' 'Series A'
#  'Series B' 'Debt' 'Pre-series C' 'Pre-series B' 'Series E' 'Bridge'
#  'Series D' 'Series B2' 'Series F' 'Pre- series A' 'Edge' 'Series H'
#  'Pre-Series B' 'Seed A' 'Series A-1' 'Seed Funding' 'Pre-Seed'
#  'Seed round' 'Pre-seed Round' 'Seed Round & Series A' 'Pre Series A'
#  'Pre seed Round' 'Angel Round' 'Pre series A1' 'Series E2' 'Pre series A'
#  'Seed Round' 'Bridge Round' 'Pre seed round' 'Pre series B'
#  'Pre series C' 'Seed Investment' 'Series D1' 'Mid series' 'Series C, D'
#  'Seed funding']
# ____________________________________________________________________________________________________
#
# Column-10: column10: 3
#  [None 'Pre-Seed' 'Seed Round']
# ____________________________________________________________________________________________________

# %% [markdown]
# ##### Identifying Odd Entries in Each Column

# %% [markdown]
# **Column-1: Company_Brand: 905 Unique values**

# %%
# Check for number of duplicated values within the 'Company_Brand' column
dup20_count = df2020.duplicated(subset=key_columns, keep=False).sum()

# Identify duplicate entries in the 'Company_Brand' column
dup_c1_20 = df2020[df2020.duplicated(subset=key_columns, keep=False)]

# Extract the list of duplicated company brands
unidup_c1_20 = dup_c1_20['Company_Brand'].unique()

# Display results
print(f"Number of duplicated values in 'Company_Brand' column: {dup20_count}")
print("\nList of duplicated company brands:")
print(unidup_c1_20)
dup_c1_20
# Out:
# Number of duplicated values in 'Company_Brand' column: 61
#
# List of duplicated company brands:
# ['Credgenics' 'Nykaa' 'Krimanshi' 'FreshtoHome' 'Genius Teacher' 'Byju’s'
#  'Zomato' 'Trell' 'Magicpin' 'Aye Finance' 'Zetwerk' 'LetsTransport'
#  'BankBazaar' 'Rentmojo' 'Khatabook' 'Clover' 'Vedantu' 'Yap'
#  'Capital Float' 'Rebel Foods' 'Lido Learning' 'Swiggy' 'Vogo' 'BharatPe'
#  'Digit Insurance' 'Shuttl' 'Byju' 'Bounce']
#         Company_Brand  Founded HeadQuarter                  Sector  \
# 109        Credgenics   2018.0    Gurugram                 FinTech
# 120             Nykaa   2012.0      Mumbai               Cosmetics
# 129         Krimanshi   2015.0     Jodhpur   Biotechnology company
# 145         Krimanshi   2015.0     Jodhpur   Biotechnology company
# 195       FreshtoHome   2015.0   Bangalore              E-commerce
# 202        Credgenics   2018.0    Gurugram                 FinTech
# 205             Nykaa   2012.0      Mumbai               Cosmetics
# 211       FreshtoHome   2015.0   Bangalore              E-commerce
# 215    Genius Teacher   2016.0      Mumbai                  Edtech
# 233    Genius Teacher   2016.0      Mumbai                  Edtech
# 326            Byju’s   2011.0   Bangalore                  EdTech
# 348            Zomato   2008.0     Haryana          Food devlivery
# 362            Byju’s   2011.0   Bangalore                  EdTech
# 367            Zomato   2008.0     Haryana          Food devlivery
# 503             Trell   2016.0   Bangalore       Social e-commerce
# 569          Magicpin   2015.0    Gurugram                    None
# 597       Aye Finance   2014.0    Gurugram                 Fintech
# 609           Zetwerk   2018.0   Bangalore             Marketplace
# 623       Aye Finance   2014.0    Gurugram                 Fintech
# 639     LetsTransport   2015.0   Bangalore                Logitech
# 663        BankBazaar   2008.0     Chennai                 Fintech
# 664          Rentmojo   2012.0   Bangalore                  Rental
# 667     LetsTransport   2015.0   Bangalore                Logitech
# 692         Khatabook      NaN   Bangalore                 Fintech
# 695     LetsTransport   2015.0   Bangalore                Logitech
# 703          Rentmojo   2012.0   Bangalore                  Rental
# 707          Magicpin   2015.0    Gurugram                    None
# 712             Nykaa   2012.0      Mumbai               Ecommerce
# 721            Clover      NaN   Bangalore                Agritech
# 756           Vedantu      NaN   Bangalore                  Edtech
# 764               Yap      NaN     Chennai                 Fintech
# 771     Capital Float   2013.0   Bangalore                 Fintech
# 785       Rebel Foods      NaN        None               Food tech
# 786        BankBazaar   2008.0     Chennai                 Fintech
# 789     Capital Float   2013.0   Bangalore                 Fintech
# 792           Vedantu      NaN   Bangalore                  Edtech
# 797     Lido Learning      NaN      Mumbai                  Edtech
# 798       Aye Finance   2014.0    Gurugram                 Fintech
# 799            Swiggy   2014.0   Bangalore                Foodtech
# 813             Nykaa   2012.0      Mumbai               Ecommerce
# 816     Lido Learning      NaN      Mumbai                  Edtech
# 839         Khatabook      NaN   Bangalore                 Fintech
# 867             Trell   2016.0   Bangalore       Social e-commerce
# 877              Vogo   2016.0   Bangalore              Automotive
# 888          BharatPe   2018.0       Delhi                 Fintech
# 896            Swiggy   2014.0   Bangalore                Foodtech
# 901   Digit Insurance      NaN   Bangalore               Insurtech
# 911            Shuttl   2015.0       Delhi               Transport
# 920           Vedantu      NaN   Bangalore                  Edtech
# 921               Yap      NaN     Chennai                 Fintech
# 922            Clover      NaN   Bangalore                Agritech
# 935              Byju   2011.0        None                  Edtech
# 946       Rebel Foods      NaN        None               Food tech
# 961          BharatPe   2018.0       Delhi                 Fintech
# 963              Vogo   2016.0   Bangalore              Automotive
# 966           Zetwerk   2018.0   Bangalore             Marketplace
# 975   Digit Insurance      NaN   Bangalore               Insurtech
# 986            Bounce   2014.0   Bangalore  Automotive and Rentals
# 1009           Bounce   2014.0   Bangalore  Automotive and Rentals
# 1035             Byju   2011.0        None                  Edtech
# 1053           Shuttl   2015.0       Delhi               Transport
#
#                                            What_it_does  \
# 109   Credgenics is a tech-enabled platform backed b...
# 120   Nykaa is an online marketplace for different b...
# 129   Krimanshi aims to increase rural income by imp...
# 145   Krimanshi aims to increase rural income by imp...
# 195   Freshtohome is an e-commerce platform for fres...
# 202   Credgenics is a tech-enabled platform backed b...
# 205   Nykaa is an online marketplace for different b...
# 211   Freshtohome is an e-commerce platform for fres...
# 215   Genius Teacher creates engaging educational co...
# 233   Genius Teacher creates engaging educational co...
# 326   An Indian educational technology and online tu...
# 348   Get online food delivery from restaurants near...
# 362   An Indian educational technology and online tu...
# 367   Get online food delivery from restaurants near...
# 503      Allows users to share their travel experiences
# 569   It is a local discovery, rewards, and commerce...
# 597                            A finance lender to SMEs
# 609   B2B marketplace that connects manufacturing co...
# 623                            A finance lender to SMEs
# 639                   Offers techno logistics solutions
# 663   Online marketplace that gives customers instan...
# 664   Rental platform for furniture, appliances & el...
# 667                   Offers techno logistics solutions
# 692   It helps SMEs to maintain their accounts and l...
# 695                   Offers techno logistics solutions
# 703   Rental platform for furniture, appliances & el...
# 707   It is a local discovery, rewards, and commerce...
# 712             Deals in cosmetic and wellness products
# 721   Provides agricultural solution to farmers work...
# 756                             Onine learning platform
# 764   Banking and payment products-focused API platform
# 771   Online platform that provides working capital ...
# 785                            It runs internet kitchen
# 786   Online marketplace that gives customers instan...
# 789   Online platform that provides working capital ...
# 792                             Onine learning platform
# 797                             Online teaching service
# 798                            A finance lender to SMEs
# 799   Platform to order food online from restaurants...
# 813             Deals in cosmetic and wellness products
# 816                             Online teaching service
# 839   It helps SMEs to maintain their accounts and l...
# 867      Allows users to share their travel experiences
# 877   A scooter-sharing platform allowing users to r...
# 888                           Digital payments platform
# 896   Platform to order food online from restaurants...
# 901                           General Insurance Company
# 911                     App based bus aggregator serice
# 920                             Onine learning platform
# 921   Banking and payment products-focused API platform
# 922   Provides agricultural solution to farmers work...
# 935                    Provides online learning classes
# 946                            It runs internet kitchen
# 961                           Digital payments platform
# 963   A scooter-sharing platform allowing users to r...
# 966   B2B marketplace that connects manufacturing co...
# 975                           General Insurance Company
# 986   Offers a variety of bikes and scooters that ca...
# 1009  Offers a variety of bikes and scooters that ca...
# 1035                   Provides online learning classes
# 1053                    App based bus aggregator serice
#
#                                                Founders  \
# 109           Anand Agrawal, Mayank Khera, Rishabh Goel
# 120                                       Falguni Nayar
# 129                                        Nikhil Bohra
# 145                                        Nikhil Bohra
# 195                                        Shan Kadavil
# 202           Anand Agrawal, Mayank Khera, Rishabh Goel
# 205                                       Falguni Nayar
# 211                                        Shan Kadavil
# 215                      Advitiya Sharma, Gaurav Lahoti
# 233                      Advitiya Sharma, Gaurav Lahoti
# 326                                     Byju Raveendran
# 348                     Deepinder Goyal, Pankaj Chaddah
# 362                                     Byju Raveendran
# 367                     Deepinder Goyal, Pankaj Chaddah
# 503   Pulkit Agrawal, Prashant Sachan, Arun Lodhi, B...
# 569                         Anshoo Sharma, Brij Bhushan
# 597                        Vikram Jetley, Sanjay Sharma
# 609   Amrit Acharya, Srinath Ramakkrushnan, Vishal C...
# 623                        Vikram Jetley, Sanjay Sharma
# 639       Pushkar Singh, Sudarshan Ravi, Ankit Parasher
# 663            Adhil Shetty, Arjun Shetty, Rati Shetty,
# 664                                    Geetansh Bamania
# 667       Pushkar Singh, Sudarshan Ravi, Ankit Parasher
# 692                                       Ravish Naresh
# 695       Pushkar Singh, Sudarshan Ravi, Ankit Parasher
# 703                                    Geetansh Bamania
# 707                         Anshoo Sharma, Brij Bhushan
# 712                                       Falguni Nayar
# 721   Avinash BR, Gururaj Rao, Arvind Murali, Santho...
# 756   Saurabh Saxena, Pulkit Jain, Anand Prakash, Va...
# 764               Madhusudanan R, Muthukumar and Prabhu
# 771                Gaurav Hinduja, Sashank Rishyasringa
# 785                    Jaydeep Barman, Kallol Bannerjee
# 786            Adhil Shetty, Arjun Shetty, Rati Shetty,
# 789                Gaurav Hinduja, Sashank Rishyasringa
# 792   Saurabh Saxena, Pulkit Jain, Anand Prakash, Va...
# 797                                         Sahil Sheth
# 798                        Vikram Jetley, Sanjay Sharma
# 799       Nandan Reddy, Sriharsha Majety, Rahul Jaimini
# 813                                       Falguni Nayar
# 816                                         Sahil Sheth
# 839                                       Ravish Naresh
# 867   Pulkit Agrawal, Prashant Sachan, Arun Lodhi, B...
# 877   Anand Ayyadurai, Padmanabhan Balakrishnan, San...
# 888                                      Ashneer Grover
# 896       Nandan Reddy, Sriharsha Majety, Rahul Jaimini
# 901                                        Kamesh Goyal
# 911                       Amit Singh, Deepanshu Malviya
# 920   Saurabh Saxena, Pulkit Jain, Anand Prakash, Va...
# 921               Madhusudanan R, Muthukumar and Prabhu
# 922   Avinash BR, Gururaj Rao, Arvind Murali, Santho...
# 935                                     Byju Raveendran
# 946                    Jaydeep Barman, Kallol Bannerjee
# 961                                      Ashneer Grover
# 963   Anand Ayyadurai, Padmanabhan Balakrishnan, San...
# 966   Amrit Acharya, Srinath Ramakkrushnan, Vishal C...
# 975                                        Kamesh Goyal
# 986     Vivekananda Hallekere, Anil Giri Raju,Arun Agni
# 1009    Vivekananda Hallekere, Anil Giri Raju,Arun Agni
# 1035                                    Byju Raveendran
# 1053                      Amit Singh, Deepanshu Malviya
#
#                                                Investor       Amount  \
# 109                     Accel India, Breadlake Ventures    3000000.0
# 120                            Alia Bhatt, Katrina Kaif          NaN
# 129      Rajasthan Venture Capital Fund, AIM Smart City     600000.0
# 145      Rajasthan Venture Capital Fund, AIM Smart City     600000.0
# 195                         Ascent Capital, Iron Pillar  121000000.0
# 202                               Accel, Sunder Nookala    3300000.0
# 205                            Alia Bhatt, Katrina Kaif          NaN
# 211                         Ascent Capital, Iron Pillar   16000000.0
# 215                        Sandeep Tandon, Daniel Lapus    2000000.0
# 233               Whiteboard Capital, VKG Ventures LLP.    2000000.0
# 326               Owl Ventures, Tiger Global Management  500000000.0
# 348             MacRitchie Investments, Baillie Gifford   62000000.0
# 362               Owl Ventures, Tiger Global Management  500000000.0
# 367             MacRitchie Investments, Baillie Gifford  100000000.0
# 503   KTB Network, Samsung Ventures, Ankur Nagpal, G...   11000000.0
# 569              Samsung Venture Investment Corporation    7000000.0
# 597                                    Invest in Vision   16753000.0
# 609                                           Greenoaks   21000000.0
# 623       Capital G, Alphabet's Independent growth fund   27700000.0
# 639                                     Stride Ventures    1313500.0
# 663                                         WSV Capital    5967000.0
# 664   Gautam Dalmia, Pratithi Investment Trust, Shri...    2980000.0
# 667                                          Black Soil    1326000.0
# 692                                     B Capital Group   60000000.0
# 695                                     Innoven Capital    1715000.0
# 703   Chiratae Ventures, Accel Partners, BCIP Ventur...    3226000.0
# 707                         Lightspeed Venture Partners    3879000.0
# 712                                   Steadview capital    8800000.0
# 721                                     Alteria Capital     920000.0
# 756                             KB Global Platform Firm    6800000.0
# 764                                             BeeNext    4500000.0
# 771   Ribbit Capital, SAIF Partners, Sequoia Capital...   15000000.0
# 785                                   Coatue Management   50000000.0
# 786            Amazon, Sequoia, Walden SKT Venture Fund    3800000.0
# 789                       Amazon Inc`, Dinesh J Hinduja    4800000.0
# 792                                      Legend Capital   12500000.0
# 797                                        Bace Capital    7500000.0
# 798                                         Undisclosed   23850000.0
# 799   Tencent, Ark Impact, Korea Investment Partners...   43000000.0
# 813                                   Steadview capital   13137000.0
# 816                         Pecus Capital, Madhur Deora    3000000.0
# 839                                Mahendra Singh Dhoni          NaN
# 867                           Sequoia’s Surge, Fosun RZ    4000000.0
# 877                                   Lightstone Aspada   20000000.0
# 888                                      Ribbit Capital   75000000.0
# 896                                          Prosus N.V  113000000.0
# 901                         Virat Kohli, Anushka Sharma     340000.0
# 911                               SIG Global India Fund    7975700.0
# 920                                         GGV Capital   24000000.0
# 921              Amrish Rau, Kunal Shah, Jitendra Gupta    1402000.0
# 922                  Omnivore, Accel Partners, Mayfield    5500000.0
# 935                                    General Atlantic  200000000.0
# 946                                     Alteria Capital    4900000.0
# 961                                   Coatue Management  100000000.0
# 963                                   Lightstone Aspada   35000000.0
# 966                                     InnoVen capital    2200000.0
# 975          A91 Partners, Faering Capital, TVS Capital   84000000.0
# 986                           Accel Partners, B Capital  105000000.0
# 1009                          Accel Partners, B Capital   97500000.0
# 1035                                       Tiger Global  200000000.0
# 1053                         SIG Global India Fund LLP.    8043000.0
#
#              Stage column10
# 109   Pre-series A     None
# 120           None     None
# 129           Seed     None
# 145           Seed     None
# 195       Series C     None
# 202           Seed     None
# 205           None     None
# 211           None     None
# 215           None     None
# 233           None     None
# 326           None     None
# 348           None     None
# 362           None     None
# 367           None     None
# 503       Series A     None
# 569       Series D     None
# 597       Series E     None
# 609       Series C     None
# 623       Series E     None
# 639           None     None
# 663      Series D1     None
# 664           None     None
# 667           None     None
# 692       Series B     None
# 695           None     None
# 703           None     None
# 707           None     None
# 712           None     None
# 721           None     None
# 756       Series C     None
# 764       Series A     None
# 771           None     None
# 785           None     None
# 786       Series D     None
# 789       Series F     None
# 792       Series C     None
# 797       Series B     None
# 798           None     None
# 799       Series A     None
# 813           None     None
# 816           None     None
# 839           None     None
# 867   Pre series A     None
# 877       Series C     None
# 888       Series C     None
# 896       Series A     None
# 901           None     None
# 911       Series C     None
# 920       Series C     None
# 921           None     None
# 922       Series A     None
# 935           None     None
# 946           None     None
# 961           None     None
# 963       Series C     None
# 966           None     None
# 975           None     None
# 986       Series D     None
# 1009      Series D     None
# 1035          None     None
# 1053      Series C     None

# %% [markdown]
# **Column-2: Founded: 27 Unique values**

# %%
# Filter odd entries in the 'Founded' column
odde_c2_20 = df2020[df2020['Founded'].apply(is_odd_year)]['Founded']

# Calculate the number of unique odd entries
oddn_c2_20 = odde_c2_20.unique()

# Print the number of odd entries and their details
print(f"Number of odd entries in 'Founded' column: {len(oddn_c2_20)}")
print('\nOdd entries:')
for entry in oddn_c2_20:
    print(entry)
# Out:
# Number of odd entries in 'Founded' column: 3
#
# Odd entries:
# 1978.0
# nan
# 1973.0

# %% [markdown]
# **Column-3: HeadQuarter: 78 Unique values**

# %%
# Filter odd entries in the 'HeadQuarter' column
odde_c3_20 = df2020[df2020['HeadQuarter'].apply(is_odd_location)]['HeadQuarter']

# Extract unique odd entries
oddn_c3_20 = odde_c3_20.unique()

# Print the number of odd entries and their details
print(f"Number of odd entries in 'HeadQuarter' column: {len(oddn_c3_20)}")
print('\nOdd entries:')
for entry in oddn_c3_20:
    print(entry)
# Out:
# Number of odd entries in 'HeadQuarter' column: 41
#
# Odd entries:
# Tirunelveli, Tamilnadu
# None
# Singapore
# Jaipur, Rajastan
# Frisco, Texas, United States
# California
# Dhingsara, Haryana
# New York, United States
# San Francisco, California, United States
# San Francisco, United States
# San Ramon, California
# Paris, Ile-de-France, France
# Plano, Texas, United States
# Sydney
# San Francisco Bay Area, Silicon Valley, West Coast
# Bangaldesh
# London, England, United Kingdom
# Sydney, New South Wales, Australia
# Milano, Lombardia, Italy
# Palmwoods, Queensland, Australia
# France
# San Francisco Bay Area, West Coast, Western US
# Trivandrum, Kerala, India
# Samastipur, Bihar
# Irvine, California, United States
# Tumkur, Karnataka
# Newcastle Upon Tyne, Newcastle upon Tyne, United Kingdom
# Shanghai, China
# Jiaxing, Zhejiang, China
# Rajastan
# San Franciscao
# San Francisco
# Tangerang, Jawa Barat, Indonesia
# Berlin
# Seattle
# Riyadh
# Seoul
# New York
# Bangkok
# Hyderebad
# Banglore

# %% [markdown]
# **Column-4: Sector: 303 Unique values**

# %%
# Filter odd entries in the 'Sector' column
odde_c4_20 = df2020['Sector'].apply(is_odd_sector)
oddn_c4_20 = df2020[odde_c4_20]['Sector'].unique()

# Print the number of odd entries and their details
print(f"Number of odd entries in 'Sector' column: {len(oddn_c4_20)}")
print('\nOdd entries:')
for entry in oddn_c4_20:
    print(entry)
# Out:
# Number of odd entries in 'Sector' column: 81
#
# Odd entries:
# Food & Bevarages
# Fashion startup
# Virtual auditing startup
# E-commerce
# AI startup
# Tech Startup
# IoT startup
# SaaS startup
# Retail startup
# Co-working Startup
# Gaming startup
# Blockchain startup
# Dairy startup
# Photonics startup
# Skincare startup
# Fitness startup
# PaaS startup
# EV startup
# AR/VR startup
# Recruitment startup
# QSR startup
# Luxury car startup
# Reatil startup
# Soil-Tech
# Packaging solution startup
# AI Startup
# Jewellery startup
# Deeptech startup
# Online credit management startup
# Startup laboratory
# Personal care startup
# SaaS  startup
# Marketing startup
# AR startup
# HR Tech startup
# Automotive Startup
# Food Startup
# EdTech Startup
# WL & RAC protection
# Agritech startup
# Biomaterial startup
# Healthcare/Edtech
# Agritech/Commerce
# Social e-commerce
# Food & Logistics
# None
# AR/VR
# B2B marketplace
# Health & Wellness
# IoT/Automobile
# Co-living
# Food & Beverages
# B2B
# Micro-mobiity
# Auto-tech
# Yoga & wellness
# Mobility/Transport
# AI & Debt
# SaaS/Edtech
# Co-working
# Supply chain, Agritech
# Foodtech & Logistics
# Beauty & wellness
# Travel & SaaS
# Tourism & EV
# Interior & decor
# Media & Networking
# E-market
# AI & Data science
# E-tail
# AI & Media
# VR & SaaS
# Sales & Services
# AI & Deep learning
# Housing & Rentals
# E-mobility
# Ad-tech
# Neo-banking
# Transport & Rentals
# B2B Agritech
# E-connect

# %% [markdown]
# **Column-5: What_it_does: 990 Unique values**

# %%
# Filter odd entries in the 'What_it_does' column
odde_c5_20 = df2020['What_it_does'].apply(is_odd_activity)
oddn_c5_20 = df2020[odde_c5_20]['What_it_does'].unique()

# Print the number of odd entries and their details
print(f"Number of odd entries in 'What_it_does' column: {len(oddn_c5_20)}")
print('\nOdd entries:')
for entry in oddn_c5_20:
    print(entry)
# Out:
# Number of odd entries in 'What_it_does' column: 24
#
# Odd entries:
# Escrow-as-a-service platform
# Pre-seed/Seed focussed VC investor
# SaaS-based equity management platform
# Crowdfunding, Charity, E-commerce
# A multi-game platform
# World's largest video publisher
# Agri-inputs ecommerce player
# User-generated content platform
# Subscription-based Water purifier startup
# On-demand beauty services provider
# India-based hyperlocal delivery startup
# Operates vernacular-language based education
# Pan-India Credit providing platform
# Platform for vernacular test-preparation
# Source-to-Pay Software
# Kids-focussed Youtube channel
# E-commerce for corner/retail stores.
# Inter-City Mobility Startup
# Student Co-living startup
# Cross-border consumer credit startup
# Multi-channel broadcast network
# Provides Gluten-free food
# Provides Algorithm-based financial services
# Provides IoT-enabled treadmill

# %% [markdown]
# **Column-6: Founders: 928 Unique values**

# %%
# Filter odd entries in the 'Founders' column
odde_c6_20 = df2020['Founders'].apply(is_odd_founder)
oddn_c6_20 = df2020[odde_c6_20]['Founders'].unique()

# Print the number of odd entries and their details
print(f"Number of odd entries in 'Founders' column: {len(oddn_c6_20)}")
print('\nOdd entries:')
for entry in oddn_c6_20:
    print(entry)
# Out:
# Number of odd entries in 'Founders' column: 1
#
# Odd entries:
# None

# %% [markdown]
# **Column-7: Investor: 849 Unique values**

# %%
# Filter odd entries in the 'Founders' column
odde_c7_20 = df2020['Investor'].apply(is_odd_investor)
oddn_c7_20 = df2020[odde_c7_20]['Investor'].unique()

# Print the number of odd entries and their details
print(f"Number of odd entries in 'Investor' column: {len(oddn_c7_20)}")
print('\nOdd entries:')
for entry in oddn_c7_20:
    print(entry)
# Out:
# Number of odd entries in 'Investor' column: 30
#
# Odd entries:
# ICICI Bank.
# BlackSoil, Caspian
# None
# Flipkart, Walmart
# Sequoia Capital.
# 9Unicorns, Anicut
# GoodWorker.
# Endiya Partners.
# >Vikram Sud
# AngelList, Investec
# MOX, SOSV
# SOSV, Artesian
# Startup Basket.
# NABVENTURES, Omnivore
# Triodos, Caspian
# BlackSoil, BEENEXT
# Homage Ventures.
# Prospect Partners.
# Omnivore, Zeroth.AI
# Mumbai Angels.
# responsAbility, Accel
# Madison, Anicut
# Chiratae Ventures.
# Nestavera Ventures.
# Ah! Ventures
# Atraxn Partners.
# Sauce.vc
# Prosus N.V
# Unitus Ventures.
# SOSV, Chinaccelerator

# %% [markdown]
# **Column-9: Stage: 43 Unique values**

# %%
# Identify odd entries in 'Stage' column of df2021
odde_c9_20 = odd_stage(df2020['Stage'])

# Get unique odd entries
oddn_c9_20 = set(odde_c9_20)

# Print the number of odd entries and their details
print(f"Number of odd entries in 'Stage' column: {len(oddn_c9_20)}")
print('\nOdd entries:')
for entry in oddn_c9_20:
    print(entry)
# Out:
# Number of odd entries in 'Stage' column: 4
#
# Odd entries:
# Edge
# Bridge
# Debt
# None

# %% [markdown]
# #### Load LP1_startup_funding2019 Data

# %% [markdown]
# **Structuring and ordering dataframe**

# %%
# Rename columns in the DataFrame
df2019 = df2019.rename(columns={
    'Company/Brand': 'Company_Brand',
    'What it does': 'What_it_does',
    'Amount($)': 'Amount'
})

# Display information
df2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  89 non-null     object
#  1   Founded        60 non-null     float64
#  2   HeadQuarter    70 non-null     object
#  3   Sector         84 non-null     object
#  4   What_it_does   89 non-null     object
#  5   Founders       86 non-null     object
#  6   Investor       89 non-null     object
#  7   Amount         89 non-null     object
#  8   Stage          43 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 6.4+ KB

# %% [markdown]
# ##### Missing and Duplicate Data Quality Considerations

# %%
# Determine the proportion of missing values
missing_percentage_19 = (df2019.isnull().mean() * 100).round(2)

# Check for duplicated values
duplicate_count_19 = df2019.duplicated(subset=None, keep=False).sum()

# Display duplicated rows if any
duplicated_rows_19 = df2019[df2019.duplicated(subset=None, keep=False)]

# Display Results
print("Proportion of missing values in 2019 data:")
print()
print(missing_percentage_19)
print("\nNumber of duplicated rows in 2019 data:", duplicate_count_19)
print("\nDuplicated rows in 2019 data:")
duplicated_rows_19
# Out:
# Proportion of missing values in 2019 data:
#
# Company_Brand     0.00
# Founded          32.58
# HeadQuarter      21.35
# Sector            5.62
# What_it_does      0.00
# Founders          3.37
# Investor          0.00
# Amount            0.00
# Stage            51.69
# dtype: float64
#
# Number of duplicated rows in 2019 data: 0
#
# Duplicated rows in 2019 data:
# Empty DataFrame
# Columns: [Company_Brand, Founded, HeadQuarter, Sector, What_it_does, Founders, Investor, Amount, Stage]
# Index: []

# %% [markdown]
# ##### Unique values Data Quality Considerations

# %%
# List all elements in the columns
for i, column in enumerate(df2019.columns):
    print(f'Column-{i + 1}: {column}: {len(df2019[column].unique())}\n', df2019[column].unique())
    print('_'*100)
    print()
# Out:
# Column-1: Company_Brand: 87
#  ['Bombay Shaving' 'Ruangguru' 'Eduisfun' 'HomeLane' 'Nu Genes' 'FlytBase'
#  'Finly' 'Kratikal' 'Quantiphi' 'Lenskart' 'Cub McPaws' 'Appnomic'
#  'Kaleidofin' 'JobSquare' 'Open Secret' 'LivFin' "Byju's" 'Zest Money'
#  'Witblox' 'Azah Personal Care Pvt. Ltd.' 'SalaryFits' 'Pristyn Care'
#  'Springboard' 'DROR Labs Pvt. Ltd' 'Medlife' 'Seekify' 'Toffee Insurance'
#  'Fireflies .ai' 'HungerBox' 'Bijak' 'Licious' 'truMe' 'Pumpkart'
#  'Asteria Aerospace' 'Rivigo' 'HappyEasyGo' 'Zetwerk' 'Observe.AI'
#  'Freshokartz' 'Lil’ Goodness and sCool meal' 'Trell' 'VMate'
#  'Bombay Shirt Company' 'Slintel' 'MyGameMate' 'Afinoz' 'Rein Games'
#  'Ecozen' 'Box8' 'Awign Enterprises' 'Purplle' 'Freightwalla' 'TapChief'
#  'eJOHRI' 'Ninjacart' 'Binca Games' 'KredX' 'm.Paani' 'Origo' 'WishADish'
#  'Ecom Express' 'Stanza Living' 'PiBeam' 'Euler Motors' 'Moms Co'
#  'Cubical Labs' 'Lawyered' 'Cuemath' 'Nivesh.com' 'Zebu' 'Smart Institute'
#  'CarDekho' 'Shadowfax' 'Credr' 'Sportido' 'Phable' 'Sarva' 'IndyFint'
#  'Zolostays' 'Ola' 'Zoomcar' 'Froogal' 'Infra.Market' 'Oyo' 'GoMechanic'
#  'Spinny' 'Ess Kay Fincorp']
# ____________________________________________________________________________________________________
#
# Column-2: Founded: 13
#  [  nan 2014. 2004. 2013. 2010. 2018. 2019. 2017. 2011. 2015. 2016. 2012.
#  2008.]
# ____________________________________________________________________________________________________
#
# Column-3: HeadQuarter: 18
#  [nan 'Mumbai' 'Chennai' 'Telangana' 'Pune' 'Bangalore' 'Noida' 'Delhi'
#  'Ahmedabad' 'Gurugram' 'Haryana' 'Chandigarh' 'Jaipur' 'New Delhi'
#  'Surat' 'Uttar pradesh' 'Hyderabad' 'Rajasthan']
# ____________________________________________________________________________________________________
#
# Column-4: Sector: 53
#  ['Ecommerce' 'Edtech' 'Interior design' 'AgriTech' 'Technology' 'SaaS'
#  'AI & Tech' 'E-commerce' 'E-commerce & AR' 'Fintech' 'HR tech'
#  'Food tech' 'Health' 'Healthcare' 'Safety tech' 'Pharmaceutical'
#  'Insurance technology' 'AI' 'Foodtech' 'Food' 'IoT' 'E-marketplace'
#  'Robotics & AI' 'Logistics' 'Travel' 'Manufacturing' 'Food & Nutrition'
#  'Social Media' nan 'E-Sports' 'Cosmetics' 'B2B' 'Jewellery'
#  'B2B Supply Chain' 'Games' 'Food & tech' 'Accomodation' 'Automotive tech'
#  'Legal tech' 'Mutual Funds' 'Cybersecurity' 'Automobile' 'Sports'
#  'Healthtech' 'Yoga & wellness' 'Virtual Banking' 'Transportation'
#  'Transport & Rentals' 'Marketing & Customer loyalty' 'Infratech'
#  'Hospitality' 'Automobile & Technology' 'Banking']
# ____________________________________________________________________________________________________
#
# Column-5: What_it_does: 88
#  ['Provides a range of male grooming products'
#  'A learning platform that provides topic-based journey, animated videos, quizzes, infographic and mock tests to students'
#  'It aims to make learning fun via games.'
#  'Provides interior designing solutions'
#  'It is a seed company engaged in production, processing and marketing of seeds'
#  'A drone automation platform'
#  'It builds software products that makes work simpler, pleasant, and productive'
#  'It is a product-based cybersecurity solutions provider'
#  'It is an AI and big data services company providing business solutions.'
#  'It is a eyewear company'
#  'A B2C\xa0\xa0brand that focusses on premium and comfortable merchandise for Generation Alpha – kids'
#  'It is a self-healing enterprise, the IT operations software detects, predicts and prevents problems before they happen'
#  'Platform that provides complete financial solutions for excluded individuals and households'
#  'Technology-based platform that is connecting suitable applicants to the right recruiters'
#  'It produces and sells top quality snacks'
#  'Grants small business loans, supply chain finance and working capital loans to small and medium enterprises'
#  'Provides online learning classes'
#  'Uses AI to do risk profiling of e-commerce consumers who opt for EMI'
#  'Offers a range of robotics learning tools'
#  'Aims to solve some problems in the feminine hygiene sector'
#  'A platform that promotes financial well-being of employees at workplace'
#  'Delivers advanced medical care & clinical excellence aided by next-level technology'
#  'Offers online courses and extensive mentor-based learning'
#  'It uses technology to create a trust-based network of responsible citizens to ensure safety'
#  'It solves inadequacies in the healthcare delivery system through technology'
#  'Customer Experience (CX) Automation platform'
#  'Provides variety of insurance plans and policies'
#  'Developer of an artificial intelligence-powered assistant for businesses'
#  'Offers B2B tech platform to corporates, aimed at improving the operations of their cafeterias'
#  'B2B platform for agricultural commodities.' 'Online meat shop'
#  'A global platform for Identity and Access Management'
#  'B2B model for appliances and electrical products'
#  'Develops drones that are used by the military, paramilitary, police forces and in various industries.'
#  'It offers delivery services across India to retail, e-commerce, pharmaceutical, automobile and FMCG companies'
#  'Online flight booking'
#  'Provides facilities to get products manufactured.'
#  'Creates a voice AI platform'
#  'Online fruits and vegetables delivery company'
#  "It empowers moms to provide the best of foods to their Lil' ones"
#  'Blogging platform that enables people to create visual collections of their travel and local experiences'
#  'A short video platform' 'Online custom shirt brand'
#  'It helps sales and marketing teams understand purchase intent of buyers on buying patterns, usage and renewals'
#  'eSports platform where players can access various multiplayer mobile games to participate in online tournaments'
#  'Online financial marketplace for customized rate quotes on loans and investment products in India'
#  'It develops, publishes and distributes games across various platforms'
#  'It develops technology-enabled products to strengthen the farm-to-fork value chain of perishables.'
#  'Enables to order food online' 'It supplies workforce to the economy'
#  'Online makeup and beauty products retailer'
#  'Provides digital platform for businesses to plan and manage their international freight shipments online'
#  'It connects individuals in need of advice in a specific domain to individuals who have expertise in the same'
#  'Omnichannel marketplace for gems and jewellery'
#  'It connects producers of food directly to retailers, restuarants and service providers.'
#  'It offers games that are available across India and UK.'
#  'Invoice discounting platform'
#  'It digitizes and organises local retailers'
#  'It provides post-harvest management services for agricultural commodities'
#  'Provides management solution for restaurants'
#  'It is a technology enabled logistics solutions provider to the Indian e-commerce industry'
#  'Provides comfortable and secure accomodation for students'
#  'It is engaged in building sustainable and affordable micro-mobility electric vehicles'
#  'It is offering mobility as a service'
#  'It is into mother and baby care-focused consumer goods'
#  'Home automation solution provider'
#  'It helps to connect to legal advise online'
#  'It helps students to learn math online'
#  'The platform simplifies the process of investment'
#  'Platform uses encryption technology to allow businesses to safely store files, invoices, and schedules'
#  'A platform to learn online'
#  'Enables people to buy and sell new/old cars.'
#  'A platform for delivery services'
#  'A marketplace to buy and sell used bikes and scooters'
#  'It is a sports discovery app that helps to find people and places to play 700+ sports'
#  'It creates an engagement loop between doctors, hospitals, and patients via its app'
#  'It drives a cultural change in making yoga-based wellness a part of modern lifestyle'
#  'It helps lenders to directly provide short-term loans to merchants, employees, and students'
#  'It offers affordable housing apartments to young professionals and students'
#  'It enables one to book cab online' 'A car rental service platform'
#  'Provides cyber security solutions'
#  'A cloud based Customer Loyalty & Engagement Platform'
#  'It connects client requirements to their supply chain infrastructure for ease of ordering, tracking and manufacturing'
#  'Provides rooms for comfortable stay'
#  'Find automobile repair and maintenance service providers'
#  'Online car retailer' 'Organised Non-Banking Finance Company']
# ____________________________________________________________________________________________________
#
# Column-6: Founders: 86
#  ['Shantanu Deshpande' 'Adamas Belva Syah Devara, Iman Usman.'
#  'Jatin Solanki' 'Srikanth Iyer, Rama Harinath' 'Narayana Reddy Punyala'
#  'Nitin Gupta' 'Vivek AG, Veekshith C Rai'
#  'Pavan Kushwaha, Paratosh Bansal, Dip Jung Thapa' 'Renuka Ramnath'
#  'Peyush Bansal, Amit Chaudhary, Sumeet Kapahi' 'Abhay Bhat, Kinnar Shah'
#  'D Padmanabhan' 'Puneet Gupta, Sucharita Mukherjee' 'Ishit Jethwa'
#  'Ahana Gautam, Udit Kejriwal' 'Rakesh Malhotra' 'Byju Raveendran'
#  'Chapman, Priya Sharma, Ashish Anantharaman' 'Amit Modi'
#  'Mohammed, Shashwat Diesh' 'Renato Araujo'
#  'Harsimarbir Singh, Dr Vaibhav Kapoor, Dr Garima Sawhney'
#  'Gautam Tambay, Parul Gupta' 'Dhiraj Naubhar, Dheeraj Bansal'
#  'Tushar Kumar, Prashant Singh' 'Arihant Jain, Ajeet Kushwaha'
#  'Nishant Jain, Rohan Kumar' 'Sam Udotong' 'Sandipan Mitra, Uttam Kumar'
#  'Nukul Upadhye, Mahesh Jakhotia, Jitender Bedwal, Daya Rai, Nikhil Tripathi'
#  'Vivek Gupta, Abhay Hanjura' 'Babu Dayal, Pramod Uniyal, Lalit Mehta'
#  'KS Bhatia' 'Neel Mehta, Nihar Vartak' 'Deepak Garg, Gazal Kalra'
#  'Vivek Prabhakar, Boris Zha' 'Amit Acharya, Srinath Ramakkrushnan'
#  'Swapnil' 'Rajendra Lora' nan
#  'Pulkit Agrawal, Prashant Sachan, Arun Lodhi, Bimal Kartheek Rebba'
#  'Akshay Narvekar' 'Deepak Anchala' 'Parshavv Jain& Raju Kushwaha'
#  'Rachna Suneja'
#  'Vaibhav Gupta, Himanshu Devra, Pranav Chaudhary, Nishtha Gupta'
#  'Devendra Gupta, Prateek Singhal, Vivek Pandey' 'Amit Raj, Anshul Gupta'
#  'Annanya Sarthak, Gurpreet Singh, Praveen Sah'
#  'Manish Taneja, Rahul Dash' 'Sanjay Bhatia, Bharat Tanvi, Punit Java'
#  'Shashank Murali, Binay Krishna, Arjun Krishna'
#  'Jignesh Mehta, Shailen Mehta'
#  'Thirukumaran Nagarajanin, Vasudevan Chinnathambi'
#  'Rubianca Wadhwa, Sahil Wadhwa' 'Manish Kumar' 'Akanksha Hazari'
#  'Mayank Dhanuka, Sunoor Kaul' 'Sawan Kumar, Bhavya Bhambhani'
#  'Krishnan, Manju Dhawan, K Satyanarayana, Sanjeev Saxena'
#  'Sandeep Dalmia, Anindya Dutta' 'Visakh Sasikumar' 'Saurav Kumar'
#  'Malika Sadani' 'Dhruv Ratra, Swati Vyas' 'Ashish Bhatia, Himanshu Gupta'
#  'Manan Khurma' 'Anurag Garg, Sridhar Srinivasan'
#  'Team of Waterloo-based software developers' 'Amit Jain'
#  'Abhishek Bansal, Vaibhav Khandelwal' 'Mittal'
#  'Neeraj Aggarwala, Akhil Ramachandran' 'Sumit Sinha' 'Sarvesh Shashi'
#  'Paddy Padmanabhan' 'Akhil Sikri, Nikhil Sikri, Sneha Choudhry'
#  'Bhavish Aggarwal, Ankit Bhati' 'Greg Moran, David Back' 'Pavan Kushwaha'
#  'Jeevan Chowdary M, Harshit Harchani' 'Aaditya Sharda, Souvik Sengupta'
#  'Ritesh Agarwal' 'Amit Bhasin, Kushal Karwa, Nitin Rana, Rishabh Karwa'
#  'Niraj Singh, Ramanshu Mahaur, Ganesh Pawar, Mohit Gupta'
#  'Rajendra Setia']
# ____________________________________________________________________________________________________
#
# Column-7: Investor: 86
#  ['Sixth Sense Ventures' 'General Atlantic'
#  'Deepak Parekh, Amitabh Bachchan, Piyush Pandey'
#  'Evolvence India Fund (EIF), Pidilite Group, FJ Labs'
#  'Innovation in Food and Agriculture (IFA)' 'Undisclosed'
#  'Social Capital, AngelList India, Gemba Capital, Omphalos Ventures,\xa0\xa091springboard via Atal Innovation Mission, Niti Aayog.'
#  'Gilda VC, Art Venture, Rajeev Chitrabhanu.'
#  'Multiples Alternate Asset Management' 'SoftBank' 'Venture Catalysts'
#  'Avataar Ventures' 'Oikocredit' 'Titan Capital' 'Matrix Partners'
#  'German development finance institution DEG'
#  'South Africa’s Naspers Ventures, the CPP Investment Board'
#  'Goldman Sachs.' 'Mumbai Angels Network' 'Kunal Bahl, Rohit Bansal.'
#  'Brazilian VC Fund Confrapar'
#  'Sequoia India, Hummingbird Ventures, Greenoaks Capital, AngelList.'
#  'Reach Capital' 'Inflection Point Ventures'
#  'Wilson Global Opportunities Fund' 'Sequoia Capita' 'IVM Intersurer'
#  'Canaan Partners' 'Paytm, Asian VC fund NPTK, Sabre Partners, Neoplux.'
#  'Omnivore and Omidyar Network India, Sequoia Capital'
#  'Vertex Growth Fund' 'Rajan Kaistha' 'Dinesh Dua' 'Reliance Industries'
#  'SAIF Partners India VI Ltd, Spring Canter Investment Ltd'
#  'Korea Investment Partners (KIP), Samsung Venture Investment Corporation (SVIC), UOB Venture, 10 Fund, CVCapital, Zero2IPO Ventures, M&S Partners'
#  'Lightspeed and Greenoaks Capital, Sequoia India, Accel and Kae Capital'
#  'Scale Venture Partners' 'ThinkLab' 'Sajan Pillai, Muthu Krishnan,'
#  'Ruizheng Investment, Tej Kapoor, Krinshavataram Venkata Vinjamuri, Harsh Shah'
#  'Alibaba' 'Lightbox Ventures' 'Stellaris Ventures' 'Jindagi Live Angels,'
#  'Fintech innovation lab'
#  'Manipal Education and Medical Group (MEMG) family office, Titan Capital'
#  'Innovation in Food & Agriculture Fund (IFA Fund)' 'Trifecta Capital'
#  'Work10M, Michael and Susan Dell Foundation, Eagle10, Unitus Ventures.'
#  'Goldman Sachs' 'Amplo, FJ Labs, Rogue One Capital' 'Blume Ventures.'
#  'Rajesh Ranavat' 'Walmart, Flipkart' 'Sunil Gavaskar'
#  'Tiger Global Management' 'AC Ventures, Henkel'
#  'Oikocredit, Caspian SME Impact Fund IV,\xa0\xa0Triodos Investment Management'
#  'CDC Group' 'Alteria Capital' 'GAIL (India) Ltd'
#  'Blume Ventures, Emergent Ventures'
#  'Saama Capital, DSG Consumer Partners' 'Rockstud Capital'
#  'Pramendra Tomar, Ratish Pandey, Munish Bhatia, Sumit Aggarwal'
#  'Manta Ray Ventures Limited, Google’s Capital G, Sequoia India.'
#  'Vertex Ventures' 'Windrose Capital' 'HNI investors'
#  'Ping An Global Voyager Fund, Hillhouse Capital, Sequoia Capital'
#  'Flipkart, Eight Roads Ventures, NGP Capital, Qualcomm Ventures, Mirae Asset Naver Fund, World Bank-backed IFC'
#  'Omidyar Network, Eight Roads Ventures, GrowthStory, AngelList'
#  'Inflection Point Ventures, SucSEED Venture Partners.'
#  'LetsVenture, 91 Springboard, IKP Knowledge, Angel investors, AbInbev-Serge DeVos, Wouter Peeters.'
#  'Venture fund, Fireside Ventures.' 'Saravanan Adiseshan'
#  'Kia Motors, Hyundai' 'Zoomcar Inc'
#  'Gilda VC, Art Venture, Rajeev Chitrabhanu' 'US-based angel investors'
#  'Tiger Global, Nexus Venture Partners, Accel Partners, Dhruv Agarwala'
#  'MyPreferred Transformation, Avendus Finance, SoftBank' 'Sequoia Capital'
#  'Norwest Venture Partners, General Catalyst, Fundamentum, Accel Partners'
#  'TPG, Norwest Venture Partners, Evolvence India']
# ____________________________________________________________________________________________________
#
# Column-8: Amount: 50
#  ['$6,300,000' '$150,000,000' '$28,000,000' '$30,000,000' '$6,000,000'
#  'Undisclosed' '$1,000,000' '$20,000,000' '$275,000,000' '$22,000,000'
#  '$5,000,000' '$140,500' '$540,000,000' '$15,000,000' '$182,700'
#  '$12,000,000' '$11,000,000' '$15,500,000' '$1,500,000' '$5,500,000'
#  '$2,500,000' '$140,000' '$230,000,000' '$49,400,000' '$32,000,000'
#  '$26,000,000' '$150,000' '$400,000' '$2,000,000' '$100,000,000'
#  '$8,000,000' '$100,000' '$50,000,000' '$120,000,000' '$4,000,000'
#  '$6,800,000' '$36,000,000' '$5,700,000' '$25,000,000' '$600,000'
#  '$70,000,000' '$60,000,000' '$220,000' '$2,800,000' '$2,100,000'
#  '$7,000,000' '$311,000,000' '$4,800,000' '$693,000,000' '$33,000,000']
# ____________________________________________________________________________________________________
#
# Column-9: Stage: 16
#  [nan 'Series C' 'Fresh funding' 'Series D' 'Pre series A' 'Series A'
#  'Series G' 'Series B' 'Post series A' 'Seed funding' 'Seed fund'
#  'Series E' 'Series F' 'Series B+' 'Seed round' 'Pre-series A']
# ____________________________________________________________________________________________________

# %% [markdown]
# ##### Identifying Odd Entries in Each Column

# %% [markdown]
# **Column-1: Company_Brand: 87 Unique values**
#
# There are no duplicate rows in this dataset and no non null values within this column.

# %% [markdown]
# **Column-2: Founded: 13 Unique values**

# %%
# Filter odd entries in the 'Founded' column
odde_c2_19 = df2019[df2019['Founded'].apply(is_odd_year)]['Founded']

# Calculate the number of unique odd entries
oddn_c2_19 = odde_c2_19.unique()

# Print the number of odd entries and their details
print(f"Number of odd entries in 'Founded' column: {len(oddn_c2_19)}")
print('\nOdd entries:')
for entry in oddn_c2_19:
    print(entry)
# Out:
# Number of odd entries in 'Founded' column: 1
#
# Odd entries:
# nan

# %% [markdown]
# **Column-3: HeadQuarter: 18 Unique**

# %%
# Filter odd entries in the 'HeadQuarter' column
odde_c3_19 = df2019[df2019['HeadQuarter'].apply(is_odd_location)]['HeadQuarter']

# Extract unique odd entries
oddn_c3_19 = odde_c3_19.unique()

# Print the number of odd entries and their details
print(f"Number of odd entries in 'HeadQuarter' column: {len(oddn_c3_19)}")
print('\nOdd entries:')
for entry in oddn_c3_19:
    print(entry)
# Out:
# Number of odd entries in 'HeadQuarter' column: 2
#
# Odd entries:
# nan
# Uttar pradesh

# %% [markdown]
# **Column-4: Sector: 53 Unique values**

# %%
# Filter odd entries in the 'Sector' column
odde_c4_19 = df2019['Sector'].apply(is_odd_sector)
oddn_c4_19 = df2019[odde_c4_19]['Sector'].unique()

# Print the number of odd entries and their details
print(f"Number of odd entries in 'Sector' column: {len(oddn_c4_19)}")
print('\nOdd entries:')
for entry in oddn_c4_19:
    print(entry)
# Out:
# Number of odd entries in 'Sector' column: 15
#
# Odd entries:
# AI & Tech
# E-commerce
# E-commerce & AR
# E-marketplace
# Robotics & AI
# Food & Nutrition
# nan
# E-Sports
# B2B
# B2B Supply Chain
# Food & tech
# Yoga & wellness
# Transport & Rentals
# Marketing & Customer loyalty
# Automobile & Technology

# %% [markdown]
# **Column-5: What_it_does: 88 Unique values**

# %%
# Filter odd entries in the 'What_it_does' column
odde_c5_19 = df2019['What_it_does'].apply(is_odd_activity)
oddn_c5_19 = df2019[odde_c5_19]['What_it_does'].unique()

# Print the number of odd entries and their details
print(f"Number of odd entries in 'What_it_does' column: {len(oddn_c5_19)}")
print('\nOdd entries:')
for entry in oddn_c5_19:
    print(entry)
# Out:
# Number of odd entries in 'What_it_does' column: 1
#
# Odd entries:
# Organised Non-Banking Finance Company

# %% [markdown]
# **Column-6: Founders: 86 Unique values**

# %%
# Filter odd entries in the 'Founders' column
odde_c6_19 = df2019['Founders'].apply(is_odd_founder)
oddn_c6_19 = df2019[odde_c6_19]['Founders'].unique()

# Print the number of odd entries and their details
print(f"Number of odd entries in 'Founders' column: {len(oddn_c6_19)}")
print('\nOdd entries:')
for entry in oddn_c6_19:
    print(entry)
# Out:
# Number of odd entries in 'Founders' column: 1
#
# Odd entries:
# nan

# %% [markdown]
# **Column-7: Investor: 86 Unique values**

# %%
# Filter odd entries in the 'Founders' column
odde_c7_19 = df2019['Investor'].apply(is_odd_investor)
oddn_c7_19 = df2019[odde_c7_19]['Investor'].unique()

# Print the number of odd entries and their details
print(f"Number of odd entries in 'Investor' column: {len(oddn_c7_19)}")
print('\nOdd entries:')
for entry in oddn_c7_19:
    print(entry)
# Out:
# Number of odd entries in 'Investor' column: 3
#
# Odd entries:
# Goldman Sachs.
# Blume Ventures.
# Walmart, Flipkart

# %% [markdown]
# **Column-8: Amount: 50 Unique values**

# %%
# Apply the odd_amount function to each element in the 'Amount' column of df2021
odde_c8_19 = df2019['Amount'].apply(odd_amount)

# Filter the DataFrame to get only the rows where 'Amount' column has odd entries
oddn_c8_19 = df2019[odde_c8_19]['Amount'].unique()

# Print the number of odd entries and their details
print(f"Number of odd entries in 'Amount' column: {len(oddn_c8_19)}")
print('\nOdd entries:')
for entry in oddn_c8_19:
    print(entry)
# Out:
# Number of odd entries in 'Amount' column: 50
#
# Odd entries:
# $6,300,000
# $150,000,000
# $28,000,000
# $30,000,000
# $6,000,000
# Undisclosed
# $1,000,000
# $20,000,000
# $275,000,000
# $22,000,000
# $5,000,000
# $140,500
# $540,000,000
# $15,000,000
# $182,700
# $12,000,000
# $11,000,000
# $15,500,000
# $1,500,000
# $5,500,000
# $2,500,000
# $140,000
# $230,000,000
# $49,400,000
# $32,000,000
# $26,000,000
# $150,000
# $400,000
# $2,000,000
# $100,000,000
# $8,000,000
# $100,000
# $50,000,000
# $120,000,000
# $4,000,000
# $6,800,000
# $36,000,000
# $5,700,000
# $25,000,000
# $600,000
# $70,000,000
# $60,000,000
# $220,000
# $2,800,000
# $2,100,000
# $7,000,000
# $311,000,000
# $4,800,000
# $693,000,000
# $33,000,000

# %% [markdown]
# **Column-9: Stage: 16 Unique values**

# %%
# Identify odd entries in 'Stage' column
odde_c9_19 = odd_stage(df2019['Stage'])

# Get unique odd entries
oddn_c9_19 = set(odde_c9_19)

# Print the number of odd entries and their details
print(f"Number of odd entries in 'Stage' column: {len(oddn_c9_19)}")
print('\nOdd entries:')
for entry in oddn_c9_19:
    print(entry)
# Out:
# Number of odd entries in 'Stage' column: 2
#
# Odd entries:
# nan
# Fresh funding

# %% [markdown]
# #### Load LP1_startup_funding2018 Data

# %% [markdown]
# **Structuring and ordering dataframe**

# %%
# Rename columns in the DataFrame
df2018 = df2018.rename(columns={
    'Company Name': 'Company_Brand',
    'Industry': 'Sector',
    'Round/Series': 'Stage',
    'Location': 'HeadQuarter',
    'About Company': 'What_it_does',   
})

# Add new columns with 'Not filled'
df2018['Founded'] = np.nan
df2018['Founders'] = 'Not filled'
df2018['Investor'] = 'Not filled'

# Define the new order of columns
new_order = ['Company_Brand', 'Founded', 'HeadQuarter', 'Sector', 'What_it_does', 'Founders', 'Investor', 'Amount', 'Stage']

# Rearrange columns based on the new order
df2018 = df2018[new_order]

# Display information
df2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  526 non-null    object
#  1   Founded        0 non-null      float64
#  2   HeadQuarter    526 non-null    object
#  3   Sector         526 non-null    object
#  4   What_it_does   526 non-null    object
#  5   Founders       526 non-null    object
#  6   Investor       526 non-null    object
#  7   Amount         526 non-null    object
#  8   Stage          526 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 37.1+ KB

# %% [markdown]
# ##### Missing and Duplicate Data Quality Considerations

# %%
# Determine the proportion of missing values
missing_percentage_18 = (df2018.isnull().mean() * 100).round(2)

# Check for duplicated values
duplicate_count_18 = df2018.duplicated(subset=None, keep=False).sum()

# Display duplicated rows if any
duplicated_rows_18 = df2018[df2018.duplicated(subset=None, keep=False)]

# Display Results
print("Proportion of missing values in 2018 data:")
print()
print(missing_percentage_18)
print("\nNumber of duplicated rows in 2018 data:", duplicate_count_18)
print("\nDuplicated rows in 2018 data:")
duplicated_rows_18
# Out:
# Proportion of missing values in 2018 data:
#
# Company_Brand      0.0
# Founded          100.0
# HeadQuarter        0.0
# Sector             0.0
# What_it_does       0.0
# Founders           0.0
# Investor           0.0
# Amount             0.0
# Stage              0.0
# dtype: float64
#
# Number of duplicated rows in 2018 data: 2
#
# Duplicated rows in 2018 data:
#        Company_Brand  Founded                  HeadQuarter  \
# 0    TheCollegeFever      NaN  Bangalore, Karnataka, India
# 348  TheCollegeFever      NaN  Bangalore, Karnataka, India
#
#                                                 Sector  \
# 0    Brand Marketing, Event Promotion, Marketing, S...
# 348  Brand Marketing, Event Promotion, Marketing, S...
#
#                                           What_it_does    Founders  \
# 0    TheCollegeFever is a hub for fun, fiesta and f...  Not filled
# 348  TheCollegeFever is a hub for fun, fiesta and f...  Not filled
#
#        Investor  Amount Stage
# 0    Not filled  250000  Seed
# 348  Not filled  250000  Seed

# %% [markdown]
# ##### Unique values Data Quality Considerations

# %%
# List all elements in the columns
for i, column in enumerate(df2018.columns):
    print(f'Column-{i + 1}: {column}: {len(df2018[column].unique())}\n', df2018[column].unique())
    print('_'*100)
    print()
# Out:
# Column-1: Company_Brand: 525
#  ['TheCollegeFever' 'Happy Cow Dairy' 'MyLoanCare' 'PayMe India' 'Eunimart'
#  'Hasura' 'Tripshelf' 'Hyperdata.IO' 'Freightwalla' 'Microchip Payments'
#  'BizCrum Infotech Pvt. Ltd.' 'Emojifi' 'Flock' 'Freshboxx'
#  'Wide Mobility Mechatronics' 'Pitstop' 'Mihuru' 'Fyle' 'AppWharf'
#  'Antariksh Waste Ventures Pvt ltd' 'Cogoport' 'PaisaDukan'
#  'Sleepy Owl Coffee' 'BlueJack' 'PregBuddy' 'AgNext Technologies' 'Pando'
#  'Mintifi' 'Carcrew' 'NicheAI' 'Chariot Tech'
#  'Ideal Insurance Brokers/ 121Policy.com' 'Loanzen' 'Mojro Technologies'
#  'Elemential' 'Loadshare' 'Yumlane' 'Kriger Campus' 'Pipa+Bella'
#  'Kaleidofin' 'Chakr Innovation' 'IndigoLearn' 'UClean' 'Coutloot'
#  'Letstrack' 'Pooltoo' 'Finzy' 'Fitternity' 'Keito' 'Tolet for Students'
#  'Chai Kings' 'Dainik Jagran' 'Playtoome' 'ONGO Framework' 'Notesgen'
#  'Arogya MedTech' 'Propshop24' 'myUpchar' 'MissMalini Entertainment'
#  'Rooter' 'ZestMoney' 'alphaics Corporation' 'MyDentistChoice' 'Sattviko'
#  'Sensibull' 'Bombay Shaving Company' 'MedCords' 'University Living' '&ME'
#  'Enakshi' 'Ultraviolette Automotive' 'Inthree Access'
#  'BUGWORKS Research India' 'Guardian.in' 'PrestLoans' 'Wimoxez'
#  'India Accelerator' 'HappyEMI' 'Wishup' 'Hansel.io' 'Propelld'
#  'PivotRoots' 'ZiffyHomes' 'Carmesi' 'OckyPocky' 'Racetrack' 'WHR'
#  'Asteria Aerospace' 'FabAlley' 'Tranzmeo' 'SBI Life' 'Studds Accessories'
#  'Design Cafe' 'NoPaperForms Solutions Pvt. Ltd.' 'Rays Power Infra'
#  'AuthMetrik' 'Khidki' 'LetsTransport' 'Next Digital Solutions'
#  'Portea Medical' 'Aavas Financiers' 'Swiggy' 'Milkbasket'
#  'Nutrisattva (Proliva)' 'Toppr' 'Jagaran Microfin' 'Vivriti Capital'
#  'Be U Salons' 'Impact Guru' 'MobiKwik' 'Stones2Milestones' 'Generico'
#  'Adiuvo Diagnostics' 'DataTrained' 'OneAssist'
#  'Satin Creditcare Network Limited (SCNL)' 'APAC Financial Services'
#  'Moglix' 'SEDEMAC Mechatronics' 'MadGuy Labs' 'Dee Dee Labs' 'FLEECA'
#  'Shop101' 'FeedMyPockets' 'Housejoy' 'Ambee' 'FoodBuddy' 'Ninjacart'
#  'Olly Smart Credit Card' 'Zestl' 'BYJU’S' 'Wakefit' 'Hero Electric'
#  'Pentation Analytics' 'PerkFinance' 'Roposo' 'Plum Goodness' 'Drstore'
#  'Wow Venue' 'Chizel' 'OTO Capital' 'Boodmo' 'Khabri' 'MyNewCar.in'
#  'HalaPlay Technologies' 'PlanetSpark' 'WheelsEMI'
#  'Forum for Innovation Incubation Research and Entrepreneurship' 'OYO'
#  'Quikr' 'Tabono' 'LearnApp' 'Shopkirana' 'Fric Bergen' 'Articbot'
#  'BuildSupply' 'Fusion Microfinance' 'Any time Doctor' 'Go Payments'
#  'Guiddoo World' 'ION Energy' 'UnoTag' 'CivilCops' 'Rockmetric'
#  'Classworks India' 'Snapmint' 'artbandhu' 'Survaider' 'Credy' 'iChamp'
#  'Qandle' 'Avishkaar Box' 'Gegadyne Energy' 'HyperXchange' 'Deftouch'
#  'Doodhwala' 'DronaHQ' 'FastFox' 'BuyForexOnline' 'Colive.in'
#  'Agricxlab Private Limited' 'Corefactors' 'Fincash.com'
#  'Pandorum Technologies' 'Shirsa Labs' 'PetSutra' 'Awaaz De' 'PinkBlue'
#  'Eduvanz' 'Rupeek' 'Backpacker Panda Holidays Private Limited'
#  'Shape (School Health and Physical Education)' 'Placio'
#  'Aviom India Housing Finance' 'GenRobotic' 'HeyHolidays' 'Pratilipi'
#  'SectorQube' 'Food Memories' 'ZAMROO'
#  'Silversparro Technologies Pvt. Ltd' 'Creator’s Gurukul' 'Emflux Motors'
#  'Tricog Health Services Pvt Ltd' 'Scapic' '6Degree'
#  'Chrysalis (EZ Vidya)' 'Ekincare' 'Streo' 'Groww' 'Cell Propulsion'
#  'Chezuba' 'Ontrack Technologies Pvt. Ltd' 'Wealthtrust' 'Faclon Labs'
#  'Awign Enterprises' 'CollPoll' 'Zyla Health' 'Hubhopper'
#  'Rubix108 Technologies' 'Workflexi' 'Streak' 'Kuants' 'NiYO Solutions'
#  'Hippo Video' 'Satvacart' 'Daaki' 'Simulanis' 'MY CHIRAAG CAB' 'WOTU'
#  'Flathalt' 'True Elements' 'Trendlyne Technologies' 'Planys Technologies'
#  'HealthPlix' 'dishq' 'Entropik Technology' 'myHQ' 'Trell'
#  'Kidovators (by GyanLab)' 'Log 9 Materials' 'VTION' 'HousingMan.com'
#  'Steradian Semiconductors' 'RupeeCircle' 'Wooden Street' 'The Ken'
#  'SaffronStays' 'Vebbler' 'Foyr' 'MEngage' 'Inner Being Wellness'
#  'Kobster' 'Wishberry' 'McXtra' 'Magic Crate' 'SmartVizX' 'MySEODoc'
#  'ENLYFT DIGITAL SOLUTIONS PRIVATE LIMITED' 'Scale Labs' 'HungerBox'
#  'Biryani By Kilo' 'Wholesome Habits (EAT Anytime)' 'GoBumpr' 'Fixpocket'
#  'edureka!' 'Hashtag Loyalty Private Limited' 'Wow Express' 'ZunRoof'
#  'Eggoz' 'Sqrrl Fintech' 'GalaxyCard' 'IndiQube' 'EGK Foods' 'NirogStreet'
#  'Pixr8' 'Nivesh.com' 'Theranosis Life Sciences'
#  'Poshmiles Online Solutions Private Limited' 'Reculta' 'Orbo.ai'
#  'Inntot Technologies' 'Zoctr Health' 'Hey Deedee'
#  'DigiConnectt Technologys' 'Locus.sh' 'Sports Flashes Pvt. Ltd' 'Inc42'
#  'Picxy' 'Huddle' 'Benepik' 'Cash Suvidha' 'Smartcoin' 'Carmel Organics'
#  'Roadcast' 'Printline Media(ThePrint)' 'Creditas Solutions' 'UrbanPiper'
#  'Doxper' 'i2ifunding' 'ShakeDeal' 'HelloVerify' 'Fasal' 'CoinGeto'
#  'Avail Finance' 'Tripeur' 'Wedeterna' 'Stumagz' 'Doubtnut' 'MCaffeine'
#  'TrustCheckr' 'HealthAssure' 'Picture TIme' '1Crowd'
#  'Aarav Unmanned Systems' 'Wellthy Therapeutics Pvt Ltd' 'Nua' 'Kuvera.in'
#  'Livehealth' 'Gramophone' 'Ora' 'Buddy4Study.com' 'Predible Health'
#  'Syncremedies Healthcare Pvt Ltd' 'Blueleaf Cyberspace Systems' 'Toffee'
#  'ORO Wealth' 'HealWell24' 'Acko General Insurance' 'arzooo.com'
#  'Bonphul Air Products' 'DheeYantra Research Labs' 'Edyoo' 'Chtrbox'
#  'Aashiyaan Housing and Development Finance'
#  'BetterPlace Safety Solutions Pvt. Ltd.' 'Cashkumar' 'Rocketium'
#  'FreightBazaar' 'OPEN' 'mfine' 'Earth Food' 'Charcoal Eats' 'Wishfie'
#  'The Social Hook' 'FreightBro' 'Finwego' 'Cricnwin'
#  'Wicked Ride Adventure Services Private Limited' 'Career Anna'
#  'ERUDITUS Executive Education' 'Gaia Smart Cities' 'Square Off'
#  'UrbanClap' 'Hospals' 'Kogta Financial India Limited' 'Perspectico'
#  'The Souled Store' 'Hush - Speak Up. Make Work Better' 'Drivezy'
#  'Freyr Energy' 'NIRAMAI Health Analytix' 'CloudSek' 'Lendbox' 'Verloop'
#  'Flickstree' 'Paymatrix' 'Idha Skin Clinic' 'InCred' 'Vedantu' 'Sportido'
#  'Stelis Biopharma' 'Magicpin' 'Try & Buy' 'Mech Mocha' 'Aye Finance'
#  'Aldopay' 'Detect Technologies' 'Signzy' 'CashRich' 'Cloudnine Hospitals'
#  'CropIn Technologies' 'Billdesk' 'Yaantra' 'TECHBOOZE' 'HealthifyMe'
#  'hoi foods' 'Perpule' 'Royal Sundaram General Insurance Co. Limited'
#  'CleanseCar' 'DRIVEU' 'Spinny'
#  'Asset Reconstruction Company (India) Ltd.' 'Med365 Healthcare' 'Dunzo'
#  'Mobile Premier League (MPL)' 'WalMart India' 'Cred' 'Meesho'
#  'BhaskarGuru' 'Gugu' 'FarmTaaza' 'Vizzbee'
#  'BIGPHI TECHNOLOGIES PVT. LTD.' 'Mobycy' 'Traveo Soft Pvt. Ltd.'
#  'Em Personal Care' 'Lucideus' 'Eupheus Learning' 'GamingMonk'
#  'Sukkhi Jewellery' 'INDwealth' 'Medikabazaar' 'NIRA' 'Duroflex Pvt. Ltd.'
#  'Clensta' 'Jetbrain Robotics' 'Medimetry' 'Healthkart'
#  'Indiabulls Ventures' 'Vistara' 'ClearTax' 'Shuttl' 'GuruQ' 'Azure Power'
#  'Cube' 'RAHI Care' 'Mynvax' 'Loans4SME' 'UpCyclersLab'
#  'Cellerite Systems' 'Taru Naturals' 'LetsMD' 'Twenty Two Motors'
#  'Truebil' 'FarmersFZ' 'Worxogo' 'Vivish Technologies (myGate)'
#  'Singularity Dynamics' 'Virtual MetalStreet(MetalStreet)'
#  'Veritas Finance' 'Manjushree Technopack' 'GoZefo' 'Zomato'
#  'Innov8 Coworking' 'RevFin' 'Lavelle Networks' 'Blackbuck' 'Cardekho'
#  'ElasticRun' 'Droom Technology Private Limited' 'Vogo Rentals'
#  'InnerChef' 'LivQuik' 'Disprz' '9stacks' 'Origo' 'YourOwnROOM'
#  'Vahdam Teas' 'Spoofin' 'Strom Motors' 'PharmEasy' 'Licious'
#  'Stanza Living' 'docturnal' 'Bounce (Metro Bikes)'
#  'Technology 9 Labs (T9L)' 'Goals101' 'Satya MicroCapital'
#  'Ummeed Housing Finance Private Limited' 'StockEdge' 'Sequretek'
#  'Avenues Payments India Pvt. Ltd.' 'Qbera' 'Urban Ladder'
#  'Planet11 eCommerce Solutions India (Avenue11)' 'DailyNinja'
#  'Iba Halal Care' 'Knocksense' 'Togedr' 'Parkwheels' 'ShareChat'
#  'Cyclops Medtech' 'Livspace' 'NewsBytes' 'Leena AI' 'Max Healthcare'
#  'GoBolt' 'GoGaga' 'Mate Labs' 'Furlenco' 'Ola' 'DocPrime'
#  'CLP India Pvt. Ltd.' 'Xplorabox' 'Myra' 'Vokal' 'Kissht'
#  'Upwards Fintech' 'Bon(Bonfleet Solutions)' 'Mamaearth' 'BabyChakra'
#  'Belstar Investment and Finance Private Limited' 'Naaptol'
#  'Moonshine Meadery' 'Verzeo' 'Haazri' 'Connect India' 'Flyrobe'
#  'Scholify' 'Dream11' 'srJna' 'Nykaa' 'Chaayos' 'Heelium' 'LT Foods'
#  'Multibashi' 'Cleardekho' 'Dailyhunt' 'SlicePay' 'Udaan'
#  'Happyeasygo Group' 'Mombay' 'Droni Tech' 'Netmeds']
# ____________________________________________________________________________________________________
#
# Column-2: Founded: 1
#  [nan]
# ____________________________________________________________________________________________________
#
# Column-3: HeadQuarter: 50
#  ['Bangalore, Karnataka, India' 'Mumbai, Maharashtra, India'
#  'Gurgaon, Haryana, India' 'Noida, Uttar Pradesh, India'
#  'Hyderabad, Andhra Pradesh, India' 'Bengaluru, Karnataka, India'
#  'Kalkaji, Delhi, India' 'Delhi, Delhi, India' 'India, Asia'
#  'Hubli, Karnataka, India' 'New Delhi, Delhi, India'
#  'Chennai, Tamil Nadu, India' 'Mohali, Punjab, India'
#  'Kolkata, West Bengal, India' 'Pune, Maharashtra, India'
#  'Jodhpur, Rajasthan, India' 'Kanpur, Uttar Pradesh, India'
#  'Ahmedabad, Gujarat, India' 'Azadpur, Delhi, India'
#  'Haryana, Haryana, India' 'Cochin, Kerala, India'
#  'Faridabad, Haryana, India' 'Jaipur, Rajasthan, India'
#  'Kota, Rajasthan, India' 'Anand, Gujarat, India'
#  'Bangalore City, Karnataka, India' 'Belgaum, Karnataka, India'
#  'Thane, Maharashtra, India' 'Margão, Goa, India'
#  'Indore, Madhya Pradesh, India' 'Alwar, Rajasthan, India'
#  'Kannur, Kerala, India' 'Trivandrum, Kerala, India'
#  'Ernakulam, Kerala, India' 'Kormangala, Karnataka, India'
#  'Uttar Pradesh, India, Asia' 'Andheri, Maharashtra, India'
#  'Mylapore, Tamil Nadu, India' 'Ghaziabad, Uttar Pradesh, India'
#  'Kochi, Kerala, India' 'Powai, Assam, India'
#  'Guntur, Andhra Pradesh, India' 'Kalpakkam, Tamil Nadu, India'
#  'Bhopal, Madhya Pradesh, India' 'Coimbatore, Tamil Nadu, India'
#  'Worli, Maharashtra, India' 'Alleppey, Kerala, India'
#  'Chandigarh, Chandigarh, India' 'Guindy, Tamil Nadu, India'
#  'Lucknow, Uttar Pradesh, India']
# ____________________________________________________________________________________________________
#
# Column-4: Sector: 405
#  ['Brand Marketing, Event Promotion, Marketing, Sponsorship, Ticketing'
#  'Agriculture, Farming' 'Credit, Financial Services, Lending, Marketplace'
#  'Financial Services, FinTech' 'E-Commerce Platforms, Retail, SaaS'
#  'Cloud Infrastructure, PaaS, SaaS' 'Internet, Leisure, Marketplace'
#  'Market Research' 'Information Services, Information Technology'
#  'Mobile Payments' 'B2B, Shoes' 'Internet'
#  'Apps, Collaboration, Developer Platform, Enterprise Software, Messaging, Productivity Tools, Video Chat'
#  'Food Delivery' 'Industrial Automation'
#  'Automotive, Search Engine, Service Industry' 'Finance, Internet, Travel'
#  'Accounting, Business Information Systems, Business Travel, Finance, SaaS'
#  'Artificial Intelligence, Product Search, SaaS, Service Industry, Software'
#  'Internet of Things, Waste Management'
#  'Air Transportation, Freight Service, Logistics, Marine Transportation'
#  'Financial Services' 'Food and Beverage' 'Autonomous Vehicles'
#  'Enterprise Software, Health Care, Hospital, Parenting, Personal Health, SaaS'
#  'Agriculture, Analytics, Big Data, Farming'
#  'Logistics, Supply Chain Management' 'Financial Services, Lending'
#  'Automotive, Marketplace, Online Portals' 'Artificial Intelligence'
#  'Internet of Things, Telecommunications' 'Insurance'
#  'Information Technology, Logistics, Supply Chain Management'
#  'Blockchain, Developer Tools, Enterprise Software'
#  'Industrial Automation, Logistics, Supply Chain Management'
#  'Food and Beverage, Food Delivery, Snack Food' 'Education'
#  'E-Commerce, Fashion, Jewelry, Retail' 'Renewable Energy'
#  'E-Learning, Education'
#  'Clean Energy, CleanTech, Laundry and Dry-cleaning'
#  'E-Commerce, Fashion, Mobile'
#  'Apps, Messaging, Navigation, Public Safety' 'Transportation'
#  'Fitness, Health Care, Wellness'
#  'Artificial Intelligence, Machine Learning, SaaS, Virtual Assistant'
#  'Hospitality' 'Food and Beverage, Tea'
#  'Media and Entertainment, News, Outdoors'
#  'Broadcasting, Media and Entertainment, Music, Music Streaming, Video, Video Streaming'
#  'B2B, Information Services, Information Technology'
#  'EdTech, Education, Enterprise Software, Peer to Peer'
#  'Health Care, Medical' 'E-Commerce' 'Health Care, Hospital, Wellness' '—'
#  'Sports' 'Big Data, Consumer Lending, FinTech'
#  'Cloud Computing, Computer, Semiconductor'
#  'Health Care, Medical, Pharmaceutical' 'Food Processing, Retail'
#  'Trading Platform' "Consumer Goods, Lifestyle, Men's" 'Wellness'
#  'Food and Beverage, Food Processing, Nutrition' 'Fashion'
#  'Automotive, Electric Vehicle, Energy Storage'
#  'Consulting, Retail, Social'
#  'Biotechnology, Life Science, Pharmaceutical, Product Research'
#  'Health Care' 'Credit, Financial Services, FinTech, Personal Finance'
#  'Communities, Coworking, Incubators'
#  'Consumer, Financial Services, FinTech'
#  'Consumer Applications, Information Services, Location Based Services, Virtual Assistant'
#  'Mobile, Mobile Apps, Personalization, Test and Measurement, Web Apps'
#  'Education, Financial Services, FinTech'
#  'Advertising, Consulting, Digital Marketing'
#  'Marketplace, Real Estate, Rental Property'
#  'E-Learning, Internet, Video Games'
#  'Artificial Intelligence, Cloud Computing, Video'
#  'Health Care, Information Technology' 'Aerospace'
#  'E-Commerce, Fashion, Lifestyle'
#  'Artificial Intelligence, Business Intelligence, Industrial Automation, Machine Learning'
#  'Home Decor, Home Improvement, Home Renovation, Home Services, Interior Design, Smart Home'
#  'EdTech, Education, Information Services, SaaS' 'Energy, Solar'
#  'B2B, Biometrics, Cyber Security, Fraud Detection, SaaS, Security'
#  'Artificial Intelligence, Social' 'Logistics, Transportation, Travel'
#  'Digital Marketing, SEM, SEO, Web Development'
#  'Health Care, Hospital, Medical' 'Finance, Financial Services'
#  'Food Delivery, Food Processing, Internet'
#  'E-Commerce, Food and Beverage, Internet'
#  'Fitness, Food and Beverage, Health Care, Nutrition'
#  'EdTech, Education, Knowledge Management'
#  'Apps, Beauty, Consumer, Retail'
#  'Creative Agency, Crowdfunding, EdTech, Health Care, Internet, Medical, Non Profit, Personal Health'
#  'Consumer Lending, Financial Services, FinTech, Insurance, Lending, Mobile Payments, Payments, Wealth Management'
#  'E-Learning, Education, Higher Education' 'Health Diagnostics'
#  'EdTech, Education' 'Financial Services, SaaS, Security'
#  'Banking, Finance, Financial Services, Non Profit'
#  'B2B, E-Commerce, Mobile'
#  'Automotive, Electric Vehicle, Renewable Energy' 'E-Learning'
#  'Embedded Systems, Health Care, Medical, Product Research'
#  'Apps, E-Commerce, Internet' 'Advertising, Human Resources, Marketing'
#  'Beauty, Fitness, Home Services, Internet'
#  'Health Care, Medical Device, Public Safety'
#  'Food Delivery, Online Portals, Restaurants'
#  'AgTech, B2B, Supply Chain Management'
#  'Credit Cards, Finance, Mobile Apps, Mobile Payments, Payments'
#  'Software' 'EdTech, Education, Higher Education, Secondary Education'
#  'Manufacturing, Retail' 'Manufacturing'
#  'Information Services, Information Technology, InsurTech'
#  'Consumer Lending, FinTech' 'Internet, Social Network, TV'
#  'Beauty, Health Care' 'Hospital' 'Events'
#  '3D Printing, Manufacturing, Product Design' 'Automotive'
#  'Automotive, Retail' 'Apps, Audio' 'Automotive, E-Commerce'
#  'Digital Entertainment, Fantasy Sports, Sports'
#  'E-Learning, EdTech, Education'
#  'Funding Platform, Incubators, Non Profit'
#  'Hospitality, Hotel, Leisure, Travel'
#  'Classifieds, Internet, Marketplace, Rental Property'
#  'Banking, E-Learning, Trading Platform' 'E-Commerce, Mobile, Retail'
#  'Artificial Intelligence, Information Technology'
#  'Enterprise Resource Planning (ERP), Information Services, Information Technology, Real Estate'
#  'Banking, Finance, Financial Services' 'Audio, Mobile, Tourism, Travel'
#  'Energy, Energy Storage, Infrastructure'
#  'Government, Information Technology, Software' 'Information Technology'
#  'Education, Information Technology, Internet, Mobile, Software'
#  'Consumer Lending, Financial Services, Lending, Personal Finance'
#  'Digital Media, Internet, Media and Entertainment, Online Portals, Social Media'
#  'Business Intelligence, Customer Service, Market Research, SaaS'
#  'Credit, Financial Services, FinTech, Lending'
#  'Children, Education, Parenting'
#  'Automotive, Battery, Energy, Energy Storage'
#  'E-Commerce, Mobile, Sharing Economy'
#  'Food Delivery, Organic, Organic Food' 'Mobile' 'Rental' 'Travel'
#  'Consumer' 'B2B, Farming, Marketplace' 'Wealth Management'
#  'Biotechnology' 'Education, Gaming, Training' 'Veterinary'
#  'Internet, Mobile, Social Entrepreneurship, Telecommunications, Wireless'
#  'Health Care, Hospital, Supply Chain Management' 'Tourism, Travel'
#  'Hospitality, Real Estate' 'Finance'
#  'Digital Media, EBooks, Publishing, Reading Apps'
#  'Consumer Electronics, Embedded Systems, Hardware, Smart Building, Software'
#  'Food and Beverage, Food Processing' 'Internet, Marketplace, Shopping'
#  'Analytics, Computer Vision, Enterprise Software, Machine Learning, Natural Language Processing, Speech Recognition'
#  'Facilities Support Services' 'Automotive, Electric Vehicle, Energy'
#  'Health Care, Health Diagnostics, Predictive Analytics'
#  'Cloud Computing, Computer, SaaS, Software' 'Fashion, Lifestyle, Retail'
#  'Medical' 'Music Streaming' 'Finance, Impact Investing, Internet'
#  'Internet, Social Entrepreneurship' 'Retail'
#  'Finance, Impact Investing, Mobile Apps'
#  'Cloud Computing, Computer, Software'
#  'Business Development, Market Research, Outsourcing'
#  'Health Care, Hospitality' 'Internet, Social News, Sports'
#  'Human Resources' 'Finance, Financial Services, FinTech'
#  'Customer Service, Software, Video, Video Streaming'
#  'E-Commerce, Food Processing' 'Training'
#  'Dietary Supplements, Food and Beverage, Health Care, Organic Food, Snack Food'
#  'Manufacturing, Oil and Gas, Robotics'
#  'Artificial Intelligence, Computer, Machine Learning'
#  'Collaboration, Communities, Coworking, Sharing Economy'
#  'Big Data, EdTech, Machine Learning' 'Nanotechnology'
#  'Analytics, Audio, Digital Media, Innovation Management, Internet Radio, Media and Entertainment'
#  'Financial Services, Lending, Peer to Peer'
#  'E-Commerce, Furniture, Home Decor, Interior Design, Internet'
#  'Digital Media' 'File Sharing, Personalization, Social Media'
#  'Home Decor, Interior Design' 'Health Care, Medical Device, Mobile Apps'
#  'E-Commerce, Facilities Support Services, Procurement, Supply Chain Management'
#  'Crowdfunding, Finance, Financial Services'
#  'Finance, Financial Services, Insurance'
#  'Children, Education, Online Portals' 'Software, Virtual Reality'
#  'B2B, Food and Beverage, Food Delivery'
#  'Catering, Food and Beverage, Food Delivery, Food Processing'
#  'Food and Beverage, Snack Food' 'Automotive, E-Commerce, Mobile'
#  'Computer, Digital Marketing, Facilities Support Services, Graphic Design, Internet, Mobile Apps, Social Media Marketing, Web Development'
#  'Android, Big Data, Blockchain, Cloud Computing, EdTech, Education, Information Technology, iOS, Training, Web Development'
#  'Analytics, CRM, Loyalty Programs, Machine Learning, Marketing Automation, Retail Technology, SaaS, Small and Medium Businesses'
#  'Delivery, Information Technology, Mobile Apps'
#  'Environmental Consulting, Renewable Energy'
#  'Big Data, Business Intelligence, Financial Services, FinTech, Personal Finance'
#  'Commercial Real Estate, Coworking, Office Administration, Real Estate'
#  'Food and Beverage, Food Processing, Organic Food, Snack Food'
#  'Apps, Health Care, Internet, Mobile Apps, Personal Health'
#  'Digital Media, Incubators, Social Entrepreneurship'
#  'Finance, Financial Services, Marketing'
#  'Biotechnology, Health Care, Life Science, Medical Device'
#  'Education, Human Resources' 'Consumer Electronics'
#  'Apps, Health Care, Hospital, Mobile Apps'
#  'Delivery Service, Logistics, Service Industry'
#  'Big Data, Data Visualization, Logistics, Software'
#  'Basketball, Cricket, Cycling, eSports, Fitness, Golf, Health Care, Hockey, Sports, Swimming, Table Tennis, Volley Ball'
#  'Media and Entertainment, News, Publishing' 'Consulting'
#  'Big Data, Financial Services, Machine Learning, Predictive Analytics'
#  'Agriculture, AgTech, Manufacturing' 'Digital Media, News, Publishing'
#  'Health Care, Hospital' 'B2B, E-Commerce, Enterprise'
#  'Fraud Detection, Information Services, Security'
#  'Agriculture, AgTech, Artificial Intelligence, Internet of Things, Machine Learning'
#  'Cryptocurrency, Trading Platform' 'Finance, FinTech, Mobile Payments'
#  'Wedding'
#  'E-Learning, EdTech, Education, Image Recognition, Machine Learning, STEM Education'
#  'Consumer Goods' 'Digital Entertainment'
#  'Crowdsourcing, Financial Services, Funding Platform, Venture Capital'
#  'Delivery, Drones, Geospatial, Robotics'
#  'Health Care, Information Technology, Management Information Systems'
#  'Farming'
#  'Business Travel, Hospitality, Hotel, Marketplace, Tourism, Travel Accommodations'
#  'Career Planning, Education, Higher Education, Service Industry'
#  'Medical Device' 'Alternative Medicine, Health Care' 'Internet, Software'
#  'Dental, Elder Care, Health Care, Home Health Care, Personal Health'
#  'Financial Services, Insurance, Private Social Networking'
#  'Consumer Electronics, E-Commerce, E-Commerce Platforms, Electronics, Shipping, Shopping'
#  'CleanTech' 'Advertising, Internet, Marketing'
#  'Human Resources, Security, Training'
#  'Consumer Lending, Finance, FinTech' 'Marketing, Social Media, Video'
#  'Banking' 'Food Processing' 'Apps' 'Marketing'
#  'Apps, B2B, Freight Service, Logistics, SaaS, Shipping, Supply Chain Management, Transportation'
#  'Digital Entertainment, Fantasy Sports, Gaming, Sports'
#  'Automotive, Last Mile Transportation, Peer to Peer, Ride Sharing'
#  'Commercial, E-Learning, Education'
#  'Continuing Education, EdTech, Education, Skill Assessment'
#  'Smart Cities, Telecommunications' 'Internet of Things, Robotics'
#  'Apps, Home Services, Information Services, Information Technology'
#  'Medical, Tourism' 'Career Planning, Education, Internet'
#  'Fashion, Graphic Design, Wearables'
#  'Communities, Leisure, Mobile Apps, Software'
#  'Automotive, Rental, Sharing Economy'
#  'Energy, Environmental Consulting, Renewable Energy, Solar'
#  'Information Technology, SaaS, Security'
#  'Crowdfunding, Financial Services, Internet'
#  'Customer Service, Information Technology, Internet, Sales Automation'
#  'Advertising, Artificial Intelligence, Digital Media, iOS, Location Based Services, News, Video, Video on Demand, Video Streaming'
#  'Credit Cards, Payments, Property Insurance, Property Management, Rental Property'
#  'Beauty, Cosmetics, Health Care, Service Industry'
#  'EdTech, Education, Mobile, Tutoring' 'Social Media, Sports' 'Biopharma'
#  'E-Commerce, E-Commerce Platforms, Retail'
#  'E-Commerce, Fashion, Shopping' 'Digital Entertainment, Mobile, PC Games'
#  'Finance, Financial Services, Small and Medium Businesses'
#  'Artificial Intelligence, Energy, Oil and Gas'
#  'Computer, FinTech, Risk Management, Software'
#  'Apps, Financial Services, FinTech'
#  "Child Care, Health Care, Hospital, Medical, Women's"
#  'Agriculture, Mobile'
#  'Finance, FinTech, Payments, Property Development, Rental'
#  'Information Services, Information Technology, Mobile, Software'
#  'Apps, Fitness, Health Care, mHealth' 'Food and Beverage, Food Delivery'
#  'Apps, Payments, Retail' 'Health Insurance, Insurance, Life Insurance'
#  'Rental, Taxi Service, Travel'
#  'E-Commerce, E-Commerce Platforms, Internet, Retail'
#  'Financial Services, Professional Services'
#  'Customer Service, Messaging, Mobile Apps, Personalization'
#  'Gaming, iOS, Sports'
#  'E-Commerce, E-Commerce Platforms, Internet, Mobile Apps, Social Media'
#  'Search Engine'
#  'Battery, Electric Vehicle, Energy, Renewable Energy, Transportation'
#  'Agriculture, Farmers Market, Farming'
#  'Artificial Intelligence, Drones, Navigation, Packaging Services, Robotics'
#  'Fitness, GreenTech, Internet of Things, Mobile Apps, Ride Sharing, Transportation'
#  'Mobile, Software, Travel' 'Cosmetics'
#  'Consulting, Cyber Security, Network Security'
#  'eSports, Gaming, Video Games' 'Fashion, Jewelry' 'B2B, Medical Device'
#  'Consumer Goods, Manufacturing' 'Biotechnology, Health Care, Wellness'
#  'Health Care, Hospital, Medical, Robotics'
#  'E-Commerce, Fitness, Health Care' 'Financial Services, Venture Capital'
#  'Accounting, Apps, FinTech' 'Apps, Mobile, Transportation' 'Reading Apps'
#  'Energy, Renewable Energy, Solar' 'Banking, Financial Services, FinTech'
#  'Apps, Education, Retail' 'Electric Vehicle'
#  'Automotive, Battery, Electric Vehicle, Manufacturing, Mechanical Design'
#  'Automotive, E-Commerce, Marketplace' 'Agriculture'
#  'Apps, Information Services, Information Technology' 'B2B, Marketplace'
#  'Packaging Services' 'Computer, Furniture, Software'
#  'Food Delivery, Hospitality, Reservations, Restaurants, Search Engine'
#  'Collaboration, Communities, Coworking, Real Estate'
#  'Accounting, Banking, Finance'
#  'Cloud Computing, Enterprise Software, Network Hardware, Network Security, SaaS'
#  'Information Services, Internet, Logistics, Supply Chain Management, Transportation'
#  'Automotive, E-Commerce, Information Services'
#  'Delivery, Logistics, Transportation'
#  'Automotive, E-Commerce Platforms, Marketplace'
#  'Last Mile Transportation, Railroad, Transportation, Travel'
#  'Cooking, E-Commerce, Food and Beverage, Food Delivery, Online Portals'
#  'FinTech, Mobile, Mobile Payments, Payments, Retail Technology'
#  'Online Games, Software' 'Online Portals, Property Management, Rental'
#  'E-Commerce, Food and Beverage, Tea' 'Music, Social Network, Video'
#  'Health Care, Pharmaceutical, Wellness'
#  'Delivery Service, Food and Beverage, Food Delivery'
#  'Hospitality, Information Technology, Travel Accommodations'
#  'Biotechnology, Diabetes, Health Care'
#  'Autonomous Vehicles, Last Mile Transportation, Recreational Vehicles, Rental'
#  'Finance, Financial Exchanges, Financial Services, Micro Lending'
#  'Analytics, Apps, Market Research'
#  'E-Commerce, E-Commerce Platforms, Furniture, Home Decor, Internet'
#  'Apps, Mobile, Mobile Apps, Software' 'News, Publishing, Social Media'
#  'Industrial, Industrial Automation'
#  'Internet, Mobile Apps, Social Network'
#  'Health Care, Health Diagnostics, Internet of Things, Life Science, Machine Learning, Medical, Medical Device'
#  'E-Commerce, Furniture, Interior Design' 'Apps, Events, News'
#  'Artificial Intelligence, Human Resources, Information Services, Information Technology'
#  'Logistics, Railroad, Transportation' 'Dating, Private Social Networking'
#  'Artificial Intelligence, Machine Learning, PaaS'
#  'Consumer, Furniture, Home Decor, Home Improvement'
#  'Apps, E-Commerce, Internet, Mobile, Ride Sharing, Transportation'
#  'Health Care, Health Insurance' 'Energy, Natural Resources'
#  'E-Commerce, Education, Health Care' 'Apps, Health Care, Pharmaceutical'
#  'Internet, Knowledge Management'
#  'Credit, Finance, FinTech, Lending, Sales Automation'
#  'Banking, Financial Services, Internet' 'E-Commerce, Health Care, Retail'
#  'Child Care, Information Technology' 'Financial Services, Micro Lending'
#  'E-Commerce, Retail, Shopping' 'Food and Beverage, Snack Food, Tea'
#  'Delivery Service, E-Commerce, Logistics' 'Fashion, Lifestyle, Rental'
#  'Fantasy Sports, Mobile, Sports' 'Beauty, Fashion, Wellness'
#  'Food and Beverage, Restaurants, Tea' 'Fitness, Sporting Goods, Sports'
#  'Food and Beverage, Food Processing, Manufacturing'
#  'E-Learning, Internet' 'Eyewear, Internet'
#  'Information Technology, Mobile, News, Operating Systems, Social Media, Social News'
#  'FinTech, Internet, Payments, Service Industry'
#  'B2B, Business Development, Internet, Marketplace'
#  'Food and Beverage, Food Delivery, Internet'
#  'Biotechnology, Health Care, Pharmaceutical']
# ____________________________________________________________________________________________________
#
# Column-5: What_it_does: 524
#  ['TheCollegeFever is a hub for fun, fiesta and frolic of Colleges.'
#  'A startup which aggregates milk from dairy farmers in rural Maharashtra.'
#  'Leading Online Loans Marketplace in India'
#  'PayMe India is an innovative FinTech organization which offers short term financial suport to corporate employees.'
#  'Eunimart is a one stop solution for merchants to create a difference by selling globally.'
#  'Hasura is a platform that allows developers to build, deploy, and host cloud-native applications quickly.'
#  'Tripshelf is an online market place for holiday packages.'
#  'Hyperdata combines advanced machine learning with human intelligence.'
#  'Freightwalla is an international forwarder thats helps you manage supply chain by providing online tools including instant quotations.'
#  'Microchip payments is a mobile-based payment application and point-of-sale device'
#  'Building Transactionary B2B Marketplaces'
#  'Emojifi is an app that provides live emoji, stickers & GIFs suggestions based on the typed words across chat platforms.'
#  'Flock is a real-time messaging and collaboration app for teams that speeds up and simplifies communication and boosts productivity.'
#  'Freshboxx is incubated at Sandbox Startups, a unit of the Deshpande Foundation.'
#  'Wide Mobility Mechatronics is a Private Company limited by Shares'
#  'Pitstop offers general repair and maintenance services for cars through its doorstep service vehicles.'
#  'Mihuru is an online platform which gives micro loans for air travel .'
#  'Fyle is an intelligent expense management platform for enterprises.'
#  'Appwharf is an intelligent assistant that helps find you the best-fit SaaS for your business.'
#  'Waste Management for Smart Cities'
#  'Cogoport is a platform that provides freight buying industry with spot rates and bidding process for freight buyers.'
#  'A P2P lending marketplace platform'
#  "Makers of a signature coffee that's exceptional in taste. It's super easy to brew, requires no equipment & ships to your door."
#  'Delhi-based online used vehicles marketplace.'
#  'PregBuddy is a smart connected care platform for expecting mothers.'
#  'AgNext is an agricultural sensing and solutions company focused on building data-driven solutions for agricultural stakeholders'
#  'A startup which digitizes logistics operations for Fortune 500 companies.'
#  'Online lending startup based in Mumbai.'
#  "India's Online Auto Repair Marketplace"
#  'Early stage Artificial Intelligence (AI) start up.'
#  'Chariot Tech is an Internet of Things (IoT) startup based in New Delhi.'
#  'Ideal Insurance Broking is one of the leaders in insurance broking domain.'
#  'Loanzen helps small businesses get unsecured working capital loans against their their pending invoices.'
#  "Mojro envisions to be the world's largest technology-enabled logistics platform."
#  'Blockchain Development Platform To Design, Run & Scale Blockchain Networks.'
#  'LoadShare is India’s fastest growing logistics company'
#  'Food startup Yumlane operated by QwikPik Technology'
#  'A Education Start Up.'
#  'Pipa+Bella is an online store aimed at selling fashionable and affordable costume jewelry at par with international standards and trends'
#  'A fintech platform.'
#  'Chakr has developed the world’s first retro-fit emission control device for diesel generators.'
#  "India's the premier education destination catering to the needs of aspiring students of the CA community."
#  'UClean is a tech enabled laundry service provider.'
#  'The Fashion Re-commerce platform.'
#  'Letstrack GPS tracking devices to track your kids, bike, car and other vehicles. GPS trackers for Vehicle Tracking System in India.'
#  'Pooltoo offers a premium ride sharing platform.'
#  'finzy is the premier peer to peer lending solution in India.'
#  "India's largest online fitness platform that provides an integrated eco-system to help users start & sustain their fitness journey"
#  'Building an Intelligent Digital Assistant.'
#  'Reserve your Room, Hostel or Paying Guest, while relocating for higher education.'
#  'Chai Kings is a tea retail chain'
#  'Dainik Jagran is a media and communications group.'
#  'Playtoome is a live entertainment destination'
#  'ONGO Framework is a B2B IT and digital solution provider.'
#  'A Global Peer-to-Peer and Peer-to-Group Learning Platform that helps students supplement their academic & competitive exam prep.'
#  'Arogya MedTech is a Research & Development organization in Bio-Medical industry.'
#  "Propshop24, a one-stop shop for a handpicked selection of 'fun'tastic products from around the world."
#  'To bring health issues to people in their language.'
#  'MissMalini Entertainment is a multi-platform new media network dedicated to Entertaining, Connecting & Empowering young Indians.'
#  'Rooter is a mobile-based platform'
#  "Zest is India's first completely automated consumer digital lending platform."
#  'Advancing AI compute'
#  'MyDentistChoice is a direct sales and distribution of dental equipment and accessories from top name manufacturers'
#  'Sattviko fosters wellness and shares Indianness through the Sattvik way of cooking that is wholesome and tasty!'
#  'Investment Management Platform'
#  "Bombay Shaving Company is a Men's grooming startup"
#  'Medcords is India’s first holistic healthcare ecosystem on a cloud platform that makes health management easier'
#  'University Living is an online global student housing marketplace.'
#  'Food and Beverage startup focussing on developing products using ayurveda with modern science for women empowerment and fitness.'
#  'Enakshi is an online apparel brand for women.'
#  'Ultraviolette is a startup working on electric two-wheelers and energy infrastructure.'
#  'Inthree Access is an impact venture that connects the most inaccessible rural markets with products that can transform lives in Rural India.'
#  'BUGWORKS is a drug discovery company.'
#  "GNC is a leading global specialty retailer of health and wellness products that takes pride to be the world's largest company"
#  'PrestLoans New age tech driven RBI regd NBFC helping businesses by providing easy, quick n hassle free loans.'
#  'Data Intelligence Publishing Platform, We bring the best resources to learn valuable technologies which will shape tomorrow.'
#  'India Accelerator runs mentorship-driven incubation and acceleration programs for start ups.'
#  'HappyEMI is a point of sale digital lending platform that helps consumers finance their purchases in-store and online'
#  'Premium Personal Assistance service'
#  'Hansel, a mobile app management platform, provides the infrastructure that companies need, in order to personalize product experiences.'
#  'Propelld is a student education financing platform.'
#  'Digital Marketing powered by Data & Technology; fueled by Design thinking'
#  'ZiffyHomes is a technology driven marketplace to find out home on rent.'
#  'Carmesi is a brand of high-end menstrual-hygiene products in India.'
#  'OckyPocky is a interactive and personalised language learning app for preschool kids.'
#  'Racetrack is a sales and support-focused AI-driven platform designed for education, real estate, and e-commerce sectors.'
#  'WHR is to make affordable healthcare a reality for all. Our vision is to make healthcare services easier, better and more accessible.'
#  'Asteria Aerospace is a robotics and artificial intelligence company.'
#  'FabAlley is the ultimate Indian fashion destination for fashion-forward, indie-chic girls. Founded in 2012, Tanvi Malik and Shivani Poddar'
#  'Tranzmeo Connect : is A Complete Comprehensive Anomaly forensic Solution with Actionable Insights.'
#  'SBI Life is one of the life insurance company that offers a range of life insurance plans and policies to protect you and your family.'
#  'Studds Accessories is a scooter accessories service provider in India'
#  'Design + Execution Organization that delivers beautiful & innovative designs for Home Interiors, in any budget.'
#  'NoPaperForms is a marketing automation, lead nurture and enrolment management platform for educational institutions'
#  'Rays Power Infra is a leading integrated Solar Power Company.'
#  'SaaS, B2B, Security, Stop account sharing, Fraud Detection'
#  'Vernacular Social Network Focused on Town Level Content and Interactions'
#  'Lets transport is a logistics solution provider.'
#  'Next Digital Solutions is website design & Digital Marketing development company.'
#  'Portea Medical is the largest and fastest growing provider of in-home medical care in India today with a 24-city network.'
#  'Aavas Financiers is engaged in the business of providing housing loans, primarily in the un-served, unreached and under-served market.'
#  'Swiggy is a food ordering and delivery company that provides food service solutions for restaurants.'
#  'Milkbasket delivers milk, bread, eggs, butter, juices and other daily need items, every morning, right at your doorstep, free of charge.'
#  'Nutrisattva is a protein innovation compan'
#  'Toppr.com is an online preparation platform for entrance exams in India.'
#  'Jagaran Microfin is a Microfinance institution which achieves a healthy amalgamation of social and financial'
#  'Vivriti Capital is an online platform for institutional debt in India.'
#  "Be U is India's first subscription based Salon Chain."
#  "We're a Harvard incubated crowdfunding platform for nonprofits, social enterprises, startups and individuals."
#  'MobiKwik is a payments backed fintech platform in India. MobiKwik App offers instant loans & investment products to the 500M masses of India'
#  'Stones2milestones is a Gurgaon Based Learning Company.'
#  'Generico is the fastest growing specialized pharmacy retail chain of Generic medicines.'
#  'Adiuvo Diagnostics is a medical diagnostic device company based in India.'
#  'DataTrained is a educational platform, which operates an ed-tech startup on data science'
#  'OneAssist is a protection & assistance services platform.'
#  'Satin is a non-banking finance company providing individual loans to urban shopkeepers.'
#  'APAC Financial Services is a financial services platform.'
#  'Moglix is a supplier of industrial tools like hand tools, power tools, electrical, and safety equipment.'
#  'SEDEMAC Mechatronics is technology company that distributes control-intensive products for automobiles.'
#  'MadGuy Labs is a Online Test-prep Platform.'
#  'Dee Dee Labs is design and development lab with a primary focus on the development of next generation of bionic prostheses.'
#  'FLEECA is a Tyre Care Provider company.'
#  '#1 Online Selling App. India’s leading social commerce platform. Setup free online store in 2 min. Sell own goods or resell Shop101 Supply.'
#  'On Demand Staffing Platform'
#  'Housejoy is a web-based platform that allows individuals to browse and book service providers for their homes.'
#  'Ambee is an Environment analytics startup.'
#  'FoodBuddy is a online food delivery portal, providing boundary breaking delivery.'
#  'Ninjacart is a B2B agri-marketing platform that connects vegetables and fruits farmers directly with businesses.'
#  "Olly is a digital credit card for India's working masses and young people."
#  'No-Code Workflow Automation. Build enterprise applications in days with AI, Cognitive Automation, Collaboration and more built in.'
#  'BYJU’s is an edtech company that is reinventing how students learn through its learning app.'
#  'Wakefitkart is a mattress manufacturing company. We manufacture the best quality mattresses at affordable prices.'
#  'Hero Electric, a 100% subsidiary of the Hero Group, is a pioneer in the Indian Electric Vehicle Industry.'
#  'Pentation as an Insurtech enables insurers and intermediaries with our Insurance Analytics Suite- an Insurance specific AI/ML Software Suite'
#  'PerkFinance partners with employers to provide affordable loans to their employees at no cost to the company'
#  'Roposo - TV by the People is a unique social media platform where people express visually with homemade videos and photos.'
#  'Plum Haircare Is Silicone-Free & Sulphate-Free. Designed For Damaged & Dandruff-Free Hair'
#  'Drstore is a exclusive e- commerce platform.'
#  'Wow Venue is an online platform.'
#  'Chizel is a worlds most advanced cloud platform for on-demand manufacturing in 3D Printing and CNC Machining'
#  'OTO Capital is a platform that allows you to own a car faster than ever.'
#  'boodmo.com - large online marketplace for auto parts in India.'
#  'Khabri is a digital audio platform for content in vernacular.'
#  'MyNewCar.in offers new cars at best price with great deals. Book a new car online or request a doorstep test drive'
#  'A daily fantasy sports platform.'
#  'PlanetSpark is an after-school Maths and English learning program for pre teen kids between Grades 2nd to 7th.'
#  'WheelsEMI is the brand name of NBFC, WheelsEMI Pvt. Ltd.'
#  'FiiRE, a technology business incubator helps the startup process to move from the garage to the lab.'
#  'OYO is an Indian hospitality startup that operates a network of budget hotels.'
#  'Quikr is a free classifieds and online marketplace that helps users sell, buy, rent, or discover anything across India.'
#  'Tabono is a one stop environment for all your fitness solution.'
#  'Learnapp.co - Video courses & live classes in investing, trading, banking and finance.'
#  'Shopkirana connects brands and traditional retailers with the help of technology and supply chain innovation.'
#  'Fric Bergen is a leader in the specialty food industry.'
#  'Articbot is a conversational AI platform for automated customer support and lead generation'
#  'India’s most advanced ERP system for the real estate'
#  'Fusion Microfinance Pvt. Ltd. is an NBFC registered with RBI'
#  'Anytime Doctor is a Software company.'
#  'Go Payments was founded with the mission of assisting consumers with performing a whole host of financial services at their doorstep.'
#  'We build In-Destination Experiences!'
#  'A stealth startup building a layer of infrastructure for highly efficient energy storage systems.'
#  'SaaS to verify counterfeit' 'Gov-Tech'
#  'Smarter analytics to understand how each customer uses your product. Drive growth in conversion, retention and engagement.'
#  'Saas, Web App, Mobile App, School Education'
#  'Snapmint facilitates simplified, fairly-priced and hassle-free EMI options without a Credit Card.'
#  'Ai platform for Art and Creative Community'
#  'Stethoscope for customer feedback !'
#  'Credy is a fintech platform that connects borrowers seeking capital with lenders seeking market beating returns.'
#  'iChamp is an e education innovation product from RNM E-Services Pvt Ltd.'
#  'A cloud-based HR management and employee engagement platform.'
#  'Avishkaar Box is just not another box full of material rather it is a well researched, thought through solution'
#  'A Mumbai-based startup Electric Vehicle (EV) & Energy Storage company.'
#  "hyperXchange is India's fastest growing O2O marketplace for premium refurb gadgets"
#  'Deftouch is a mobile game development company that currently focuses on winning the Cricket gaming market with a social multiplayer game.'
#  "Doodhwala is an online milk delivery startup that offers over 70 varieties of milk along with a plan based on clients' requirement."
#  'DronaHQ is an enterprise mobile engagement platform.'
#  'FastFox: Market Network for Home Rentals (India)'
#  "BuyForexOnline.com is India's first completely online provider for buying Foreign Exchange."
#  'A technology powered network of Branded Serviced Homes conveniently located near educational institutions & workplaces.'
#  'Online marketplace where farmers and traders can sell their produce to B2B buyers'
#  'Corefactors is a leading campaign management, business communication and analytics company.'
#  'A startup in the personal finance space in India .'
#  'Bengaluru based biotech startup.'
#  'Shirsa Labs is a cognitive skill assessment and training portal that provides children with fun educational games.'
#  'Gurugram-based Online petcare platform.'
#  'Awwaz.De develops inclusive mobile solutions that enable organizations to achieve last-mile connectivity for social impact.'
#  'PinkBlue.in - Super-efficient supply-chain for clinical supplies'
#  'Eduvanz is new, innovative finance company, which is completely revolutionizing the student loan market.'
#  'Rupeek is an asset backed online lending platform currently operating in the space of Gold loans.'
#  'Backpacker Panda is creating an ecosystem for youth accommodation and travel.'
#  'Physical education start up'
#  'Placio is a student housing and a complete broker-free platform.'
#  'Delhi based housing finance company.' 'A Robotic Company.'
#  'HeyHolidays, a global player in online vacation rentals.'
#  "Amazon's Kindle Direct Publishing for Indian Languages"
#  'SectorQube develops smart kitchen devices that make food automatically.'
#  'Iconic Indian Delicacies from the most renowned vendors of India Delivered Globally.'
#  'Zamroo is a growing mobile marketplace that allows users to buy and sell locally.'
#  'Silversparro is a deep learning technology solution provider.'
#  'A coworking space provider.'
#  'Emflux Motors is committed to bring clean and sustainable energy into a state of universal acceptance through technological innovation.'
#  'Predictive Healthcare Analytics Company'
#  'Virtual/Augmented Reality Start Up .'
#  'A fashion enterprise that provides a launchpad to fashion talent and brands using a tech enabled platform'
#  'Chrysalis (EZ Vidya) is India’s leading educational research and innovation organization'
#  'EKincare empowers you to take charge of your health by enabling you to monitor critical medical info and make it available anywhere.'
#  'Live stream music from nightclubs, bars & festivals!'
#  'Groww offers a new way of investing money.'
#  'Cell Propulsion is an electric mobility startup that designs autonomous electric vehicles.'
#  'Chezuba is a web-based platform enabling skilled professionals to volunteer online with Non-profits worldwide'
#  'Ontrack provides affordable independent transport to those dependent on cabs and autos for commute by renting bikes on a monthly basis.'
#  'Wealthtrust offers a wealth manager application that enables its users to invest and manage their investments online.'
#  'Faclon is an IoT and data analytics based tech startup building products to make cities and villages smart.'
#  'Operations and manpower outsourcing startup'
#  'World-class Enterprise System for Education.'
#  'Zyla is transforming the way healthcare is delivered in India with specific focus on high-risk chronic patients.'
#  'Get your daily dose of interest as summaries from news and magazine stories .'
#  'Rubix Total App makes it effortless for Institutes to send home important information and updates about the day’s learning experiences.'
#  'Be Smart, Work on Contract,Be Smart, Hire on Contract'
#  'Algorithmic trading platform.'
#  'NiYO is a fintech company that helps salaried employees access company benefits and other financial services.'
#  'A video recording and sharing software.'
#  'Satvacart is a Gurgaon’s largest online supermarket'
#  'Sports Nutrition startup'
#  'A Delhi-based Augmented Reality and Virtual Reality technology development company.'
#  'MY CHIRAAG CAB SERVICES PVT LTD'
#  'It operates a business-to-business e-commerce portal for food and beverages.'
#  'FInd your Customized Home here.'
#  'True elements offers a range of high-quality snacks and supplements that are inspired by natural foods consumed by our ancestors.'
#  'Trendlyne Technologies is a stock market analytics platform and marketplace for retail investors.'
#  'Planys Technologies is India’s first and only manufacturer of compact ROVs providing underwater robotic inspection and survey solutions.'
#  'HealthPlix is a healthtech startup'
#  "dishq leverages food science and machine learning (AI) to understand and predict people's tastes."
#  'The boundaries between Human and Machines are shrinking fast.'
#  'myHQ turns your everyday coffee space into a perfect work zone. Get an amazing work environment without paying any rent.'
#  'Trell is a location based network which helps you in exploring amazing experiences and annotating places around you.'
#  'Building future human capital through 21st Century Skills programs for K-12'
#  'Log 9 Materials is a nano-materials manufacturing and RnD startup'
#  'VTION is a media technology innovation firm aiming to solve key problems in the media based ecosystem.'
#  'New Apartments, Flats for Sale in Bangalore'
#  'It is a fabless semiconductor company focused on CMOS millimeter wave products for Radar.'
# ...
#  "India's first hotel dedicated food brand which promises great in room dining experience in budget hotels"
#  'Perpule is a self-checkout product for retail outlets to enhance the shopping experience of the customers.'
#  'Royal Sundaram provides comprehensive insurance plans and innovative insurance solutions to individuals, families and businesses.'
#  'CleanseCar is a company provides Washing and Repair Services.'
#  'DriveU is a convenient and a quick way of getting on demand drivers for consumers and businesses'
#  'Used cars marketplace in India. Ushering new era of transparency and convenience.'
#  'Asset Reconstruction Company (India) Ltd. operates as a asset reconstruction company.'
#  'Wellness, Specialised Testing, Healthcare at Home'
#  'Dunzo is an app that connects you with the nearest available delivery partner to pickup or deliver items for you.'
#  'Mobile Premier League(MPL) is a skill based E-Sports platform where you can play your favourite mobile games and win real cash always.'
#  'Wal-Mart India Private Limited is a wholly owned subsidiary of Walmart Stores Inc.,'
#  'Cred is a platform to celebrate and reward the most creditworthy people of India.'
#  'Meesho is an online reseller network of housewives and SMBs, who sell products within their network on social channels.'
#  'Bhaskarguru.com is your local search Engine'
#  "Gugu designs & Sells all Electric Connected Two-wheeler's with Network of Open & Free Fast charging Stations across India."
#  'Farm Taaza provides expert advice to the farmers on improving the yield and improving the field operations of the farmer.'
#  'Autonomous Drone Solutions for last mile delivery as well as search and rescue'
#  "BIGPHI technologies is the India's first technologically advanced apparel and wearable company."
#  "India's 1st Dockless Bicycle Sharing App"
#  'AI based Business Travel & Expense management'
#  'Em Personal Care is a Cosmetic products manufacturing Company.'
#  'Lucideus is a cybersecurity company that offers its customers with consultancy, training, and solutions to counteract cyber-attacks.'
#  'Eupheus Learning offers a seamless integrated learning solution for the K-12 market in India.'
#  'GamingMonk is an eSports gaming company based out of New Delhi, India.'
#  'Sukkhi Jewellery is a Contemporary fashion jewellery brand.'
#  'INDwealth is an Artificial Intelligence (AI) powered wealth management company'
#  "India's largest medical and surgical supplies marketplace"
#  'NIRA promotes financial inclusion by creating simple, transparent products that empower individuals to live a life of choice and freedom.'
#  'Duroflex Pvt. Ltd. operates as a dominant mattress player.'
#  'A biotechnology start-up was incorporated to improve the National Hygiene condition whilst addressing the aspect of water conservation.'
#  'Jetbrain Robotics is Hong Kong / Gurgaon based company, building advanced robotic transportation solutions for multi speciality hospitals.'
#  'MediMetry is an online platform where patients can consult specialists doctors online - from anywhere, at anytime.'
#  'The one stop shop for health, fitness & beauty.'
#  'Indiabulls Ventures Limited is one of India’s leading capital market companies providing securities and derivative broking services.'
#  'Vistara is a joint venture of Tata Sons Limited and Singapore Airlines Limited (SIA)'
#  'ClearTax India helps individuals prepare and e-file their Income Tax Return online.'
#  'Shuttl provides an app-based office shuttle service to make daily commute safe, reliable, affordable and dignified for everyone.'
#  'A one of its kind digital integrated platform connecting tutors and students.'
#  'Azure Power produces and distributes solar power to commercial, government, and utility customers in India.'
#  'Cube is consumer banking focused fintech company.'
#  'RAHI Care is a Health Care company.' 'Mynvax is a biotech Company.'
#  'Loans4SME is an alternative lending platform.'
#  'UpCyclersLab is a startup that makes sustainability-based learning tools for children above the age of five.'
#  'Cellerite Systems is a charging solutions provider for electric vehicles.'
#  'Taru Naturals is a network that connects farmer communities with clean technology and renewable energy.'
#  'LetsMD.com is a marketplace for elective surgeries'
#  'Twenty Two Motors aim of making cutting edge EV technology affordable for the current generation.'
#  'Truebil is a team of young, highly motivated professionals who strive to help you buy and sell used cars in the simplest way possible.'
#  'FarmersFZ is an online venture for fresh and safe vegetables and agri products.'
#  'worxogo’s is a pioneering persuasive technology products align employee behaviours .'
#  "India's leading mobile based security management solution ."
#  'Singularity Dynamics is a Chip-design testing startup.'
#  'Virtual MetalStreet(Metalstreet) is a B2B marketplace for steel trading in India'
#  'Veritas Finance has been promoted with a primary purpose of meeting the working capital and business credit requirements of the small bus.'
#  'Manjushree Technopack is a Rigid plastics packaging convertor in India and South Asia.'
#  'Startup working on a white space in the eCommerce industry.'
#  'Zomato is a search app offering detailed information for restaurants as well as online food delivery.'
#  'Innov8 is a Y- Combinator backed company that offers coworking and shared office spaces.'
#  'RevFin is a digital lending company.'
#  'Lavelle Networks provides Software Defined WAN (SD-WAN) Solutions to build end to end Enterprise Networking Platforms for tomorrow'
#  'Blackbuck is a logistics startup based in India.'
#  'Cardekho is a car search venture that helps users buy cars that are right for them.'
#  'ElasticRun develops an online system that improves the reception of orders from customers and the dispatch of delivery drivers in India.'
#  'Droom is a marketplace for automobiles and automobile services.'
#  'Vogo is a dockless scooter rental company in India which lets customers rent scooters for short one way trips.'
#  'InnerChef is an online food discovery and delivery experience that will make the foodie in you come alive.'
#  'LivQuik was incorporated with the vision to simplify payments for merchants and consumers in an increasingly digital world'
#  'Disprz is a one-of-its-kind “knowledge-tech” start-up that strives to make people knowledgeable, productive and smarter at what they do.'
#  'Online gaming startup.'
#  'Origo Commodities, a complete post-harvest management services for agricultural commodities, is the fastest growing company in its sector.'
#  'Good quality, strategically located homes closer to work for millennials'
#  'Vahdam Teas is a vertically integrated online-first tea brand that sources premium garden fresh teas direct from over 150+ tea plantations.'
#  'A social networking app that lets you create and view Spoofs of your favourite videos.'
#  'Strom Motors is a smart urban mobility Company.'
#  'PharmEasy - Indias largest healthcare delivery platform'
#  'Licious is an online meat and fish ordering startup that solves existing problem of finding safe, delectable, trustworthy fresh meat.'
#  'Stanza Living is a co-living platform created for students moving to a new place.'
#  'Docturnal, an online platform, enables individuals to find information and diagnostic services related to diabetes, cancer, and more.'
#  'Bounce (formerly Metro Bikes) is an urban mobility solution that makes daily commute stress-free, time-saving, reliable, and convenient.'
#  'Technology 9 Labs is an Information Technology and Services company.'
#  'Goals101 is a one of the fastest growing big-data platforms.'
#  'New Delhi-based non-banking financial company.'
#  'Ummeed Housing Finance Private Limited'
#  'StockEdge is a unique platform, which is 100% focused on research and analytics'
#  'Sequretek is a cyber security start-up.'
#  'Avenues Payments is an IT solutions provider for the remittance\\money transfer and forex industries.'
#  'Qbera is a managed marketplace for unsecured personal loans.'
#  'Urban Ladder is a Bangalore-based online furniture company.'
#  'Planet11 is backed by SK Planet, which is a part of the SK Group – one of the largest conglomerates in South Korea.'
#  'Daily Ninja, a mobile app that delivers daily needs on a subscription model'
#  'Iba Halal Care is a cosmetics brand company.'
#  'Knocksense is a fast growing lifestyle website.'
#  'Togedr is an activity discovery & booking platform.'
#  'Parkwheels aims at solving the big, bad & unsexy parking problems of India.'
#  'ShareChat is a social networking and regional content platform for the fast growing Internet users in India.'
#  'Medtech startup working on clinical and wearable diagnostic and rehab products for neuro vestibular disorders using eye tracking technology.'
#  'Livspace is the new online shopping destination where you can design, decorate and furnish your dream home.'
#  'NewsBytes provides your everyday news in a contextual timeline to reduce information overload.'
#  'Leena is smart AI powered HR companion dedicated towards engaging employees.'
#  'Max Healthcare is one of the leading chain of hospitals in India.'
#  'Delhi-based logistics technology.'
#  'GoGaga is a new age dating app that has removed the mindless swiping on strangers and connects users through their network and find matches.'
#  'Mate Labs is a machine learning solutions platform for beginners.'
#  'Furlenco is a Bangalore-based company that offers a home furniture subscription program.'
#  'Ola is a mobile app that brings together cab drivers and customers using technology to make transportation hassle-free in India.'
#  "DocPrime offers a one-stop healthcare solution right at the comfort of patients' homes."
#  'CLP India Pvt. Ltd. is a foreign investor in the Indian power sector.'
#  'Xplorabox is as an educational activity box subscription startup aiming to revolutionize the early education industry.'
#  'Myra is a unique solution of technology and operations that makes buying medicines fast and efficient.'
#  "India's Largest Peer-to-Peer Knowledge Sharing Platform in Indian Languages."
#  'Kissht is a financial technology platform that enables instant, seamless credit for consumers to make purchases at digital points of sales'
#  'Upwards Fintech financial company.'
#  'Bon, a Pune-based FinTech firm was created to bring financial services to the gig-economy workforce.'
#  'Mamaearth is an online retailer specializing in baby and toddler products.'
#  "BabyChakra is India's largest & most loved platform to discover the right maternity and childcare."
#  'Belstar Investment and Finance Private Limited is a provider of scalable microfinance services to entrepreneurs.'
#  'Koku Gamer is an online platform that offers gaming related news, editorials, reviews, previews, and other content.'
#  'Moonshine Meadery is a first craft meadery.'
#  'Verzeo is anAI-focussed edtech startup.'
#  'Haazri is a tea and snack quick service restaurant startup'
#  'To create pervasive network where connections are simpler, more powerful, more affordable, more global and more available to all.'
#  'Flyrobe is an on-demand apparel rental platform that provides premium designer wear.'
#  'Edutech'
#  'Dream11 is India’s Biggest Sports Game with 30 million+ users playing Fantasy Cricket, Football, Kabaddi and NBA.'
#  'SRJNA is a brand of Elation Edtech Pvt. Ltd., which helps schools to integrate hands on, affordable and turnkey STEM.'
#  'Nykaa.com is a premier online beauty and wellness destination'
#  'Chaayos was born in November 2012 out of this premise - a contemporary interpretation of the chai adda.'
#  'Heelium is an athletic footwear and wearable startup with primary focus on sports safety and sustainability.'
#  'LT Foods believe that nature will continue to nurture us until we as a species continue to breathe and live.'
#  'Free language learning platform.'
#  'Uttar Pradesh based online eyewear marketplace.'
#  'NewsHunt is a Bangalore based eBooks company.'
#  'SlicePay is an AI based instant credit app for youngsters in India.'
#  'Udaan is a B2B trade platform, designed specifically for small and medium businesses in India.'
#  'HappyEasyGo is an online travel domain.'
#  'Mombay is a unique opportunity for housewives to start household food business and avail everyone with their homemade healthy dishes.'
#  'Droni Tech manufacture UAVs and develop software to service a range of industry requirements.'
#  "Welcome to India's most convenient pharmacy!"]
# ____________________________________________________________________________________________________
#
# Column-6: Founders: 1
#  ['Not filled']
# ____________________________________________________________________________________________________
#
# Column-7: Investor: 1
#  ['Not filled']
# ____________________________________________________________________________________________________
#
# Column-8: Amount: 198
#  ['250000' '₹40,000,000' '₹65,000,000' '2000000' '—' '1600000'
#  '₹16,000,000' '₹50,000,000' '₹100,000,000' '150000' '1100000' '₹500,000'
#  '6000000' '650000' '₹35,000,000' '₹64,000,000' '₹20,000,000' '1000000'
#  '5000000' '4000000' '₹30,000,000' '2800000' '1700000' '1300000'
#  '₹5,000,000' '₹12,500,000' '₹15,000,000' '500000' '₹104,000,000'
#  '₹45,000,000' '13400000' '₹25,000,000' '₹26,400,000' '₹8,000,000'
#  '₹60,000' '9000000' '100000' '20000' '120000' '₹34,000,000'
#  '₹342,000,000' '$143,145' '₹600,000,000' '$742,000,000' '₹1,000,000,000'
#  '₹2,000,000,000' '$3,980,000' '$10,000' '₹100,000' '₹250,000,000'
#  '$1,000,000,000' '$7,000,000' '$35,000,000' '₹550,000,000' '$28,500,000'
#  '$2,000,000' '₹240,000,000' '₹120,000,000' '$2,400,000' '$30,000,000'
#  '₹2,500,000,000' '$23,000,000' '$150,000' '$11,000,000' '₹44,000,000'
#  '$3,240,000' '₹60,000,000' '$540,000,000' '₹650,000,000' '₹1,600,000,000'
#  '$900,000' '$10,000,000' '$1,500,000' '₹70,000,000' '$1,000,000'
#  '$5,000,000' '$14,000,000' '₹102,500,000' '$100,000,000' '₹1,200,000'
#  '₹5,200,000,000' '$800,000' '$1,041,000' '$100,000' '$15,000' '1400000'
#  '1200000' '2200000' '1800000' '3600000' '₹9,500,000' '300000' '6830000'
#  '200000' '₹150,000,000' '4300000' '364846' '400000' '1500000'
#  '₹7,000,000' '₹1,400,000' '₹10,000,000' '₹22,500,000' '13200000' '50000'
#  '₹140,200,000' '3000000' '1250000' '180000' '₹19,200,000' '₹103,000,000'
#  '4200000' '175000' '1450000' '₹200,000' '4500000' '600000' '₹16,600,000'
#  '₹12,000,000' '15000000' '₹33,000,000' '125000' '130000' '₹34,900,000'
#  '₹72,000,000' '17200000' '₹32,000,000' '3500000' '₹135,000,000'
#  '12000000' '$40,000,000' '$1,100,000' '$50,000,000' '₹1,540,000,000'
#  '$3,000,000' '$6,000,000' '₹140,000,000' '$41,900,000' '₹1,410,000,000'
#  '$3,530,000' '$200,000' '$3,300,000' '₹580,000,000' '₹36,000,000'
#  '₹340,000,000' '$210,000,000' '$37,680,000' '$250,000' '$20,000'
#  '₹510,000,000' '₹2,200,000,000' '22000000' '70000' '10000000'
#  '₹15,392,000,000' '₹20,000,000,000' '₹4,000,000,000' '185000000'
#  '65000000' '₹165,000,000' '700000' '30000000' '₹210,000,000' '210000000'
#  '₹2,029,600,000' '75000000' '₹80,000,000' '1760000' '2700000'
#  '₹280,000,000' '₹800,000,000' '750000' '2500000' '80000000' '25000000'
#  '₹730,000,000' '₹400,000,000' '3700000' '5600000' '₹260,000,000'
#  '99230000' '70000000' '40000' '550000' '50000000' '365000000'
#  '₹8,750,000' '₹78,000,000' '28000000' '₹264,000,000' '100000000'
#  '₹1,130,000,000' '₹810,000,000' '₹1,400,000,000' '14900000' '225000000'
#  '7500' '35000000']
# ____________________________________________________________________________________________________
#
# Column-9: Stage: 21
#  ['Seed' 'Series A' 'Angel' 'Series B' 'Pre-Seed' 'Private Equity'
#  'Venture - Series Unknown' 'Grant' 'Debt Financing' 'Post-IPO Debt'
#  'Series H' 'Series C' 'Series E' 'Corporate Round' 'Undisclosed'
#  'https://docs.google.com/spreadsheets/d/1x9ziNeaz6auNChIHnMI8U6kS7knTr3byy_YBGfQaoUA/edit#gid=1861303593'
#  'Series D' 'Secondary Market' 'Post-IPO Equity' 'Non-equity Assistance'
#  'Funding Round']
# ____________________________________________________________________________________________________

# %% [markdown]
# ##### Identifying Odd Entries in Each Column

# %% [markdown]
# **Column-1: Company_Brand: 525 Unique values**

# %%
# Check for number of duplicated values within the 'Company_Brand' column
dup18_count = df2018.duplicated(subset=key_columns, keep=False).sum()

# Identify duplicate entries in the 'Company_Brand' column
dup_c1_18 = df2018[df2018.duplicated(subset=key_columns, keep=False)]

# Extract the list of duplicated company brands
unidup_c1_18 = dup_c1_18['Company_Brand'].unique()

# Display results
print(f"Number of duplicated values in 'Company_Brand' column: {dup18_count}")
print("\nList of duplicated company brands:")
print(unidup_c1_18)
dup_c1_18
# Out:
# Number of duplicated values in 'Company_Brand' column: 2
#
# List of duplicated company brands:
# ['TheCollegeFever']
#        Company_Brand  Founded                  HeadQuarter  \
# 0    TheCollegeFever      NaN  Bangalore, Karnataka, India
# 348  TheCollegeFever      NaN  Bangalore, Karnataka, India
#
#                                                 Sector  \
# 0    Brand Marketing, Event Promotion, Marketing, S...
# 348  Brand Marketing, Event Promotion, Marketing, S...
#
#                                           What_it_does    Founders  \
# 0    TheCollegeFever is a hub for fun, fiesta and f...  Not filled
# 348  TheCollegeFever is a hub for fun, fiesta and f...  Not filled
#
#        Investor  Amount Stage
# 0    Not filled  250000  Seed
# 348  Not filled  250000  Seed

# %% [markdown]
# **Column-2: Founded: 1 Unique value**

# %%
# Filter odd entries in the 'Founded' column
odde_c2_18 = df2018[df2018['Founded'].apply(is_odd_year)]['Founded']

# Calculate the number of unique odd entries
oddn_c2_18 = odde_c2_18.unique()

# Print the number of odd entries and their details
print(f"Number of odd entries in 'Founded' column: {len(oddn_c2_18)}")
print('\nOdd entries:')
for entry in oddn_c2_18:
    print(entry)
# Out:
# Number of odd entries in 'Founded' column: 1
#
# Odd entries:
# nan

# %% [markdown]
# **Column-3: HeadQuarter: 50 Unique values**

# %%
# Filter odd entries in the 'HeadQuarter' column
odde_c3_18 = df2018[df2018['HeadQuarter'].apply(is_odd_location)]['HeadQuarter']

# Extract unique odd entries
oddn_c3_18 = odde_c3_18.unique()

# Print the number of odd entries and their details
print(f"Number of odd entries in 'HeadQuarter' column: {len(oddn_c3_18)}")
print('\nOdd entries:')
for entry in oddn_c3_18:
    print(entry)
# Out:
# Number of odd entries in 'HeadQuarter' column: 50
#
# Odd entries:
# Bangalore, Karnataka, India
# Mumbai, Maharashtra, India
# Gurgaon, Haryana, India
# Noida, Uttar Pradesh, India
# Hyderabad, Andhra Pradesh, India
# Bengaluru, Karnataka, India
# Kalkaji, Delhi, India
# Delhi, Delhi, India
# India, Asia
# Hubli, Karnataka, India
# New Delhi, Delhi, India
# Chennai, Tamil Nadu, India
# Mohali, Punjab, India
# Kolkata, West Bengal, India
# Pune, Maharashtra, India
# Jodhpur, Rajasthan, India
# Kanpur, Uttar Pradesh, India
# Ahmedabad, Gujarat, India
# Azadpur, Delhi, India
# Haryana, Haryana, India
# Cochin, Kerala, India
# Faridabad, Haryana, India
# Jaipur, Rajasthan, India
# Kota, Rajasthan, India
# Anand, Gujarat, India
# Bangalore City, Karnataka, India
# Belgaum, Karnataka, India
# Thane, Maharashtra, India
# Margão, Goa, India
# Indore, Madhya Pradesh, India
# Alwar, Rajasthan, India
# Kannur, Kerala, India
# Trivandrum, Kerala, India
# Ernakulam, Kerala, India
# Kormangala, Karnataka, India
# Uttar Pradesh, India, Asia
# Andheri, Maharashtra, India
# Mylapore, Tamil Nadu, India
# Ghaziabad, Uttar Pradesh, India
# Kochi, Kerala, India
# Powai, Assam, India
# Guntur, Andhra Pradesh, India
# Kalpakkam, Tamil Nadu, India
# Bhopal, Madhya Pradesh, India
# Coimbatore, Tamil Nadu, India
# Worli, Maharashtra, India
# Alleppey, Kerala, India
# Chandigarh, Chandigarh, India
# Guindy, Tamil Nadu, India
# Lucknow, Uttar Pradesh, India

# %% [markdown]
# **Column-4: Sector: 405 Unique values**

# %%
# Filter odd entries in the 'Sector' column
odde_c4_18 = df2018['Sector'].apply(is_odd_sector)
oddn_c4_18 = df2018[odde_c4_18]['Sector'].unique()

# Print the number of odd entries and their details
print(f"Number of odd entries in 'Sector' column: {len(oddn_c4_18)}")
print('\nOdd entries:')
for entry in oddn_c4_18:
    print(entry)
# Out:
# Number of odd entries in 'Sector' column: 343
#
# Odd entries:
# Brand Marketing, Event Promotion, Marketing, Sponsorship, Ticketing
# Agriculture, Farming
# Credit, Financial Services, Lending, Marketplace
# Financial Services, FinTech
# E-Commerce Platforms, Retail, SaaS
# Cloud Infrastructure, PaaS, SaaS
# Internet, Leisure, Marketplace
# Information Services, Information Technology
# B2B, Shoes
# Apps, Collaboration, Developer Platform, Enterprise Software, Messaging, Productivity Tools, Video Chat
# Automotive, Search Engine, Service Industry
# Finance, Internet, Travel
# Accounting, Business Information Systems, Business Travel, Finance, SaaS
# Artificial Intelligence, Product Search, SaaS, Service Industry, Software
# Internet of Things, Waste Management
# Air Transportation, Freight Service, Logistics, Marine Transportation
# Enterprise Software, Health Care, Hospital, Parenting, Personal Health, SaaS
# Agriculture, Analytics, Big Data, Farming
# Logistics, Supply Chain Management
# Financial Services, Lending
# Automotive, Marketplace, Online Portals
# Internet of Things, Telecommunications
# Information Technology, Logistics, Supply Chain Management
# Blockchain, Developer Tools, Enterprise Software
# Industrial Automation, Logistics, Supply Chain Management
# Food and Beverage, Food Delivery, Snack Food
# E-Commerce, Fashion, Jewelry, Retail
# E-Learning, Education
# Clean Energy, CleanTech, Laundry and Dry-cleaning
# E-Commerce, Fashion, Mobile
# Apps, Messaging, Navigation, Public Safety
# Fitness, Health Care, Wellness
# Artificial Intelligence, Machine Learning, SaaS, Virtual Assistant
# Food and Beverage, Tea
# Media and Entertainment, News, Outdoors
# Broadcasting, Media and Entertainment, Music, Music Streaming, Video, Video Streaming
# B2B, Information Services, Information Technology
# EdTech, Education, Enterprise Software, Peer to Peer
# Health Care, Medical
# E-Commerce
# Health Care, Hospital, Wellness
# Big Data, Consumer Lending, FinTech
# Cloud Computing, Computer, Semiconductor
# Health Care, Medical, Pharmaceutical
# Food Processing, Retail
# Consumer Goods, Lifestyle, Men's
# Food and Beverage, Food Processing, Nutrition
# Automotive, Electric Vehicle, Energy Storage
# Consulting, Retail, Social
# Biotechnology, Life Science, Pharmaceutical, Product Research
# Credit, Financial Services, FinTech, Personal Finance
# Communities, Coworking, Incubators
# Consumer, Financial Services, FinTech
# Consumer Applications, Information Services, Location Based Services, Virtual Assistant
# Mobile, Mobile Apps, Personalization, Test and Measurement, Web Apps
# Education, Financial Services, FinTech
# Advertising, Consulting, Digital Marketing
# Marketplace, Real Estate, Rental Property
# E-Learning, Internet, Video Games
# Artificial Intelligence, Cloud Computing, Video
# Health Care, Information Technology
# E-Commerce, Fashion, Lifestyle
# Artificial Intelligence, Business Intelligence, Industrial Automation, Machine Learning
# Home Decor, Home Improvement, Home Renovation, Home Services, Interior Design, Smart Home
# EdTech, Education, Information Services, SaaS
# Energy, Solar
# B2B, Biometrics, Cyber Security, Fraud Detection, SaaS, Security
# Artificial Intelligence, Social
# Logistics, Transportation, Travel
# Digital Marketing, SEM, SEO, Web Development
# Health Care, Hospital, Medical
# Finance, Financial Services
# Food Delivery, Food Processing, Internet
# E-Commerce, Food and Beverage, Internet
# Fitness, Food and Beverage, Health Care, Nutrition
# EdTech, Education, Knowledge Management
# Apps, Beauty, Consumer, Retail
# Creative Agency, Crowdfunding, EdTech, Health Care, Internet, Medical, Non Profit, Personal Health
# Consumer Lending, Financial Services, FinTech, Insurance, Lending, Mobile Payments, Payments, Wealth Management
# E-Learning, Education, Higher Education
# EdTech, Education
# Financial Services, SaaS, Security
# Banking, Finance, Financial Services, Non Profit
# B2B, E-Commerce, Mobile
# Automotive, Electric Vehicle, Renewable Energy
# E-Learning
# Embedded Systems, Health Care, Medical, Product Research
# Apps, E-Commerce, Internet
# Advertising, Human Resources, Marketing
# Beauty, Fitness, Home Services, Internet
# Health Care, Medical Device, Public Safety
# Food Delivery, Online Portals, Restaurants
# AgTech, B2B, Supply Chain Management
# Credit Cards, Finance, Mobile Apps, Mobile Payments, Payments
# EdTech, Education, Higher Education, Secondary Education
# Manufacturing, Retail
# Information Services, Information Technology, InsurTech
# Consumer Lending, FinTech
# Internet, Social Network, TV
# Beauty, Health Care
# 3D Printing, Manufacturing, Product Design
# Automotive, Retail
# Apps, Audio
# Automotive, E-Commerce
# Digital Entertainment, Fantasy Sports, Sports
# E-Learning, EdTech, Education
# Funding Platform, Incubators, Non Profit
# Hospitality, Hotel, Leisure, Travel
# Classifieds, Internet, Marketplace, Rental Property
# Banking, E-Learning, Trading Platform
# E-Commerce, Mobile, Retail
# Artificial Intelligence, Information Technology
# Enterprise Resource Planning (ERP), Information Services, Information Technology, Real Estate
# Banking, Finance, Financial Services
# Audio, Mobile, Tourism, Travel
# Energy, Energy Storage, Infrastructure
# Government, Information Technology, Software
# Education, Information Technology, Internet, Mobile, Software
# Consumer Lending, Financial Services, Lending, Personal Finance
# Digital Media, Internet, Media and Entertainment, Online Portals, Social Media
# Business Intelligence, Customer Service, Market Research, SaaS
# Credit, Financial Services, FinTech, Lending
# Children, Education, Parenting
# Automotive, Battery, Energy, Energy Storage
# E-Commerce, Mobile, Sharing Economy
# Food Delivery, Organic, Organic Food
# B2B, Farming, Marketplace
# Education, Gaming, Training
# Internet, Mobile, Social Entrepreneurship, Telecommunications, Wireless
# Health Care, Hospital, Supply Chain Management
# Tourism, Travel
# Hospitality, Real Estate
# Digital Media, EBooks, Publishing, Reading Apps
# Consumer Electronics, Embedded Systems, Hardware, Smart Building, Software
# Food and Beverage, Food Processing
# Internet, Marketplace, Shopping
# Analytics, Computer Vision, Enterprise Software, Machine Learning, Natural Language Processing, Speech Recognition
# Automotive, Electric Vehicle, Energy
# Health Care, Health Diagnostics, Predictive Analytics
# Cloud Computing, Computer, SaaS, Software
# Fashion, Lifestyle, Retail
# Music Streaming
# Finance, Impact Investing, Internet
# Internet, Social Entrepreneurship
# Finance, Impact Investing, Mobile Apps
# Cloud Computing, Computer, Software
# Business Development, Market Research, Outsourcing
# Health Care, Hospitality
# Internet, Social News, Sports
# Finance, Financial Services, FinTech
# Customer Service, Software, Video, Video Streaming
# E-Commerce, Food Processing
# Dietary Supplements, Food and Beverage, Health Care, Organic Food, Snack Food
# Manufacturing, Oil and Gas, Robotics
# Artificial Intelligence, Computer, Machine Learning
# Collaboration, Communities, Coworking, Sharing Economy
# Big Data, EdTech, Machine Learning
# Analytics, Audio, Digital Media, Innovation Management, Internet Radio, Media and Entertainment
# Financial Services, Lending, Peer to Peer
# E-Commerce, Furniture, Home Decor, Interior Design, Internet
# File Sharing, Personalization, Social Media
# Home Decor, Interior Design
# Health Care, Medical Device, Mobile Apps
# E-Commerce, Facilities Support Services, Procurement, Supply Chain Management
# Crowdfunding, Finance, Financial Services
# Finance, Financial Services, Insurance
# Children, Education, Online Portals
# Software, Virtual Reality
# B2B, Food and Beverage, Food Delivery
# Catering, Food and Beverage, Food Delivery, Food Processing
# Food and Beverage, Snack Food
# Automotive, E-Commerce, Mobile
# Computer, Digital Marketing, Facilities Support Services, Graphic Design, Internet, Mobile Apps, Social Media Marketing, Web Development
# Android, Big Data, Blockchain, Cloud Computing, EdTech, Education, Information Technology, iOS, Training, Web Development
# Analytics, CRM, Loyalty Programs, Machine Learning, Marketing Automation, Retail Technology, SaaS, Small and Medium Businesses
# Delivery, Information Technology, Mobile Apps
# Environmental Consulting, Renewable Energy
# Big Data, Business Intelligence, Financial Services, FinTech, Personal Finance
# Commercial Real Estate, Coworking, Office Administration, Real Estate
# Food and Beverage, Food Processing, Organic Food, Snack Food
# Apps, Health Care, Internet, Mobile Apps, Personal Health
# Digital Media, Incubators, Social Entrepreneurship
# Finance, Financial Services, Marketing
# Biotechnology, Health Care, Life Science, Medical Device
# Education, Human Resources
# Apps, Health Care, Hospital, Mobile Apps
# Delivery Service, Logistics, Service Industry
# Big Data, Data Visualization, Logistics, Software
# Basketball, Cricket, Cycling, eSports, Fitness, Golf, Health Care, Hockey, Sports, Swimming, Table Tennis, Volley Ball
# Media and Entertainment, News, Publishing
# Big Data, Financial Services, Machine Learning, Predictive Analytics
# Agriculture, AgTech, Manufacturing
# Digital Media, News, Publishing
# Health Care, Hospital
# B2B, E-Commerce, Enterprise
# Fraud Detection, Information Services, Security
# Agriculture, AgTech, Artificial Intelligence, Internet of Things, Machine Learning
# Cryptocurrency, Trading Platform
# Finance, FinTech, Mobile Payments
# E-Learning, EdTech, Education, Image Recognition, Machine Learning, STEM Education
# Crowdsourcing, Financial Services, Funding Platform, Venture Capital
# Delivery, Drones, Geospatial, Robotics
# Health Care, Information Technology, Management Information Systems
# Business Travel, Hospitality, Hotel, Marketplace, Tourism, Travel Accommodations
# Career Planning, Education, Higher Education, Service Industry
# Alternative Medicine, Health Care
# Internet, Software
# Dental, Elder Care, Health Care, Home Health Care, Personal Health
# Financial Services, Insurance, Private Social Networking
# Consumer Electronics, E-Commerce, E-Commerce Platforms, Electronics, Shipping, Shopping
# Advertising, Internet, Marketing
# Human Resources, Security, Training
# Consumer Lending, Finance, FinTech
# Marketing, Social Media, Video
# Apps, B2B, Freight Service, Logistics, SaaS, Shipping, Supply Chain Management, Transportation
# Digital Entertainment, Fantasy Sports, Gaming, Sports
# Automotive, Last Mile Transportation, Peer to Peer, Ride Sharing
# Commercial, E-Learning, Education
# Continuing Education, EdTech, Education, Skill Assessment
# Smart Cities, Telecommunications
# Internet of Things, Robotics
# Apps, Home Services, Information Services, Information Technology
# Medical, Tourism
# Career Planning, Education, Internet
# Fashion, Graphic Design, Wearables
# Communities, Leisure, Mobile Apps, Software
# Automotive, Rental, Sharing Economy
# Energy, Environmental Consulting, Renewable Energy, Solar
# Information Technology, SaaS, Security
# Crowdfunding, Financial Services, Internet
# Customer Service, Information Technology, Internet, Sales Automation
# Advertising, Artificial Intelligence, Digital Media, iOS, Location Based Services, News, Video, Video on Demand, Video Streaming
# Credit Cards, Payments, Property Insurance, Property Management, Rental Property
# Beauty, Cosmetics, Health Care, Service Industry
# EdTech, Education, Mobile, Tutoring
# Social Media, Sports
# E-Commerce, E-Commerce Platforms, Retail
# E-Commerce, Fashion, Shopping
# Digital Entertainment, Mobile, PC Games
# Finance, Financial Services, Small and Medium Businesses
# Artificial Intelligence, Energy, Oil and Gas
# Computer, FinTech, Risk Management, Software
# Apps, Financial Services, FinTech
# Child Care, Health Care, Hospital, Medical, Women's
# Agriculture, Mobile
# Finance, FinTech, Payments, Property Development, Rental
# Information Services, Information Technology, Mobile, Software
# Apps, Fitness, Health Care, mHealth
# Food and Beverage, Food Delivery
# Apps, Payments, Retail
# Health Insurance, Insurance, Life Insurance
# Rental, Taxi Service, Travel
# E-Commerce, E-Commerce Platforms, Internet, Retail
# Financial Services, Professional Services
# Customer Service, Messaging, Mobile Apps, Personalization
# Gaming, iOS, Sports
# E-Commerce, E-Commerce Platforms, Internet, Mobile Apps, Social Media
# Battery, Electric Vehicle, Energy, Renewable Energy, Transportation
# Agriculture, Farmers Market, Farming
# Artificial Intelligence, Drones, Navigation, Packaging Services, Robotics
# Fitness, GreenTech, Internet of Things, Mobile Apps, Ride Sharing, Transportation
# Mobile, Software, Travel
# Consulting, Cyber Security, Network Security
# eSports, Gaming, Video Games
# Fashion, Jewelry
# B2B, Medical Device
# Consumer Goods, Manufacturing
# Biotechnology, Health Care, Wellness
# Health Care, Hospital, Medical, Robotics
# E-Commerce, Fitness, Health Care
# Financial Services, Venture Capital
# Accounting, Apps, FinTech
# Apps, Mobile, Transportation
# Energy, Renewable Energy, Solar
# Banking, Financial Services, FinTech
# Apps, Education, Retail
# Automotive, Battery, Electric Vehicle, Manufacturing, Mechanical Design
# Automotive, E-Commerce, Marketplace
# Apps, Information Services, Information Technology
# B2B, Marketplace
# Computer, Furniture, Software
# Food Delivery, Hospitality, Reservations, Restaurants, Search Engine
# Collaboration, Communities, Coworking, Real Estate
# Accounting, Banking, Finance
# Cloud Computing, Enterprise Software, Network Hardware, Network Security, SaaS
# Information Services, Internet, Logistics, Supply Chain Management, Transportation
# Automotive, E-Commerce, Information Services
# Delivery, Logistics, Transportation
# Automotive, E-Commerce Platforms, Marketplace
# Last Mile Transportation, Railroad, Transportation, Travel
# Cooking, E-Commerce, Food and Beverage, Food Delivery, Online Portals
# FinTech, Mobile, Mobile Payments, Payments, Retail Technology
# Online Games, Software
# Online Portals, Property Management, Rental
# E-Commerce, Food and Beverage, Tea
# Music, Social Network, Video
# Health Care, Pharmaceutical, Wellness
# Delivery Service, Food and Beverage, Food Delivery
# Hospitality, Information Technology, Travel Accommodations
# Biotechnology, Diabetes, Health Care
# Autonomous Vehicles, Last Mile Transportation, Recreational Vehicles, Rental
# Finance, Financial Exchanges, Financial Services, Micro Lending
# Analytics, Apps, Market Research
# E-Commerce, E-Commerce Platforms, Furniture, Home Decor, Internet
# Apps, Mobile, Mobile Apps, Software
# News, Publishing, Social Media
# Industrial, Industrial Automation
# Internet, Mobile Apps, Social Network
# Health Care, Health Diagnostics, Internet of Things, Life Science, Machine Learning, Medical, Medical Device
# E-Commerce, Furniture, Interior Design
# Apps, Events, News
# Artificial Intelligence, Human Resources, Information Services, Information Technology
# Logistics, Railroad, Transportation
# Dating, Private Social Networking
# Artificial Intelligence, Machine Learning, PaaS
# Consumer, Furniture, Home Decor, Home Improvement
# Apps, E-Commerce, Internet, Mobile, Ride Sharing, Transportation
# Health Care, Health Insurance
# Energy, Natural Resources
# E-Commerce, Education, Health Care
# Apps, Health Care, Pharmaceutical
# Internet, Knowledge Management
# Credit, Finance, FinTech, Lending, Sales Automation
# Banking, Financial Services, Internet
# E-Commerce, Health Care, Retail
# Child Care, Information Technology
# Financial Services, Micro Lending
# E-Commerce, Retail, Shopping
# Food and Beverage, Snack Food, Tea
# Delivery Service, E-Commerce, Logistics
# Fashion, Lifestyle, Rental
# Fantasy Sports, Mobile, Sports
# Beauty, Fashion, Wellness
# Food and Beverage, Restaurants, Tea
# Fitness, Sporting Goods, Sports
# Food and Beverage, Food Processing, Manufacturing
# E-Learning, Internet
# Eyewear, Internet
# Information Technology, Mobile, News, Operating Systems, Social Media, Social News
# FinTech, Internet, Payments, Service Industry
# B2B, Business Development, Internet, Marketplace
# Food and Beverage, Food Delivery, Internet
# Biotechnology, Health Care, Pharmaceutical

# %% [markdown]
# **Column-5: What_it_does: 524 Unique values**

# %%
# Filter odd entries in the 'What_it_does' column
odde_c5_18 = df2018['What_it_does'].apply(is_odd_activity)
oddn_c5_18 = df2018[odde_c5_18]['What_it_does'].unique()

# Print the number of odd entries and their details
print(f"Number of odd entries in 'What_it_does' column: {len(oddn_c5_18)}")
print('\nOdd entries:')
for entry in oddn_c5_18:
    print(entry)
# Out:
# Number of odd entries in 'What_it_does' column: 22
#
# Odd entries:
# A Education Start Up.
# A fintech platform.
# The Fashion Re-commerce platform.
# We build In-Destination Experiences!
# Gov-Tech
# Bengaluru based biotech startup.
# Gurugram-based Online petcare platform.
# A Robotic Company.
# A coworking space provider.
# Algorithmic trading platform.
# A coworking incubator Company.
# HR Technology start-up.
# A digital news platform.
# Gurgaon based E-learning platform.
# Peer-to-Peer motor vehicles sharing
# An Education Management startup.
# Try & Buy
# A Mumbai-based fin-tech startup
# Online gaming startup.
# Delhi-based logistics technology.
# Upwards Fintech financial company.
# Free language learning platform.

# %% [markdown]
# **Column-6: Founders: 1 Unique value**

# %%
# Filter odd entries in the 'Founders' column
odde_c6_18 = df2018['Founders'].apply(is_odd_founder)
oddn_c6_18 = df2018[odde_c6_18]['Founders'].unique()

# Print the number of odd entries and their details
print(f"Number of odd entries in 'Founders' column: {len(oddn_c6_18)}")
print('\nOdd entries:')
for entry in oddn_c6_18:
    print(entry)
# Out:
# Number of odd entries in 'Founders' column: 0
#
# Odd entries:

# %% [markdown]
# **Column-7: Investor: 1 Unique values**

# %%
# Filter odd entries in the 'Founders' column
odde_c7_18 = df2018['Investor'].apply(is_odd_investor)
oddn_c7_18 = df2018[odde_c7_18]['Investor'].unique()

# Print the number of odd entries and their details
print(f"Number of odd entries in 'Investor' column: {len(oddn_c7_18)}")
print('\nOdd entries:')
for entry in oddn_c7_18:
    print(entry)
# Out:
# Number of odd entries in 'Investor' column: 0
#
# Odd entries:

# %% [markdown]
# **Column-8: Amount: 198 Unique values**

# %%
# Apply the odd_amount function to each element in the 'Amount' column of df2021
odde_c8_18 = df2018['Amount'].apply(odd_amount)

# Filter the DataFrame to get only the rows where 'Amount' column has odd entries
oddn_c8_18 = df2018[odde_c8_18]['Amount'].unique()

# Print the number of odd entries and their details
print(f"Number of odd entries in 'Amount' column: {len(oddn_c8_18)}")
print('\nOdd entries:')
for entry in oddn_c8_18:
    print(entry)
# Out:
# Number of odd entries in 'Amount' column: 41
#
# Odd entries:
# —
# $143,145
# $742,000,000
# $3,980,000
# $10,000
# $1,000,000,000
# $7,000,000
# $35,000,000
# $28,500,000
# $2,000,000
# $2,400,000
# $30,000,000
# $23,000,000
# $150,000
# $11,000,000
# $3,240,000
# $540,000,000
# $900,000
# $10,000,000
# $1,500,000
# $1,000,000
# $5,000,000
# $14,000,000
# $100,000,000
# $800,000
# $1,041,000
# $100,000
# $15,000
# $40,000,000
# $1,100,000
# $50,000,000
# $3,000,000
# $6,000,000
# $41,900,000
# $3,530,000
# $200,000
# $3,300,000
# $210,000,000
# $37,680,000
# $250,000
# $20,000

# %% [markdown]
# **Column-9: Stage: 21 Unique values**

# %%
# Identify odd entries in 'Stage' column
odde_c9_18 = odd_stage(df2018['Stage'])

# Get unique odd entries
oddn_c9_18 = set(odde_c9_18)

# Print the number of odd entries and their details
print(f"Number of odd entries in 'Stage' column: {len(oddn_c9_18)}")
print('\nOdd entries:')
for entry in oddn_c9_18:
    print(entry)
# Out:
# Number of odd entries in 'Stage' column: 13
#
# Odd entries:
# Corporate Round
# Post-IPO Equity
# Private Equity
# Venture - Series Unknown
# Debt Financing
# Grant
# Angel
# Secondary Market
# Non-equity Assistance
# Post-IPO Debt
# https://docs.google.com/spreadsheets/d/1x9ziNeaz6auNChIHnMI8U6kS7knTr3byy_YBGfQaoUA/edit#gid=1861303593
# Funding Round
# Undisclosed

# %% [markdown]
# [Back to Top](#Table-of-Contents)
#
# ## Step 3: Data Preparation
#
# `Data Cleaning`
#
# Effective data cleaning is crucial to ensure the integrity and usability of the dataset for analysis. The steps involved in data cleaning will include:
#
# **A. Remove Duplicates:**
#
# Identify and remove duplicate records to ensure that each entry is unique and not counted multiple times. This involves checking for repeated start-up names, funding amounts, and investor details.
#
# **B. Eliminate Irrelevant Data:**
#
# Remove any data that is not relevant to the analysis. This could include fields that do not contribute to the understanding of funding trends or extraneous information not related to start-up funding.
#
# **C. Handle Missing Values:**
#
# - Imputation: For fields with missing data, use appropriate imputation methods to fill in the gaps. This could involve using mean, median, or mode for numerical values, or the most frequent category for categorical variables.
#
# - Removal: If the amount of missing data is substantial and imputation is not feasible, records are removed entirely. However, this is done if deletion does not significantly impact the overall dataset integrity.
#
# **D. Standardise Formats:**
#
# - Dates: Ensure all date fields follow a consistent format (e.g., YYYY-MM-DD) to facilitate accurate time-based analysis.
#
# - Funding Amounts: Standardize funding amounts to a common currency and format, ensuring consistency in how values are presented and analysed.
#
# - Categorical Variables: Ensure uniform labelling for categorical variables such as sectors, funding stages, and locations to avoid discrepancies (e.g., "Health Care" vs. "Healthcare").
#
# `Data Transformation`
#
# Data transformation involves modifying the data to better suit the analytical methods to be applied. The steps include:
#
# **A. Aggregate Funding Data:**
#
# - By Year: Summarize funding data on an annual basis to identify year-over-year trends in funding amounts and number of funding rounds.
#
# - By Sector: Aggregate funding by sector to determine which industries are receiving the most investment.
#
# - By Funding Stage: Summarize data by funding stage (e.g., seed, series A, series B) to understand the distribution of investments across different start-up maturity levels.
#
# **B. Normalize Funding Amounts:**
#
# Adjust funding amounts for inflation or currency changes over the years to ensure that comparisons are made on a like-for-like basis. This is important for accurately assessing trends and changes in funding amounts over time.
#
# `Data Integration`
#
# Data integration involves combining multiple datasets into a single, comprehensive dataset for analysis. This includes:
#
# **A. Combine Datasets from Different Years:**
#
# Merge datasets from 2018 to 2021 into a unified dataset. Ensure that the structure and format of data from each year are consistent to facilitate seamless integration. Address any discrepancies or differences in data schema across years to create a cohesive dataset.
#
# **B. Ensure Consistency:**
#
# Verify that all integrated data follows the standardized formats and labelling conventions established during the data cleaning process. Cross-reference and validate combined data to ensure no information is lost or misrepresented during the integration process.

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# #### Load LP1_startup_funding2021 Data

# %% [markdown]
# ##### Remove Duplicates

# %% [markdown]
# **Based on all Features**

# %%
# Create a copy of df2021 to avoid modifying the original DataFrame
cl_df2021 = df2021.copy()

# Remove duplicate rows from cl_df2021, and reset the index of the resulting DataFrame
cl_df2021.drop_duplicates(inplace=True, ignore_index=True)

# Display info of Data Frame
cl_df2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1190 entries, 0 to 1189
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1190 non-null   object
#  1   Founded        1189 non-null   float64
#  2   HeadQuarter    1189 non-null   object
#  3   Sector         1190 non-null   object
#  4   What_it_does   1190 non-null   object
#  5   Founders       1186 non-null   object
#  6   Investor       1129 non-null   object
#  7   Amount         1187 non-null   object
#  8   Stage          769 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 83.8+ KB

# %% [markdown]
# **Based on First Eight Features**

# %%
# Filter rows with duplicated values in all columns except the last one
cl_df2021[cl_df2021.duplicated(subset=cl_df2021.columns[0:8], keep=False)]
# Out:
#      Company_Brand  Founded HeadQuarter                    Sector  \
# 95     TartanSense   2015.0   Bangalore    Information Technology
# 97       Kirana247   2018.0   New Delhi  Logistics & Supply Chain
# 99         NeoDocs   2020.0      Mumbai                Healthtech
# 100  IsGoingOnline   2015.0      Cochin                    Retail
# 101       Camp K12   2010.0    Gurugram                    EdTech
# 102    Elda Health   2020.0   Bangalore                Healthcare
# 103         Sporjo   2020.0      Mumbai                SportsTech
# 105    SuperGaming   2017.0        Pune                    Gaming
# 107    TartanSense   2015.0   Bangalore    Information Technology
# 108      Kirana247   2018.0   New Delhi  Logistics & Supply Chain
# 109        NeoDocs   2020.0      Mumbai                Healthtech
# 110  IsGoingOnline   2015.0      Cochin                    Retail
# 111       Camp K12   2010.0    Gurugram                    EdTech
# 112    Elda Health   2020.0   Bangalore                Healthcare
# 113         Sporjo   2020.0      Mumbai                SportsTech
# 114    SuperGaming   2017.0        Pune                    Gaming
#
#                                           What_it_does  \
# 95   TartanSense unlocks value for small farm holde...
# 97   An on-demand FMCG supply chain company leverag...
# 99   Neodocs is a part of India's prominent Social ...
# 100  Kochi-based digital catalogue and marketplace ...
# 101  Camp K12 is a global online school for 21st ce...
# 102  Elda Health is a digital wellness platform tha...
# 103  A one stop destination to build a successful c...
# 105  At SuperGaming, building India's best gaming c...
# 107  TartanSense unlocks value for small farm holde...
# 108  An on-demand FMCG supply chain company leverag...
# 109  Neodocs is a part of India's prominent Social ...
# 110  Kochi-based digital catalogue and marketplace ...
# 111  Camp K12 is a global online school for 21st ce...
# 112  Elda Health is a digital wellness platform tha...
# 113  A one stop destination to build a successful c...
# 114  At SuperGaming, building India's best gaming c...
#
#                                              Founders  \
# 95                                       Jaisimha Rao
# 97                Tarun Jiwarajka, Pankhuri Jiwarajka
# 99         Nikunj Malpani, Anurag Meena, Pratik Lodha
# 100                                        Eobin Alex
# 101                                      Anshul Bhagi
# 102  Swathi Kulkarni, Sindhuri Ananth, Shubham Sharma
# 103                                     G Srinivvasan
# 105        Roby John, Sanket Nadhani, Navneet Waraich
# 107                                      Jaisimha Rao
# 108               Tarun Jiwarajka, Pankhuri Jiwarajka
# 109        Nikunj Malpani, Anurag Meena, Pratik Lodha
# 110                                        Eobin Alex
# 111                                      Anshul Bhagi
# 112  Swathi Kulkarni, Sindhuri Ananth, Shubham Sharma
# 113                                     G Srinivvasan
# 114        Roby John, Sanket Nadhani, Navneet Waraich
#
#                                               Investor        Amount  \
# 95                       FMC, Omnivore, Blume Ventures      $5000000
# 97                                                None      $1000000
# 99              Y Combinator, 9Unicorns, Titan Capital  $Undisclosed
# 100     Unicorn India Ventures, SEA Fund, Devdatt Shah       $200000
# 101           Matrix Partners India, Elevation Capital     $12000000
# 102                     Avaana Capital, Orios Ventures      $1500000
# 103                                        Punit Balan      $2000000
# 105  Skycatcher, AET Fund, BAce Capital, Dream Incu...      $5500000
# 107                      FMC, Omnivore, Blume Ventures      $5000000
# 108                                               None      $1000000
# 109             Y Combinator, 9Unicorns, Titan Capital  $Undisclosed
# 110     Unicorn India Ventures, SEA Fund, Devdatt Shah       $200000
# 111           Matrix Partners India, Elevation Capital     $12000000
# 112                     Avaana Capital, Orios Ventures      $1500000
# 113                                        Punit Balan      $2000000
# 114  Skycatcher, AET Fund, BAce Capital, Dream Incu...      $5500000
#
#             Stage
# 95           None
# 97           None
# 99           None
# 100          None
# 101          None
# 102          None
# 103          None
# 105          None
# 107      Series A
# 108  Pre-series A
# 109      Pre-seed
# 110  Pre-series A
# 111      Series A
# 112          Seed
# 113  Pre-series A
# 114      Series A

# %%
# Remove duplicate rows based on the first 8 columns, keeping the last occurrence
cl_df2021.drop_duplicates(subset=cl_df2021.columns[0:8], inplace=True, ignore_index=True, keep='last')

# Display info of Data Frame
cl_df2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1182 entries, 0 to 1181
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1182 non-null   object
#  1   Founded        1181 non-null   float64
#  2   HeadQuarter    1181 non-null   object
#  3   Sector         1182 non-null   object
#  4   What_it_does   1182 non-null   object
#  5   Founders       1178 non-null   object
#  6   Investor       1122 non-null   object
#  7   Amount         1179 non-null   object
#  8   Stage          769 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 83.2+ KB

# %% [markdown]
# **Based on First Seven Features**

# %%
# Filter rows with duplicated values in all columns except the last two
cl_df2021[cl_df2021.duplicated(subset=cl_df2021.columns[0:7], keep=False)]
# Out:
#     Company_Brand  Founded HeadQuarter   Sector  \
# 345           MPL   2018.0   Bangalore   Gaming
# 367           MPL   2018.0   Bangalore   Gaming
# 374      BharatPe   2018.0   New Delhi  FinTech
# 380      BharatPe   2018.0   New Delhi  FinTech
# 611        BYJU'S   2011.0   Bangalore   EdTech
# 835        BYJU'S   2011.0   Bangalore   EdTech
#
#                                           What_it_does  \
# 345  Mobile Premier League is a skill-based eSports...
# 367  Mobile Premier League is a skill-based eSports...
# 374  BharatPe develops a QR code-based payment app ...
# 380  BharatPe develops a QR code-based payment app ...
# 611  BYJU'S is an educational technology company th...
# 835  BYJU'S is an educational technology company th...
#
#                                    Founders  \
# 345  Sai Srinivas Kiran G, Shubham Malhotra
# 367  Sai Srinivas Kiran G, Shubham Malhotra
# 374        Ashneer Grover, Shashvat Nakrani
# 380        Ashneer Grover, Shashvat Nakrani
# 611        Byju Raveendran, Divya Gokulnath
# 835        Byju Raveendran, Divya Gokulnath
#
#                                  Investor        Amount Stage
# 345  Pegasus Tech Ventures, Base Partners   $95,000,000  None
# 367  Pegasus Tech Ventures, Base Partners    $5,000,000  None
# 374    InnoVen Capital, Steadview Capital    $6,000,000  Debt
# 380    InnoVen Capital, Steadview Capital   $10,000,000  Debt
# 611       Tiga Investments, Baron Capital    $350000000  None
# 835       Tiga Investments, Baron Capital  $150,000,000  None

# %% [markdown]
# `Comments`
#
# 1. MPL (Mobile Premier League) raised $95M and $5M from Pegasus Tech Ventures and Base Partners. The $95M is likely a later-stage round for scaling, while the $5M is probably a seed or early-stage round.
#
# 2. BharatPe raised $6M and $10M from InnoVen Capital and Steadview Capital as debt investments. The $6M is likely an early-stage debt round for initial growth, and the $10M a subsequent stage for further scaling.
#
# 3. BYJU'S raised $350M and $150M from Tiga Investments and Baron Capital. Both amounts suggest later-stage rounds for business expansion and growth.
#
#     Without further details regarding the specific funding rounds, these inferences are derived solely from the funding amounts. Therefore, before considering the removal of these rows, it is advisable to determine if any of the amounts are outliers. Dropping such outliers should not adversely impact the integrity of the dataset.

# %% [markdown]
# ***Converting the 'Amount' column to float***

# %%
# Define a function to convert string to float or NaN if not convertible
def convert_to_float(value):
    try:
        return float(value)
    except ValueError:
        return np.nan

# Apply the function to each element in the "Amount" column
cl_df2021['Amount'] = cl_df2021['Amount'].apply(lambda x: convert_to_float(re.sub(r'[^\d.]', '', str(x))))

# Check the data type of the "Amount" column
cl_df2021['Amount'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ***Univariate Analysis of the 'Amount' Column***

# %%
# Descriptive Statistics
print("Descriptive Statistics for 'Amount' column:")
print(cl_df2021['Amount'].describe())

# Skewness and Kurtosis
amount_skewness = skew(cl_df2021['Amount'])
amount_kurtosis = kurtosis(cl_df2021['Amount'])

print(f"\nSkewness for 'Amount' column: {amount_skewness}")
print(f"Kurtosis for 'Amount' column: {amount_kurtosis}")

# set theme
sns.set_theme(style="dark", palette="dark", font="sans-serif", font_scale=1.5)
plt.style.use("dark_background")
custom_palette = ["cyan", "magenta", "yellow"]

# Box Plot
plt.figure(figsize=(10, 6))
sns.boxplot(y=cl_df2021['Amount'], palette=custom_palette)
plt.title('Box Plot of Amount')
plt.xlabel('Amount')
plt.show()
# Out:
# Descriptive Statistics for 'Amount' column:
# count    1.033000e+03
# mean     1.738079e+08
# std      4.666860e+09
# min      1.000000e+04
# 25%      1.000000e+06
# 50%      3.800000e+06
# 75%      1.500000e+07
# max      1.500000e+11
# Name: Amount, dtype: float64
#
# Skewness for 'Amount' column: nan
# Kurtosis for 'Amount' column: nan

# %% [markdown]
# ***Drop all duplicates that have none in 'Stage' column***

# %%
# Separate rows with 'Debt' in the 'Stage' column
debt_rows = cl_df2021[cl_df2021['Stage'] == 'Debt']
non_debt_rows = cl_df2021[cl_df2021['Stage'] != 'Debt']

# Remove all duplicate rows based on the first 7 columns in non-debt rows, keeping the last occurrence
non_debt_rows.drop_duplicates(subset=non_debt_rows.columns[0:7], inplace=True, ignore_index=True, keep=False)

# Concatenate the debt and non-debt rows back together
cl_df2021 = pd.concat([non_debt_rows,debt_rows], ignore_index=True)

# Display info of Data Frame
cl_df2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1178 entries, 0 to 1177
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1178 non-null   object
#  1   Founded        1177 non-null   float64
#  2   HeadQuarter    1177 non-null   object
#  3   Sector         1178 non-null   object
#  4   What_it_does   1178 non-null   object
#  5   Founders       1174 non-null   object
#  6   Investor       1118 non-null   object
#  7   Amount         1029 non-null   float64
#  8   Stage          769 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 83.0+ KB

# %% [markdown]
# **Based on Key Columns**

# %% [markdown]
# ***Duplicated columns based on key columns after deletion  of duplicates***

# %%
# Check for number of duplicated values within the 'Company_Brand' column
dupl_count = cl_df2021.duplicated(subset=key_columns, keep=False).sum()

# Identify duplicate entries in the 'Company_Brand' column
dup_cl_21 = cl_df2021[cl_df2021.duplicated(subset=key_columns, keep=False)]

# Extract the list of duplicated company brands
unidup_cl_21 = dup_cl_21['Company_Brand'].unique()

# Display results
print(f"Number of duplicated values in 'Company_Brand' column: {dupl_count}")
print("\nList of duplicated company brands:")
print(unidup_cl_21)
# Out:
# Number of duplicated values in 'Company_Brand' column: 18
#
# List of duplicated company brands:
# ['DealShare' 'BharatPe' 'Nazara Technologies' 'Spinny' 'KreditBee'
#  'Euler Motors' 'Delhivery' 'Northern Arc']

# %% [markdown]
# ***Duplicated columns only in list of duplicated company brands before deletion of duplicates***

# %%
# Create a set of the list of duplicated company brands based on key columns before deletion of duplicates
unidup_c1_21_values = set(unidup_c1_21)

# Create a set of the list of duplicated company brands based on key columns after deletion of duplicates
unidup_cl_21_values = set(unidup_cl_21)

# Find the values that only appear in the list of duplicated company brands before deletion of duplicates
values_only_in_unidup_c1_21 = unidup_c1_21_values - unidup_cl_21_values

# Display Results
print("Values only in list of duplicated company brands before deletion of duplicates:")
print(values_only_in_unidup_c1_21)

# Filter rows where 'Company_Brand' is 'Values only in list of duplicated company brands before deletion of duplicates'
values_only_in_unidup_c1_21_rows = cl_df2021[cl_df2021['Company_Brand'].isin(values_only_in_unidup_c1_21)]

# Filter 'values_only_in_unidup_c1_21_rows' based on the key columns
values_only_in_unidup_c1_21_rows[values_only_in_unidup_c1_21_rows.duplicated(subset=key_columns, keep=False)]
# Out:
# Values only in list of duplicated company brands before deletion of duplicates:
# {'Insurance Samadhan', 'Bewakoof', 'FanAnywhere', 'Elda Health', 'NeoDocs', 'Zorro', 'NephroPlus', 'Sporjo', 'Curefoods', 'Evenflow Brands', 'MasterChow', 'Fullife Healthcare', 'Kirana247', 'MPL', 'SuperGaming', 'IsGoingOnline', 'Enmovil', "BYJU'S", 'Ruptok', 'Trinkerr', 'Camp K12', 'Ultraviolette', 'FanPlay', 'ASQI Advisors', 'PingoLearn', 'TartanSense', 'Unremot', 'Advantage Club', 'Spry'}
# Empty DataFrame
# Columns: [Company_Brand, Founded, HeadQuarter, Sector, What_it_does, Founders, Investor, Amount, Stage]
# Index: []

# %% [markdown]
# ##### Handling Odd Entries and Irrelevant Data

# %% [markdown]
# **Drop companies founded before 1980 and after 2021**

# %%
# Drop rows where the 'founded' column has values less than 1980 or greater than 2021
cl_df2021 = cl_df2021[(cl_df2021['Founded'] >= 1980) & (cl_df2021['Founded'] <= 2021)].reset_index(drop=True)

# Display info of Data Frame
cl_df2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1175 entries, 0 to 1174
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1175 non-null   object
#  1   Founded        1175 non-null   float64
#  2   HeadQuarter    1174 non-null   object
#  3   Sector         1175 non-null   object
#  4   What_it_does   1175 non-null   object
#  5   Founders       1171 non-null   object
#  6   Investor       1115 non-null   object
#  7   Amount         1026 non-null   float64
#  8   Stage          768 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 82.7+ KB

# %% [markdown]
# **Replacing and dropping odd locations**

# %%
def replace_odd_location(location):
    # Check if the location is None or not a string
    if location is None or not isinstance(location, str):
        return 'Not filled'
    
    # Check if the location contains '#REF!'
    if '#REF!' in location:
        return 'Not filled'
    
    # Check if the location contains 'India' or 'Asia'
    if 'India' in location:
        # Compile the regular expression for better performance if used multiple times
        regex = re.compile(r'([^,]+),')
        match = regex.match(location)
        if match:
            city = match.group(1).strip()
            # Ensure the extracted city is not "India" or ambiguous terms
            if city and city.lower() not in {'india', 'asia'}:
                return city
            else:
                return 'Not filled'  

    # Specific replacements
    if location == 'India, Asia':
        return 'Not filled'    
    if location == 'Small Towns, Andhra Pradesh':
        return 'Andhra Pradesh'
    if location == 'Uttar pradesh':
        return 'Uttar Pradesh'    
    if location == 'Faridabad, Haryana':
        return 'Faridabad'
    if location == 'Ahmadabad':
        return 'Ahmedabad'
    if location == 'Mountain View, CA':
        return 'Mountain View'
    if location == 'Tirunelveli, Tamilnadu':
        return 'Tirunelveli'
    if location == 'Jaipur, Rajastan':
        return 'Jaipur'
    if location == 'Dhingsara, Haryana':
        return 'Dhingsara'
    if location == 'Thiruvananthapuram':
        return 'Trivandrum'    
    if location == 'Samastipur, Bihar':
        return 'Samastipur'
    if location == 'Tumkur, Karnataka':
        return 'Tumkur'
    if location == 'Rajastan':
        return 'Rajasthan'
    if location == 'Warangal':
        return 'Warangal'
    if location == 'Hyderebad':
        return 'Hyderabad'
    if location == 'Banglore' or location == 'Bengaluru' or location == 'Bangalore City':
        return 'Bangalore'   
    if location == 'Frisco, Texas, United States':
        return 'Frisco'
    if location == 'New York, United States':
        return 'New York'
    if location == 'San Francisco, California, United States' or location == 'San Francisco, United States' or location == 'San Francisco Bay Area, Silicon Valley, West Coast' or location == 'San Francisco Bay Area, West Coast, Western US' or location == 'San Franciscao':
        return 'San Francisco'
    if location == 'San Ramon, California':
        return 'San Ramon'
    if location == 'Paris, Ile-de-France, France':
        return 'Paris'
    if location == 'Plano, Texas, United States':
        return 'Plano'
    if location == 'Sydney, New South Wales, Australia':
        return 'Sydney'
    if location == 'Milano, Lombardia, Italy':
        return 'Milan'
    if location == 'Palmwoods, Queensland, Australia':
        return 'Palmwoods'
    if location == 'Irvine, California, United States':
        return 'Irvine'
    if location == 'Newcastle Upon Tyne, Newcastle upon Tyne, United Kingdom':
        return 'Newcastle upon Tyne'
    if location == 'Shanghai, China':
        return 'Shanghai'
    if location == 'Jiaxing, Zhejiang, China':
        return 'Jiaxing'
    if location == 'Tangerang, Jawa Barat, Indonesia':
        return 'Tangerang'
    
    # A simple regex to identify locations with non-geographic content (basic approach)
    if re.search(r'\d', location) or re.search(r'[^a-zA-Z, ]', location) or len(location.split()) > 2:
        return 'Not filled'
    
    # A list of non-geographic keywords
    non_geographic_keywords = ['Computer Games', 'Food & Beverages', 'Pharmaceuticals', 'Online Media', 'Information Technology & Services', 'Santra']
    
    # Check if location is in the list of non-geographic keywords
    if location in non_geographic_keywords:
        return 'Not filled'
    
    return location

# Replace non-geographic odd entries in the 'HeadQuarter' column
cl_df2021['HeadQuarter'] = cl_df2021['HeadQuarter'].apply(replace_odd_location)

# Replace 'Bengaluru' and 'Bangalore City' with 'Bangalore' in the 'HeadQuarter' column
cl_df2021['HeadQuarter'] = cl_df2021['HeadQuarter'].replace({'Bengaluru': 'Bangalore', 'Bangalore City': 'Bangalore'})

# List of entries to drop
entries_to_drop21 = ['Beijing', 'New York', 'Mountain View', 'London']

# Drop rows where 'HeadQuarter' contains any of the entries in the list
cl_df2021 = cl_df2021[~cl_df2021['HeadQuarter'].isin(entries_to_drop21)].reset_index(drop=True)

# Display info of Data Frame
cl_df2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1171 entries, 0 to 1170
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1171 non-null   object
#  1   Founded        1171 non-null   float64
#  2   HeadQuarter    1171 non-null   object
#  3   Sector         1171 non-null   object
#  4   What_it_does   1171 non-null   object
#  5   Founders       1167 non-null   object
#  6   Investor       1112 non-null   object
#  7   Amount         1023 non-null   float64
#  8   Stage          767 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 82.5+ KB

# %% [markdown]
# **Redistributing entries in sector column**

# %%
# Dictionary for common misspellings and inconsistencies
replacement_dict = {
    "Helathcare": "healthcare",
    "Healtcare": "healthcare",
    "Heathcare": "healthcare",
    "HeathTech": "healthtech",
    "Med Tech": "medtech",
    "Information Technology & Services": "it",
    "Manufacturing": "electronics manufacturing",
    "Company-as-a-Service": "caas",
    "Telecommuncation": "telecommunication",
    "HeathTech": "healthTech",
    "Deep Tech": "deeptech",
    "Deep Tech AI": "deeptech",
    "HR Tech": "hrtech",
    "HR tech": "hrtech",
    "HR": "Human Resource",
    "Insurtech": "insuretech",
    "Tech company": "tech",
    "Tech hub": "tech",
    "Tech Platform": "tech",
    "Techonology": "technology",
    "Travel Tech": "traveltech",
    "Travel tech": "traveltech",
    "Travel": "traveltech",
    "Coworking": "co-working",
    "E store": "estore",
    "Deisgning": "designing",
    "Data Science": "datasc",
    "Cloud company": "cloudcmp",
    "Multinational conglomerate company": "multiconglom",
    "Entreprenurship": "Entrepreneurship",
    "Ad-tech": "adtech",
    "E-connect": "econnect",
    "Aero company": "aerial",
    "Aero company": "aerial",
    "Agri tech": "agritech",
    "Soil-Tech": "soiltech",
    "Customer service company": "custsvc",
    "Service industry": "servindust",
    "EdtTech": "edtech",
    "API platform": "api",
    "Hygiene management": "hygienement",
    "Appliance": "appenergy",
    "Data Intelligence": "dataintel",
    "Auto-tech": "autotech",
    "Life sciences": "lifesci",
    "Mobile Payments": "mobpay",
    "Apps": "ap_s",
    "Packaging Services": "pksrv",
    "Reading Apps": "readapp",
    "Mobile": "mbl",
    "Wealth Management": "wlthman"
    }

# Replace sector names based on the dictionary
cl_df2021['Sector'] = cl_df2021['Sector'].replace(replacement_dict)


def sector_redistribution(sector):
    if sector is None or not isinstance(sector, str):
        return 'Not filled'
    # Handle specific cases for sectors that should be marked as 'Not filled'
    if sector in ['Manchester, Greater Manchester', 'Hauz Khas', '—']:
        return 'Not filled'
           
    # Remove leading and trailing whitespace
    sector = sector.strip()

    # Redistribute sectors into broader categories based on keywords  
    if re.search(r'banking|fintech|financial|finance|insurance|investment|crypto|advisory|venture|capital|blockchain|insuretech|escrow|taxation|funds|mobpay|wlthman', sector, re.IGNORECASE):
        return 'Finance and Technology'
    elif re.search(r'agriculture|farming|agritech|fishery|agritech|soiltech', sector, re.IGNORECASE):
        return 'Agriculture and Technology'
    elif re.search(r'education|edtech|e-learning|innovation|readapp', sector, re.IGNORECASE):
        return 'Education and Learning'
    elif re.search(r'health|medical|wellness|medtech|hygiene|ayurveda|lifesci', sector, re.IGNORECASE):
        return 'Healthcare and Health Technology'
    elif re.search(r'e-commerce|retail|d2c|b2b|commerce|business|sales|product|wholesale|trading|Jewellery', sector, re.IGNORECASE):
        return 'E-commerce and Retail'
    elif re.search(r'consumer|food|beverage|gaming|hospitality|cosmetics|games|pet|beauty|lifestyle|cannabis|milk|personal|tobacco|delivery|wine|femtech|estore|beer|custsvc', sector, re.IGNORECASE):
        return 'Consumer Goods and Services'
    elif re.search(r'industrial|automation|telecommunication|electronics|drone|pksrv', sector, re.IGNORECASE):
        return 'Technology Solutions for Industry'   
    elif re.search(r'renewable|environment|solar|energy|pollution|purification|cleantech|nanotechnology|ev|multiconglom|hygienement|appenergy|dataintel', sector, re.IGNORECASE):
        return 'Energy and Environment'    
    elif re.search(r'automotive|vehicle|automobile|battery|moeving|tyre|autotech', sector, re.IGNORECASE):
        return 'Automotive'    
    elif re.search(r'human|consulting|job|video|information|legal|staffing|coaching|hrtech|fulfillment|consultancy|crowdsourcing', sector, re.IGNORECASE):
        return 'Human Resources and Consultancy'
    elif re.search(r'transport|logistics|location|traveltech|distribution|aerial|wl|navigation', sector, re.IGNORECASE):
        return 'Transport and Logistics'
    elif re.search(r'marketing|advertisement|content|storytelling|analytics|adtech', sector, re.IGNORECASE):
        return 'Marketing and Advertising'    
    elif re.search(r'tech|software|saas|ai|it|internet|ar|crm|robotics|iot|mlops|translation|computer|caas|fmcg|proptech|designing|datasc|cloudcmp|scanning|deeptech|servindust|api|mbl', sector, re.IGNORECASE):
        return 'Technology and Software'
    elif re.search(r'media|music|sports|nft|arts|podcast|audio|blogging|ott|publication|econnect|fm|ap_s', sector, re.IGNORECASE):
        return 'Media and Entertainment'
    elif re.search(r'estate|rental|design|accomodation|housing|co-living', sector, re.IGNORECASE):
        return 'Real Estate and Housing'
    elif re.search(r'fashion|eyewear|textiles|clothing|footwear|merchandise|eyeglasses', sector, re.IGNORECASE):
        return 'Fashion and Apparel'
    elif re.search(r'construction|home|decor', sector, re.IGNORECASE):
        return 'Construction and Home Services'
    elif re.search(r'dating|matrimony|networking|social|co-working|wedding', sector, re.IGNORECASE):
        return 'Social Networking'
    elif re.search(r'cultural|tourism', sector, re.IGNORECASE):
        return 'Cultural and Tourism'
    elif re.search(r'space|aviation|defense', sector, re.IGNORECASE):
        return 'Defence and Aviation'
    elif re.search(r'entrepreneurship', sector, re.IGNORECASE):
        return 'Entrepreneurship and Business Incubation'        
    else:
        return sector

# Apply sector redistribution function to 'Sector' column
cl_df2021['Sector'] = cl_df2021['Sector'].apply(sector_redistribution)

# Get the value counts for the 'Sector' column
sector_counts = cl_df2021['Sector'].value_counts()

# Display results
print(sector_counts)
# Out:
# Sector
# Finance and Technology               219
# Technology and Software              212
# Consumer Goods and Services          131
# Education and Learning               131
# Healthcare and Health Technology     112
# E-commerce and Retail                 92
# Transport and Logistics               37
# Automotive                            35
# Human Resources and Consultancy       34
# Media and Entertainment               33
# Energy and Environment                27
# Agriculture and Technology            26
# Technology Solutions for Industry     20
# Real Estate and Housing               17
# Fashion and Apparel                   10
# Marketing and Advertising             10
# Social Networking                      9
# Construction and Home Services         8
# Defence and Aviation                   4
# Not filled                             2
# Cultural and Tourism                   2
# Name: count, dtype: int64

# %% [markdown]
# **Filling 'Amount' Column with values that were accidentally filled in adjacent columns**

# %% [markdown]
# ***Based on 'Investor' Column***

# %%
def matches_pattern(entry):
    if pd.isna(entry):
        return False
    if '\t#REF!' in entry:
        return True
    return bool(re.match(r'^\$[0-9]{1,}$', entry))

# Apply the function to filter the DataFrame
filter1_cl_df2021 = cl_df2021[
    (cl_df2021['Amount'].isna()) &
    (cl_df2021['Investor'].apply(matches_pattern) |
     cl_df2021['Investor'].isin(['#REF!', '$Undisclosed']))
]

# Display results
filter1_cl_df2021
# Out:
#            Company_Brand  Founded HeadQuarter  \
# 225   Fullife Healthcare   2009.0  Not filled
# 226              MoEVing   2021.0  Not filled
# 499            AdmitKard   2016.0       Noida
# 1037            Sochcast   2020.0  Not filled
# 1084           Godamwale   2016.0      Mumbai
#
#                                 Sector  \
# 225   Healthcare and Health Technology
# 226             Energy and Environment
# 499             Education and Learning
# 1037           Media and Entertainment
# 1084           Transport and Logistics
#
#                                            What_it_does  \
# 225                                        Varun Khanna
# 226                         Vikash Mishra, Mragank Jain
# 499   A tech solution for end to end career advisory...
# 1037  CA Harvinderjit Singh Bhatia, Garima Surana, A...
# 1084  Godamwale is tech enabled integrated logistics...
#
#                                               Founders        Investor  \
# 225                 Morgan Stanley Private Equity Asia       $22000000
# 226     Anshuman Maheshwary, Dr Srihari Raju Kalidindi        $5000000
# 499   Vamsi Krishna, Pulkit Jain, Gaurav Munjal\t#REF!        $1000000
# 1037           Vinners, Raj Nayak, Amritaanshu Agrawal    $Undisclosed
# 1084         Basant Kumar, Vivek Tiwari, Ranbir Nandan  1000000\t#REF!
#
#       Amount Stage
# 225      NaN  None
# 226      NaN  None
# 499      NaN  None
# 1037     NaN  None
# 1084     NaN  None

# %%
# Fill the Amount column with values from the Investor column in the filtered rows
cl_df2021.loc[filter1_cl_df2021.index, 'Amount'] = cl_df2021.loc[filter1_cl_df2021.index, 'Investor']

# Filter out specific rows using iloc
cl_df2021.iloc[cl_df2021.index.isin([225, 226, 499, 1037, 1084])]
# Out:
#            Company_Brand  Founded HeadQuarter  \
# 225   Fullife Healthcare   2009.0  Not filled
# 226              MoEVing   2021.0  Not filled
# 499            AdmitKard   2016.0       Noida
# 1037            Sochcast   2020.0  Not filled
# 1084           Godamwale   2016.0      Mumbai
#
#                                 Sector  \
# 225   Healthcare and Health Technology
# 226             Energy and Environment
# 499             Education and Learning
# 1037           Media and Entertainment
# 1084           Transport and Logistics
#
#                                            What_it_does  \
# 225                                        Varun Khanna
# 226                         Vikash Mishra, Mragank Jain
# 499   A tech solution for end to end career advisory...
# 1037  CA Harvinderjit Singh Bhatia, Garima Surana, A...
# 1084  Godamwale is tech enabled integrated logistics...
#
#                                               Founders        Investor  \
# 225                 Morgan Stanley Private Equity Asia       $22000000
# 226     Anshuman Maheshwary, Dr Srihari Raju Kalidindi        $5000000
# 499   Vamsi Krishna, Pulkit Jain, Gaurav Munjal\t#REF!        $1000000
# 1037           Vinners, Raj Nayak, Amritaanshu Agrawal    $Undisclosed
# 1084         Basant Kumar, Vivek Tiwari, Ranbir Nandan  1000000\t#REF!
#
#               Amount Stage
# 225        $22000000  None
# 226         $5000000  None
# 499         $1000000  None
# 1037    $Undisclosed  None
# 1084  1000000\t#REF!  None

# %%
def replace_odd_investor(investor):
    # Check if the investor is None, not a string, or a missing value
    if investor is None or not isinstance(investor, str) or pd.isna(investor):
        return 'Not filled'
    
    # Check if the investor contains '#REF!' 
    if '\t#REF!' in investor:
        return 'Not filled'
    
    # Check for entries containing unusual special characters and a word count less than 2
    special_characters = ['#REF!', '$']
    if any(char in investor for char in special_characters) and len(investor.split()) < 2:
        return 'Not filled'
    
    # Check for entries that include a string pattern like $xxxxxxxxxxxx
    if re.match(r'^\$[0-9]{1,}$', investor):
        return 'Not filled'
    
    return investor

# Replace odd entries in the 'Investor' column
cl_df2021['Investor'] = cl_df2021['Investor'].apply(replace_odd_investor)

# Filter out specific rows using iloc
cl_df2021.iloc[cl_df2021.index.isin([225, 226, 499, 1037, 1084])]
# Out:
#            Company_Brand  Founded HeadQuarter  \
# 225   Fullife Healthcare   2009.0  Not filled
# 226              MoEVing   2021.0  Not filled
# 499            AdmitKard   2016.0       Noida
# 1037            Sochcast   2020.0  Not filled
# 1084           Godamwale   2016.0      Mumbai
#
#                                 Sector  \
# 225   Healthcare and Health Technology
# 226             Energy and Environment
# 499             Education and Learning
# 1037           Media and Entertainment
# 1084           Transport and Logistics
#
#                                            What_it_does  \
# 225                                        Varun Khanna
# 226                         Vikash Mishra, Mragank Jain
# 499   A tech solution for end to end career advisory...
# 1037  CA Harvinderjit Singh Bhatia, Garima Surana, A...
# 1084  Godamwale is tech enabled integrated logistics...
#
#                                               Founders    Investor  \
# 225                 Morgan Stanley Private Equity Asia  Not filled
# 226     Anshuman Maheshwary, Dr Srihari Raju Kalidindi  Not filled
# 499   Vamsi Krishna, Pulkit Jain, Gaurav Munjal\t#REF!  Not filled
# 1037           Vinners, Raj Nayak, Amritaanshu Agrawal  Not filled
# 1084         Basant Kumar, Vivek Tiwari, Ranbir Nandan  Not filled
#
#               Amount Stage
# 225        $22000000  None
# 226         $5000000  None
# 499         $1000000  None
# 1037    $Undisclosed  None
# 1084  1000000\t#REF!  None

# %% [markdown]
# ***Based on 'Stage' Column***

# %%
# Apply the function to filter the DataFrame
filter2_cl_df2021 = cl_df2021[
    (cl_df2021['Amount'].isna()) &
    (cl_df2021['Stage'].apply(matches_pattern))
]

# Display results
filter2_cl_df2021
# Out:
#         Company_Brand  Founded HeadQuarter                           Sector  \
# 94            FanPlay   2020.0  Not filled      Consumer Goods and Services
# 492       Little Leap   2020.0   New Delhi           Education and Learning
# 505             BHyve   2020.0      Mumbai  Human Resources and Consultancy
# 625      MYRE Capital   2020.0      Mumbai          Real Estate and Housing
# 628  Saarthi Pedagogy   2015.0   Ahmedabad           Education and Learning
#
#                                           What_it_does  \
# 94   A real money game app specializing in trivia g...
# 492                Soft Skills that make Smart Leaders
# 505  A Future of Work Platform for diffusing Employ...
# 625                Democratising Real Estate Ownership
# 628  India's fastest growing Pedagogy company, serv...
#
#                                               Founders  \
# 94                                              YC W21
# 492  Holistic Development Programs for children in ...
# 505                                  Backed by 100x.VC
# 625            Own rent yielding commercial properties
# 628                                           Pedagogy
#
#                             Investor Amount     Stage
# 94       Pritesh Kumar, Bharat Gupta    NaN  $1200000
# 492                     Vishal Gupta    NaN   $300000
# 505  Omkar Pandharkame, Ketaki Ogale    NaN   $300000
# 625                      Aryaman Vir    NaN  $6000000
# 628                   Sushil Agarwal    NaN  $1000000

# %%
# Fill the Amount column with values from the Stage column in the filtered rows
cl_df2021.loc[filter2_cl_df2021.index, 'Amount'] = cl_df2021.loc[filter2_cl_df2021.index, 'Stage']

# Filter out specific rows using iloc
cl_df2021.iloc[cl_df2021.index.isin([94, 492, 505, 625, 628])]
# Out:
#         Company_Brand  Founded HeadQuarter                           Sector  \
# 94            FanPlay   2020.0  Not filled      Consumer Goods and Services
# 492       Little Leap   2020.0   New Delhi           Education and Learning
# 505             BHyve   2020.0      Mumbai  Human Resources and Consultancy
# 625      MYRE Capital   2020.0      Mumbai          Real Estate and Housing
# 628  Saarthi Pedagogy   2015.0   Ahmedabad           Education and Learning
#
#                                           What_it_does  \
# 94   A real money game app specializing in trivia g...
# 492                Soft Skills that make Smart Leaders
# 505  A Future of Work Platform for diffusing Employ...
# 625                Democratising Real Estate Ownership
# 628  India's fastest growing Pedagogy company, serv...
#
#                                               Founders  \
# 94                                              YC W21
# 492  Holistic Development Programs for children in ...
# 505                                  Backed by 100x.VC
# 625            Own rent yielding commercial properties
# 628                                           Pedagogy
#
#                             Investor    Amount     Stage
# 94       Pritesh Kumar, Bharat Gupta  $1200000  $1200000
# 492                     Vishal Gupta   $300000   $300000
# 505  Omkar Pandharkame, Ketaki Ogale   $300000   $300000
# 625                      Aryaman Vir  $6000000  $6000000
# 628                   Sushil Agarwal  $1000000  $1000000

# %%
def replace_odd_stage(stage):
    # Check if the stage is not missing and matches a specific pattern like $xxxxxxxxxxxx
    if pd.notna(stage) and re.match(r'^\$[0-9]{1,}$', stage):
        return np.NaN
    
    return stage

# Replace odd entries in the 'Stage' column
cl_df2021['Stage'] = cl_df2021['Stage'].apply(replace_odd_stage)

# Filter out specific rows using iloc
cl_df2021.iloc[cl_df2021.index.isin([94, 492, 505, 625, 628])]
# Out:
#         Company_Brand  Founded HeadQuarter                           Sector  \
# 94            FanPlay   2020.0  Not filled      Consumer Goods and Services
# 492       Little Leap   2020.0   New Delhi           Education and Learning
# 505             BHyve   2020.0      Mumbai  Human Resources and Consultancy
# 625      MYRE Capital   2020.0      Mumbai          Real Estate and Housing
# 628  Saarthi Pedagogy   2015.0   Ahmedabad           Education and Learning
#
#                                           What_it_does  \
# 94   A real money game app specializing in trivia g...
# 492                Soft Skills that make Smart Leaders
# 505  A Future of Work Platform for diffusing Employ...
# 625                Democratising Real Estate Ownership
# 628  India's fastest growing Pedagogy company, serv...
#
#                                               Founders  \
# 94                                              YC W21
# 492  Holistic Development Programs for children in ...
# 505                                  Backed by 100x.VC
# 625            Own rent yielding commercial properties
# 628                                           Pedagogy
#
#                             Investor    Amount Stage
# 94       Pritesh Kumar, Bharat Gupta  $1200000   NaN
# 492                     Vishal Gupta   $300000   NaN
# 505  Omkar Pandharkame, Ketaki Ogale   $300000   NaN
# 625                      Aryaman Vir  $6000000   NaN
# 628                   Sushil Agarwal  $1000000   NaN

# %% [markdown]
# ***Converting the 'Amount' column to float***

# %%
# Apply the 'convert_to_float' function to each element in the "Amount" column
cl_df2021['Amount'] = cl_df2021['Amount'].apply(lambda x: convert_to_float(re.sub(r'[^\d.]', '', str(x))))

# Check the data type of the "Amount" column
print("Data type of 'Amount' column after conversion:", cl_df2021['Amount'].dtype)

# Filter out specific rows using iloc
cl_df2021.iloc[cl_df2021.index.isin([94, 225, 226, 492, 499, 505, 625, 628, 1037, 1084])]
# Out:
# Data type of 'Amount' column after conversion: float64
#            Company_Brand  Founded HeadQuarter  \
# 94               FanPlay   2020.0  Not filled
# 225   Fullife Healthcare   2009.0  Not filled
# 226              MoEVing   2021.0  Not filled
# 492          Little Leap   2020.0   New Delhi
# 499            AdmitKard   2016.0       Noida
# 505                BHyve   2020.0      Mumbai
# 625         MYRE Capital   2020.0      Mumbai
# 628     Saarthi Pedagogy   2015.0   Ahmedabad
# 1037            Sochcast   2020.0  Not filled
# 1084           Godamwale   2016.0      Mumbai
#
#                                 Sector  \
# 94         Consumer Goods and Services
# 225   Healthcare and Health Technology
# 226             Energy and Environment
# 492             Education and Learning
# 499             Education and Learning
# 505    Human Resources and Consultancy
# 625            Real Estate and Housing
# 628             Education and Learning
# 1037           Media and Entertainment
# 1084           Transport and Logistics
#
#                                            What_it_does  \
# 94    A real money game app specializing in trivia g...
# 225                                        Varun Khanna
# 226                         Vikash Mishra, Mragank Jain
# 492                 Soft Skills that make Smart Leaders
# 499   A tech solution for end to end career advisory...
# 505   A Future of Work Platform for diffusing Employ...
# 625                 Democratising Real Estate Ownership
# 628   India's fastest growing Pedagogy company, serv...
# 1037  CA Harvinderjit Singh Bhatia, Garima Surana, A...
# 1084  Godamwale is tech enabled integrated logistics...
#
#                                                Founders  \
# 94                                               YC W21
# 225                  Morgan Stanley Private Equity Asia
# 226      Anshuman Maheshwary, Dr Srihari Raju Kalidindi
# 492   Holistic Development Programs for children in ...
# 499    Vamsi Krishna, Pulkit Jain, Gaurav Munjal\t#REF!
# 505                                   Backed by 100x.VC
# 625             Own rent yielding commercial properties
# 628                                            Pedagogy
# 1037            Vinners, Raj Nayak, Amritaanshu Agrawal
# 1084          Basant Kumar, Vivek Tiwari, Ranbir Nandan
#
#                              Investor      Amount Stage
# 94        Pritesh Kumar, Bharat Gupta   1200000.0   NaN
# 225                        Not filled  22000000.0  None
# 226                        Not filled   5000000.0  None
# 492                      Vishal Gupta    300000.0   NaN
# 499                        Not filled   1000000.0  None
# 505   Omkar Pandharkame, Ketaki Ogale    300000.0   NaN
# 625                       Aryaman Vir   6000000.0   NaN
# 628                    Sushil Agarwal   1000000.0   NaN
# 1037                       Not filled         NaN  None
# 1084                       Not filled   1000000.0  None

# %% [markdown]
# ***Drop row with outlier (maximum value)***

# %%
# Find the index label of the row with the maximum value in the 'Amount' column
max_amount_index = cl_df2021['Amount'].idxmax()

# Drop the row using the index label
cl_df2021 = cl_df2021.drop(max_amount_index).reset_index(drop=True)

# Check DataFrame information
cl_df2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1170 entries, 0 to 1169
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1170 non-null   object
#  1   Founded        1170 non-null   float64
#  2   HeadQuarter    1170 non-null   object
#  3   Sector         1170 non-null   object
#  4   What_it_does   1170 non-null   object
#  5   Founders       1166 non-null   object
#  6   Investor       1170 non-null   object
#  7   Amount         1031 non-null   float64
#  8   Stage          761 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 82.4+ KB

# %% [markdown]
# **Replacing odd founders**

# %%
def replace_odd_founders(founders):
    if None or not isinstance(founders, str):
        return 'Not filled'  
    
    special_characters = ['#REF!','$']  
    if any(char in founders for char in special_characters) and len(founders.split()) < 2:
        return 'Not filled'
    
    # Regular expression pattern to match string pattern like $xxxxxxxxxxxx
    if re.match(r'^\$[0-9]{1,}$', founders):
        return 'Not filled'  
    
    return founders  

# Apply the function to replace odd entries in the 'Founders' column
cl_df2021['Founders'] = cl_df2021['Founders'].apply(replace_odd_founders)

# Display information
cl_df2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1170 entries, 0 to 1169
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1170 non-null   object
#  1   Founded        1170 non-null   float64
#  2   HeadQuarter    1170 non-null   object
#  3   Sector         1170 non-null   object
#  4   What_it_does   1170 non-null   object
#  5   Founders       1170 non-null   object
#  6   Investor       1170 non-null   object
#  7   Amount         1031 non-null   float64
#  8   Stage          761 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 82.4+ KB

# %% [markdown]
# **Redistributing entries in 'Stage' column**

# %%
# Define a dictionary to map misspellings and inconsistencies to their corrected forms
corrections = {
    "Seies A": "Series A",
    "PE": "Private Equity",
    "Bridge Round": "Bridge",
    "Corperate Round": "Corporate Round"    
}

# Use the replace() method with the corrections dictionary
cl_df2021['Stage'] = cl_df2021['Stage'].replace(corrections, regex=True)

def replace_stage(stage):
    # Check if the stage is not missing and matches a specific pattern like $xxxxxxxxxxxx
    if pd.notna(stage):

        # Regular expression to detect URLs containing "http" and ".com"
        url_pattern = re.compile(r'https?://\S+\.com\S*')

        # Check if the stage matches the URL pattern
        if url_pattern.match(stage):
            return np.nan
           
        stage = str(stage).strip().lower()  
        
        if stage in [
            'pre-seed', 'early seed', 'pre-seed round', 'pre-seed', 'pre seed round', 'pre seed round', 'seed fund'
        ]:
            return 'Ideation'
        if stage in [
            'pre-series', 'pre-series a', 'pre-series a1', 'seed', 'seed+', 'pre series a', 'pre- series a', 
            'seed round', 'seed round', 'seed funding', 'pre-series a', 'bridge round', 'seed investment', 
            'seed round & series a', 'seed a', 'pre series a', 'pre series a1', 'seed funding'
        ]:
            return 'Validation'
        if stage in ['series a', 'series a+', 'series a2', 'series a-1', 'pre-series b', 'pre series b', 'pre-series b']:
            return 'Early Traction'
        if stage in [
            'series b', 'series b3', 'series b2', 'series c', 'series d', 'series d1', 'series e', 'series f', 'series f1', 'post series a', 
            'series f2', 'series g', 'series h', 'series i', 'mid series', 'series c, d', 'pre-series c', 'series e2', 'pre series c', 'series b+'
        ]:
            return 'Scaling'
        if stage in [
            'angel', 'angel round', 'corporate round', 'venture - series unknown', 'post-ipo equity', 'private equity'
        ]:
            return 'Equity'
        if stage in [
            'debt', 'debt financing', 'post-ipo debt'
        ]:        
            return 'Debt'
        if stage in [
            'grant', 'non-equity assistance'
        ]:        
            return 'Non-Equity'

        if stage in [
            'secondary market'
        ]:        
            return 'Market Transactions'

        stage = str(stage).title()

        if stage in ['Funding Round', 'Undisclosed', 'Edge', 'Fresh Funding']:
            return np.nan

    return stage

# Replace stages in the DataFrame
cl_df2021['Stage'] = cl_df2021['Stage'].apply(replace_stage)

# Get the value counts for the 'Stage' column
stage_counts21 = cl_df2021['Stage'].value_counts()

# Display results
print(stage_counts21)
# Out:
# Stage
# Validation        400
# Scaling           146
# Early Traction    138
# Ideation           48
# Debt               26
# Bridge              2
# Equity              1
# Name: count, dtype: int64

# %% [markdown]
# ##### Handling Missing Values

# %% [markdown]
# **Check missing values**

# %%
# Determine the proportion of missing values
missing_cl_df2021_st = (cl_df2021.isnull().mean() * 100).round(2)

# Display Results
print("Proportion of missing values in 2021 data:")
print()
print(missing_cl_df2021_st)
# Out:
# Proportion of missing values in 2021 data:
#
# Company_Brand     0.00
# Founded           0.00
# HeadQuarter       0.00
# Sector            0.00
# What_it_does      0.00
# Founders          0.00
# Investor          0.00
# Amount           11.88
# Stage            34.96
# dtype: float64

# %% [markdown]
# **Group by Stage and determine the mean, median and mode amounts**

# %%
# Calculate mean, median, and mode amounts by stage
mean_amounts21 = cl_df2021.groupby('Stage')['Amount'].mean()
median_amounts21 = cl_df2021.groupby('Stage')['Amount'].median()
mode_amounts21 = cl_df2021.groupby('Stage')['Amount'].apply(lambda x: x.mode().iloc[0] if not x.mode().empty else None)

# Display results
print("Mean Amounts by Stage:")
print(mean_amounts21)

print("\nMedian Amounts by Stage:")
print(median_amounts21)

print("\nMode Amounts by Stage:")
print(mode_amounts21)
# Out:
# Mean Amounts by Stage:
# Stage
# Bridge            5.000000e+05
# Debt              1.266154e+07
# Early Traction    1.217847e+07
# Equity            1.000000e+08
# Ideation          7.010811e+05
# Scaling           8.659931e+07
# Validation        2.956782e+06
# Name: Amount, dtype: float64
#
# Median Amounts by Stage:
# Stage
# Bridge               500000.0
# Debt                6000000.0
# Early Traction      6500000.0
# Equity            100000000.0
# Ideation             340000.0
# Scaling            48000000.0
# Validation          1200000.0
# Name: Amount, dtype: float64
#
# Mode Amounts by Stage:
# Stage
# Bridge               500000.0
# Debt               10000000.0
# Early Traction      5000000.0
# Equity            100000000.0
# Ideation             300000.0
# Scaling            30000000.0
# Validation          1000000.0
# Name: Amount, dtype: float64

# %% [markdown]
# **Univariate Analysis of the 'Amount' Column**

# %%
# Descriptive Statistics
print("Descriptive Statistics for 'Amount' column:")
print(cl_df2021['Amount'].describe())

# Skewness and Kurtosis
amount_skewness21 = skew(cl_df2021['Amount'])
amount_kurtosis21 = kurtosis(cl_df2021['Amount'])

print(f"\nSkewness for 'Amount' column: {amount_skewness21}")
print(f"Kurtosis for 'Amount' column: {amount_kurtosis21}")

# set theme
sns.set_theme(style="dark", palette="dark", font="sans-serif", font_scale=1.5)
plt.style.use("dark_background")
custom_palette = ["cyan", "magenta", "yellow"]

# Box Plot
plt.figure(figsize=(10, 6))
sns.boxplot(y=cl_df2021['Amount'], palette=custom_palette)
plt.title('Box Plot of Amount')
plt.xlabel('Amount')
plt.show()

# Histogram with KDE Plot
plt.figure(figsize=(10, 6))
sns.histplot(cl_df2021['Amount'], kde=True, color='cyan')
plt.title('Histogram and KDE of Amount')
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.show()
# Out:
# Descriptive Statistics for 'Amount' column:
# count    1.031000e+03
# mean     2.777607e+07
# std      8.086648e+07
# min      1.000000e+04
# 25%      1.000000e+06
# 50%      3.500000e+06
# 75%      1.500000e+07
# max      1.000000e+09
# Name: Amount, dtype: float64
#
# Skewness for 'Amount' column: nan
# Kurtosis for 'Amount' column: nan

# %% [markdown]
# **Filling missing values in 'Stage' column**

# %% [markdown]
# `Comment`
#
# The numerical values in the 'Amount' column exhibit outliers, making median imputation a more suitable method for addressing missing values. The robustness of the median against outliers ensures that the imputation process is not skewed by extreme values, thus preserving the dataset's integrity. Furthermore, distinct median values observed across different stages support the preference for median imputation, as it accurately reflects the central tendency within each group.
#
# It is important to note that the imputation strategy is designed to fill missing values in the stage column with stage groups based on the median values derived from each stage, which differs from using the mode of the stage column to fill missing values, a common approach for categorical data.
#
# Conversely, if the 'Amount' data were devoid of outliers, mean imputation would be appropriate for handling missing numerical values due to its simplicity and effectiveness in symmetrical distributions. As mentioned earlier for categorical data, mode imputation would be the preferred method, utilizing the most frequently occurring category to maintain the distributional characteristics of the dataset. Although the calculated mean and mode values illustrate these alternative methods, given the current data characteristics, median imputation remains the optimal choice.

# %%
# Define a function to fill missing stages based on median amounts
def fill_missing_stage21(row):
    if pd.isna(row['Stage']):
        for stage, median in median_amounts21.items():
            if row['Amount'] <= median:
                return stage
        return pd.NA  # Default to NaN if no condition matches
    return row['Stage']

# Apply the function to fill missing stages
cl_df2021['Stage'] = cl_df2021.apply(fill_missing_stage21, axis=1)

# Display information
cl_df2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1170 entries, 0 to 1169
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1170 non-null   object
#  1   Founded        1170 non-null   float64
#  2   HeadQuarter    1170 non-null   object
#  3   Sector         1170 non-null   object
#  4   What_it_does   1170 non-null   object
#  5   Founders       1170 non-null   object
#  6   Investor       1170 non-null   object
#  7   Amount         1031 non-null   float64
#  8   Stage          1075 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 82.4+ KB

# %%
# Filter the rows where 'Stage' is missing
filter_min21_df = cl_df2021[cl_df2021['Stage'].isna()]

# Find the minimum 'Amount' value in the filtered DataFrame
filter_min21_amount = filter_min21_df['Amount'].min()

# Print the minimum 'Amount' value
print('The minimum amount value in the filtered dataframe is:', filter_min21_amount)
# Out:
# The minimum amount value in the filtered dataframe is: 110000000.0

# %% [markdown]
# `Comment`
#
# Based on exploratory analysis of the 'Amount' column within the dataset above, it has been ascertained that the recorded minimum value stands at 110,000,000. Consequently, the imputation strategy for missing values in the 'Stage' column entails identifying the stage category whose median amount value closely approximates this observed minimum, while ensuring exclusion of categories labeled as 'debt', 'bridge', 'market transactions', 'equity' or 'non-equity'.
#
# Upon meticulous examination of the dataset, it has been established that the 'Scaling' stage category exhibits the nearest median amount value (48,000,000) to the aforementioned minimum amount. Thus, as an integral part of the imputation process, the missing entries in the 'Stage' column meeting the criterion of possessing a non-null float entry in the corresponding 'Amount' column will be substituted with the 'Scaling' stage category. This aligns with the predefined criteria for selection and ensures coherence in the imputation procedure.

# %%
def fill_missing_stage_scl(row):
    if pd.isna(row['Stage']):  # Checking if 'Stage' column is NaN
        if pd.notna(row['Amount']):  # Checking if 'Amount' column is not NaN
            return 'Scaling'
    return row['Stage']

# Apply the function to fill missing stages
cl_df2021['Stage'] = cl_df2021.apply(fill_missing_stage_scl, axis=1)

# Display information
cl_df2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1170 entries, 0 to 1169
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1170 non-null   object
#  1   Founded        1170 non-null   float64
#  2   HeadQuarter    1170 non-null   object
#  3   Sector         1170 non-null   object
#  4   What_it_does   1170 non-null   object
#  5   Founders       1170 non-null   object
#  6   Investor       1170 non-null   object
#  7   Amount         1031 non-null   float64
#  8   Stage          1104 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 82.4+ KB

# %% [markdown]
# **Filling missing values in 'Amount' column**

# %% [markdown]
# `Comment`
#
# In the task of filling missing values in the 'Amount' column, multiple imputation emerges as a superior choice over KNN imputation due to its robustness, adaptability, and modeling capabilities. Multiple imputation, by modeling the entire distribution of the data, exhibits heightened resilience to outliers compared to KNN imputation, which is sensitive to outlier influence owing to its reliance on distance metrics. Furthermore, the suitability of multiple imputation extends to scenarios where missing data follows either a missing at random (MAR) or missing completely at random (MCAR) pattern, as it can effectively model various missing data mechanisms using observed data. In contrast, while KNN imputation excels in scenarios of localized missing data patterns, its assumption of local similarity may lead to suboptimal imputations in more complex or non-localized missing data scenarios.

# %%
# Select only the columns with missing values
X_missing21 = cl_df2021[['Amount']]  

# Initialize IterativeImputer
multiple_imputer = IterativeImputer(max_iter=10, random_state=0)  

# Fit and transform the data, and fill missing values directly in the DataFrame
cl_df2021[['Amount']] = multiple_imputer.fit_transform(X_missing21)  

# Display DataFrame information
cl_df2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1170 entries, 0 to 1169
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1170 non-null   object
#  1   Founded        1170 non-null   float64
#  2   HeadQuarter    1170 non-null   object
#  3   Sector         1170 non-null   object
#  4   What_it_does   1170 non-null   object
#  5   Founders       1170 non-null   object
#  6   Investor       1170 non-null   object
#  7   Amount         1170 non-null   float64
#  8   Stage          1104 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 82.4+ KB

# %% [markdown]
# **Complete filling missing values in 'Stage' column**

# %%
# Find indices of missing values in the original 'Amount' column
missing_indices21 = np.where(X_missing21.isna())[0]

# Extract unique imputed values using indices
cl_df2021_imputed = (cl_df2021.iloc[missing_indices21]['Amount']).unique()

# Print the unique imputed values
print(cl_df2021_imputed)
# Out:
# [27776067.89524733]

# %% [markdown]
# `Comment`
#
# The imputation process has yielded a unique value of 27,776,067.89524733 for the 'Amount' column. Consequently, the imputation strategy for missing values in the 'Stage' column involves identifying the stage category whose median amount closely approximates this observed value, while ensuring exclusion of categories labeled as 'debt', 'bridge', or 'private equity'.
#
# After thorough scrutiny of the dataset, it has been determined that the 'Scaling' stage category exhibits the closest median amount value (48,000,000) to the aforementioned amount value. Hence, the remaining missing values in the 'Stage' column will be replaced with the 'Scaling' stage category. This decision adheres to the predefined selection criteria, ensuring consistency and coherence in the imputation process.

# %%
# Apply the function to fill missing stages
cl_df2021['Stage'] = cl_df2021.apply(fill_missing_stage_scl, axis=1)

# Determine the proportion of missing values
missing_cl_df2021_ed = (cl_df2021.isnull().mean() * 100).round(2)

# Display Results
print("Proportion of missing values in 2021 data:")
print()
print(missing_cl_df2021_ed)
# Out:
# Proportion of missing values in 2021 data:
#
# Company_Brand    0.0
# Founded          0.0
# HeadQuarter      0.0
# Sector           0.0
# What_it_does     0.0
# Founders         0.0
# Investor         0.0
# Amount           0.0
# Stage            0.0
# dtype: float64

# %% [markdown]
# ##### Standardise Formats

# %%
# Standardize 'Founded Year' column to integer datatype
cl_df2021['Founded'] = cl_df2021['Founded'].astype(int)

# Identify object columns (excluding 'What_it_does' and 'Company_Brand')
object_columns_to_convert21 = [col for col in cl_df2021.select_dtypes(include=['object']).columns
                             if col not in ['What_it_does', 'Company_Brand']]

# Convert object columns to category datatype
cl_df2021[object_columns_to_convert21] = cl_df2021[object_columns_to_convert21].astype('category')

# Display information
cl_df2021.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1170 entries, 0 to 1169
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1170 non-null   object
#  1   Founded        1170 non-null   int32
#  2   HeadQuarter    1170 non-null   category
#  3   Sector         1170 non-null   category
#  4   What_it_does   1170 non-null   object
#  5   Founders       1170 non-null   category
#  6   Investor       1170 non-null   category
#  7   Amount         1170 non-null   float64
#  8   Stage          1170 non-null   category
# dtypes: category(5), float64(1), int32(1), object(2)
# memory usage: 543.6 KB

# %% [markdown]
# #### Load LP1_startup_funding2020 Data

# %% [markdown]
# ##### Remove Duplicates

# %% [markdown]
# **Based on all Features**

# %%
# Create a copy of df2021 to avoid modifying the original DataFrame
cl_df2020 = df2020.copy()

# Remove duplicate rows from cl_df2021, and reset the index of the resulting DataFrame
cl_df2020.drop_duplicates(inplace=True, ignore_index=True)

# Display info of Data Frame
cl_df2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1052 entries, 0 to 1051
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1052 non-null   object
#  1   Founded        839 non-null    float64
#  2   HeadQuarter    958 non-null    object
#  3   Sector         1039 non-null   object
#  4   What_it_does   1052 non-null   object
#  5   Founders       1040 non-null   object
#  6   Investor       1014 non-null   object
#  7   Amount         799 non-null    float64
#  8   Stage          590 non-null    object
#  9   column10       2 non-null      object
# dtypes: float64(2), object(8)
# memory usage: 82.3+ KB

# %% [markdown]
# **Based on First Eight Features**

# %%
# Filter rows with duplicated values in all columns except the last two
cl_df2020[cl_df2020.duplicated(subset=cl_df2020.columns[0:8], keep=False)]
# Out:
# Empty DataFrame
# Columns: [Company_Brand, Founded, HeadQuarter, Sector, What_it_does, Founders, Investor, Amount, Stage, column10]
# Index: []

# %% [markdown]
# **Based on First Seven Features**

# %%
# Filter rows with duplicated values in all columns except the last three
cl_df2020[cl_df2020.duplicated(subset=cl_df2020.columns[0:7], keep=False)]
# Out:
#      Company_Brand  Founded HeadQuarter                  Sector  \
# 194    FreshtoHome   2015.0   Bangalore              E-commerce
# 209    FreshtoHome   2015.0   Bangalore              E-commerce
# 346         Zomato   2008.0     Haryana          Food devlivery
# 364         Zomato   2008.0     Haryana          Food devlivery
# 709          Nykaa   2012.0      Mumbai               Ecommerce
# 810          Nykaa   2012.0      Mumbai               Ecommerce
# 874           Vogo   2016.0   Bangalore              Automotive
# 960           Vogo   2016.0   Bangalore              Automotive
# 983         Bounce   2014.0   Bangalore  Automotive and Rentals
# 1006        Bounce   2014.0   Bangalore  Automotive and Rentals
#
#                                            What_it_does  \
# 194   Freshtohome is an e-commerce platform for fres...
# 209   Freshtohome is an e-commerce platform for fres...
# 346   Get online food delivery from restaurants near...
# 364   Get online food delivery from restaurants near...
# 709             Deals in cosmetic and wellness products
# 810             Deals in cosmetic and wellness products
# 874   A scooter-sharing platform allowing users to r...
# 960   A scooter-sharing platform allowing users to r...
# 983   Offers a variety of bikes and scooters that ca...
# 1006  Offers a variety of bikes and scooters that ca...
#
#                                                Founders  \
# 194                                        Shan Kadavil
# 209                                        Shan Kadavil
# 346                     Deepinder Goyal, Pankaj Chaddah
# 364                     Deepinder Goyal, Pankaj Chaddah
# 709                                       Falguni Nayar
# 810                                       Falguni Nayar
# 874   Anand Ayyadurai, Padmanabhan Balakrishnan, San...
# 960   Anand Ayyadurai, Padmanabhan Balakrishnan, San...
# 983     Vivekananda Hallekere, Anil Giri Raju,Arun Agni
# 1006    Vivekananda Hallekere, Anil Giri Raju,Arun Agni
#
#                                      Investor       Amount     Stage column10
# 194               Ascent Capital, Iron Pillar  121000000.0  Series C     None
# 209               Ascent Capital, Iron Pillar   16000000.0      None     None
# 346   MacRitchie Investments, Baillie Gifford   62000000.0      None     None
# 364   MacRitchie Investments, Baillie Gifford  100000000.0      None     None
# 709                         Steadview capital    8800000.0      None     None
# 810                         Steadview capital   13137000.0      None     None
# 874                         Lightstone Aspada   20000000.0  Series C     None
# 960                         Lightstone Aspada   35000000.0  Series C     None
# 983                 Accel Partners, B Capital  105000000.0  Series D     None
# 1006                Accel Partners, B Capital   97500000.0  Series D     None

# %% [markdown]
# `Comment`
#
# FreshtoHome: The difference in amounts ($121M and $16M) and their unspecified stage for the $16M suggests the need for clarification. Given the large discrepancy, it is advisable to confirm if the $16M is part of the same Series C round or another adjacent stage.
#
# Zomato: Both rounds are from the same investors with significantly different amounts ($62M and $100M). Clarification is needed on whether these are separate rounds or if the $62M is part of a larger round. Given the total amounts, none appear to be outliers.
#
# Nykaa: The funding amounts ($8.8M and $13.137M) suggest early to mid-stage rounds. Further details on the specific stage of the $13.137M would help.
#
# Vogo: Both amounts ($20M and $35M) are Series C rounds from the same investor, indicating continued growth funding.
#
# Bounce: Similar large amounts in Series D rounds ($105M and $97.5M) from the same investors indicate strong continued growth and expansion.
#
# Before removing any rows, ensure that these amounts are not outliers that could skew the dataset. It is recommended to verify the stage and purpose of each round to maintain the integrity of the dataset.

# %% [markdown]
# ***Univariate Analysis of the 'Amount' Column***

# %%
# Descriptive Statistics
print("Descriptive Statistics for 'Amount' column:")
print(cl_df2020['Amount'].describe())

# Skewness and Kurtosis
amount_skewness = skew(cl_df2020['Amount'])
amount_kurtosis = kurtosis(cl_df2020['Amount'])

print(f"\nSkewness for 'Amount' column: {amount_skewness}")
print(f"Kurtosis for 'Amount' column: {amount_kurtosis}")

# set theme
sns.set_theme(style="dark", palette="dark", font="sans-serif", font_scale=1.5)
plt.style.use("dark_background")
custom_palette = ["cyan", "magenta", "yellow"]

# Box Plot
plt.figure(figsize=(10, 6))
sns.boxplot(y=cl_df2020['Amount'], palette=custom_palette)
plt.title('Box Plot of Amount')
plt.xlabel('Amount')
plt.show()
# Out:
# Descriptive Statistics for 'Amount' column:
# count    7.990000e+02
# mean     1.126994e+08
# std      2.479695e+09
# min      1.270000e+04
# 25%      1.000000e+06
# 50%      3.000000e+06
# 75%      1.100000e+07
# max      7.000000e+10
# Name: Amount, dtype: float64
#
# Skewness for 'Amount' column: nan
# Kurtosis for 'Amount' column: nan

# %% [markdown]
# ***Drop all duplicates that have none in 'Stage' column***

# %%
# Separate rows with missing values in the 'Stage' column
missing_stage_rows = cl_df2020[cl_df2020['Stage'].isna()]
non_missing_stage_rows = cl_df2020[cl_df2020['Stage'].notna()]

# Remove all duplicate rows based on the first 7 columns in missing stage rows
missing_stage_rows.drop_duplicates(subset=missing_stage_rows.columns[0:7], inplace=True, ignore_index=True, keep=False)

# Concatenate the missing and non-missing stage rows back together
cl_df2020 = pd.concat([non_missing_stage_rows,missing_stage_rows], ignore_index=True)

# # Display info of Data Frame
cl_df2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1048 non-null   object
#  1   Founded        835 non-null    float64
#  2   HeadQuarter    954 non-null    object
#  3   Sector         1035 non-null   object
#  4   What_it_does   1048 non-null   object
#  5   Founders       1036 non-null   object
#  6   Investor       1010 non-null   object
#  7   Amount         795 non-null    float64
#  8   Stage          590 non-null    object
#  9   column10       2 non-null      object
# dtypes: float64(2), object(8)
# memory usage: 82.0+ KB

# %% [markdown]
# **Based on Key Columns**

# %% [markdown]
# ***Duplicated columns based on key columns after deletion  of duplicates***

# %%
# Check for number of duplicated values within the 'Company_Brand' column
dupl20_count = cl_df2020.duplicated(subset=key_columns, keep=False).sum()

# Identify duplicate entries in the 'Company_Brand' column
dup_cl_20 = cl_df2020[cl_df2020.duplicated(subset=key_columns, keep=False)]

# Extract the list of duplicated company brands
unidup_cl_20 = dup_cl_20['Company_Brand'].unique()

# Display results
print(f"Number of duplicated values in 'Company_Brand' column: {dupl20_count}")
print("\nList of duplicated company brands:")
print(unidup_cl_20)
# Out:
# Number of duplicated values in 'Company_Brand' column: 51
#
# List of duplicated company brands:
# ['Credgenics' 'FreshtoHome' 'Trell' 'Magicpin' 'Aye Finance' 'Zetwerk'
#  'BankBazaar' 'Khatabook' 'Vedantu' 'Yap' 'Capital Float' 'Lido Learning'
#  'Swiggy' 'Vogo' 'BharatPe' 'Shuttl' 'Clover' 'Bounce' 'Genius Teacher'
#  'LetsTransport' 'Rentmojo' 'Rebel Foods' 'Digit Insurance' 'Byju']

# %% [markdown]
# ***Duplicated columns only in list of duplicated company brands before deletion of duplicates***

# %%
# Create a set of the list of duplicated company brands based on key columns before deletion of duplicates
unidup_c1_20_values = set(unidup_c1_20)

# Create a set of the list of duplicated company brands based on key columns after deletion of duplicates
unidup_cl_20_values = set(unidup_cl_20)

# Find the values that only appear in the list of duplicated company brands before deletion of duplicates
values_only_in_unidup_c1_20 = unidup_c1_20_values - unidup_cl_20_values

# Display Results
print("Values only in list of duplicated company brands before deletion of duplicates:")
print(values_only_in_unidup_c1_20)

# Filter rows where 'Company_Brand' is 'Values only in list of duplicated company brands before deletion of duplicates'
values_only_in_unidup_c1_20_rows = cl_df2020[cl_df2020['Company_Brand'].isin(values_only_in_unidup_c1_20)]

# Filter 'values_only_in_unidup_c1_21_rows' based on the key columns
values_only_in_unidup_c1_20_rows[values_only_in_unidup_c1_20_rows.duplicated(subset=key_columns, keep=False)]
# Out:
# Values only in list of duplicated company brands before deletion of duplicates:
# {'Nykaa', 'Zomato', 'Byju’s', 'Krimanshi'}
# Empty DataFrame
# Columns: [Company_Brand, Founded, HeadQuarter, Sector, What_it_does, Founders, Investor, Amount, Stage, column10]
# Index: []

# %% [markdown]
# ##### Handling Odd Entries and Irrelevant Data

# %% [markdown]
# **Drop companies founded before 1980 and after 2020**

# %% [markdown]
# ***Imputing missing values by identifying and matching rows with identical core attributes***

# %%
# Find duplicate rows based on specified columns
duplicate_rowsf20 = cl_df2020[cl_df2020.duplicated(subset=['Company_Brand', 'HeadQuarter', 'Sector', 'What_it_does', 'Founders'], keep=False)]

# Filter out entries with a single unique value and missing value in the 'Founded' column within each group
filtered_duplicate_f20 = duplicate_rowsf20.groupby(['Company_Brand']).filter(lambda x: ((x['Founded'].nunique() == 1) and (x['Founded'].isna().any())))

# Display the filtered duplicate rows
filtered_duplicate_f20
# Out:
#     Company_Brand  Founded HeadQuarter  Sector             What_it_does  \
# 325       Vedantu   2011.0   Bangalore  Edtech  Onine learning platform
# 428       Vedantu      NaN   Bangalore  Edtech  Onine learning platform
# 445       Vedantu      NaN   Bangalore  Edtech  Onine learning platform
# 516       Vedantu      NaN   Bangalore  Edtech  Onine learning platform
# 898     DailyHunt   2009.0        None   Media          News aggregator
# 918     DailyHunt      NaN        None   Media          News aggregator
#
#                                               Founders  \
# 325  Saurabh Saxena, Pulkit Jain, Anand Prakash, Va...
# 428  Saurabh Saxena, Pulkit Jain, Anand Prakash, Va...
# 445  Saurabh Saxena, Pulkit Jain, Anand Prakash, Va...
# 516  Saurabh Saxena, Pulkit Jain, Anand Prakash, Va...
# 898                                     Virendra Gupta
# 918                                     Virendra Gupta
#
#                                               Investor       Amount     Stage  \
# 325                                             Coatue  100000000.0  Series D
# 428                            KB Global Platform Firm    6800000.0  Series C
# 445                                     Legend Capital   12500000.0  Series C
# 516                                        GGV Capital   24000000.0  Series C
# 898                                         Lupa India   35600000.0      None
# 918  Bytedance, Falcon Edge, Goldman Sachs, Advent ...   24000000.0      None
#
#     column10
# 325     None
# 428     None
# 445     None
# 516     None
# 898     None
# 918     None

# %%
# Extract unique company brands from the filtered duplicate rows
unique_brands_f20 = filtered_duplicate_f20['Company_Brand'].unique()

# Store the unique company brands in a list named 'target'
targetf20 = list(unique_brands_f20)

# Filter the DataFrame to include only rows with Company_Brand in the target list and specified indices
target_brands_dff20 = cl_df2020[cl_df2020['Company_Brand'].isin(targetf20) & cl_df2020.index.isin([325, 428, 445, 516, 898, 918])]

# Iterate through each Company_Brand in target2
for brand in targetf20:
    # Get the non-null 'Founded' value for this brand
    founded_value = target_brands_dff20.loc[target_brands_dff20['Company_Brand'] == brand, 'Founded'].dropna().values[0]
    
    # Fill missing 'Founded' values with the identified non-null value
    cl_df2020.loc[(cl_df2020['Company_Brand'] == brand) & (cl_df2020['Founded'].isna()), 'Founded'] = founded_value

# Display info of Data Frame
cl_df2020.info()

# Display the Dataframe to confirm imputation
target_brands_dff20_filled = cl_df2020[cl_df2020['Company_Brand'].isin(targetf20)]
target_brands_dff20_filled[target_brands_dff20_filled.duplicated(subset=key_columns, keep=False)]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1048 non-null   object
#  1   Founded        839 non-null    float64
#  2   HeadQuarter    954 non-null    object
#  3   Sector         1035 non-null   object
#  4   What_it_does   1048 non-null   object
#  5   Founders       1036 non-null   object
#  6   Investor       1010 non-null   object
#  7   Amount         795 non-null    float64
#  8   Stage          590 non-null    object
#  9   column10       2 non-null      object
# dtypes: float64(2), object(8)
# memory usage: 82.0+ KB
#     Company_Brand  Founded HeadQuarter  Sector             What_it_does  \
# 325       Vedantu   2011.0   Bangalore  Edtech  Onine learning platform
# 428       Vedantu   2011.0   Bangalore  Edtech  Onine learning platform
# 445       Vedantu   2011.0   Bangalore  Edtech  Onine learning platform
# 516       Vedantu   2011.0   Bangalore  Edtech  Onine learning platform
# 898     DailyHunt   2009.0        None   Media          News aggregator
# 918     DailyHunt   2009.0        None   Media          News aggregator
#
#                                               Founders  \
# 325  Saurabh Saxena, Pulkit Jain, Anand Prakash, Va...
# 428  Saurabh Saxena, Pulkit Jain, Anand Prakash, Va...
# 445  Saurabh Saxena, Pulkit Jain, Anand Prakash, Va...
# 516  Saurabh Saxena, Pulkit Jain, Anand Prakash, Va...
# 898                                     Virendra Gupta
# 918                                     Virendra Gupta
#
#                                               Investor       Amount     Stage  \
# 325                                             Coatue  100000000.0  Series D
# 428                            KB Global Platform Firm    6800000.0  Series C
# 445                                     Legend Capital   12500000.0  Series C
# 516                                        GGV Capital   24000000.0  Series C
# 898                                         Lupa India   35600000.0      None
# 918  Bytedance, Falcon Edge, Goldman Sachs, Advent ...   24000000.0      None
#
#     column10
# 325     None
# 428     None
# 445     None
# 516     None
# 898     None
# 918     None

# %% [markdown]
# `Comment`
#
# Upon detailed examination, it has been observed that a significant proportion of the entries in the 'Founded' column are missing. Efforts to impute these missing values by identifying and matching rows with identical core attributes—namely 'Company_Brand', 'HeadQuarter', 'Sector', 'What_it_does', and 'Founders' — have yielded only partial success. Despite these imputation efforts, the remaining number of entries with missing values remains substantial.
#
# This high prevalence of missing data poses a challenge to applying a stringent criterion that requires all companies to have founding years within the range of 1980 to 2020. Given the current state of the dataset, enforcing such a criterion would result in an imprudent loss of data, undermining the integrity and comprehensiveness of the dataset. Therefore, alternative approaches for handling missing 'Founded' values need to be considered to ensure the robustness of subsequent analyses.

# %% [markdown]
# **Handling odd locations**

# %% [markdown]
# ***Imputing missing values by identifying and matching rows with identical core attributes***

# %%
# Find duplicate rows based on specified columns
duplicate_rowsl20 = cl_df2020[cl_df2020.duplicated(subset=['Company_Brand', 'Founded', 'Sector', 'What_it_does', 'Founders'], keep=False)]

# Filter out entries with a single unique value and missing value in the 'Founded' column within each group
filtered_duplicate_l20 = duplicate_rowsl20.groupby(['Company_Brand']).filter(lambda x: ((x['HeadQuarter'].nunique() == 1) and (x['HeadQuarter'].isna().any())))

# Display the filtered duplicate rows
filtered_duplicate_l20
# Out:
#      Company_Brand  Founded HeadQuarter           Sector  \
# 857          Sarva      NaN      Mumbai  Yoga & wellness
# 907          Sarva      NaN        None  Yoga & wellness
# 934         Zomato      NaN    Gurugram         Foodtech
# 1037        Zomato      NaN        None         Foodtech
#
#                                            What_it_does         Founders  \
# 857   It drives a cultural change in making yoga-bas...   Sarvesh Shashi
# 907   It drives a cultural change in making yoga-bas...   Sarvesh Shashi
# 934   Online food delivery and restaurant discovery ...  Deepinder Goyal
# 1037  Online food delivery and restaurant discovery ...  Deepinder Goyal
#
#                           Investor       Amount Stage column10
# 857                 Shikhar Dhawan          NaN  None     None
# 907   Mantra Capital, Patni Family          NaN  None     None
# 934                Pacific Horizon    5000000.0  None     None
# 1037                 Ant Financial  150000000.0  None     None

# %%
# Extract unique company brands from the filtered duplicate rows
unique_brands_l20 = filtered_duplicate_l20['Company_Brand'].unique()

# Store the unique company brands in a list named 'target'
targetl20 = list(unique_brands_l20)

# Filter the DataFrame to include only rows with Company_Brand in the target list and specified indices
target_brands_dfl20 = cl_df2020[cl_df2020['Company_Brand'].isin(targetl20) & cl_df2020.index.isin([857, 907, 934, 1037])]


# Iterate through each Company_Brand in targetl20
for brand in targetl20:
    # Get the non-null 'HeadQuarter' value for this brand
    location_value = target_brands_dfl20.loc[target_brands_dfl20['Company_Brand'] == brand, 'HeadQuarter'].dropna().values[0]
        
    # Fill missing 'HeadQuarter' values with the identified non-null value
    cl_df2020.loc[(cl_df2020['Company_Brand'] == brand) & (cl_df2020['HeadQuarter'].isna()), 'HeadQuarter'] = location_value

# Display info of Data Frame
cl_df2020.info()

# Display the Dataframe to confirm imputation
target_brands_dfl20_filled = cl_df2020[cl_df2020['Company_Brand'].isin(targetl20)]
target_brands_dfl20_filled[target_brands_dfl20_filled.duplicated(subset=key_columns, keep=False)]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1048 non-null   object
#  1   Founded        839 non-null    float64
#  2   HeadQuarter    956 non-null    object
#  3   Sector         1035 non-null   object
#  4   What_it_does   1048 non-null   object
#  5   Founders       1036 non-null   object
#  6   Investor       1010 non-null   object
#  7   Amount         795 non-null    float64
#  8   Stage          590 non-null    object
#  9   column10       2 non-null      object
# dtypes: float64(2), object(8)
# memory usage: 82.0+ KB
#      Company_Brand  Founded HeadQuarter           Sector  \
# 857          Sarva      NaN      Mumbai  Yoga & wellness
# 907          Sarva      NaN      Mumbai  Yoga & wellness
# 934         Zomato      NaN    Gurugram         Foodtech
# 1037        Zomato      NaN    Gurugram         Foodtech
#
#                                            What_it_does         Founders  \
# 857   It drives a cultural change in making yoga-bas...   Sarvesh Shashi
# 907   It drives a cultural change in making yoga-bas...   Sarvesh Shashi
# 934   Online food delivery and restaurant discovery ...  Deepinder Goyal
# 1037  Online food delivery and restaurant discovery ...  Deepinder Goyal
#
#                           Investor       Amount Stage column10
# 857                 Shikhar Dhawan          NaN  None     None
# 907   Mantra Capital, Patni Family          NaN  None     None
# 934                Pacific Horizon    5000000.0  None     None
# 1037                 Ant Financial  150000000.0  None     None

# %% [markdown]
# ***Replacing and dropping odd location***

# %%
# Replace non-geographic odd entries in the 'HeadQuarter' column
cl_df2020['HeadQuarter'] = cl_df2020['HeadQuarter'].apply(replace_odd_location)

# Replace 'Bengaluru' and 'Bangalore City' with 'Bangalore' in the 'HeadQuarter' column
cl_df2020['HeadQuarter'] = cl_df2020['HeadQuarter'].replace({'Bengaluru': 'Bangalore', 'Bangalore City': 'Bangalore'})

# List of entries to drop
entries_to_drop = ['California', 'France', 'Bangaldesh']

# Drop rows where 'HeadQuarter' contains any of the entries in the list
cl_df2020 = cl_df2020[~cl_df2020['HeadQuarter'].isin(entries_to_drop)].reset_index(drop=True)

# Display info of Data Frame
cl_df2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1041 entries, 0 to 1040
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1041 non-null   object
#  1   Founded        832 non-null    float64
#  2   HeadQuarter    1041 non-null   object
#  3   Sector         1028 non-null   object
#  4   What_it_does   1041 non-null   object
#  5   Founders       1029 non-null   object
#  6   Investor       1004 non-null   object
#  7   Amount         789 non-null    float64
#  8   Stage          585 non-null    object
#  9   column10       2 non-null      object
# dtypes: float64(2), object(8)
# memory usage: 81.5+ KB

# %% [markdown]
# `Comment`
#
# Rows with the following cities outside India will not be excluded at this stage but may be considered for removal in subsequent data cleaning phases if they constitute an insignificant percentage of the final dataset. This approach deviates from the predefined criteria for handling anomalous entries in the HeadQuarter column. Nonetheless, this measure is vital to maintaining data integrity. The cities under consideration include: San Francisco, San Ramon, Plano, New York, Irvine, Tangerang, Berlin, Seattle, Riyadh, Singapore, Seoul, Bangkok, Frisco, Paris, Sydney, Milan, Palmwoods, Newcastle upon Tyne, Shanghai, and Jiaxing.

# %% [markdown]
# **Redistributing entries in sector column**

# %%
# Replace sector names based on the dictionary
cl_df2020['Sector'] = cl_df2020['Sector'].replace(replacement_dict)

# Apply sector redistribution function to 'Sector' column
cl_df2020['Sector'] = cl_df2020['Sector'].apply(sector_redistribution)

# Get the value counts for the 'Sector' column
sector_counts = cl_df2020['Sector'].value_counts()

# Display results
print(sector_counts)
# Out:
# Sector
# Technology and Software                     267
# Finance and Technology                      163
# Education and Learning                      120
# Consumer Goods and Services                  98
# E-commerce and Retail                        80
# Healthcare and Health Technology             72
# Agriculture and Technology                   46
# Transport and Logistics                      34
# Media and Entertainment                      31
# Automotive                                   25
# Human Resources and Consultancy              22
# Real Estate and Housing                      20
# Energy and Environment                       17
# Not filled                                   13
# Marketing and Advertising                     9
# Fashion and Apparel                           8
# Social Networking                             6
# Technology Solutions for Industry             6
# Construction and Home Services                3
# Entrepreneurship and Business Incubation      1
# Name: count, dtype: int64

# %% [markdown]
# **Replacing odd founders**

# %%
# Apply the function to replace odd entries in the 'Founders' column
cl_df2020['Founders'] = cl_df2020['Founders'].apply(replace_odd_founders)

# Display information
cl_df2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1041 entries, 0 to 1040
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1041 non-null   object
#  1   Founded        832 non-null    float64
#  2   HeadQuarter    1041 non-null   object
#  3   Sector         1041 non-null   object
#  4   What_it_does   1041 non-null   object
#  5   Founders       1041 non-null   object
#  6   Investor       1004 non-null   object
#  7   Amount         789 non-null    float64
#  8   Stage          585 non-null    object
#  9   column10       2 non-null      object
# dtypes: float64(2), object(8)
# memory usage: 81.5+ KB

# %% [markdown]
# **Replacing odd investor**

# %%
# Replace odd entries in the 'Investor' column
cl_df2020['Investor'] = cl_df2020['Investor'].apply(replace_odd_investor)

# Display information
cl_df2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1041 entries, 0 to 1040
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1041 non-null   object
#  1   Founded        832 non-null    float64
#  2   HeadQuarter    1041 non-null   object
#  3   Sector         1041 non-null   object
#  4   What_it_does   1041 non-null   object
#  5   Founders       1041 non-null   object
#  6   Investor       1041 non-null   object
#  7   Amount         789 non-null    float64
#  8   Stage          585 non-null    object
#  9   column10       2 non-null      object
# dtypes: float64(2), object(8)
# memory usage: 81.5+ KB

# %% [markdown]
# **Redistributing entries in 'Stage' column**

# %%
# Define a dictionary to map misspellings and inconsistencies to their corrected forms
corrections = {
    "Seies A": "Series A",
    "PE": "Private Equity",
    "Bridge Round": "Bridge"
}

# Use the replace() method with the corrections dictionary
cl_df2020['Stage'] = cl_df2020['Stage'].replace(corrections, regex=True)

# Replace stages in the DataFrame
cl_df2020['Stage'] = cl_df2020['Stage'].apply(replace_stage)

# Get the value counts for the 'Stage' column
stage_counts20 = cl_df2020['Stage'].value_counts()

# Display results
print(stage_counts20)
# Out:
# Stage
# Validation        285
# Scaling           149
# Early Traction    104
# Ideation           20
# Debt               15
# Bridge              7
# Equity              4
# Name: count, dtype: int64

# %% [markdown]
# **Drop row with outlier (maximum value)**

# %%
# Find the index label of the row with the maximum value in the 'Amount' column
max_amount_index = cl_df2020['Amount'].idxmax()

# Drop the row using the index label
cl_df2020 = cl_df2020.drop(max_amount_index).reset_index(drop=True)

# Check DataFrame information
cl_df2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1040 entries, 0 to 1039
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1040 non-null   object
#  1   Founded        831 non-null    float64
#  2   HeadQuarter    1040 non-null   object
#  3   Sector         1040 non-null   object
#  4   What_it_does   1040 non-null   object
#  5   Founders       1040 non-null   object
#  6   Investor       1040 non-null   object
#  7   Amount         788 non-null    float64
#  8   Stage          584 non-null    object
#  9   column10       2 non-null      object
# dtypes: float64(2), object(8)
# memory usage: 81.4+ KB

# %% [markdown]
# **Drop irrelevant data**

# %%
# Drop the 'column10' column from the DataFrame
cl_df2020 = cl_df2020.drop(columns=['column10'])

# Display information
cl_df2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1040 entries, 0 to 1039
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1040 non-null   object
#  1   Founded        831 non-null    float64
#  2   HeadQuarter    1040 non-null   object
#  3   Sector         1040 non-null   object
#  4   What_it_does   1040 non-null   object
#  5   Founders       1040 non-null   object
#  6   Investor       1040 non-null   object
#  7   Amount         788 non-null    float64
#  8   Stage          584 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 73.2+ KB

# %% [markdown]
# ##### Handling Missing Values

# %% [markdown]
# **Check missing values**

# %%
# Determine the proportion of missing values
missing_cl_df2020_st = (cl_df2020.isnull().mean() * 100).round(2)

# Display Results
print("Proportion of missing values in 2020 data:")
print()
print(missing_cl_df2020_st)
# Out:
# Proportion of missing values in 2020 data:
#
# Company_Brand     0.00
# Founded          20.10
# HeadQuarter       0.00
# Sector            0.00
# What_it_does      0.00
# Founders          0.00
# Investor          0.00
# Amount           24.23
# Stage            43.85
# dtype: float64

# %% [markdown]
# **Group by Stage and determine the mean, median and mode amounts**

# %%
# Calculate mean, median, and mode amounts by stage
mean_amounts20 = cl_df2020.groupby('Stage')['Amount'].mean()
median_amounts20 = cl_df2020.groupby('Stage')['Amount'].median()
mode_amounts20 = cl_df2020.groupby('Stage')['Amount'].apply(lambda x: x.mode().iloc[0] if not x.mode().empty else None)

# Display results
print("Mean Amounts by Stage:")
print(mean_amounts20)

print("\nMedian Amounts by Stage:")
print(median_amounts20)

print("\nMode Amounts by Stage:")
print(mode_amounts20)
# Out:
# Mean Amounts by Stage:
# Stage
# Bridge            2.875000e+06
# Debt              1.199547e+07
# Early Traction    9.335816e+06
# Equity            2.640000e+05
# Ideation          5.475000e+05
# Scaling           3.456126e+07
# Validation        1.767549e+06
# Name: Amount, dtype: float64
#
# Median Amounts by Stage:
# Stage
# Bridge             1500000.0
# Debt               5000000.0
# Early Traction     5000000.0
# Equity              264000.0
# Ideation            270000.0
# Scaling           20000000.0
# Validation         1000000.0
# Name: Amount, dtype: float64
#
# Mode Amounts by Stage:
# Stage
# Bridge              500000.0
# Debt               5000000.0
# Early Traction     3000000.0
# Equity              264000.0
# Ideation            100000.0
# Scaling           30000000.0
# Validation         1000000.0
# Name: Amount, dtype: float64

# %% [markdown]
# **Univariate Analysis of the 'Amount' Column**

# %%
# Descriptive Statistics
print("Descriptive Statistics for 'Amount' column:")
print(cl_df2020['Amount'].describe())

# Skewness and Kurtosis
amount_skewness20 = skew(cl_df2020['Amount'])
amount_kurtosis20 = kurtosis(cl_df2020['Amount'])

print(f"\nSkewness for 'Amount' column: {amount_skewness20}")
print(f"Kurtosis for 'Amount' column: {amount_kurtosis20}")

# set theme
sns.set_theme(style="dark", palette="dark", font="sans-serif", font_scale=1.5)
plt.style.use("dark_background")
custom_palette = ["cyan", "magenta", "yellow"]

# Box Plot
plt.figure(figsize=(10, 6))
sns.boxplot(y=cl_df2020['Amount'], palette=custom_palette)
plt.title('Box Plot of Amount')
plt.xlabel('Amount')
plt.show()

# Histogram with KDE Plot
plt.figure(figsize=(10, 6))
sns.histplot(cl_df2020['Amount'], kde=True, color='cyan')
plt.title('Histogram and KDE of Amount')
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.show()
# Out:
# Descriptive Statistics for 'Amount' column:
# count    7.880000e+02
# mean     2.125835e+07
# std      9.817786e+07
# min      1.270000e+04
# 25%      1.000000e+06
# 50%      3.000000e+06
# 75%      1.062500e+07
# max      2.200000e+09
# Name: Amount, dtype: float64
#
# Skewness for 'Amount' column: nan
# Kurtosis for 'Amount' column: nan

# %% [markdown]
# **Filling missing values in 'Stage' column**

# %% [markdown]
# `Comment`
#
# The 'Amount' column in the dataset displays outliers, highlighting the necessity for robust imputation techniques. While mode imputation, selecting the most frequently occurring value, is a straightforward approach, its susceptibility to outliers may introduce bias and compromise data integrity. However, in scenarios where data distribution exhibits significant skewness or multimodality, mode imputation remains a viable option.
#
# Notably, distinct mode values, contrasting with median values observed across various stages, bolster the rationale for mode imputation. This method accurately captures the central tendency within each group, reinforcing its suitability for addressing missing values.
#
# In the absence of outliers within the 'Amount' data, mean imputation emerges as a viable alternative due to its simplicity and efficacy in symmetric distributions.
#
# It is pertinent to emphasize that the imputation strategy aims to fill missing values in the stage column by leveraging mode values derived from individual stage groups. This approach differs from employing the mode of the stage column itself to address missing values, a common practice in categorical data imputation methodologies.

# %%
# Define a function to fill missing stages based on mode amounts
def fill_missing_stage20(row):
    if pd.isna(row['Stage']):
        for stage, mode in mode_amounts20.items():
            if row['Amount'] <= mode:
                return stage
        return pd.NA  
    return row['Stage']

# Apply the function to fill missing stages
cl_df2020['Stage'] = cl_df2020.apply(fill_missing_stage20, axis=1)

# Display information
cl_df2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1040 entries, 0 to 1039
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1040 non-null   object
#  1   Founded        831 non-null    float64
#  2   HeadQuarter    1040 non-null   object
#  3   Sector         1040 non-null   object
#  4   What_it_does   1040 non-null   object
#  5   Founders       1040 non-null   object
#  6   Investor       1040 non-null   object
#  7   Amount         788 non-null    float64
#  8   Stage          859 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 73.2+ KB

# %%
# Filter the rows where 'Stage' is missing
filter_min20_df = cl_df2020[cl_df2020['Stage'].isna()]

# Find the minimum 'Amount' value in the filtered DataFrame
filter_min20_amount = filter_min20_df['Amount'].min()

# Print the minimum 'Amount' value
print('The minimum amount value in the filtered dataframe is:', filter_min20_amount)
# Out:
# The minimum amount value in the filtered dataframe is: 33000000.0

# %% [markdown]
# `Comment`
#
# Based on exploratory analysis of the 'Amount' column within the dataset above, it has been ascertained that the recorded minimum value stands at 33,000,000. Consequently, the imputation strategy for missing values in the 'Stage' column entails identifying the stage category whose mode amount value closely approximates this observed minimum, while ensuring exclusion of categories labeled as 'debt', 'bridge', 'market transactions', 'equity' or 'non-equity'.
#
# Upon meticulous examination of the dataset, it has been established that the 'Scaling' stage category exhibits the nearest mode amount value (30,000,000) to the aforementioned minimum amount. Thus, as an integral part of the imputation process, the missing entries in the 'Stage' column meeting the criterion of possessing a non-null float entry in the corresponding 'Amount' column will be substituted with the 'Scaling' stage category. This aligns with the predefined criteria for selection and ensures coherence in the imputation procedure.

# %%
# Apply the function to fill missing stages
cl_df2020['Stage'] = cl_df2020.apply(fill_missing_stage_scl, axis=1)

# Display information
cl_df2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1040 entries, 0 to 1039
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1040 non-null   object
#  1   Founded        831 non-null    float64
#  2   HeadQuarter    1040 non-null   object
#  3   Sector         1040 non-null   object
#  4   What_it_does   1040 non-null   object
#  5   Founders       1040 non-null   object
#  6   Investor       1040 non-null   object
#  7   Amount         788 non-null    float64
#  8   Stage          900 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 73.2+ KB

# %% [markdown]
# **Filling missing values in 'Amount' column**

# %%
# Select only the columns with missing values
X_missing20 = cl_df2020[['Amount']]  

# Initialize IterativeImputer
multiple_imputer = IterativeImputer(max_iter=10, random_state=0)  

# Fit and transform the data, and fill missing values directly in the DataFrame
cl_df2020[['Amount']] = multiple_imputer.fit_transform(X_missing20)  

# Display DataFrame information
cl_df2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1040 entries, 0 to 1039
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1040 non-null   object
#  1   Founded        831 non-null    float64
#  2   HeadQuarter    1040 non-null   object
#  3   Sector         1040 non-null   object
#  4   What_it_does   1040 non-null   object
#  5   Founders       1040 non-null   object
#  6   Investor       1040 non-null   object
#  7   Amount         1040 non-null   float64
#  8   Stage          900 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 73.2+ KB

# %% [markdown]
# **Complete filling missing values in 'Stage' column**

# %%
# Find indices of missing values in the original 'Amount' column
missing_indices20 = np.where(X_missing20.isna())[0]

# Extract unique imputed values using indices
cl_df2020_imputed = (cl_df2020.iloc[missing_indices20]['Amount']).unique()

# Print the unique imputed values
print(cl_df2020_imputed)
# Out:
# [21258352.2893401]

# %% [markdown]
# `Comment`
#
# The imputation process has yielded a unique value of 21,258,352.30 for the 'Amount' column. Consequently, the imputation strategy for missing values in the 'Stage' column involves identifying the stage category whose mode amount closely approximates this observed value, while ensuring exclusion of categories labeled as 'debt', 'bridge', or 'private equity'.
#
# After thorough scrutiny of the dataset, it has been determined that the 'Scaling' stage category exhibits the closest mode amount value (30,000,000) to the aforementioned amount value. Hence, the remaining missing values in the 'Stage' column will be replaced with the 'Scaling' stage category. This decision adheres to the predefined selection criteria, ensuring consistency and coherence in the imputation process.

# %%
# Apply the function to fill missing stages
cl_df2020['Stage'] = cl_df2020.apply(fill_missing_stage_scl, axis=1)

# Determine the proportion of missing values
missing_cl_df2020_ed = (cl_df2020.isnull().mean() * 100).round(2)

# Display Results
print("Proportion of missing values in 2020 data:")
print()
print(missing_cl_df2020_ed)
# Out:
# Proportion of missing values in 2020 data:
#
# Company_Brand     0.0
# Founded          20.1
# HeadQuarter       0.0
# Sector            0.0
# What_it_does      0.0
# Founders          0.0
# Investor          0.0
# Amount            0.0
# Stage             0.0
# dtype: float64

# %% [markdown]
# ##### Standardise Formats

# %%
# Standardize 'Founded Year' column to integer datatype
cl_df2020['Founded'] = cl_df2020['Founded'].replace([np.inf, -np.inf], np.nan).astype('Int64')


# Identify object columns (excluding 'What_it_does' and 'Company_Brand')
object_columns_to_convert20 = [col for col in cl_df2020.select_dtypes(include=['object']).columns
                             if col not in ['What_it_does', 'Company_Brand']]

# Convert object columns to category datatype
cl_df2020[object_columns_to_convert20] = cl_df2020[object_columns_to_convert20].astype('category')

# Display information
cl_df2020.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1040 entries, 0 to 1039
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1040 non-null   object
#  1   Founded        831 non-null    Int64
#  2   HeadQuarter    1040 non-null   category
#  3   Sector         1040 non-null   category
#  4   What_it_does   1040 non-null   object
#  5   Founders       1040 non-null   category
#  6   Investor       1040 non-null   category
#  7   Amount         1040 non-null   float64
#  8   Stage          1040 non-null   category
# dtypes: Int64(1), category(5), float64(1), object(2)
# memory usage: 444.4 KB

# %% [markdown]
# #### Load LP1_startup_funding2019 Data

# %% [markdown]
# ##### Remove Duplicates

# %% [markdown]
# There are no duplicate rows in this dataset.

# %% [markdown]
# ##### Handling Odd Entries and Irrelevant Data

# %% [markdown]
# **Replacing and dropping odd location**

# %%
# Create a copy of df2021 to avoid modifying the original DataFrame
cl_df2019 = df2019.copy()

# Replace non-geographic odd entries in the 'HeadQuarter' column
cl_df2019['HeadQuarter'] = cl_df2019['HeadQuarter'].apply(replace_odd_location)

# Replace 'Bengaluru' and 'Bangalore City' with 'Bangalore' in the 'HeadQuarter' column
cl_df2019['HeadQuarter'] = cl_df2019['HeadQuarter'].replace({'Bengaluru': 'Bangalore', 'Bangalore City': 'Bangalore'})

# Display info of Data Frame
cl_df2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  89 non-null     object
#  1   Founded        60 non-null     float64
#  2   HeadQuarter    89 non-null     object
#  3   Sector         84 non-null     object
#  4   What_it_does   89 non-null     object
#  5   Founders       86 non-null     object
#  6   Investor       89 non-null     object
#  7   Amount         89 non-null     object
#  8   Stage          43 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 6.4+ KB

# %% [markdown]
# **Redistributing entries in sector column**

# %%
# Replace sector names based on the dictionary
cl_df2019['Sector'] = cl_df2019['Sector'].replace(replacement_dict)

# Apply sector redistribution function to 'Sector' column
cl_df2019['Sector'] = cl_df2019['Sector'].apply(sector_redistribution)

# Get the value counts for the 'Sector' column
sector_counts = cl_df2019['Sector'].value_counts()

# Display results
print(sector_counts)
# Out:
# Sector
# Technology and Software              20
# Consumer Goods and Services          10
# Finance and Technology                9
# E-commerce and Retail                 8
# Education and Learning                7
# Transport and Logistics               6
# Automotive                            6
# Not filled                            5
# Agriculture and Technology            4
# Healthcare and Health Technology      4
# Real Estate and Housing               3
# Media and Entertainment               3
# Human Resources and Consultancy       2
# Technology Solutions for Industry     1
# Marketing and Advertising             1
# Name: count, dtype: int64

# %% [markdown]
# **Converting the 'Amount' column to float**

# %%
# Apply the 'convert_to_float' function to each element in the "Amount" column
cl_df2019['Amount'] = cl_df2019['Amount'].apply(lambda x: convert_to_float(re.sub(r'[^\d.]', '', str(x))))

# Check the data type of the "Amount" column
cl_df2019['Amount'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# **Replacing odd founders**

# %%
# Apply the function to replace odd entries in the 'Founders' column
cl_df2019['Founders'] = cl_df2019['Founders'].apply(replace_odd_founders)

# Display information
cl_df2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  89 non-null     object
#  1   Founded        60 non-null     float64
#  2   HeadQuarter    89 non-null     object
#  3   Sector         89 non-null     object
#  4   What_it_does   89 non-null     object
#  5   Founders       89 non-null     object
#  6   Investor       89 non-null     object
#  7   Amount         77 non-null     float64
#  8   Stage          43 non-null     object
# dtypes: float64(2), object(7)
# memory usage: 6.4+ KB

# %% [markdown]
# **Redistributing entries in 'Stage' column**

# %%
# Replace stages in the DataFrame
cl_df2019['Stage'] = cl_df2019['Stage'].apply(replace_stage)

# Get the value counts for the 'Stage' column
stage_counts19 = cl_df2019['Stage'].value_counts()

# Display results
print(stage_counts19)
# Out:
# Stage
# Scaling           20
# Validation        11
# Early Traction    10
# Ideation           1
# Name: count, dtype: int64

# %% [markdown]
# ##### Handling Missing Values

# %% [markdown]
# **Check missing values**

# %%
# Determine the proportion of missing values
missing_cl_df2019_st = (cl_df2019.isnull().mean() * 100).round(2)

# Display Results
print("Proportion of missing values in 2019 data:")
print()
print(missing_cl_df2019_st)
# Out:
# Proportion of missing values in 2019 data:
#
# Company_Brand     0.00
# Founded          32.58
# HeadQuarter       0.00
# Sector            0.00
# What_it_does      0.00
# Founders          0.00
# Investor          0.00
# Amount           13.48
# Stage            52.81
# dtype: float64

# %% [markdown]
# **Group by Stage and determine the mean, median and mode amounts**

# %%
# Calculate mean, median, and mode amounts by stage
mean_amounts19 = cl_df2019.groupby('Stage')['Amount'].mean()
median_amounts19 = cl_df2019.groupby('Stage')['Amount'].median()
mode_amounts19 = cl_df2019.groupby('Stage')['Amount'].apply(lambda x: x.mode().iloc[0] if not x.mode().empty else None)

# Display results
print("Mean Amounts by Stage:")
print(mean_amounts19)

print("\nMedian Amounts by Stage:")
print(median_amounts19)

print("\nMode Amounts by Stage:")
print(mode_amounts19)
# Out:
# Mean Amounts by Stage:
# Stage
# Early Traction    9.810000e+06
# Ideation          2.500000e+06
# Scaling           4.763333e+07
# Validation        6.315000e+06
# Name: Amount, dtype: float64
#
# Median Amounts by Stage:
# Stage
# Early Traction     5500000.0
# Ideation           2500000.0
# Scaling           28000000.0
# Validation         1250000.0
# Name: Amount, dtype: float64
#
# Mode Amounts by Stage:
# Stage
# Early Traction     4000000.0
# Ideation           2500000.0
# Scaling           30000000.0
# Validation         1000000.0
# Name: Amount, dtype: float64

# %% [markdown]
# **Univariate Analysis of the 'Amount' Column**

# %%
# Descriptive Statistics
print("Descriptive Statistics for 'Amount' column:")
print(cl_df2019['Amount'].describe())

# Skewness and Kurtosis
amount_skewness19 = skew(cl_df2019['Amount'])
amount_kurtosis19 = kurtosis(cl_df2019['Amount'])

print(f"\nSkewness for 'Amount' column: {amount_skewness19}")
print(f"Kurtosis for 'Amount' column: {amount_kurtosis19}")

# set theme
sns.set_theme(style="dark", palette="dark", font="sans-serif", font_scale=1.5)
plt.style.use("dark_background")
custom_palette = ["cyan", "magenta", "yellow"]

# Box Plot
plt.figure(figsize=(10, 6))
sns.boxplot(y=cl_df2019['Amount'], palette=custom_palette)
plt.title('Box Plot of Amount')
plt.xlabel('Amount')
plt.show()

# Histogram with KDE Plot
plt.figure(figsize=(10, 6))
sns.histplot(cl_df2019['Amount'], kde=True, color='cyan')
plt.title('Histogram and KDE of Amount')
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.show()
# Out:
# Descriptive Statistics for 'Amount' column:
# count    7.700000e+01
# mean     4.333030e+07
# std      1.106216e+08
# min      1.000000e+05
# 25%      2.100000e+06
# 50%      6.000000e+06
# 75%      3.000000e+07
# max      6.930000e+08
# Name: Amount, dtype: float64
#
# Skewness for 'Amount' column: nan
# Kurtosis for 'Amount' column: nan

# %% [markdown]
# **Filling missing values in 'Stage' column**

# %% [markdown]
# `Comment`
#
# The numerical values in the 'Amount' column exhibit outliers, making median imputation a more suitable method for addressing missing values. The robustness of the median against outliers ensures that the imputation process is not skewed by extreme values, thus preserving the dataset's integrity. Furthermore, distinct median values observed across different stages support the preference for median imputation, as it accurately reflects the central tendency within each group.
#
# It is important to note that the imputation strategy is designed to fill missing values in the stage column with stage groups based on the median values derived from each stage, which differs from using the mode of the stage column to fill missing values, a common approach for categorical data.
#
# Conversely, if the 'Amount' data were devoid of outliers, mean imputation would be appropriate for handling missing numerical values due to its simplicity and effectiveness in symmetrical distributions. As mentioned earlier for categorical data, mode imputation would be the preferred method, utilizing the most frequently occurring category to maintain the distributional characteristics of the dataset. Although the calculated mean and mode values illustrate these alternative methods, given the current data characteristics, median imputation remains the optimal choice.

# %%
# Define a function to fill missing stages based on median amounts
def fill_missing_stage19(row):
    if pd.isna(row['Stage']):
        for stage, median in median_amounts19.items():
            if row['Amount'] <= median:
                return stage
        return pd.NA  
    return row['Stage']

# Apply the function to fill missing stages
cl_df2019['Stage'] = cl_df2019.apply(fill_missing_stage19, axis=1)

# Display information
cl_df2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  89 non-null     object
#  1   Founded        60 non-null     float64
#  2   HeadQuarter    89 non-null     object
#  3   Sector         89 non-null     object
#  4   What_it_does   89 non-null     object
#  5   Founders       89 non-null     object
#  6   Investor       89 non-null     object
#  7   Amount         77 non-null     float64
#  8   Stage          70 non-null     object
# dtypes: float64(2), object(7)
# memory usage: 6.4+ KB

# %%
# Filter the rows where 'Stage' is missing
filter_min19_df = cl_df2019[cl_df2019['Stage'].isna()]

# Find the minimum 'Amount' value in the filtered DataFrame
filter_min19_amount = filter_min19_df['Amount'].min()

# Print the minimum 'Amount' value
print('The minimum amount value in the filtered dataframe is:', filter_min19_amount)
# Out:
# The minimum amount value in the filtered dataframe is: 33000000.0

# %% [markdown]
# `Comment`
#
# Based on exploratory analysis of the 'Amount' column within the dataset above, it has been ascertained that the recorded minimum value stands at 33,000,000. Consequently, the imputation strategy for missing values in the 'Stage' column entails identifying the stage category whose median amount value closely approximates this observed minimum, while ensuring exclusion of categories labeled as 'debt', 'bridge', 'market transactions', 'equity',  or 'non-equity'.
#
# Upon meticulous examination of the dataset, it has been established that the 'Scaling' stage category exhibits the nearest median amount value (28,000,000) to the aforementioned minimum amount. Thus, as an integral part of the imputation process, the missing entries in the 'Stage' column meeting the criterion of possessing a non-null float entry in the corresponding 'Amount' column will be substituted with the 'Scaling' stage category. This aligns with the predefined criteria for selection and ensures coherence in the imputation procedure.

# %%
# Apply the function to fill missing stages
cl_df2019['Stage'] = cl_df2019.apply(fill_missing_stage_scl, axis=1)

# Display information
cl_df2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  89 non-null     object
#  1   Founded        60 non-null     float64
#  2   HeadQuarter    89 non-null     object
#  3   Sector         89 non-null     object
#  4   What_it_does   89 non-null     object
#  5   Founders       89 non-null     object
#  6   Investor       89 non-null     object
#  7   Amount         77 non-null     float64
#  8   Stage          80 non-null     object
# dtypes: float64(2), object(7)
# memory usage: 6.4+ KB

# %% [markdown]
# **Filling missing values in 'Amount' column**

# %%
# Select only the columns with missing values
X_missing19 = cl_df2019[['Amount']]  

# Initialize IterativeImputer
multiple_imputer = IterativeImputer(max_iter=10, random_state=0)  

# Fit and transform the data, and fill missing values directly in the DataFrame
cl_df2019[['Amount']] = multiple_imputer.fit_transform(X_missing19)  

# Display DataFrame information
cl_df2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  89 non-null     object
#  1   Founded        60 non-null     float64
#  2   HeadQuarter    89 non-null     object
#  3   Sector         89 non-null     object
#  4   What_it_does   89 non-null     object
#  5   Founders       89 non-null     object
#  6   Investor       89 non-null     object
#  7   Amount         89 non-null     float64
#  8   Stage          80 non-null     object
# dtypes: float64(2), object(7)
# memory usage: 6.4+ KB

# %% [markdown]
# **Complete filling missing values in 'Stage' column**

# %%
# Find indices of missing values in the original 'Amount' column
missing_indices19 = np.where(X_missing19.isna())[0]

# Extract unique imputed values using indices
cl_df2019_imputed = (cl_df2019.iloc[missing_indices19]['Amount']).unique()

# Print the unique imputed values
print(cl_df2019_imputed)
# Out:
# [43330301.2987013]

# %% [markdown]
# `Comment`
#
# The imputation process has yielded a unique value of 43,330,301.30 for the 'Amount' column. Consequently, the imputation strategy for missing values in the 'Stage' column involves identifying the stage category whose median amount closely approximates this observed value, while ensuring exclusion of categories labeled as 'debt', 'bridge', 'market transactions', 'equity' or 'non-equity'.
#
# After thorough scrutiny of the dataset, it has been determined that the 'Scaling' stage category exhibits the closest median amount value (28,000,000) to the aforementioned amount value. Hence, the remaining missing values in the 'Stage' column will be replaced with the 'Scaling' stage category. This decision adheres to the predefined selection criteria, ensuring consistency and coherence in the imputation process.

# %%
# Apply the function to fill missing stages
cl_df2019['Stage'] = cl_df2019.apply(fill_missing_stage_scl, axis=1)

# Determine the proportion of missing values
missing_cl_df2019_ed = (cl_df2019.isnull().mean() * 100).round(2)

# Display Results
print("Proportion of missing values in 2019 data:")
print()
print(missing_cl_df2019_ed)
# Out:
# Proportion of missing values in 2019 data:
#
# Company_Brand     0.00
# Founded          32.58
# HeadQuarter       0.00
# Sector            0.00
# What_it_does      0.00
# Founders          0.00
# Investor          0.00
# Amount            0.00
# Stage             0.00
# dtype: float64

# %% [markdown]
# ##### Standardise Formats

# %%
# Standardize 'Founded Year' column to integer datatype
cl_df2019['Founded'] = cl_df2019['Founded'].replace([np.inf, -np.inf], np.nan).astype('Int64')


# Identify object columns (excluding 'What_it_does' and 'Company_Brand')
object_columns_to_convert19 = [col for col in cl_df2019.select_dtypes(include=['object']).columns
                             if col not in ['What_it_does', 'Company_Brand']]

# Convert object columns to category datatype
cl_df2019[object_columns_to_convert19] = cl_df2019[object_columns_to_convert19].astype('category')

# Display information
cl_df2019.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  89 non-null     object
#  1   Founded        60 non-null     Int64
#  2   HeadQuarter    89 non-null     category
#  3   Sector         89 non-null     category
#  4   What_it_does   89 non-null     object
#  5   Founders       89 non-null     category
#  6   Investor       89 non-null     category
#  7   Amount         89 non-null     float64
#  8   Stage          89 non-null     category
# dtypes: Int64(1), category(5), float64(1), object(2)
# memory usage: 41.5 KB

# %% [markdown]
# #### Load LP1_startup_funding2018 Data

# %% [markdown]
# **Replacing odd founders**

# %% [markdown]
# ##### Remove Duplicates

# %% [markdown]
# **Based on all Features**

# %%
# Create a copy of df2021 to avoid modifying the original DataFrame
cl_df2018 = df2018.copy()

# Remove duplicate rows 
cl_df2018.drop_duplicates(inplace=True, ignore_index=True)

# Display info of Data Frame
cl_df2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525 entries, 0 to 524
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  525 non-null    object
#  1   Founded        0 non-null      float64
#  2   HeadQuarter    525 non-null    object
#  3   Sector         525 non-null    object
#  4   What_it_does   525 non-null    object
#  5   Founders       525 non-null    object
#  6   Investor       525 non-null    object
#  7   Amount         525 non-null    object
#  8   Stage          525 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 37.0+ KB

# %% [markdown]
# ##### Handling Odd Entries and Irrelevant Data

# %% [markdown]
# **Replacing and dropping odd location**

# %%
# Replace non-geographic odd entries in the 'HeadQuarter' column
cl_df2018['HeadQuarter'] = cl_df2018['HeadQuarter'].apply(replace_odd_location)

# Replace 'Bengaluru' and 'Bangalore City' with 'Bangalore' in the 'HeadQuarter' column
cl_df2018['HeadQuarter'] = cl_df2018['HeadQuarter'].replace({'Bengaluru': 'Bangalore', 'Bangalore City': 'Bangalore'})

# Display info of Data Frame
cl_df2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525 entries, 0 to 524
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  525 non-null    object
#  1   Founded        0 non-null      float64
#  2   HeadQuarter    525 non-null    object
#  3   Sector         525 non-null    object
#  4   What_it_does   525 non-null    object
#  5   Founders       525 non-null    object
#  6   Investor       525 non-null    object
#  7   Amount         525 non-null    object
#  8   Stage          525 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 37.0+ KB

# %% [markdown]
# **Redistributing entries in sector column**

# %%
# Replace sector names based on the dictionary
cl_df2018['Sector'] = cl_df2018['Sector'].replace(replacement_dict)

# Apply sector redistribution function to 'Sector' column
cl_df2018['Sector'] = cl_df2018['Sector'].apply(sector_redistribution)

# Get the value counts for the 'Sector' column
sector_counts18 = cl_df2018['Sector'].value_counts()

# Display results
print(sector_counts18)
# Out:
# Sector
# Finance and Technology               88
# Technology and Software              67
# E-commerce and Retail                60
# Healthcare and Health Technology     57
# Consumer Goods and Services          52
# Education and Learning               40
# Human Resources and Consultancy      37
# Not filled                           30
# Energy and Environment               21
# Transport and Logistics              15
# Automotive                           11
# Agriculture and Technology           10
# Technology Solutions for Industry     9
# Media and Entertainment               9
# Real Estate and Housing               5
# Marketing and Advertising             4
# Fashion and Apparel                   3
# Cultural and Tourism                  3
# Defence and Aviation                  2
# Social Networking                     2
# Name: count, dtype: int64

# %% [markdown]
# **Cleaning th 'Amount' column**
#
# For this dataset the approach would require the following:
#
# 1. Converting Rupees (INR) to US Dollars (USD):
#
#    This will be done by calulating the average exchange rate for the Indian Rupee to US Dollar in 2018 using the franfurter app and cross-referencing with information provided by the [Reserve Bank of India (RBI)](https://website.rbi.org.in/web/rbi/exchange-rate-archive).
#
# 2. Converting all string or non numeric values to float

# %% [markdown]
# ***Determine average exchange rate for INR to USD in 2018 using the Frankfurter app***

# %%
# Define the start date and end date and type of conversion
"2018-01-01..2018-12-31?from=USD&to=INR"

# Host and URL
host = "api.frankfurter.app"
url18 = f"https://{host}/2018-01-01..2018-12-31?from=USD&to=INR"

# Sending a GET request to the Frankfurter API to retrieve exchange rate data
response = requests.get(url18)

# Parsing the JSON response into a Python dictionary
data = response.json()

# Creating a pandas DataFrame from the JSON data
usdinr_df18 = pd.DataFrame(data)

# Normalizing the "rates" column of the DataFrame to expand nested data into separate columns
usdinr_df18_rates = pd.json_normalize(usdinr_df18["rates"])

# Resetting the index of the DataFrame to default integer index
usdinr_df18 = usdinr_df18.reset_index()

# Renaming the previous index column as "index_date"
usdinr_df18 = usdinr_df18.rename(columns={"index": "index_date"})

# Convert the 'Date' column to DateTime format
usdinr_df18["index_date"] = pd.to_datetime(usdinr_df18["index_date"], format="ISO8601")

# Dropping the "rates" column from the DataFrame
usdinr_df18 = usdinr_df18.drop("rates", axis=1)

# Concatenating the DataFrame containing the index and the normalized rates DataFrame horizontally
usdinr_df18 = pd.concat([usdinr_df18, usdinr_df18_rates], axis=1)

# Printing the constructed URL to the console for verification
print("\nReference:", url18)

# Generate descriptive statistics for the Data Frame
usdinr_df18.describe().T
# Out:
# Reference: https://api.frankfurter.app/2018-01-01..2018-12-31?from=USD&to=INR
#             count                           mean                  min  \
# index_date    255  2018-07-01 11:34:35.294117632  2018-01-02 00:00:00
# amount      255.0                            1.0                  1.0
# INR         255.0                      68.448325                63.37
#
#                             25%                  50%                  75%  \
# index_date  2018-04-03 12:00:00  2018-07-03 00:00:00  2018-09-29 12:00:00
# amount                      1.0                  1.0                  1.0
# INR                      65.192               68.519               71.105
#
#                             max       std
# index_date  2018-12-31 00:00:00       NaN
# amount                      1.0       0.0
# INR                      74.403  3.206166

# %% [markdown]
# ***Determine exchange rate for INR to USD in 2018 from Reserve Bank of India***

# %%
# Path of excel file
rbi_data = '../Data/Exchange_Rates.xls'

# Read the CSV file into a pandas DataFrame
rbi_df18 = pd.read_excel(rbi_data)

# Convert the "Effective Date" to ISO standard format
rbi_df18['Effective Date'] = pd.to_datetime(rbi_df18['Effective Date'])

# Define the date range
start_date = '2018-01-01'
end_date = '2018-12-31'

# Generate the date range
date_range = pd.date_range(start=start_date, end=end_date)

# Filter the DataFrame based on the date range
rbi_filter_df18 = rbi_df18[rbi_df18['Effective Date'].isin(date_range)]

# Printing the source URL for verification
print("\nReference: https://website.rbi.org.in/web/rbi/exchange-rate-archive")

# Generate descriptive statistics for the filtered dataframe
rbi_filter_df18.describe().T
# Out:
# Reference: https://website.rbi.org.in/web/rbi/exchange-rate-archive
#                 count                           mean                  min  \
# Effective Date    245  2018-06-30 08:07:50.204081664  2018-01-01 00:00:00
# USD             245.0                      68.359489              63.3482
# GBP             245.0                      91.167689              85.7432
# EURO            245.0                      80.661163              75.9153
# YEN             245.0                      61.859306                55.95
#
#                                 25%                  50%                  75%  \
# Effective Date  2018-04-04 00:00:00  2018-06-29 00:00:00  2018-09-27 00:00:00
# USD                         65.1031              68.4094              70.9065
# GBP                         89.7389              90.5843              92.2846
# EURO                        79.6327              80.1179              81.4253
# YEN                           61.02                61.71                63.28
#
#                                 max       std
# Effective Date  2018-12-31 00:00:00       NaN
# USD                         74.3875  3.179066
# GBP                         98.2961  2.418955
# EURO                        85.9012  2.071325
# YEN                           66.29  2.147517

# %% [markdown]
# ***Determine overall average exchange rate***

# %%
# Calculate the mean exchange rate of the Indian Rupee (INR) for the year 2018 in Frankfurter App data
frank_mean = usdinr_df18['INR'].mean()

# Calculate the mean exchange rate of the US Dollar (USD) for the year 2018 in Reserve Bank of India data
rbi_mean = rbi_filter_df18['USD'].mean()

# Calculate the overall mean exchange rate by averaging the mean exchange rates from Frankfurter App and Reserve Bank of India
ovr_mean = ((frank_mean + rbi_mean) / 2).round(2)

# Print the overall mean exchange rate
print(ovr_mean)
# Out:
# 68.4

# %% [markdown]
# ***Define and apply function for cleaning data***

# %%
def convert_inr_to_usd(amount):
    try:
        amount = str(amount)

        # Remove commas and dashes
        amount = amount.replace(",", "").replace("-", "")
        
        # Check if the value is in Indian Rupees and convert to US Dollars
        if "₹" in amount:
            amount = amount.replace("₹", "")
            return round(float(amount) / ovr_mean)

        # Check if the value is in US Dollars
        if "$" in amount:
            amount = amount.replace("$", "")
            return round(float(amount))

        # Check if no currency symbol is present, assume US Dollars
        return round(float(amount))

    except ValueError:
        # If the value is not a number, return NaN
        return np.nan
     
# Clean the Amount column of the DataFrame
cl_df2018["Amount"] = cl_df2018["Amount"].apply(convert_inr_to_usd)

# Display Dataframe
cl_df2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525 entries, 0 to 524
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  525 non-null    object
#  1   Founded        0 non-null      float64
#  2   HeadQuarter    525 non-null    object
#  3   Sector         525 non-null    object
#  4   What_it_does   525 non-null    object
#  5   Founders       525 non-null    object
#  6   Investor       525 non-null    object
#  7   Amount         377 non-null    float64
#  8   Stage          525 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 37.0+ KB

# %% [markdown]
# **Redistributing entries in 'Stage' column**

# %%
# Use the replace() method with the corrections dictionary
cl_df2018['Stage'] = cl_df2018['Stage'].replace(corrections, regex=True)

# Replace stages in the DataFrame
cl_df2018['Stage'] = cl_df2018['Stage'].apply(replace_stage)

# Get the value counts for the 'Stage' column
stage_counts18 = cl_df2018['Stage'].value_counts()

# Display results
print(stage_counts18)
# Out:
# Stage
# Validation             279
# Equity                  95
# Early Traction          73
# Scaling                 45
# Debt                    15
# Ideation                 6
# Non-Equity               5
# Market Transactions      3
# Name: count, dtype: int64

# %% [markdown]
# ##### Handling Missing Values

# %% [markdown]
# **Check missing values**

# %%
# Determine the proportion of missing values
missing_cl_df2018_st = (cl_df2018.isnull().mean() * 100).round(2)

# Display Results
print("Proportion of missing values in 2018 data:")
print()
print(missing_cl_df2018_st)
# Out:
# Proportion of missing values in 2018 data:
#
# Company_Brand      0.00
# Founded          100.00
# HeadQuarter        0.00
# Sector             0.00
# What_it_does       0.00
# Founders           0.00
# Investor           0.00
# Amount            28.19
# Stage              0.76
# dtype: float64

# %% [markdown]
# **Group by Stage and determine the mean, median and mode amounts**

# %%
# Calculate mean, median, and mode amounts by stage
mean_amounts18 = cl_df2018.groupby('Stage')['Amount'].mean()
median_amounts18 = cl_df2018.groupby('Stage')['Amount'].median()
mode_amounts18 = cl_df2018.groupby('Stage')['Amount'].apply(lambda x: x.mode().iloc[0] if not x.mode().empty else None)

# Display results
print("Mean Amounts by Stage:")
print(mean_amounts18)

print("\nMedian Amounts by Stage:")
print(median_amounts18)

print("\nMode Amounts by Stage:")
print(mode_amounts18)
# Out:
# Mean Amounts by Stage:
# Stage
# Debt                   1.310815e+07
# Early Traction         4.456495e+06
# Equity                 4.655860e+07
# Ideation               5.875000e+04
# Market Transactions    1.132602e+08
# Non-Equity             3.915205e+05
# Scaling                6.000463e+07
# Validation             1.042583e+06
# Name: Amount, dtype: float64
#
# Median Amounts by Stage:
# Stage
# Debt                     3000000.0
# Early Traction           3827485.5
# Equity                   3070175.0
# Ideation                   60000.0
# Market Transactions    113260234.0
# Non-Equity                 28772.0
# Scaling                 25000000.0
# Validation                584795.0
# Name: Amount, dtype: float64
#
# Mode Amounts by Stage:
# Stage
# Debt                    8040936.0
# Early Traction          5000000.0
# Equity                   250000.0
# Ideation                 100000.0
# Market Transactions    16520468.0
# Non-Equity                10000.0
# Scaling                 8771930.0
# Validation              1000000.0
# Name: Amount, dtype: float64

# %% [markdown]
# ***Univariate Analysis of the 'Amount' Column***

# %%
# Descriptive Statistics
print("Descriptive Statistics for 'Amount' column:")
print(cl_df2018['Amount'].describe())

# Skewness and Kurtosis
amount_skewness = skew(cl_df2018['Amount'])
amount_kurtosis = kurtosis(cl_df2018['Amount'])

print(f"\nSkewness for 'Amount' column: {amount_skewness}")
print(f"Kurtosis for 'Amount' column: {amount_kurtosis}")

# set theme
sns.set_theme(style="dark", palette="dark", font="sans-serif", font_scale=1.5)
plt.style.use("dark_background")
custom_palette = ["cyan", "magenta", "yellow"]

# Box Plot
plt.figure(figsize=(10, 6))
sns.boxplot(y=cl_df2018['Amount'], palette=custom_palette)
plt.title('Box Plot of Amount')
plt.xlabel('Amount')
plt.show()

# Histogram with KDE Plot
plt.figure(figsize=(10, 6))
sns.histplot(cl_df2018['Amount'], kde=True, color='cyan')
plt.title('Histogram and KDE of Amount')
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.show()
# Out:
# Descriptive Statistics for 'Amount' column:
# count    3.770000e+02
# mean     1.762126e+07
# std      7.797884e+07
# min      8.770000e+02
# 25%      5.000000e+05
# 50%      1.300000e+06
# 75%      5.000000e+06
# max      1.000000e+09
# Name: Amount, dtype: float64
#
# Skewness for 'Amount' column: nan
# Kurtosis for 'Amount' column: nan

# %% [markdown]
# **Filling missing values in 'Stage' column**

# %% [markdown]
# `Comment`
#
# The numerical values in the 'Amount' column exhibit outliers, making median imputation a more suitable method for addressing missing values. The robustness of the median against outliers ensures that the imputation process is not skewed by extreme values, thus preserving the dataset's integrity. Furthermore, distinct median values observed across different stages support the preference for median imputation, as it accurately reflects the central tendency within each group.
#
# It is important to note that the imputation strategy is designed to fill missing values in the stage column with stage groups based on the median values derived from each stage, which differs from using the mode of the stage column to fill missing values, a common approach for categorical data.
#
# Conversely, if the 'Amount' data were devoid of outliers, mean imputation would be appropriate for handling missing numerical values due to its simplicity and effectiveness in symmetrical distributions. As mentioned earlier for categorical data, mode imputation would be the preferred method, utilizing the most frequently occurring category to maintain the distributional characteristics of the dataset. Although the calculated mean and mode values illustrate these alternative methods, given the current data characteristics, median imputation remains the optimal choice.

# %%
# Define a function to fill missing stages based on mode amounts
def fill_missing_stage18(row):
    if pd.isna(row['Stage']):
        for stage, median in median_amounts18.items():
            if row['Amount'] <= median:
                return stage
        return pd.NA  
    return row['Stage']

# Apply the function to fill missing stages
cl_df2018['Stage'] = cl_df2018.apply(fill_missing_stage18, axis=1)

# Display information
cl_df2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525 entries, 0 to 524
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  525 non-null    object
#  1   Founded        0 non-null      float64
#  2   HeadQuarter    525 non-null    object
#  3   Sector         525 non-null    object
#  4   What_it_does   525 non-null    object
#  5   Founders       525 non-null    object
#  6   Investor       525 non-null    object
#  7   Amount         377 non-null    float64
#  8   Stage          525 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 37.0+ KB

# %% [markdown]
# **Filling missing values in 'Amount' column**

# %%
# Select only the columns with missing values
X_missing18 = cl_df2018[['Amount']]  

# Initialize IterativeImputer
multiple_imputer = IterativeImputer(max_iter=10, random_state=0)  

# Fit and transform the data, and fill missing values directly in the DataFrame
cl_df2018[['Amount']] = multiple_imputer.fit_transform(X_missing18)  

# Determine the proportion of missing values
missing_cl_df2018_ed = (cl_df2018.isnull().mean() * 100).round(2)

# Display Results
print("Proportion of missing values in 2018 data:")
print()
print(missing_cl_df2018_ed)
# Out:
# Proportion of missing values in 2018 data:
#
# Company_Brand      0.0
# Founded          100.0
# HeadQuarter        0.0
# Sector             0.0
# What_it_does       0.0
# Founders           0.0
# Investor           0.0
# Amount             0.0
# Stage              0.0
# dtype: float64

# %% [markdown]
# ##### Standardise Formats

# %%
# Standardize 'Founded Year' column to integer datatype
cl_df2018['Founded'] = cl_df2018['Founded'].replace([np.inf, -np.inf], np.nan).astype('Int64')


# Identify object columns (excluding 'What_it_does' and 'Company_Brand')
object_columns_to_convert18 = [col for col in cl_df2018.select_dtypes(include=['object']).columns
                             if col not in ['What_it_does', 'Company_Brand']]

# Convert object columns to category datatype
cl_df2018[object_columns_to_convert18] = cl_df2018[object_columns_to_convert18].astype('category')

# Display information
cl_df2018.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525 entries, 0 to 524
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  525 non-null    object
#  1   Founded        0 non-null      Int64
#  2   HeadQuarter    525 non-null    category
#  3   Sector         525 non-null    category
#  4   What_it_does   525 non-null    object
#  5   Founders       525 non-null    category
#  6   Investor       525 non-null    category
#  7   Amount         525 non-null    float64
#  8   Stage          525 non-null    category
# dtypes: Int64(1), category(5), float64(1), object(2)
# memory usage: 129.5 KB

# %% [markdown]
# ### Data Integration

# %%
# Assign the year 2021 to a new column 'Funding_Year' in the DataFrame cl_df2021
cl_df2021['Funding_Year'] = 2021

# Assign the year 2020 to a new column 'Funding_Year' in the DataFrame cl_df2020
cl_df2020['Funding_Year'] = 2020

# Assign the year 2019 to a new column 'Funding_Year' in the DataFrame cl_df2019
cl_df2019['Funding_Year'] = 2019

# Assign the year 2018 to a new column 'Funding_Year' in the DataFrame cl_df2018
cl_df2018['Funding_Year'] = 2018

# Combine the four DataFrames into a single DataFrame
lp1df = pd.concat([cl_df2021, cl_df2020, cl_df2019, cl_df2018], ignore_index=True)

# Standardize 'Founded' column to integer datatype
lp1df['Founded'] = lp1df['Founded'].replace([np.inf, -np.inf], np.nan).astype('Int64')

# Identify object columns (excluding 'What_it_does' and 'Company_Brand') to convert to category datatype
object_columns_to_convertlp1 = [col for col in lp1df.select_dtypes(include=['object']).columns
                                if col not in ['What_it_does', 'Company_Brand']]

# Convert object columns to category datatype
lp1df[object_columns_to_convertlp1] = lp1df[object_columns_to_convertlp1].astype('category')

# Display DataFrame information with deep memory usage
lp1df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2824 entries, 0 to 2823
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  2824 non-null   object
#  1   Founded        2061 non-null   Int64
#  2   HeadQuarter    2824 non-null   category
#  3   Sector         2824 non-null   category
#  4   What_it_does   2824 non-null   object
#  5   Founders       2824 non-null   category
#  6   Investor       2824 non-null   category
#  7   Amount         2824 non-null   float64
#  8   Stage          2824 non-null   category
#  9   Funding_Year   2824 non-null   int64
# dtypes: Int64(1), category(5), float64(1), int64(1), object(2)
# memory usage: 296.7+ KB

# %% [markdown]
# #### Data Pruning of Final Data

# %% [markdown]
# **Check missing values in final data**

# %%
# Determine the proportion of missing values
missing_percentage_lp1_st = (lp1df.isnull().mean() * 100).round(2)

# Display results
print("Proportion of missing values in final data:")
print()
print(missing_percentage_lp1_st)
# Out:
# Proportion of missing values in final data:
#
# Company_Brand     0.00
# Founded          27.02
# HeadQuarter       0.00
# Sector            0.00
# What_it_does      0.00
# Founders          0.00
# Investor          0.00
# Amount            0.00
# Stage             0.00
# Funding_Year      0.00
# dtype: float64

# %% [markdown]
# ##### Pruning 'Founded' Column

# %% [markdown]
# **Filling missing values in 'founded' column**

# %% [markdown]
# ***Phase one***

# %%
# Create a copy of the original DataFrame to preserve the original data
cl_lp1df = lp1df.copy()

# Add a new column 'Company_Brand_lower' with all values in the 'Company_Brand' column converted to lowercase
cl_lp1df['Company_Brand_lower'] = cl_lp1df['Company_Brand'].str.lower()

# Filter rows where the 'Founded' column has missing values
companies1_without_flp1 = cl_lp1df[cl_lp1df['Founded'].isna()]

# Get unique company brands (in lowercase) from the rows where 'Founded' values are missing
unique1_companies_without_flp1 = companies1_without_flp1['Company_Brand_lower'].unique()

# Filter the original DataFrame to include only rows with these unique company brands (in lowercase)
filter1_companies_flp1 = cl_lp1df[cl_lp1df['Company_Brand_lower'].isin(unique1_companies_without_flp1)]

# Further filter the subset to include only rows where 'Founded' values are not missing
filter2_companies_flp1 = filter1_companies_flp1[filter1_companies_flp1['Founded'].notna()]

# Display the resulting DataFrame
filter2_companies_flp1
# Out:
#      Company_Brand  Founded HeadQuarter                       Sector  \
# 13    Freyr Energy     2014   Hyderabad       Energy and Environment
# 21           Uable     2020   Bangalore       Education and Learning
# 53          Swiggy     2014   Bangalore  Consumer Goods and Services
# 56         Pitstop     2015   Bangalore                   Automotive
# 57            CRED     2018   Bangalore       Finance and Technology
# ...            ...      ...         ...                          ...
# 2282      CarDekho     2008      Jaipur                   Automotive
# 2285      Sportido     2015       Noida      Media and Entertainment
# 2290           Ola     2010   Bangalore      Transport and Logistics
# 2295           Oyo     2013    Gurugram  Consumer Goods and Services
# 2297        Spinny     2015       Delhi                   Automotive
#
#                                            What_it_does  \
# 13    Freyr Energy is a company that provides full s...
# 21    Uable offers role based programmes to empower ...
# 53    Swiggy is an on-demand food delivery platform ...
# 56    Pitstop offers general repair and maintenance ...
# 57    CRED is a members-only credit card management ...
# ...                                                 ...
# 2282       Enables people to buy and sell new/old cars.
# 2285  It is a sports discovery app that helps to fin...
# 2290                  It enables one to book cab online
# 2295                Provides rooms for comfortable stay
# 2297                                Online car retailer
#
#                                                Founders  \
# 13                      Radhika Choudary, Saurabh Marda
# 21                                       Saurabh Saxena
# 53        Nandan Reddy, Rahul Jaimini, Sriharsha Majety
# 56    Mihir Mohan Mishra, Nirant Ramakuru, Ruchi Deepak
# 57                                           Kunal Shah
# ...                                                 ...
# 2282                                          Amit Jain
# 2285               Neeraj Aggarwala, Akhil Ramachandran
# 2290                      Bhavish Aggarwal, Ankit Bhati
# 2295                                     Ritesh Agarwal
# 2297  Niraj Singh, Ramanshu Mahaur, Ganesh Pawar, Mo...
#
#                                                Investor        Amount  \
# 13                        Impact Partners, C4D Partners  2.000000e+06
# 21                        Chiratae Ventures, JAFCO Asia  2.777607e+07
# 53                       Carmignac, Falcon Edge Capital  8.000000e+08
# 56               Acko Technology, Services, LetsVenture  3.500000e+06
# 57    Dragoneer Investment Group, Tiger Global Manag...  2.150000e+08
# ...                                                 ...           ...
# 2282  Ping An Global Voyager Fund, Hillhouse Capital...  7.000000e+07
# 2285  Inflection Point Ventures, SucSEED Venture Par...  4.333030e+07
# 2290                                Kia Motors, Hyundai  3.110000e+08
# 2295  MyPreferred Transformation, Avendus Finance, S...  6.930000e+08
# 2297  Norwest Venture Partners, General Catalyst, Fu...  5.000000e+07
#
#                Stage  Funding_Year Company_Brand_lower
# 13              Debt          2021        freyr energy
# 21        Validation          2021               uable
# 53           Scaling          2021              swiggy
# 56    Early Traction          2021             pitstop
# 57           Scaling          2021                cred
# ...              ...           ...                 ...
# 2282         Scaling          2019            cardekho
# 2285         Scaling          2019            sportido
# 2290         Scaling          2019                 ola
# 2295         Scaling          2019                 oyo
# 2297         Scaling          2019              spinny
#
# [300 rows x 11 columns]

# %%
# Get unique company brands (in lowercase) from the filtered DataFrame with non-missing 'Founded' values
unique2_companies_without_flp1 = filter2_companies_flp1['Company_Brand_lower'].unique()

# Store the unique company brands in a list named 'target1flp1'
target1flp1 = list(unique2_companies_without_flp1)

# Filter the DataFrame to include only rows where 'Company_Brand_lower' is in the target list
target1_brands_dfflp1 = cl_lp1df[cl_lp1df['Company_Brand_lower'].isin(target1flp1)]

# Iterate through each company brand in the target1flp1 list
for brand in target1flp1:
    # Get the non-null 'Founded' value for this brand from the filtered DataFrame
    founded_value = target1_brands_dfflp1.loc[target1_brands_dfflp1['Company_Brand_lower'] == brand, 'Founded'].dropna().values[0]
    
    # Fill missing 'Founded' values in the original DataFrame with the identified non-null value
    cl_lp1df.loc[(cl_lp1df['Company_Brand_lower'] == brand) & (cl_lp1df['Founded'].isna()), 'Founded'] = founded_value

# Display information about the updated DataFrame
cl_lp1df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2824 entries, 0 to 2823
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Company_Brand        2824 non-null   object
#  1   Founded              2252 non-null   Int64
#  2   HeadQuarter          2824 non-null   category
#  3   Sector               2824 non-null   category
#  4   What_it_does         2824 non-null   object
#  5   Founders             2824 non-null   category
#  6   Investor             2824 non-null   category
#  7   Amount               2824 non-null   float64
#  8   Stage                2824 non-null   category
#  9   Funding_Year         2824 non-null   int64
#  10  Company_Brand_lower  2824 non-null   object
# dtypes: Int64(1), category(5), float64(1), int64(1), object(3)
# memory usage: 318.7+ KB

# %% [markdown]
# ***Phase two***

# %%
# Filter rows where the 'Founded' column has missing values
companies2_without_flp1 = cl_lp1df[cl_lp1df['Founded'].isna()]

# Get unique company brands (in lowercase) from the rows where 'Founded' values are missing
unique2_companies_without_flp1 = companies2_without_flp1['Company_Brand_lower'].unique()

# Filter the original DataFrame to include only rows with these unique company brands (in lowercase)
filter12_companies_flp1 = cl_lp1df[cl_lp1df['Company_Brand_lower'].isin(unique2_companies_without_flp1)]

# Further filter the subset to include only rows where 'Founded' values are not missing
filter22_companies_flp1 = filter12_companies_flp1[filter12_companies_flp1['Founded'].notna()]

# Display the resulting DataFrame
filter22_companies_flp1
# Out:
# Empty DataFrame
# Columns: [Company_Brand, Founded, HeadQuarter, Sector, What_it_does, Founders, Investor, Amount, Stage, Funding_Year, Company_Brand_lower]
# Index: []

# %% [markdown]
# ***Drop companies founded before 1980 and after 2021***

# %%
# Identify rows where the 'Founded' column has missing values
missing_founded = cl_lp1df[cl_lp1df['Founded'].isna()]

# Identify rows where the 'Founded' column has non-missing values
non_missing_founded = cl_lp1df[cl_lp1df['Founded'].notna()]

# Apply the filtering condition to rows with non-missing values in the 'Founded' column within the specified range
filtered_non_missing_founded = non_missing_founded[((cl_lp1df['Founded'] >= 1980) & (cl_lp1df['Founded'] <= 2021))]

# Concatenate the filtered non-missing founded rows with the missing founded rows
cl_lp1df = pd.concat([filtered_non_missing_founded, missing_founded], ignore_index=True)

# Display information about the DataFrame
cl_lp1df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2822 entries, 0 to 2821
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Company_Brand        2822 non-null   object
#  1   Founded              2250 non-null   Int64
#  2   HeadQuarter          2822 non-null   category
#  3   Sector               2822 non-null   category
#  4   What_it_does         2822 non-null   object
#  5   Founders             2822 non-null   category
#  6   Investor             2822 non-null   category
#  7   Amount               2822 non-null   float64
#  8   Stage                2822 non-null   category
#  9   Funding_Year         2822 non-null   int64
#  10  Company_Brand_lower  2822 non-null   object
# dtypes: Int64(1), category(5), float64(1), int64(1), object(3)
# memory usage: 318.6+ KB

# %% [markdown]
# ##### Pruning 'HeadQuarter' Column

# %% [markdown]
# **Filling Invalid Values in 'HeadQuarter' Column**

# %%
# Filter rows where the 'HeadQuarter' column has the value 'Not filled'
companies1_without_llp1 = cl_lp1df[cl_lp1df['HeadQuarter'].isin(['Not filled'])]

# Get unique company brands (in lowercase) from the rows where 'HeadQuarter' is 'Not filled'
unique1_companies_without_llp1 = companies1_without_llp1['Company_Brand_lower'].unique()

# Filter the original DataFrame to include only rows with these unique company brands (in lowercase)
filter1_companies_llp1 = cl_lp1df[cl_lp1df['Company_Brand_lower'].isin(unique1_companies_without_llp1)]

# Further filter the subset to include only rows where 'HeadQuarter' is not 'Not filled'
filter2_companies_llp1 = filter1_companies_llp1[~filter1_companies_llp1['HeadQuarter'].isin(['Not filled'])]

# Display the resulting DataFrame
filter2_companies_llp1
# Out:
#         Company_Brand  Founded    HeadQuarter  \
# 27       Pristyn Care     2018       Gurugram
# 45            moEVing     2021       Gurugram
# 125           Postman     2014      Bangalore
# 127         RACEnergy     2018      Hyderabad
# 144              Klub     2019      Bangalore
# 147             Zupee     2018       Gurugram
# 168            Neeman     2017      Hyderabad
# 227      Pristyn Care     2018       Gurugram
# 279         Mamaearth     2016       Gurugram
# 303            Phable     2017      Bangalore
# 371            DeHaat     2012          Patna
# 393             Zupee     2018        Gurgaon
# 444         Mamaearth     2016       Gurugram
# 459             Otipy     2020       Gurugram
# 538        Shiprocket     2012      New Delhi
# 541             Vahak     2017      Bangalore
# 575                F5     2018      New Delhi
# 601   Juicy chemistry     2014     Coimbatore
# 636         Classplus     2017          Noida
# 686            BYJU'S     2011      Bangalore
# 701             OZiva     2016         Mumbai
# 702             Blive     2004         Panaji
# 711   Juicy Chemistry     2014     Coimbatore
# 740            Bijnis     2014      New Delhi
# 798    Myelin Foundry     2019      Bangalore
# 872             Park+     2019      New Delhi
# 876         Rentomojo     2014      Bangalore
# 889            BYJU'S     2011      Bangalore
# 906       Rebel Foods     2011         Mumbai
# 913                F5     2018      New Delhi
# 980            DeHaat     2012       Gurugram
# 1034           Bijnis     2015      New Delhi
# 1108       Peppermint     2019           Pune
# 1119         Vidyakul     2017       Gurugram
# 1169             Klub     2019      Bangalore
# 1179       Shiprocket     2017      New Delhi
# 1181          CoinDCX     2017         Mumbai
# 1207          Gamerji     2018      Ahmedabad
# 1286          InVideo     2017         Mumbai
# 1307           Fleetx     2017       Gurugram
# 1335          FanPlay     2018      New Delhi
# 1362         Onsitego     2010         Mumbai
# 1378         Illumnus     2018           Pune
# 1463      Rebel Foods     2011         Mumbai
# 1490        Zolostays     2015      Bangalore
# 1549           Rooter     2016          Delhi
# 1552        Classplus     2008          Delhi
# 1563            Bijak     2019       Gurugram
# 1602               F5     2018          Delhi
# 1669        Ninjacart     2015      Bangalore
# 1677           Rivigo     2014       Gurugram
# 1713           Rivigo     2014        Gurgaon
# 1739             NIRA     2017      Bangalore
# 1740           Byju's     2011      Bangalore
# 1752       Xpressbees     2015           Pune
# 1789          Slintel     2016  San Francisco
# 1794        RACEnergy     2018      Hyderabad
# 1799        Ninjacart     2015      Bangalore
# 1816     Pristyn Care     2018       Gurugram
# 1824        Classplus     2018          Noida
# 1843      Rebel Foods     2011           Pune
# 1890           Byju's     2011      Bangalore
# 1928           Byju's     2011      Bangalore
# 2161          Shop101     2015         Mumbai
# 2162        Ninjacart     2015      Bangalore
# 2185        SmartVizX     2015          Noida
# 2220             NIRA     2018      Bangalore
# 2243        Mamaearth     2016        Gurgaon
# 2246          Chaayos     2012      New Delhi
# 2248        Dailyhunt     2009      Bangalore
# 2272             Toch     <NA>         Mumbai
# 2720        TECHBOOZE     <NA>      New Delhi
#
#                                  Sector  \
# 27     Healthcare and Health Technology
# 45              Transport and Logistics
# 125             Technology and Software
# 127                          Automotive
# 144              Finance and Technology
# 147         Consumer Goods and Services
# 168         Consumer Goods and Services
# 227    Healthcare and Health Technology
# 279    Healthcare and Health Technology
# 303    Healthcare and Health Technology
# 371          Agriculture and Technology
# 393         Consumer Goods and Services
# 444    Healthcare and Health Technology
# 459         Consumer Goods and Services
# 538             Transport and Logistics
# 541             Transport and Logistics
# 575         Consumer Goods and Services
# 601    Healthcare and Health Technology
# 636              Education and Learning
# 686              Education and Learning
# 701    Healthcare and Health Technology
# 702                Cultural and Tourism
# 711    Healthcare and Health Technology
# 740               E-commerce and Retail
# 798             Technology and Software
# 872             Technology and Software
# 876             Technology and Software
# 889              Education and Learning
# 906             Technology and Software
# 913               E-commerce and Retail
# 980             Technology and Software
# 1034              E-commerce and Retail
# 1108  Technology Solutions for Industry
# 1119             Education and Learning
# 1169             Finance and Technology
# 1179              E-commerce and Retail
# 1181             Finance and Technology
# 1207        Consumer Goods and Services
# 1286    Human Resources and Consultancy
# 1307            Technology and Software
# 1335        Consumer Goods and Services
# 1362        Consumer Goods and Services
# 1378             Education and Learning
# 1463        Consumer Goods and Services
# 1490            Real Estate and Housing
# 1549        Consumer Goods and Services
# 1552             Education and Learning
# 1563         Agriculture and Technology
# 1602            Technology and Software
# 1669         Agriculture and Technology
# 1677            Transport and Logistics
# 1713            Transport and Logistics
# 1739             Finance and Technology
# 1740             Education and Learning
# 1752              E-commerce and Retail
# 1789          Marketing and Advertising
# 1794                         Automotive
# 1799        Consumer Goods and Services
# 1816   Healthcare and Health Technology
# 1824             Education and Learning
# 1843        Consumer Goods and Services
# 1890             Education and Learning
# 1928             Education and Learning
# 2161              E-commerce and Retail
# 2162              E-commerce and Retail
# 2185            Technology and Software
# 2220             Finance and Technology
# 2243   Healthcare and Health Technology
# 2246        Consumer Goods and Services
# 2248    Human Resources and Consultancy
# 2272            Technology and Software
# 2720             Education and Learning
#
#                                            What_it_does  \
# 27    Pristyn Care is Health Care Startup that is di...
# 45    Delivering clean, cost-effective and efficient...
# 125   Postman is the collaboration platform for API ...
# 127   RACEnergy is working to power the future of mo...
# 144   Klub was founded with the vision of revolution...
# 147   Mission to improve people’s lives by improving...
# 168   India's first Startup to use the world's most ...
# 227   A new age health tech company that aims to sim...
# 279                          Baby and mother care brand
# 303                 Mobile App for Patients and Doctors
# 371   DeHaat connects farmers to suppliers and buyer...
# 393   Zupee is a skill-based gaming app that enables...
# 444   A brand which develops products from world-cla...
# 459   Otipy helps the farmer to deliver farm fresh v...
# 538   India's #1 eCommerce Logistics and Shipping So...
# 541   Building India's Largest & Most Trusted Online...
# 575                F5 is a foods and beverages company.
# 601   Juicy Chemistry operates as an eponymous consu...
# 636   Classplus was born out of an urge to redefine ...
# 686   BYJU'S is an educational technology company th...
# 701       OZiva is a plant-based Clean Nutrition Brand.
# 702     B: Live is an electric vehicle tourism startup.
# 711   Juicy Chemistry operates as an eponymous consu...
# 740   Digitizing the Factories of the Unorganised In...
# 798   Myelin Foundry is a deep tech product start-up...
# 872   Building an eco-system for car owners which wi...
# 876   Furniture, appliances, electronics, and fitnes...
# 889   BYJU’S is India's largest ed-tech company and ...
# 906   World’s largest internet restaurant company. B...
# 913         One-Stop Solution for Daily Workplace Needs
# 980   DeHaat™ is one of the fastest growing start-up...
# 1034  Bijnis is revolutionizing the way manufacturer...
# 1108  Intelligent Housekeeping Robots for public and...
# 1119           Vidyakul is a group of academic experts.
# 1169  A team of fintech, investment banking, venture...
# 1179  Shiprocket helps online retailers simplify the...
# 1181  CoinDCX is a company that specializes in crypt...
# 1207  Gamerji is an online esports gaming platform w...
# 1286  InVideo enables you to transform your content ...
# 1307  Fleetx is an intelligent data platform which u...
# 1335  FanPlay Technologies operates as a real-money ...
# 1362  Onsitego is a customer service company for dev...
# 1378  An innovative EdTech startup from IITB & BITS ...
# 1463                             Cloud kitchen platform
# 1490  It offers affordable housing apartments to you...
# 1549                    Live sports engagement platform
# 1552  It provides mobile-first software for coaching...
# 1563  It is a platform that gives agricultural commo...
# 1602                                  Retail Aggregator
# 1669                   Online grocery delivery platform
# 1677  It offers delivery services across India to re...
# 1713  Rivigo is a technology-enabled logistics platf...
# 1739  NIRA promotes financial inclusion by creating ...
# 1740  BYJU'S is an educational technology company th...
# 1752  Xpressbees is an e-commerce logistics company ...
# 1789  Slintel, a leader in capturing technographics-...
# 1794  RACEnergy builds and deploys battery swapping ...
# 1799  Ninjacart is a business-to-business fresh prod...
# 1816  Pristyn Care is Health Care Startup that is di...
# 1824  Classplus offers a mobile-first SaaS platform ...
# 1843  Known for its larger brands – Faasos, Behrouz ...
# 1890                   Provides online learning classes
# 1928                   Provides online learning classes
# 2161  #1 Online Selling App. India’s leading social ...
# 2162  Ninjacart is a B2B agri-marketing platform tha...
# 2185          It is a Virtual Reality Solutions StartUp
# 2220  NIRA promotes financial inclusion by creating ...
# 2243  Mamaearth is an online retailer specializing i...
# 2246  Chaayos was born in November 2012 out of this ...
# 2248      NewsHunt is a Bangalore based eBooks company.
# 2272  Helps online video creators, media companies, ...
# 2720  Techbooze[1] "AN OPEN FORUM" is an educational...
#
#                                                Founders  \
# 27                            Harsimarbir (Harsh) Singh
# 45                                        VIKASH MISHRA
# 125          Abhinav Asthana, Abhijit Kane, Ankit Sobti
# 127                                   Arun Sreyas Reddy
# 144                          Anurakt Jain, Ishita Verma
# 147                     Dilsher Singh, Siddhant Saurabh
# 168                                       Taran Chhabra
# 227   Harsimarbir (Harsh) Singh, Dr Vaibhav Kapoor, ...
# 279                                 Ghazal, Varun Alagh
# 303          Mukesh Bansal, Prasanth Reddy, Sumit Sinha
# 371                        Shashank Kumar, Manish Kumar
# 393               Dilsher Singh Malhi, Siddhant Saurabh
# 444                           Varun Alagh, Ghazal Alagh
# 459                                       Varun Khurana
# 538                         Saahil Goel, Akshay Ghulati
# 541                       Vikas Chandrawat, Karan Shaha
# 575                        Lalit Aggarwal, Raghav Arora
# 601                                Megha, Pritesh Asher
# 636                      Mukul Rustagi, Bhaswat Agarwal
# 686                    Byju Raveendran, Divya Gokulnath
# 701                                 Aarti, Mihir Gadani
# 702                  Samarth Kholkar, Sandeep Mukherjee
# 711                               Megha, Pritesh Asher.
# 740   Chaitanya Rathi, Shubham Agarwal, Siddharth Ra...
# 798   Gopichand Katragadda, Ganesh Suryanarayanan, A...
# 872                                       Amit Lakhotia
# 876                                    Geetansh Bamania
# 889                    Byju Raveendran, Divya Gokulnath
# 906                    Jaydeep Barman, Kallol Banerjee.
# 913                        Raghav Arora, Lalit Aggarwal
# 980   Amrendra Singh, Shyam Sundar, Adarsh Srivastav...
# 1034  Siddharth, Chaitanya Rathi, Siddharth Rastogi,...
# 1108                       Runal Dahiwade, Miraj C Vora
# 1119                        Tarun Saini, Gaurav Singhvi
# 1169                         Anurakt Jain, Ishita Verma
# 1179        Gautam Kapoor, Saahil Goel, Vishesh Khurana
# 1181                     Neeraj Khandelwal, Sumit Gupta
# 1207           Soham Thacker, Valay Patel, Varun Gajjar
# 1286         Harsh Vakharia, Pankit Chheda, Sanket Shah
# 1307  Abhay Jeet Gupta, Parveen Kataria, Udbhav Rai,...
# 1335                        Bharat Gupta, Pritesh Kumar
# 1362                                      Kunal Mahipal
# 1378  Akash Deep Singhal, Akshaya Singhal, Devashish...
# 1463                   Jaydeep Barman, Kallol Bannerjee
# 1490          Akhil Sikri, Nikhil Sikri, Sneha Choudhry
# 1549                             Piyush, Dipesh Agarwal
# 1552                     Mukul Rustagi, Bhaswat Agarwal
# 1563  Nukul Upadhye, Mahesh Jakhotia, Jitender Bedwa...
# 1602                 Raghav Arora, Lalit Kumar Aggarwal
# 1669  Thirukumaran Nagarajan, Sharath Loganathan, Sa...
# 1677                           Deepak Garg, Gazal Kalra
# 1713                           Deepak Garg, Gazal Kalra
# 1739                             Rohit Sen, Nupur Gupta
# 1740                   Byju Raveendran, Divya Gokulnath
# 1752                     Amitava Saha, Supam Maheshwari
# 1789     Deepak Anchala, Rahul Bhattacharya, Ranjana TN
# 1794                    Arun Sreyas, Gautham Maheswaran
# 1799  Ashutosh Vikram, Kartheeswaran K K, Sharath Lo...
# 1816                          Harsimarbir (Harsh) Singh
# 1824  Bhaswat Agarwal, Bikash Dash, Mukul Rustagi, V...
# 1843                    Jaydeep Barman, Kallol Banerjee
# 1890                                    Byju Raveendran
# 1928                                    Byju Raveendran
# 2161                                         Not filled
# 2162                                         Not filled
# 2185                                         Not filled
# 2220                                         Not filled
# 2243                                         Not filled
# 2246                                         Not filled
# 2248                                         Not filled
# 2272      Vinayak Srivastav, Saket Dandotia, Alok Patil
# 2720                                         Not filled
#
#                                                Investor        Amount  \
# 27          Sequoia Capital India, Hummingbird Ventures  5.300000e+07
# 45                                           Not filled  1.000000e+06
# 125                         CRV, Nexus Venture Partners  2.250000e+08
# 127                        Micelio Fund, growX ventures  1.300000e+06
# 144            9Unicorns, Sequoia Capital India’s Surge  2.000000e+07
# 147                  WestCap Group, Tomales Bay Capital  3.000000e+07
# 168                                Sixth Sense Ventures  2.000000e+06
# 227     Kunal Shah, Deepinder Goyal, Abhiraj Singh Bhal  9.600000e+07
# 279                                             Sequoia  3.700000e+07
# 303                       Fresco Capital, Social Starts  1.200000e+07
# 371                         Prosus Ventures, RTP Global  3.000000e+07
# 393       Orios Venture Partners, Matrix Partners India  1.000000e+07
# 444                                  Sofina Ventures SA  5.000000e+07
# 459              Omidyar Network India, Innoven Capital  1.020000e+07
# 538                        March Capital, Tribe Capital  4.100000e+07
# 541                                          RTP Global  5.000000e+06
# 575                     Venture Catalysts, Jeevak Gupta  3.000000e+05
# 601                            Spring Marketing Capital  2.777607e+07
# 636                                        Tiger Global  6.500000e+07
# 686                             BlackRock, Owl Ventures  4.600000e+08
# 701         F-Prime Capital, Eight Roads Ventures India  1.200000e+07
# 702           Mumbai Angels, DNA Entertainment Networks  1.000000e+06
# 711                                       Akya Ventures  6.300000e+06
# 740        Sequoia Capital India, Matrix Partners India  2.777607e+07
# 798                                Beyond Next Ventures  1.000000e+06
# 872                    Sequoia Capital, Matrix Partners  2.500000e+07
# 876                                 Accel, Bain Capital  1.000000e+07
# 889    Oxshott Capital Partners, XN Exponent, Edelweiss  3.000000e+08
# 906                          Qatar Investment Authority  1.750000e+08
# 913                                      Auxano Capital  6.000000e+05
# 980                    Sofina, Lightrock India, Temasek  1.150000e+08
# 1034                                 Westbridge Capital  3.000000e+07
# 1108            Venture Catalysts, Indian Angel Network  6.000000e+05
# 1119                                  We Founder Circle  5.000000e+05
# 1169                                   Trifecta Capital  2.000000e+06
# 1179     Bertelsmann India Investments, InnoVen Capital  7.500000e+06
# 1181                       Coinbase Ventures, Polychain  1.000000e+07
# 1207                                   La Gajjar Group.  2.125835e+07
# 1286               Base Partners, Sequoia Capital India  1.500000e+07
# 1307                        Rohit Bansal, Rohan Ranavat  3.000000e+06
# 1335                         Core91 Fund, Anupam Mittal  2.125835e+07
# 1362                              Accel, Zodius Capital  3.000000e+07
# 1378               23 High Networth Individuals (HNIs).  1.000000e+05
# 1463                                  Coatue Management  2.650000e+07
# 1490  Investcorp, Nexus Venture Partners, Mirae Asse...  5.600000e+07
# 1549  Paytm, leAD Sports, Rockstud Capital, Founder ...  1.700000e+06
# 1552                                         RTP Global  8.200000e+06
# 1563                                         RTP Global  1.200000e+07
# 1602                              LetsVenture investors  2.125835e+07
# 1669               Flipkart India, Singapore-based GEC3  1.000000e+07
# 1677                                   Trifecta Capital  3.400000e+06
# 1713       Elevation Capital, Trifecta Capital Advisors  1.900000e+07
# 1739         Techstars Bangalore Accelerator, Techstars  1.000000e+06
# 1740              Owl Ventures, Tiger Global Management  2.000000e+08
# 1752                     Alibaba Group, InnoVen Capital  1.000000e+08
# 1789                  Accel, Stellaris Venture Partners  4.200000e+06
# 1794                 growX Ventures, Huddle (Incubator)  2.125835e+07
# 1799                         Syngenta Ventures, Walmart  3.000000e+07
# 1816        Sequoia Capital India, Hummingbird Ventures  1.100000e+07
# 1824                             Spiral Ventures, Surge  1.000000e+07
# 1843                                  Coatue Management  5.000000e+07
# 1890                                         DST Global  1.220000e+08
# 1928                                               BOND  2.125835e+07
# 2161                                         Not filled  1.100000e+07
# 2162                                         Not filled  3.654971e+07
# 2185                                         Not filled  1.450000e+06
# 2220                                         Not filled  1.000000e+06
# 2243                                         Not filled  4.000000e+06
# 2246                                         Not filled  1.184210e+07
# 2248                                         Not filled  6.000000e+06
# 2272  Chinaccelerator, 9 Unicorns Fund, Inflection P...  1.000000e+06
# 2720                                         Not filled  1.000000e+05
#
#                Stage  Funding_Year Company_Brand_lower
# 27           Scaling          2021        pristyn care
# 45        Validation          2021             moeving
# 125          Scaling          2021             postman
# 127       Validation          2021           racenergy
# 144           Equity          2021                klub
# 147           Equity          2021               zupee
# 168   Early Traction          2021              neeman
# 227          Scaling          2021        pristyn care
# 279           Equity          2021           mamaearth
# 303   Early Traction          2021              phable
# 371          Scaling          2021              dehaat
# 393           Equity          2021               zupee
# 444           Equity          2021           mamaearth
# 459   Early Traction          2021               otipy
# 538          Scaling          2021          shiprocket
# 541       Validation          2021               vahak
# 575       Validation          2021                  f5
# 601          Scaling          2021     juicy chemistry
# 636          Scaling          2021           classplus
# 686          Scaling          2021              byju's
# 701          Scaling          2021               oziva
# 702       Validation          2021               blive
# 711   Early Traction          2021     juicy chemistry
# 740          Scaling          2021              bijnis
# 798       Validation          2021      myelin foundry
# 872          Scaling          2021               park+
# 876           Equity          2021           rentomojo
# 889          Scaling          2021              byju's
# 906          Scaling          2021         rebel foods
# 913       Validation          2021                  f5
# 980          Scaling          2021              dehaat
# 1034         Scaling          2021              bijnis
# 1108            Debt          2021          peppermint
# 1119          Bridge          2021            vidyakul
# 1169            Debt          2021                klub
# 1179         Scaling          2020          shiprocket
# 1181         Scaling          2020             coindcx
# 1207      Validation          2020             gamerji
# 1286  Early Traction          2020             invideo
# 1307  Early Traction          2020              fleetx
# 1335      Validation          2020             fanplay
# 1362         Scaling          2020            onsitego
# 1378      Validation          2020            illumnus
# 1463         Scaling          2020         rebel foods
# 1490         Scaling          2020           zolostays
# 1549      Validation          2020              rooter
# 1552         Scaling          2020           classplus
# 1563  Early Traction          2020               bijak
# 1602      Validation          2020                  f5
# 1669         Scaling          2020           ninjacart
# 1677         Scaling          2020              rivigo
# 1713         Scaling          2020              rivigo
# 1739            Debt          2020                nira
# 1740         Scaling          2020              byju's
# 1752         Scaling          2020          xpressbees
# 1789            Debt          2020             slintel
# 1794         Scaling          2020           racenergy
# 1799         Scaling          2020           ninjacart
# 1816         Scaling          2020        pristyn care
# 1824         Scaling          2020           classplus
# 1843         Scaling          2020         rebel foods
# 1890         Scaling          2020              byju's
# 1928         Scaling          2020              byju's
# 2161         Scaling          2018             shop101
# 2162         Scaling          2018           ninjacart
# 2185      Validation          2018           smartvizx
# 2220      Validation          2018                nira
# 2243  Early Traction          2018           mamaearth
# 2246         Scaling          2018             chaayos
# 2248         Scaling          2018           dailyhunt
# 2272      Validation          2020                toch
# 2720      Validation          2018           techbooze

# %%
# Get unique company brands (in lowercase) from the filtered DataFrame where 'HeadQuarter' is not 'Not filled'
unique1_companies_without_llp1 = filter2_companies_llp1['Company_Brand_lower'].unique()

# Store the unique company brands in a list named 'target1llp1'
target1llp1 = list(unique1_companies_without_llp1)

# Filter the original DataFrame to include only rows where 'Company_Brand_lower' is in the target list
target1_brands_dfllp1 = cl_lp1df[cl_lp1df['Company_Brand_lower'].isin(target1llp1)]

# target1_brands_dfllp1

# Iterate through each company brand in the target1llp1 list
for brand in target1llp1:
    # Get the 'HeadQuarter' value for this brand from the filtered DataFrame, excluding entries where 'HeadQuarter' is 'Not filled'
    location_value = target1_brands_dfllp1.loc[
        (target1_brands_dfllp1['Company_Brand_lower'] == brand) & 
        (target1_brands_dfllp1['HeadQuarter'] != 'Not filled'), 
        'HeadQuarter'
    ].values[0]
    
    # Fill 'HeadQuarter' values that are 'Not filled' in the original DataFrame with the identified valid value for this brand
    cl_lp1df.loc[
        (cl_lp1df['Company_Brand_lower'] == brand) & 
        (cl_lp1df['HeadQuarter'] == 'Not filled'), 
        'HeadQuarter'
    ] = location_value

companies2_without_llp1 = cl_lp1df[cl_lp1df['HeadQuarter'].isin(['Not filled'])]

# Display results
print("Number of 'Not filled' entries in 'HeadQuarter' column before replacement with valid cities:")
print(len(companies1_without_llp1))
print("\nNumber of 'Not filled' entries in 'HeadQuarter' column after replacement with valid cities:")
print(len(companies2_without_llp1))
print()

# Display information about the updated DataFrame
cl_lp1df.info()
# Out:
# Number of 'Not filled' entries in 'HeadQuarter' column before replacement with valid cities:
# 125
#
# Number of 'Not filled' entries in 'HeadQuarter' column after replacement with valid cities:
# 75
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2822 entries, 0 to 2821
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Company_Brand        2822 non-null   object
#  1   Founded              2250 non-null   Int64
#  2   HeadQuarter          2822 non-null   category
#  3   Sector               2822 non-null   category
#  4   What_it_does         2822 non-null   object
#  5   Founders             2822 non-null   category
#  6   Investor             2822 non-null   category
#  7   Amount               2822 non-null   float64
#  8   Stage                2822 non-null   category
#  9   Funding_Year         2822 non-null   int64
#  10  Company_Brand_lower  2822 non-null   object
# dtypes: Int64(1), category(5), float64(1), int64(1), object(3)
# memory usage: 318.6+ KB

# %% [markdown]
# **Standardising Unique Values per Company Brand in 'HeadQuarter'**

# %%
# Group by 'Company_Brand_lower' and filter groups with more than one unique 'HeadQuarter'
duplicate1_brands_llp1 = cl_lp1df.groupby('Company_Brand_lower').filter(lambda x: x['HeadQuarter'].nunique() > 1)

# Display results
print("Number of Companies with more than one unique 'HeadQuarter':")
print(len(duplicate1_brands_llp1))
# Out:
# Number of Companies with more than one unique 'HeadQuarter':
# 339

# %% [markdown]
# `Comment`
#
# Although 339 companies have multiple headquarter locations, the 'HeadQuarter' column will not be standardized based on unique values. This decision accounts for the possibility that a company may have relocated its headquarters multiple times during the four-year period encompassed by this dataset.

# %% [markdown]
# ##### Pruning 'Sector' Column

# %% [markdown]
# **Filling Invalid Values in 'Sector' Column**

# %%
# Filter rows where the 'Sector' column has the value 'Not filled'
companies1_without_slp1 = cl_lp1df[cl_lp1df['Sector'] == 'Not filled']

# Get unique company brands (in lowercase) from the rows where 'Sector' is 'Not filled'
unique1_companies_without_slp1 = companies1_without_slp1['Company_Brand_lower'].unique()

# Filter the original DataFrame to include only rows with these unique company brands (in lowercase)
filter1_companies_slp1 = cl_lp1df[cl_lp1df['Company_Brand_lower'].isin(unique1_companies_without_slp1)]

# Further filter the subset to include only rows where 'Sector' is not 'Not filled'
filter2_companies_slp1 = filter1_companies_slp1[~filter1_companies_slp1['Sector'].isin(['Not filled'])]

# Display the resulting DataFrame
filter2_companies_slp1
# Out:
#                  Company_Brand  Founded HeadQuarter  \
# 57                        CRED     2018   Bangalore
# 121                 DrinkPrime     2016   Bangalore
# 398                       Cred     2018   Bangalore
# 493                      Trell     2016   Bangalore
# 584            Cell Propulsion     2016   Bangalore
# 601            Juicy chemistry     2014  Coimbatore
# 711            Juicy Chemistry     2014  Coimbatore
# 944                       CRED     2018   Bangalore
# 963                      Trell     2016   Bangalore
# 1151                     Origo     2010    Gurugram
# 1215                      CRED     2018   Bangalore
# 1245           Kitchens Centre     2019   New Delhi
# 1282                     Origo     2010    Gurugram
# 1364                   Servify     2015      Mumbai
# 1387                   Servify     2015      Mumbai
# 1410           Cell Propulsion     2017   Bangalore
# 1431                Brick&Bolt     2018   Bangalore
# 1441                     Trell     2016   Bangalore
# 1462                DrinkPrime     2016   Bangalore
# 1513                   Servify     2015      Mumbai
# 1514                  Innoviti     2002   Bangalore
# 1606                     Trell     2016   Bangalore
# 1696         Awign Enterprises     2016   Bangalore
# 1761  Steradian Semiconductors     2016   Bangalore
# 1908                 Leap Club     2020    Gurugram
# 2099                     Trell     2016   Bangalore
# 2110                     Origo     2010    Gurugram
# 2176         Awign Enterprises     2016   Bangalore
# 2207                  Magicpin     2015     Gurgaon
#
#                                  Sector  \
# 57               Finance and Technology
# 121         Consumer Goods and Services
# 398              Finance and Technology
# 493               E-commerce and Retail
# 584              Energy and Environment
# 601    Healthcare and Health Technology
# 711    Healthcare and Health Technology
# 944              Finance and Technology
# 963               E-commerce and Retail
# 1151         Agriculture and Technology
# 1215             Finance and Technology
# 1245            Technology and Software
# 1282         Agriculture and Technology
# 1364            Technology and Software
# 1387  Technology Solutions for Industry
# 1410                         Automotive
# 1431     Construction and Home Services
# 1441              E-commerce and Retail
# 1462             Energy and Environment
# 1513            Technology and Software
# 1514            Technology and Software
# 1606              E-commerce and Retail
# 1696    Human Resources and Consultancy
# 1761            Technology and Software
# 1908              E-commerce and Retail
# 2099            Media and Entertainment
# 2110         Agriculture and Technology
# 2176              E-commerce and Retail
# 2207              E-commerce and Retail
#
#                                            What_it_does  \
# 57    CRED is a members-only credit card management ...
# 121   India's Smartest Water Purifiers and are redef...
# 398   CRED is a Bengaluru-based fintech startup that...
# 493   India's Largest Lifestyle Social Commerce plat...
# 584   Cell Propulsion is a fleet electrification com...
# 601   Juicy Chemistry operates as an eponymous consu...
# 711   Juicy Chemistry operates as an eponymous consu...
# 944   CRED is a credit card payment platform that re...
# 963   Trell is turning over a new leaf with the wave...
# 1151  Origo Commodities, a complete post-harvest man...
# 1215  CRED is a members-only app that rewards the us...
# 1245  Kitchens Centre offers turnkey solutions to cl...
# 1282  Provider of marketing and warehousing services...
# 1364  Servify is a self-learning platform that provi...
# 1387  Enables top OEMs & ODMs in device distribution...
# 1410  Designs and develops electric power drives and...
# 1431  A construction company doing house constructio...
# 1441     Allows users to share their travel experiences
# 1462          Subscription-based Water purifier startup
# 1513    Operates device management and support platform
# 1514                 Digital payments solutions company
# 1606     Allows users to share their travel experiences
# 1696        Operations and manpower outsourcing startup
# 1761  Semiconductor company focused on CMOS millimet...
# 1908       Community led professional network for women
# 2099  Blogging platform that enables people to creat...
# 2110  It provides post-harvest management services f...
# 2176        Operations and manpower outsourcing startup
# 2207  Magicpin is a platform where users and merchan...
#
#                                                Founders  \
# 57                                           Kunal Shah
# 121                                       Anil Kejriwal
# 398                                          Kunal Shah
# 493   Pulkit Agarwal, Prashant Sachan, Arun Lodhi, B...
# 584                          Nakul Kukar, Paras Kaushal
# 601                                Megha, Pritesh Asher
# 711                               Megha, Pritesh Asher.
# 944                                          Kunal Shah
# 963    Pulkit Agrawal, Arun Lodhi, Bimal Kartheek Rebba
# 1151                        Sunoor Kaul, Mayank Dhanuka
# 1215                                         Kunal Shah
# 1245                                       Lakshay Jain
# 1282                                       Sunoor Kaul,
# 1364                               Sreevathsa Prabhakar
# 1387                               Sreevathsa Prabhakar
# 1410        Nakul Kukar, Paras Kaushal, Supratim Naskar
# 1431                Arpit Rajpurohit, Jayesh Rajpurohit
# 1441  Pulkit Agrawal, Prashant Sachan, Arun Lodhi, B...
# 1462                 Viijender Reddy, Manas Ranjan Hota
# 1513                               Sreevathsa Prabhakar
# 1514                                     Rajeev Agrawal
# 1606  Pulkit Agrawal, Prashant Sachan, Arun Lodhi, B...
# 1696       Annanya Sarthak, Gurpreet Singh, Praveen Sah
# 1761  Gireesh Rajendran, Ashish Lachhwani, Apu Sivad...
# 1908                            Ragini Das, Anand Sinha
# 2099  Pulkit Agrawal, Prashant Sachan, Arun Lodhi, B...
# 2110                        Mayank Dhanuka, Sunoor Kaul
# 2176                                         Not filled
# 2207                                         Not filled
#
#                                                Investor        Amount  \
# 57    Dragoneer Investment Group, Tiger Global Manag...  2.150000e+08
# 121                UC Inclusive Credit, Western Capital  1.000000e+06
# 398                        DST Global, General Catalyst  8.100000e+07
# 493                                    Mirae Asset, H&M  4.500000e+07
# 584                                      growX ventures  2.000000e+06
# 601                            Spring Marketing Capital  2.777607e+07
# 711                                       Akya Ventures  6.300000e+06
# 944                           Tiger Global, Falcon Edge  2.500000e+08
# 963                                              Amazon  1.000000e+08
# 1151                                           YES Bank  1.000000e+07
# 1215                   General Catalyst, Ribbit Capital  8.000000e+07
# 1245                      Jonathan Swanson, Ankush Gera  2.125835e+07
# 1282                               Northern Arc Capital  4.000000e+06
# 1364                             Blume Ventures, Tetrao  2.300000e+07
# 1387                             Blume Ventures, Tetrao  1.137000e+07
# 1410                    growX ventures, Sangam Ventures  2.125835e+07
# 1431                      Meghna Agarwal, Navin Dhanuka  2.200000e+06
# 1441  KTB Network, Samsung Ventures, Ankur Nagpal, G...  1.100000e+07
# 1462                                      Sequoia Surge  2.879000e+06
# 1513                        Iron Pillar, Blume Ventures  1.137000e+07
# 1514  Entrepreneurial Development Bank, Bessemer Ven...  2.125835e+07
# 1606                          Sequoia’s Surge, Fosun RZ  4.000000e+06
# 1696                           Unitus Ventures, Work10M  5.000000e+05
# 1761                                   Endiya Partners.  2.125835e+07
# 1908                                      Titan Capital  2.125835e+07
# 2099  Ruizheng Investment, Tej Kapoor, Krinshavatara...  2.000000e+06
# 2110  Oikocredit, Caspian SME Impact Fund IV,  Triod...  6.800000e+06
# 2176                                         Not filled  7.309940e+05
# 2207                                         Not filled  2.061404e+07
#
#                Stage  Funding_Year       Company_Brand_lower
# 57           Scaling          2021                      cred
# 121             Debt          2021                drinkprime
# 398          Scaling          2021                      cred
# 493          Scaling          2021                     trell
# 584             Debt          2021           cell propulsion
# 601          Scaling          2021           juicy chemistry
# 711   Early Traction          2021           juicy chemistry
# 944          Scaling          2021                      cred
# 963           Equity          2021                     trell
# 1151            Debt          2021                     origo
# 1215         Scaling          2020                      cred
# 1245      Validation          2020           kitchens centre
# 1282            Debt          2020                     origo
# 1364         Scaling          2020                   servify
# 1387         Scaling          2020                   servify
# 1410      Validation          2020           cell propulsion
# 1431  Early Traction          2020                brick&bolt
# 1441  Early Traction          2020                     trell
# 1462      Validation          2020                drinkprime
# 1513         Scaling          2020                   servify
# 1514         Scaling          2020                  innoviti
# 1606      Validation          2020                     trell
# 1696          Bridge          2020         awign enterprises
# 1761         Scaling          2020  steradian semiconductors
# 1908         Scaling          2020                 leap club
# 2099      Validation          2019                     trell
# 2110         Scaling          2019                     origo
# 2176      Validation          2018         awign enterprises
# 2207         Scaling          2018                  magicpin

# %%
# Get unique company brands (in lowercase) from the filtered DataFrame where 'Sector' is not 'Not filled'
unique1_companies_without_slp1 = filter2_companies_slp1['Company_Brand_lower'].unique()

# Store the unique company brands in a list named 'target1slp1'
target1slp1 = list(unique1_companies_without_slp1)

# Filter the original DataFrame to include only rows where 'Company_Brand_lower' is in the target list
target1_brands_dfslp1 = cl_lp1df[cl_lp1df['Company_Brand_lower'].isin(target1slp1)]

# Iterate through each company brand in the target1slp1 list
for brand in target1slp1:
    # Get the 'Sector' value for this brand from the filtered DataFrame, excluding entries where 'Sector' is 'Not filled'
    location_value = target1_brands_dfslp1.loc[
        (target1_brands_dfslp1['Company_Brand_lower'] == brand) & 
        (target1_brands_dfslp1['Sector'] != 'Not filled'), 
        'Sector'
    ].values[0]
    
    # Fill 'Sector' values that are 'Not filled' in the original DataFrame with the identified valid value for this brand
    cl_lp1df.loc[
        (cl_lp1df['Company_Brand_lower'] == brand) & 
        (cl_lp1df['Sector'] == 'Not filled'), 
        'Sector'
    ] = location_value

companies2_without_slp1 = cl_lp1df[cl_lp1df['Sector'].isin(['Not filled'])]

# Display results
print("Number of 'Not filled' entries in 'Sector' column before replacement with valid sectors:")
print(len(companies1_without_slp1))
print("\nNumber of 'Not filled' entries in 'Sector' column after replacement with valid sectors:")
print(len(companies2_without_slp1))
print()

# Display information about the updated DataFrame
cl_lp1df.info()
# Out:
# Number of 'Not filled' entries in 'Sector' column before replacement with valid sectors:
# 50
#
# Number of 'Not filled' entries in 'Sector' column after replacement with valid sectors:
# 35
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2822 entries, 0 to 2821
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Company_Brand        2822 non-null   object
#  1   Founded              2250 non-null   Int64
#  2   HeadQuarter          2822 non-null   category
#  3   Sector               2822 non-null   category
#  4   What_it_does         2822 non-null   object
#  5   Founders             2822 non-null   category
#  6   Investor             2822 non-null   category
#  7   Amount               2822 non-null   float64
#  8   Stage                2822 non-null   category
#  9   Funding_Year         2822 non-null   int64
#  10  Company_Brand_lower  2822 non-null   object
# dtypes: Int64(1), category(5), float64(1), int64(1), object(3)
# memory usage: 318.6+ KB

# %% [markdown]
# **Standardising unique values per company brand in 'sector'**

# %%
# Group by 'Company_Brand_lower' and filter groups with more than one unique 'Sector'
duplicate1_brands_slp1 = cl_lp1df.groupby('Company_Brand_lower').filter(lambda x: x['Sector'].nunique() > 1)

# Function to replace sectors with the first unique sector within each group
def replace_sectors_grp(group):
    first_unique_sector = group['Sector'].iloc[0]  # Get the first unique sector
    group['Sector'] = first_unique_sector  # Replace all sectors in the group with the first unique sector
    return group  

# Apply the function to each group by 'Company_Brand_lower'
cl_lp1df = cl_lp1df.groupby('Company_Brand_lower').apply(replace_sectors_grp).reset_index(drop=True)

# Group by 'Company_Brand_lower' again and filter groups with more than one unique 'Sector' after standardisation
duplicate_brands_slp2 = cl_lp1df.groupby('Company_Brand_lower').filter(lambda x: x['Sector'].nunique() > 1)

# Display results
print("Number of Companies with more than one unique 'Sector' before standardising:")
print(len(duplicate1_brands_slp1))
print("\nNumber of Companies with more than one unique 'Sector' after standardising:")
print(len(duplicate_brands_slp2))
print()

# Display information about the updated DataFrame
cl_lp1df.info()
# Out:
# Number of Companies with more than one unique 'Sector' before standardising:
# 442
#
# Number of Companies with more than one unique 'Sector' after standardising:
# 0
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2822 entries, 0 to 2821
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Company_Brand        2822 non-null   object
#  1   Founded              2250 non-null   Int64
#  2   HeadQuarter          2822 non-null   category
#  3   Sector               2822 non-null   object
#  4   What_it_does         2822 non-null   object
#  5   Founders             2822 non-null   category
#  6   Investor             2822 non-null   category
#  7   Amount               2822 non-null   float64
#  8   Stage                2822 non-null   category
#  9   Funding_Year         2822 non-null   int64
#  10  Company_Brand_lower  2822 non-null   object
# dtypes: Int64(1), category(4), float64(1), int64(1), object(4)
# memory usage: 337.2+ KB

# %% [markdown]
# ##### Pruning 'Founders' Column

# %% [markdown]
# **Filling Invalid Values in 'Founders' Column**

# %%
# Filter rows where the 'Founders' column has the value 'Not filled'
companies1_without_fslp1 = cl_lp1df[cl_lp1df['Founders'].isin(['Not filled'])]

# Get unique company brands (in lowercase) from the rows where 'Founders' is 'Not filled'
unique1_companies_without_fslp1 = companies1_without_fslp1['Company_Brand_lower'].unique()

# Filter the original DataFrame to include only rows with these unique company brands (in lowercase)
filter1_companies_fslp1 = cl_lp1df[cl_lp1df['Company_Brand_lower'].isin(unique1_companies_without_fslp1)]

# Further filter the subset to include only rows where 'Founders' is not 'Not filled'
filter2_companies_fslp1 = filter1_companies_fslp1[~filter1_companies_fslp1['Founders'].isin(['Not filled'])]

# Display the resulting DataFrame
filter2_companies_fslp1
# Out:
#           Company_Brand  Founded HeadQuarter                       Sector  \
# 11              6Degree     2014      Mumbai        E-commerce and Retail
# 12              6Degree     2014      Mumbai        E-commerce and Retail
# 133   Asteria Aerospace     2011   Bangalore      Technology and Software
# 147       Avail Finance     2017   Bangalore       Finance and Technology
# 148       Avail Finance     2017   Bangalore       Finance and Technology
# ...                 ...      ...         ...                          ...
# 2801             Zomato     2008     Gurgaon  Consumer Goods and Services
# 2802             Zomato     2008    Gurugram  Consumer Goods and Services
# 2803             Zomato     2008    Gurugram  Consumer Goods and Services
# 2804             Zomato     2008    Gurugram  Consumer Goods and Services
# 2813            ZunRoof     2016    Gurugram       Energy and Environment
#
#                                            What_it_does  \
# 11    6Degree is a fashion retail startup that provi...
# 12            India's leading fashion business platform
# 133   Develops drones that are used by the military,...
# 147   Avail is a mobile-first platform aiming to fin...
# 148                             Instant online loan app
# ...                                                 ...
# 2801  Zomato is a food delivery and restaurant disco...
# 2802  Zomato is a food delivery and restaurant disco...
# 2803  Online food delivery and restaurant discovery ...
# 2804  Online food delivery and restaurant discovery ...
# 2813  It specialises in solar rooftop design, instal...
#
#                                            Founders  \
# 11                      Amit Bhardwaj, Nikhil Hegde
# 12                     Amit Bhardwaj, Nikhil Hegde.
# 133                        Neel Mehta, Nihar Vartak
# 147             Ankush Aggarwal, Tushar Mehndiratta
# 148             Ankush Aggarwal, Tushar Mehndiratta
# ...                                             ...
# 2801  Deepinder Goyal, Gaurav Gupta, Pankaj Chaddah
# 2802  Deepinder Goyal, Gaurav Gupta, Pankaj Chaddah
# 2803                                Deepinder Goyal
# 2804                                Deepinder Goyal
# 2813              Pranesh Chaudhary, Sushant Sachan
#
#                                       Investor       Amount           Stage  \
# 11    Keiretsu Forum, SucSEED Venture Partners    1000000.0            Debt
# 12    Keiretsu Forum, SucSEED Venture Partners     340000.0          Bridge
# 133                        Reliance Industries  230000000.0         Scaling
# 147     Alteria Capital, Matrix Partners India    3000000.0            Debt
# 148                 Alphawave, Matrix Partners   11635000.0         Scaling
# ...                                        ...          ...             ...
# 2801             Kora, Tiger Global Management  660000000.0         Scaling
# 2802             Kora, Tiger Global Management   52000000.0         Scaling
# 2803                           Pacific Horizon    5000000.0            Debt
# 2804                             Ant Financial  150000000.0         Scaling
# 2813                        Godrej Investments    3000000.0  Early Traction
#
#       Funding_Year Company_Brand_lower
# 11            2021             6degree
# 12            2020             6degree
# 133           2019   asteria aerospace
# 147           2021       avail finance
# 148           2020       avail finance
# ...            ...                 ...
# 2801          2020              zomato
# 2802          2020              zomato
# 2803          2020              zomato
# 2804          2020              zomato
# 2813          2020             zunroof
#
# [218 rows x 11 columns]

# %%
# Get unique company brands (in lowercase) from the filtered DataFrame where 'Founders' is not 'Not filled'
unique1_companies_without_fslp1 = filter2_companies_fslp1['Company_Brand_lower'].unique()

# Store the unique company brands in a list named 'target1fslp1'
target1fslp1 = list(unique1_companies_without_fslp1)

# Filter the original DataFrame to include only rows where 'Company_Brand_lower' is in the target list
target1_brands_dffslp1 = cl_lp1df[cl_lp1df['Company_Brand_lower'].isin(target1fslp1)]

# Iterate through each company brand in the target1fslp1 list
for brand in target1fslp1:
    # Get the 'Founders' value for this brand from the filtered DataFrame, excluding entries where 'Founders' is 'Not filled'
    location_value = target1_brands_dffslp1.loc[
        (target1_brands_dffslp1['Company_Brand_lower'] == brand) & 
        (target1_brands_dffslp1['Founders'] != 'Not filled'), 
        'Founders'
    ].values[0]
    
    # Fill 'Sector' values that are 'Not filled' in the original DataFrame with the identified valid value for this brand
    cl_lp1df.loc[
        (cl_lp1df['Company_Brand_lower'] == brand) & 
        (cl_lp1df['Founders'] == 'Not filled'), 
        'Founders'
    ] = location_value

companies2_without_fslp1 = cl_lp1df[cl_lp1df['Founders'].isin(['Not filled'])]

# Display results
print("Number of 'Not filled' entries in 'Founders' column before replacement with valid founders:")
print(len(companies1_without_fslp1))
print("\nNumber of 'Not filled' entries in 'Founders' column after replacement with valid founders:")
print(len(companies2_without_fslp1))
print()

# Display information about the updated DataFrame
cl_lp1df.info()
# Out:
# Number of 'Not filled' entries in 'Founders' column before replacement with valid founders:
# 544
#
# Number of 'Not filled' entries in 'Founders' column after replacement with valid founders:
# 422
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2822 entries, 0 to 2821
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Company_Brand        2822 non-null   object
#  1   Founded              2250 non-null   Int64
#  2   HeadQuarter          2822 non-null   category
#  3   Sector               2822 non-null   object
#  4   What_it_does         2822 non-null   object
#  5   Founders             2822 non-null   category
#  6   Investor             2822 non-null   category
#  7   Amount               2822 non-null   float64
#  8   Stage                2822 non-null   category
#  9   Funding_Year         2822 non-null   int64
#  10  Company_Brand_lower  2822 non-null   object
# dtypes: Int64(1), category(4), float64(1), int64(1), object(4)
# memory usage: 337.2+ KB

# %% [markdown]
# **Standardising unique values per company brand in 'founders'**

# %%
# Group by 'Company_Brand_lower' and filter groups with more than one unique 'Sector'
duplicate1_brands_fslp1 = cl_lp1df.groupby('Company_Brand_lower').filter(lambda x: x['Founders'].nunique() > 1)

# Function to replace sectors with the first unique sector within each group
def replace_founders_grp(group):
    first_unique_founders = group['Founders'].iloc[0]  # Get the first unique sector
    group['Founders'] = first_unique_founders  # Replace all sectors in the group with the first unique sector
    return group  

# Apply the function to each group by 'Company_Brand_lower'
cl_lp1df = cl_lp1df.groupby('Company_Brand_lower').apply(replace_founders_grp).reset_index(drop=True)

# Group by 'Company_Brand_lower' again and filter groups with more than one unique 'Sector' after standardisation
duplicate1_brands_fslp2 = cl_lp1df.groupby('Company_Brand_lower').filter(lambda x: x['Founders'].nunique() > 1)

# Convert 'Founders' column to category data type
cl_lp1df['Founders'] = cl_lp1df['Founders'].astype('category')

# Display results
print("Number of Companies with more than one unique 'Founders' before standardising:")
print(len(duplicate1_brands_fslp1))
print("\nNumber of Companies with more than one unique 'Founders' after standardising:")
print(len(duplicate1_brands_fslp2))
print()

# Display information about the updated DataFrame
cl_lp1df.info()
# Out:
# Number of Companies with more than one unique 'Founders' before standardising:
# 688
#
# Number of Companies with more than one unique 'Founders' after standardising:
# 0
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2822 entries, 0 to 2821
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Company_Brand        2822 non-null   object
#  1   Founded              2250 non-null   Int64
#  2   HeadQuarter          2822 non-null   category
#  3   Sector               2822 non-null   object
#  4   What_it_does         2822 non-null   object
#  5   Founders             2822 non-null   category
#  6   Investor             2822 non-null   category
#  7   Amount               2822 non-null   float64
#  8   Stage                2822 non-null   category
#  9   Funding_Year         2822 non-null   int64
#  10  Company_Brand_lower  2822 non-null   object
# dtypes: Int64(1), category(4), float64(1), int64(1), object(4)
# memory usage: 334.9+ KB

# %% [markdown]
# ##### Dropping Invalid Entries

# %% [markdown]
# **Check the percentage of companies headquartered outside India**

# %%
# Ensure city names are compared correctly by stripping and converting to lower case
indian_cities_normalized = [city.lower().strip() for city in indian_cities]

# Filter the rows where the headquarters is not in the list of Indian cities
outside1_llp1 = cl_lp1df[~cl_lp1df['HeadQuarter'].str.lower().str.strip().isin(indian_cities_normalized)]

# List unique cities outside India
cities1_outside_llp1 = outside1_llp1['HeadQuarter'].unique()

# Calculate the percentage of data with headquarters outside India
percentage1_outside_llp1 = (len(outside1_llp1) / len(cl_lp1df)) * 100

# Return the results
percentage1_outside_llp1, cities1_outside_llp1
# Out:
# (3.933380581148122,
#  ['Not filled', 'Paris', 'San Francisco', 'New York', 'Sydney', ..., 'Frisco', 'Plano', 'Tangerang', 'Shanghai', 'Seattle']
#  Length: 21
#  Categories (109, object): ['Ahmedabad', 'Alleppey', 'Alwar', 'Ambernath', ..., 'Vadodara', 'Warangal', 'West Bengal', 'Worli'])

# %% [markdown]
# **Drop only companies headquartered outside India**

# %%
# Drop the rows where the headquarters is outside India
cl_lp1df.drop(outside1_llp1.index, inplace=True)

# Filter the rows where the headquarters is not in the list of Indian cities
outside2_llp1 = cl_lp1df[~cl_lp1df['HeadQuarter'].str.lower().str.strip().isin(indian_cities_normalized)]

# List unique cities outside India
cities2_outside_llp1 = outside2_llp1['HeadQuarter'].unique()

# Calculate the percentage of data with headquarters outside India
percentage2_outside_llp1 = (len(outside2_llp1) / len(cl_lp1df)) * 100

# Return the results
percentage2_outside_llp1, cities2_outside_llp1
# Out:
# (0.0,
#  [], Categories (109, object): ['Ahmedabad', 'Alleppey', 'Alwar', 'Ambernath', ..., 'Vadodara', 'Warangal', 'West Bengal', 'Worli'])

# %% [markdown]
# ##### Final Hedging of Data

# %% [markdown]
# **Eliminate 'Not filled' entries in 'Sector' column**

# %%
# Filter rows where the 'Sector' column is 'Not filled'
not_filled1_slp1 = cl_lp1df[cl_lp1df['Sector'] == 'Not filled']

# Get unique company brands from the filtered rows
unique1_not_filled_slp1 = not_filled1_slp1['Company_Brand'].unique()

# Display unique company brands with 'Sector' column not filled
unique1_not_filled_slp1
# Out:
# array(['Avenues Payments India Pvt. Ltd.', 'Corefactors', 'Deftouch',
#        'dishq', 'ENLYFT DIGITAL SOLUTIONS PRIVATE LIMITED', 'Finwego',
#        'Flathalt', 'FLEECA', 'Fric Bergen', 'HousingMan.com',
#        'Iba Halal Care', 'Inner Being Wellness', 'Jagaran Microfin',
#        'KredX', 'm.Paani', 'MissMalini Entertainment', 'MySEODoc',
#        'ORO Wealth', 'Planet11 eCommerce Solutions India (Avenue11)',
#        'Roadcast', 'SaffronStays', 'Scale Labs', 'Scholify', 'Sequretek',
#        'TapChief', 'Text Mercato', 'Toddle', 'Toffee', 'Togedr',
#        'Wagonfly', 'WheelsEMI'], dtype=object)

# %%
# Dictionary mapping company names to sectors
company_sector_mapping = {
    'Avenues Payments India Pvt. Ltd.': 'Finance and Technology',
    'Corefactors': 'Marketing and Advertising',
    'Deftouch': 'Media and Entertainment',
    'dishq': 'Technology and Software',
    'ENLYFT DIGITAL SOLUTIONS PRIVATE LIMITED': 'Marketing and Advertising',
    'Finwego': 'Finance and Technology',
    'Flathalt': 'Real Estate and Housing',
    'FLEECA': 'Automotive',
    'Fric Bergen': 'Consumer Goods and Services',
    'HousingMan.com': 'Real Estate and Housing',
    'Iba Halal Care': 'Consumer Goods and Services',
    'Inner Being Wellness': 'Healthcare and Health Technology',
    'Jagaran Microfin': 'Finance and Technology',
    'KredX': 'Finance and Technology',
    'm.Paani': 'Technology and Software',
    'MissMalini Entertainment': 'Media and Entertainment',
    'MySEODoc': 'Technology and Software',
    'ORO Wealth': 'Finance and Technology',
    'Planet11 eCommerce Solutions India (Avenue11)': 'E-commerce and Retail',
    'Roadcast': 'Transport and Logistics',
    'SaffronStays': 'Hospitality and Tourism',
    'Scale Labs': 'Technology and Software',
    'Scholify': 'Education and Learning',
    'Sequretek': 'Technology and Software',
    'TapChief': 'Human Resources and Consultancy',
    'Text Mercato': 'E-commerce and Retail',
    'Toddle': 'Education and Learning',
    'Toffee': 'Insurance and Finance',
    'Togedr': 'Hospitality and Tourism',
    'Wagonfly': 'E-commerce and Retail',
    'WheelsEMI': 'Finance and Technology'
}

# Define a mask to identify rows where the 'Sector' column is 'Not filled'
not_filled_mask = cl_lp1df['Sector'] == 'Not filled'

# Apply the company-sector mapping only to the rows where the 'Sector' column is 'Not filled'
cl_lp1df.loc[not_filled_mask, 'Sector'] = cl_lp1df.loc[not_filled_mask, 'Company_Brand'].map(company_sector_mapping)

# Convert 'Sector' column to category data type
cl_lp1df['Sector'] = cl_lp1df['Sector'].astype('category')

# Filter rows where the 'Sector' column is 'Not filled'
not_filled2_slp1 = cl_lp1df[cl_lp1df['Sector'] == 'Not filled']

# Display information about the updated DataFrame
cl_lp1df.info()

# Display rows where the 'Sector' column is 'Not filled'
not_filled2_slp1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2711 entries, 0 to 2821
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Company_Brand        2711 non-null   object
#  1   Founded              2169 non-null   Int64
#  2   HeadQuarter          2711 non-null   category
#  3   Sector               2711 non-null   category
#  4   What_it_does         2711 non-null   object
#  5   Founders             2711 non-null   category
#  6   Investor             2711 non-null   category
#  7   Amount               2711 non-null   float64
#  8   Stage                2711 non-null   category
#  9   Funding_Year         2711 non-null   int64
#  10  Company_Brand_lower  2711 non-null   object
# dtypes: Int64(1), category(5), float64(1), int64(1), object(3)
# memory usage: 331.3+ KB
# Empty DataFrame
# Columns: [Company_Brand, Founded, HeadQuarter, Sector, What_it_does, Founders, Investor, Amount, Stage, Funding_Year, Company_Brand_lower]
# Index: []

# %% [markdown]
# **Drop 'Company_Brand_lower' column and rename 'Stage' column**

# %%
# Drop the 'Company_Brand_lower' column
cl_lp1df = cl_lp1df.drop(columns=['Company_Brand_lower'])

# Rename 'Stage' column in the DataFrame
cl_lp1df = cl_lp1df.rename(columns={'Stage': 'Stage_and_Type'})

# Display the DataFrame to verify the change
cl_lp1df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2711 entries, 0 to 2821
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Company_Brand   2711 non-null   object
#  1   Founded         2169 non-null   Int64
#  2   HeadQuarter     2711 non-null   category
#  3   Sector          2711 non-null   category
#  4   What_it_does    2711 non-null   object
#  5   Founders        2711 non-null   category
#  6   Investor        2711 non-null   category
#  7   Amount          2711 non-null   float64
#  8   Stage_and_Type  2711 non-null   category
#  9   Funding_Year    2711 non-null   int64
# dtypes: Int64(1), category(5), float64(1), int64(1), object(2)
# memory usage: 1.1 MB

# %% [markdown]
# **Check missing values in cleaned final data**

# %%
# Determine the proportion of missing values
missing_percentage_lp1_ed = (cl_lp1df.isnull().mean() * 100).round(2)

# Display results
print("Proportion of missing values in cleaned final data:")
print()
print(missing_percentage_lp1_ed)
# Out:
# Proportion of missing values in cleaned final data:
#
# Company_Brand      0.00
# Founded           19.99
# HeadQuarter        0.00
# Sector             0.00
# What_it_does       0.00
# Founders           0.00
# Investor           0.00
# Amount             0.00
# Stage_and_Type     0.00
# Funding_Year       0.00
# dtype: float64

# %% [markdown]
# ##### Exporting Data

# %%
# # Export the DataFrame to an Excel file
# output_file = '../Data/LP1_final.xlsx'
# cl_lp1df.to_excel(output_file, index=False)

# %% [markdown]
# ### Data Transformation

# %% [markdown]
# #### 1. Who are the most active investors in the Indian start-up ecosystem?
#
# Identifying the most active investors helps understand the key players driving the start-up ecosystem. This information is essential for forming strategic partnerships, understanding investment patterns, and identifying potential sources of capital.
#
# i. Ranking: Rank investors based on the number of deals made.
# ii. Visualization: Use bar charts and heatmaps to visualize the most active investors and their investment patterns by year, total funding amounts and average funding amounts.
# iii. Network Analysis: Conduct a network analysis to understand the relationships and co-investment patterns among top investors.

# %% [markdown]
# ##### a. Investment Patterns of Top 10 Most Active Investors by Year
#
# This provides a clear visualization of investment trends, helping startups strategize their fundraising efforts by targeting the most active investors during peak investment periods. The ranking of investors is based on the number of deals made.

# %%
# Filter out rows where 'Investor' column is not 'Not filled'
cl_lp1df1 = cl_lp1df[cl_lp1df['Investor'] != 'Not filled']

# Split the 'Investor' column by comma to handle multiple investors
cl_lp1df1['Investor'] = cl_lp1df1['Investor'].str.split(',')

# Normalize the dataframe so each investor is a separate row
investors_df = cl_lp1df1.explode('Investor')

# Clean any leading/trailing whitespace from investor names
investors_df['Investor'] = investors_df['Investor'].str.strip()

# Count the frequency of each investor
investor_counts = investors_df['Investor'].value_counts()

# Filter the top 10 most active investors
most_active_investors = investor_counts.head(10)

# Create a DataFrame for most active investors
most_active_investors_df = most_active_investors.reset_index()
most_active_investors_df.columns = ['Investor', 'Number_of_Deals']

# Create a DataFrame for heatmap
investor_year_df = investors_df.groupby(['Investor', 'Funding_Year']).size().unstack(fill_value=0)

# Filter to include only the top 10 most active investors
top_investors_heatmap_df = investor_year_df.loc[most_active_investors.index]

# Plotting the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(top_investors_heatmap_df, annot=True, fmt='d', cmap='viridis', linewidths=0.5)
plt.title('Investment Patterns of Top 10 Most Active Investors by Year')
plt.xlabel('Year')
plt.ylabel('Investor')
plt.show()

# Display the top 10 most active investors
print('Top 10 Most Active Investors in the Indian Start-up Ecosystem')
most_active_investors_df
# Out:
# Top 10 Most Active Investors in the Indian Start-up Ecosystem
#                     Investor  Number_of_Deals
# 0          Venture Catalysts               57
# 1  Inflection Point Ventures               43
# 2      Sequoia Capital India               36
# 3              Titan Capital               33
# 4             Better Capital               29
# 5               Y Combinator               28
# 6                  9Unicorns               26
# 7               Tiger Global               25
# 8      Matrix Partners India               22
# 9             Blume Ventures               21

# %% [markdown]
# `Comment`
#
# **Key Insights**
# The heatmap reveals a general trend of increased investment activity from 2019 to 2021 among the top 10 most active investors. Investors like Venture Catalysts and Inflection Point Ventures exhibit substantial growth, maintaining high levels of investment activity. Others, such as Titan Capital and Tiger Global, show a notable surge in investments in 2021, while Better Capital, Y Combinator, and 9Unicorns demonstrate moderate but steady increases. These patterns indicate varying investment strategies and timelines among the investors.
#
# **Implications for Startups**
# Startups should prioritize targeting investors with consistent high activity, like Venture Catalysts and Inflection Point Ventures, for better chances of securing funding. Understanding the timing of investment surges, as seen with Titan Capital and Tiger Global in 2021, can help in planning fundraising efforts. A diversified approach, engaging both consistently active investors and those with recent activity spikes, can enhance fundraising success by aligning with different investment strategies and cycles.

# %% [markdown]
# ##### b. Total Funding Amount of Top 10 Most Active Investors
#
# Understanding an investor's total funding amount is crucial for assessing their capacity and commitment to investing significant capital, which is essential for startups seeking long-term financial support. This metric provides insights into the investor's capability to sustainably back startups, suggesting potential for follow-on funding rounds as the startup grows. Investors with higher total funding amounts are generally perceived as having greater resources and stability, making them potentially more reliable partners in scaling operations and navigating future funding needs.

# %%
# Define a function to format y-axis labels as currency in billions
def billions_formatter(x, pos):
    return f'${x / 1e9:.1f}B'

# Filter the dataframe to include only the top 10 most active investors
top_investors_df = investors_df[investors_df['Investor'].isin(most_active_investors.index)]

# Calculate the total funding amount for each of these investors
total_funding = top_investors_df.groupby('Investor')['Amount'].sum().sort_values(ascending=False)

# Format the 'Amount' column to display funding amounts in currency format
total_funding_formatted = total_funding.reset_index()
total_funding_formatted["Amount"] = total_funding_formatted["Amount"].apply(lambda x: "${:,.2f}".format(x))

# Plot the total funding amount
plt.figure(figsize=(12, 8))
funding_bars = sns.barplot(x=total_funding.values, y=total_funding.index, palette='viridis')

# Set the title and labels for the plot
plt.suptitle('Total Funding Amount of Top 10 Most Active Investors', y=0.95)
plt.xlabel('Total Funding Amount (USD)')
plt.ylabel('Investor')

# Apply the custom formatter to the x-axis to format labels as currency in billions
plt.gca().xaxis.set_major_formatter(FuncFormatter(billions_formatter))

# Adding data labels
for bar in funding_bars.patches:
    width = bar.get_width()
    plt.text(width + 2.5e7, bar.get_y() + bar.get_height() / 2,
             f'${width / 1e9:.2f}B', va='center', ha='left')

# Display the plot
plt.show()

# Display the top 10 most active investors and their total funding amounts
print('Total Funding Amount of Top 10 Most Active Investors:')
total_funding_formatted
# Out:
# Total Funding Amount of Top 10 Most Active Investors:
#                     Investor             Amount
# 0               Tiger Global  $3,207,100,000.00
# 1      Sequoia Capital India  $1,472,574,420.18
# 2          Venture Catalysts    $652,501,881.98
# 3               Y Combinator    $445,005,339.48
# 4      Matrix Partners India    $393,534,420.18
# 5             Blume Ventures    $345,508,067.90
# 6                  9Unicorns    $320,348,680.74
# 7             Better Capital    $274,316,669.71
# 8  Inflection Point Ventures    $232,977,795.26
# 9              Titan Capital    $215,981,476.16

# %% [markdown]
# `Comment`
#
# The graph provides an insightful analysis of the total funding amounts of the top 10 most active investors, reflecting their capacity and commitment to providing substantial capital to startups. This metric is crucial for understanding an investor's ability to sustainably back startups through various growth stages, offering potential for follow-on funding rounds as the startup scales.
#
# Tiger Global leads the pack with an impressive $3.21 billion in total funding, underscoring its substantial resources and reliability for growth-stage startups. This significant capital infusion highlights Tiger Global's strong capacity to support scaling operations and meet future financing needs. Sequoia Capital India follows with $1.47 billion, indicating a robust financial backing capability, making it a formidable partner for startups seeking sustained support.
#
# Venture Catalysts and Y Combinator, with total funding amounts of $0.65 billion and $0.45 billion respectively, also demonstrate significant funding capabilities. Their substantial resources suggest a strong potential for sustained support, essential for startups looking to grow. Matrix Partners India and Blume Ventures, with funding amounts of $0.39 billion and $0.35 billion respectively, exhibit solid capacities for supporting startups through scaling operations, ensuring reliability for future funding needs.
#
# 9Unicorns and Better Capital, with $0.32 billion and $0.27 billion in total funding respectively, show notable financial resources. Their ability to provide reliable backing is crucial for startups navigating future financing rounds. Inflection Point Ventures and Titan Capital, though having lower funding amounts of $0.23 billion and $0.22 billion respectively, still reflect a strong ability to support startups, ensuring sustained backing through various growth stages.
#
# In conclusion, the graph underscores the importance of an investor's total funding amount as a key indicator of their capacity and commitment to supporting startups. Higher funding amounts suggest greater resources and stability, making these investors potentially more reliable partners. This is particularly critical for growth-stage startups seeking substantial and sustained financial support to scale their operations and meet future funding needs.

# %% [markdown]
# ##### c. Average Funding Amount of Top 10 Most Active Investors
#
# Understanding an investor's average funding amount per investment is crucial for startups seeking funding. It offers insights into the typical size of investments an investor makes, aiding in assessing alignment with the startup's funding requirements and growth stage. A higher average funding amount suggests a preference for larger, potentially more mature startups or larger stakes, while lower averages may indicate a focus on early-stage ventures. This metric helps startups gauge potential investor fit and strategic alignment based on investment size and stage preferences.

# %%
# Define a function to format y-axis labels as currency in millions
def millions_formatter(x, pos):
    return f'${x / 1e6:.1f}M'

# Calculate the average funding amount for each of these investors
average_funding = top_investors_df.groupby('Investor')['Amount'].mean().sort_values(ascending=False)

# Format the 'Amount' column to display funding amounts in currency format
average_funding_formatted = average_funding.reset_index()
average_funding_formatted["Amount"] = average_funding_formatted["Amount"].apply(lambda x: "${:,.2f}".format(x))

# Plot the average funding amount
plt.figure(figsize=(12, 8))
funding_bars = sns.barplot(x=average_funding.values, y=average_funding.index, palette='viridis')

# Set the title and labels for the plot
plt.suptitle('Average Funding Amount of Top 10 Most Active Investors', y=0.95)
plt.xlabel('Average Funding Amount (USD)')
plt.ylabel('Investor')

# Apply the custom formatter to the x-axis to format labels as currency in millions
plt.gca().xaxis.set_major_formatter(FuncFormatter(millions_formatter))

# Adding data labels
for bar in funding_bars.patches:
    width = bar.get_width()
    plt.text(width + 10.5e5, bar.get_y() + bar.get_height() / 2,
             f'${width / 1e6:.2f}M', va='center', ha='left')

# Display the plot
plt.show()

# Display the top 10 most active investors and their average funding amounts
print('Average Funding Amount of Top 10 Most Active Investors:')
average_funding_formatted
# Out:
# Average Funding Amount of Top 10 Most Active Investors:
#                     Investor           Amount
# 0               Tiger Global  $128,284,000.00
# 1      Sequoia Capital India   $40,904,845.01
# 2      Matrix Partners India   $17,887,928.19
# 3             Blume Ventures   $16,452,765.14
# 4               Y Combinator   $15,893,047.84
# 5                  9Unicorns   $12,321,103.11
# 6          Venture Catalysts   $11,447,401.44
# 7             Better Capital    $9,459,195.51
# 8              Titan Capital    $6,544,893.22
# 9  Inflection Point Ventures    $5,418,088.26

# %% [markdown]
# `Comment`
#
# The graph illustrates the average funding amount per investment for the top 10 most active investors. This metric is vital for startups as it provides insights into the typical investment size an investor makes, helping startups assess alignment with their funding requirements and growth stages.
#
# Tiger Global stands out with an average funding amount of $128.28 million, indicating a preference for larger investments, likely targeting more mature startups or seeking larger stakes. Sequoia Capital India follows with an average of $40.90 million, also suggesting a tendency towards substantial investments, aligning well with startups in advanced stages of development.
#
# Matrix Partners India, Blume Ventures, and Y Combinator, with average funding amounts of $17.89 million, $16.45 million, and $15.89 million respectively, exhibit a balanced approach, making them suitable for both mid-stage and somewhat early-stage startups seeking significant but not overly large investments.
#
# 9Unicorns and Venture Catalysts, with average investments of $12.32 million and $11.45 million respectively, reflect a focus on early to mid-stage startups, providing a substantial but more moderate level of funding. Better Capital, Titan Capital, and Inflection Point Ventures, with lower average funding amounts of $9.46 million, $6.54 million, and $5.42 million respectively, indicate a strong focus on early-stage ventures, aligning well with startups in the initial stages of development.
#
# For early-stage startups, understanding these average funding amounts is particularly useful. It helps gauge whether an investor typically invests at a stage and size matching the startup's current funding needs and growth trajectory. This metric thus assists startups in identifying potential investor fit and strategic alignment based on investment size and stage preferences.

# %% [markdown]
# ##### d. Co-Investment Network of Top 10 Most Active Investors.
#
# This provides valuable insights into the relationships and co-investment patterns among top investors in the Indian start-up ecosystem. It highlights the central players, collaborative clusters, and potential isolated investors, offering a strategic view of the investment landscape. Understanding these co-investment patterns can help new start-ups identify which investors tend to work together, aiding them in strategizing their pitch and networking efforts to secure funding.

# %%
# Create the co-investment network
G = nx.Graph()

# Add edges for co-investments
for _, group in investors_df.groupby('Company_Brand'):
    investors = group['Investor'].tolist()
    # Add edges between all pairs of investors who co-invested in the same start-up
    for i in range(len(investors)):
        for j in range(i + 1, len(investors)):
            if investors[i] in most_active_investors.index and investors[j] in most_active_investors.index:                
                if investors[i] != investors[j]: # Avoid self-loops
                    if G.has_edge(investors[i], investors[j]):
                        G[investors[i]][investors[j]]['weight'] += 1
                    else:
                        G.add_edge(investors[i], investors[j], weight=1)

# Plotting the network
plt.figure(figsize=(12, 8))
pos = nx.spring_layout(G, seed=42)
edges = list(G.edges(data=True))
weights = [edge[2]['weight'] for edge in edges]  

# Draw nodes and edges
nx.draw_networkx_nodes(G, pos, node_size=1000, node_color='grey')
nx.draw_networkx_edges(G, pos, width=weights, edge_color='white')
nx.draw_networkx_labels(G, pos, font_size=10, font_weight='bold', font_color='white')

# Set the title and labels for the plot
plt.suptitle('Co-Investment Network of Top 10 Most Active Investors', y=0.95)

# Display the plot
plt.show()

# %% [markdown]
# `Comment`
#
# - Central investors like Y Combinator, Titan Capital, and Matrix Partners India are crucial for networking.
# - Clusters of investors can be targeted for co-investment opportunities. For example a cluster including Y Combinator, Titan Capital, and 9Unicorns, and another cluster with Matrix Partners India, Sequoia Capital India, and Tiger Global.
# - Frequent co-investors like Sequoia Capital India and Matrix Partners India indicate strong partnerships.
# - Diverse local (e.g., Sequoia Capital India, Blume Ventures) and international (e.g., Y Combinator, Tiger Global) investors broaden potential funding sources.
# - Outlier investors like Venture Catalysts may provide niche expertise or selective funding.
# - Influential investors like Y Combinator and Sequoia Capital India enhance credibility and attract further investment.
# - Strategic introductions can be leveraged through well-connected investors.
# - Sector and stage preferences should guide tailored pitches. For example, if a cluster of investors frequently co-invests in early-stage tech startups, a new tech startup at an early stage should prioritize pitching to these investors.
#
# Inflection Point Ventures, absent from the network matrix, likely specializes in niche markets or employs unique investment criteria, operating independently with a highly selective approach. As an isolated investor, it offers distinct opportunities and resources unavailable through more interconnected investors, with a focus on underrepresented markets or innovative sectors. Its exclusion from the co-investment network underscores the importance of a diversified funding strategy, balancing its unique strengths with the broader support of other investors.

# %% [markdown]
# ##### Comprehensive Analysis of Investment Trends Among Top Active Investors: Actionable Insights for Startups

# %% [markdown]
# The landscape of investment activity from 2018 to 2021 among the top 10 most active investors reveals significant trends and strategic implications for startups seeking funding. Analyzing various aspects such as total funding amounts, average funding per investment, and co-investment patterns provides a comprehensive understanding of investor behaviours and preferences.
#
# **Investment Activity Trends**
# The heatmap analysis indicates an overall increase in investment activity from 2019 to 2021 among these investors. Notably, Venture Catalysts and Inflection Point Ventures have exhibited substantial and consistent growth, maintaining high levels of investment activity. Meanwhile, Titan Capital and Tiger Global show significant surges in investments in 2021, whereas Better Capital, Y Combinator, and 9Unicorns demonstrate moderate but steady increases. These patterns reflect varying investment strategies and timelines, highlighting the dynamic nature of investment flows in the startup ecosystem.
#
# **Total Funding Capacity**
# Examining the total funding amounts provides crucial insights into the capacity and commitment of these investors to support startups through various growth stages. Tiger Global leads with an impressive $3.21 billion, underscoring its substantial resources and reliability for growth-stage startups. Sequoia Capital India follows with $1.47 billion, indicating robust financial backing capabilities, making it a formidable partner for startups seeking sustained support.
#
# Venture Catalysts and Y Combinator, with total funding amounts of $0.65 billion and $0.45 billion respectively, also demonstrate significant funding capabilities. Matrix Partners India and Blume Ventures, with $0.39 billion and $0.35 billion respectively, exhibit solid capacities for supporting startups through scaling operations, ensuring reliability for future funding needs. Despite having lower total funding amounts, Inflection Point Ventures and Titan Capital, with $0.23 billion and $0.22 billion respectively, still reflect strong abilities to support startups, ensuring sustained backing through various growth stages.
#
# **Average Funding Per Investment**
# Understanding the average funding amount per investment is crucial for startups in assessing alignment with their funding requirements and growth stages. Tiger Global stands out with an average funding amount of $128.28 million, indicating a preference for larger investments, likely targeting more mature startups or seeking larger stakes. Sequoia Capital India, with an average of $40.90 million, also suggests a tendency towards substantial investments, aligning well with startups in advanced stages of development.
#
# Matrix Partners India, Blume Ventures, and Y Combinator, with average funding amounts of $17.89 million, $16.45 million, and $15.89 million respectively, exhibit a balanced approach, making them suitable for both mid-stage and somewhat early-stage startups seeking significant but not overly large investments. 9Unicorns and Venture Catalysts, with average investments of $12.32 million and $11.45 million respectively, focus on early to mid-stage startups. Better Capital, Titan Capital, and Inflection Point Ventures, with lower averages of $9.46 million, $6.54 million, and $5.42 million respectively, indicate a strong focus on early-stage ventures.
#
# **Co-Investment Patterns and Strategic Implications**
# Analyzing co-investment patterns reveals critical insights into investor relationships and potential networking opportunities. Central investors like Y Combinator, Titan Capital, and Matrix Partners India are crucial for networking and establishing strategic partnerships. Clusters of investors can be targeted for co-investment opportunities, such as Y Combinator, Titan Capital, and 9Unicorns forming one cluster, and Matrix Partners India, Sequoia Capital India, and Tiger Global forming another.
#
# Frequent co-investors like Sequoia Capital India and Matrix Partners India indicate strong partnerships, suggesting potential collaborative opportunities for startups. A diverse mix of local investors (e.g., Sequoia Capital India, Blume Ventures) and international investors (e.g., Y Combinator, Tiger Global) broadens the potential funding sources and enhances credibility.
#
# Outlier investors like Venture Catalysts may provide niche expertise or selective funding, offering unique opportunities for startups in specific sectors. Influential investors like Y Combinator and Sequoia Capital India enhance credibility and attract further investment, making strategic introductions through well-connected investors valuable.
#
# **Implications for Startups**
# For startups, targeting investors with consistent high activity, such as Venture Catalysts and Inflection Point Ventures, can increase the chances of securing funding. Understanding the timing of investment surges, as seen with Titan Capital and Tiger Global in 2021, can help in planning fundraising efforts. A diversified approach, engaging both consistently active investors and those with recent activity spikes, can enhance fundraising success by aligning with different investment strategies and cycles.
#
# Early-stage startups should focus on investors with lower average funding amounts, such as Better Capital, Titan Capital, and Inflection Point Ventures, which align well with their funding needs. Meanwhile, growth-stage startups should target investors with higher average funding amounts, like Tiger Global and Sequoia Capital India, to secure substantial support for scaling operations.
#
# Inflection Point Ventures, absent from the co-investment network, likely specializes in niche markets or employs unique investment criteria. As an isolated investor, it offers distinct opportunities and resources unavailable through more interconnected investors, with a focus on underrepresented markets or innovative sectors. This underscores the importance of a diversified funding strategy, balancing unique strengths with the broader support of other investors.
#
# In conclusion, understanding the detailed investment patterns and strategies of the top active investors provides actionable insights for startups, helping them align their fundraising efforts with the right investors to maximize their chances of success.

# %% [markdown]
# #### 2. Are there any geographical trends or hotspots for start-up funding in India?
#
# Identifying geographical trends or hotspots for start-up funding helps in understanding the regional distribution of investments. This information is valuable for targeting investments, identifying regional hubs of innovation, and planning market entry strategies.
#
# i. Visualization: Use heatmaps to visualize funding concentrations across different regions.
# ii. Cluster Analysis: Perform cluster analysis to identify regions with high concentrations of start-up funding.
# iii. Comparative Analysis: Compare funding amounts across regions to highlight hotspots.

# %% [markdown]
# ##### a. Top 10 locations with highest startup funding
#
# Targeted Funding Opportunities: Knowing which cities or regions attract the highest funding can guide startups in targeting their fundraising efforts more effectively.
#
# Access to Resources: Locations with high funding indicate access to resources and networks that support scaling and innovation, offering startups better growth prospects.
#
# Networking and Collaboration: Startups can leverage these insights to network with local investors and ecosystem players, fostering collaborations that could accelerate their growth.

# %%
# Copying the DataFrame
cl_lp1df2 = cl_lp1df.copy()

# Group by 'HeadQuarter' and calculate the total funding amount for each location
location_funding = cl_lp1df2.groupby('HeadQuarter')['Amount'].sum().reset_index()

# Sort the DataFrame by total funding amount in descending order
location_funding = location_funding.sort_values(by='Amount', ascending=False)

# Get the top 10 locations with the highest total funding
top_ten_locations = location_funding.head(10).reset_index(drop=True)

# Format the 'Amount' column to display funding amounts in currency format
top_ten_locations_formatted = top_ten_locations.copy()
top_ten_locations_formatted["Amount"] = top_ten_locations_formatted["Amount"].apply(lambda x: "${:,.2f}".format(x))

# Plot the total funding amount
plt.figure(figsize=(12, 8))
colors = plt.cm.viridis(np.linspace(0, 1, len(top_ten_locations)))
bars = plt.barh(top_ten_locations['HeadQuarter'], top_ten_locations['Amount'], color=colors)

# Set the title and labels for the plot
plt.xlabel('Total Funding Amount (USD)')
plt.ylabel('Location')
plt.suptitle('Top 10 Locations with Highest Startup Funding in India', y=0.95)
plt.gca().invert_yaxis()

# Apply the custom formatter to the x-axis to format labels as currency in billions
plt.gca().xaxis.set_major_formatter(FuncFormatter(billions_formatter))

# Adding data labels
for bar in bars:
    width = bar.get_width()
    plt.text(width + 2.5e8, bar.get_y() + bar.get_height() / 2,
              f'${width / 1e9:.2f}B', va='center', ha='left')

# Display the plot
plt.show()

# Display the top 10 locations with the highest funding
print("Top 10 locations with highest startup funding:")
top_ten_locations_formatted
# Out:
# Top 10 locations with highest startup funding:
#   HeadQuarter              Amount
# 0   Bangalore  $27,903,927,582.09
# 1      Mumbai  $10,651,447,333.14
# 2    Gurugram   $6,512,522,151.78
# 3   New Delhi   $4,585,084,286.91
# 4        Pune   $2,084,178,928.39
# 5     Gurgaon   $1,680,288,689.31
# 6       Delhi   $1,473,268,436.66
# 7     Chennai   $1,391,550,454.44
# 8       Noida   $1,132,759,297.32
# 9     Haryana     $876,914,272.32

# %% [markdown]
# `Comment`
#
# 1. **Targeted Funding Opportunities:**
#    - The graph shows that Bangalore is the most attractive city for startup funding, with a significant total funding amount of $27.90 billion.
#    - Mumbai follows with $10.65 billion, indicating it as the second most preferred destination for startup investments.
#    - Other notable locations include Gurugram ($6.51 billion) and New Delhi ($4.59 billion).
#    - Startups seeking to maximize their fundraising efforts should focus on these top cities where investors are more active and the funding amounts are substantial.
#
# 2. **Access to Resources:**
#    - High funding in these locations suggests that they have well-developed ecosystems that provide access to various resources essential for startup growth.
#    - Cities like Bangalore and Mumbai are likely to offer better infrastructure, a skilled workforce, and supportive regulatory environments.
#    - The substantial funding indicates robust support networks, including accelerators, incubators, and industry expertise, which can help startups scale efficiently.
#
# 3. **Networking and Collaboration:**
#    - The graph highlights the importance of networking in cities with high funding levels. Startups can benefit from connecting with local investors, mentors, and other startups.
#    - Collaboration opportunities in these locations can lead to strategic partnerships, access to new markets, and faster growth.
#    - For instance, startups in Bangalore can leverage the city’s vibrant tech community to foster innovation and collaboration.
#
# Overall, the graph suggests that startups should consider focusing their efforts on cities like Bangalore, Mumbai, and Gurugram for better funding opportunities, access to resources, and networking advantages.

# %% [markdown]
# ##### b. Top 10 Locations with Highest Number of Startups in India
#
# Networking Opportunities: Concentrated startup hubs offer ample networking opportunities, allowing startups to connect with peers, mentors, and potential partners.
#
# Emerging Market Identification: High startup density in certain regions may signal emerging market opportunities where startups can enter and thrive with lower competition.
#
# Ecosystem Support: Startups in these locations may benefit from established support structures and infrastructure tailored to entrepreneurial needs, facilitating growth and sustainability.

# %%
# Count the number of startups in each location
startup_count_location = cl_lp1df2['HeadQuarter'].value_counts().reset_index()
startup_count_location.columns = ['HeadQuarter', 'Number_of_Startups']

# Get the top 10 locations with the highest number of startups
top_ten_startup_count = startup_count_location.head(10).reset_index(drop=True)

# Plot the number of startups
plt.figure(figsize=(12, 8))
colors = plt.cm.viridis(np.linspace(0, 1, len(top_ten_startup_count)))
bars = plt.barh(top_ten_startup_count['HeadQuarter'], top_ten_startup_count['Number_of_Startups'], color=colors)

# Set the title and labels for the plot
plt.xlabel('Number of Startups')
plt.ylabel('Location')
plt.suptitle('Top 10 Locations with Highest Number of Startups in India', y=0.95)
plt.gca().invert_yaxis()  

# Adding data labels
for bar in bars:
    width = bar.get_width()
    plt.text(width + 7.5, bar.get_y() + bar.get_height() / 2,
              f'{width}', va='center', ha='left')

# Display the plot
plt.show()

# Display the top 10 locations with the highest number of startups
print("Top 10 Locations with Highest Number of Startups in India:")
top_ten_startup_count
# Out:
# Top 10 Locations with Highest Number of Startups in India:
#   HeadQuarter  Number_of_Startups
# 0   Bangalore                 926
# 1      Mumbai                 469
# 2    Gurugram                 247
# 3   New Delhi                 236
# 4        Pune                 106
# 5     Chennai                 106
# 6       Delhi                  89
# 7       Noida                  88
# 8     Gurgaon                  80
# 9   Hyderabad                  79

# %% [markdown]
# `Comment`
#
# 1. **Networking Opportunities:**
#    - Bangalore leads with a significant margin, hosting 926 startups. This high concentration makes Bangalore a prime location for networking opportunities.
#    - Mumbai, with 469 startups, also offers substantial opportunities for startups to connect with peers, mentors, and potential partners.
#    - Other notable locations like Gurugram (247 startups) and New Delhi (236 startups) also provide rich networking environments.
#    - Being part of these hubs allows startups to tap into vibrant communities where they can share knowledge, collaborate on projects, and gain insights from experienced entrepreneurs.
#
# 2. **Emerging Market Identification:**
#    - The high density of startups in Bangalore and Mumbai indicates that these cities are mature markets with numerous players. However, this also means more competition.
#    - Cities like Pune (106 startups), Chennai (106 startups), and New Delhi (236 startups) represent emerging markets with growing entrepreneurial activities.
#    - Startups might find opportunities in these regions where the ecosystem is developing, potentially facing lower competition compared to Bangalore and Mumbai.
#
# 3. **Ecosystem Support:**
#    - Locations with a high number of startups often benefit from established support structures such as incubators, accelerators, co-working spaces, and access to funding.
#    - Bangalore, with the highest number of startups, likely has a well-developed ecosystem offering resources tailored to startups’ needs, facilitating their growth and sustainability.
#    - Mumbai, Gurugram, and New Delhi also likely provide substantial ecosystem support, helping startups navigate challenges and scale their operations.
#    - Startups in these hubs can take advantage of the existing infrastructure and support mechanisms designed to foster innovation and growth.
#
# Overall, the graph indicates that while Bangalore and Mumbai are the leading hubs for startups with the most significant networking opportunities and established support systems, emerging markets like Pune and Chennai offer potential for growth with possibly less competition.

# %% [markdown]
# ##### c. Average Funding of Top 10 Locations with Highest Funding Amount and Number of Startups in India
#
# Optimal Investment Targets: Comparing average funding levels across startup hubs helps startups identify regions where investors are willing to fund at higher levels, potentially enhancing financial support.
#
# Strategic Location Decisions: Startups can strategically choose locations with both high funding averages and startup density to maximize their chances of securing funding and gaining market visibility.
#
# Ecosystem Strength Indicators: Locations with robust average funding and high startup density signify strong and supportive entrepreneurial ecosystems, providing startups with stability and growth opportunities.

# %%
# Define the target locations of interest
target_locations = ['Bangalore', 'Mumbai', 'Gurugram', 'New Delhi', 'Pune', 'Gurgaon', 'Delhi', 'Chennai', 'Noida', 'Haryana', 'Hyderabad']

# Merge the DataFrames containing funding amount and startup count based on 'HeadQuarter' column
st_locations = pd.merge(location_funding, startup_count_location, on='HeadQuarter')

# Filter the merged DataFrame to include only target locations
target_st_locations = st_locations[st_locations['HeadQuarter'].isin(target_locations)]

# Calculate the average funding per startup for each target location
target_st_locations['Average_Funding'] = target_st_locations['Amount'] / (target_st_locations['Number_of_Startups'])

# Sort the DataFrame by average funding in descending order
target_st_locations = target_st_locations.sort_values(by='Average_Funding', ascending=False).reset_index(drop=True)

# Create a copy of the DataFrame for formatting
target_st_locations_formatted = target_st_locations.copy()

# Format the 'Amount' and 'Average_Funding' columns to display values in currency format
target_st_locations_formatted["Amount"] = target_st_locations_formatted["Amount"].apply(lambda x: "${:,.2f}".format(x))
target_st_locations_formatted["Average_Funding"] = (target_st_locations_formatted["Average_Funding"]).apply(lambda x: "${:,.2f}".format(x))

# Plotting the average funding for target locations
plt.figure(figsize=(12, 8))
colors = plt.cm.viridis(np.linspace(0, 1, len(target_st_locations)))
bars = plt.barh(target_st_locations['HeadQuarter'], target_st_locations['Average_Funding'], color=colors)

# Set the title and labels for the plot
plt.xlabel('Average Funding Amount (USD)')
plt.ylabel('Location')
plt.suptitle('Average Funding of Top 10 Locations with Highest Funding Amount and Number of Startups in India', y=0.95)
plt.gca().invert_yaxis()

# Applying custom formatter to the x-axis to format labels as currency in millions
plt.gca().xaxis.set_major_formatter(FuncFormatter(millions_formatter))

# Adding data labels
for bar in bars:
    width = bar.get_width()
    plt.text(width + 2.5e5, bar.get_y() + bar.get_height() / 2,
              f'${width / 1e6:.2f}M', va='center', ha='left')
    
# Display the plot
plt.show()

# Display the top 10 locations with the highest average funding per startup
print("Average Funding of Top 10 Locations with Highest Funding Amount and Number of Startups in India:")
target_st_locations_formatted
# Out:
# Average Funding of Top 10 Locations with Highest Funding Amount and Number of Startups in India:
#    HeadQuarter              Amount  Number_of_Startups Average_Funding
# 0      Haryana     $876,914,272.32                  24  $36,538,094.68
# 1    Bangalore  $27,903,927,582.09                 926  $30,133,831.08
# 2     Gurugram   $6,512,522,151.78                 247  $26,366,486.44
# 3       Mumbai  $10,651,447,333.14                 469  $22,710,975.12
# 4      Gurgaon   $1,680,288,689.31                  80  $21,003,608.62
# 5         Pune   $2,084,178,928.39                 106  $19,662,065.36
# 6    New Delhi   $4,585,084,286.91                 236  $19,428,323.25
# 7        Delhi   $1,473,268,436.66                  89  $16,553,577.94
# 8      Chennai   $1,391,550,454.44                 106  $13,127,834.48
# 9        Noida   $1,132,759,297.32                  88  $12,872,264.74
# 10   Hyderabad     $730,750,627.47                  79   $9,250,007.94

# %% [markdown]
# `Comment`
#
# 1. **Optimal Investment Targets:**
#    - Haryana stands out with the highest average funding amount of $36.54 million, indicating a strong willingness of investors to fund startups at higher levels in this region.
#    - Bangalore follows with an average funding of $30.13 million, making it another attractive target for startups seeking substantial financial support.
#    - Other notable locations include Gurugram ($26.37 million) and Mumbai ($22.71 million), highlighting them as potential optimal investment targets where investors are more generous.
#
# 2. **Strategic Location Decisions:**
#    - Startups can strategically choose locations such as Bangalore and Gurugram, which not only have high average funding but also a significant number of startups, maximizing their chances of securing funding and gaining market visibility.
#    - Mumbai and New Delhi also offer a balance of high average funding and a considerable number of startups, making them strategic choices for startups aiming to tap into established markets with substantial financial backing.
#    - Locations with moderate average funding, like Pune ($19.66 million) and New Delhi ($19.43 million), still provide substantial support and could be attractive for startups aiming to enter less competitive markets while still benefiting from strong funding opportunities.
#
# 3. **Ecosystem Strength Indicators:**
#    - Locations like Bangalore, with high average funding and startup density, signify strong and supportive entrepreneurial ecosystems, offering stability and growth opportunities for startups.
#    - Mumbai and Gurugram also demonstrate robust ecosystems with significant average funding, indicating the presence of established support structures, resources, and networks that can aid startup growth.
#    - Even regions like Pune and New Delhi show strong average funding, suggesting a supportive environment conducive to entrepreneurial activities, albeit with slightly lower startup density compared to top hubs like Bangalore.
#
# Overall, the graph suggests that startups should consider regions like Haryana, Bangalore, and Gurugram for optimal financial support, while also factoring in the density of startups to leverage networking, visibility, and ecosystem benefits.

# %% [markdown]
# ##### Comprehensive Analysis of Startup Investment Opportunities and Ecosystem Support in India

# %% [markdown]
# India's startup ecosystem is vibrant and rapidly evolving, with several key cities emerging as major hubs for entrepreneurial activity. Analyzing data from three distinct yet interconnected perspectives—targeted funding opportunities, networking and collaboration potential, and optimal investment targets—provides actionable insights for stakeholders looking to invest in or launch startups in India. The data underscores the importance of strategic location decisions to maximize funding, access resources, and leverage ecosystem strengths.
#
# **Targeted Funding Opportunities**
# The total funding amounts in different Indian cities highlight specific locations as prime targets for startups seeking substantial investment. **Bangalore** leads significantly, attracting a total of $27.90 billion in startup funding. This dominance underscores Bangalore's position as the most attractive city for startup funding. **Mumbai** follows with $10.65 billion, indicating its status as the second most preferred destination for startup investments. Other notable cities include **Gurugram** with $6.51 billion and **New Delhi** with $4.59 billion in total funding.
#
# Startups aiming to maximize their fundraising efforts should prioritize these top cities where investor activity and funding amounts are substantial. The high funding levels in these locations reflect well-developed ecosystems that offer crucial resources essential for startup growth, including better infrastructure, a skilled workforce, and supportive regulatory environments. Furthermore, these cities likely boast robust support networks, including accelerators, incubators, and industry expertise, facilitating efficient scaling of startups.
#
# **Networking and Collaboration**
# Networking opportunities are critical for startup success, and cities with high funding levels often host dense startup populations, fostering vibrant entrepreneurial communities. **Bangalore** again stands out, hosting 926 startups, making it a prime location for networking opportunities. **Mumbai**, with 469 startups, also offers substantial networking potential, allowing startups to connect with peers, mentors, and potential partners. **Gurugram** and **New Delhi** further provide rich networking environments with 247 and 236 startups, respectively.
#
# Being part of these hubs allows startups to tap into vibrant communities where they can share knowledge, collaborate on projects, and gain insights from experienced entrepreneurs. Collaboration opportunities in these locations can lead to strategic partnerships, access to new markets, and accelerated growth. For instance, startups in Bangalore can leverage the city’s dynamic tech community to foster innovation and collaboration, enhancing their growth prospects.
#
# **Optimal Investment Targets**
# When evaluating optimal investment targets, it is crucial to consider both the average funding amounts and the number of startups in each location. **Haryana** stands out with the highest average funding amount of $36.54 million, indicating a strong willingness of investors to fund startups at higher levels. **Bangalore** follows with an average funding of $30.13 million, reinforcing its attractiveness for startups seeking substantial financial support.
#
# Other notable locations include **Gurugram** ($26.37 million) and **Mumbai** ($22.71 million), highlighting them as potential optimal investment targets where investors are more generous. **Pune** and **New Delhi** also show strong average funding levels ($19.66 million and $19.43 million, respectively), providing substantial support and making them attractive for startups aiming to enter less competitive markets while still benefiting from robust funding opportunities.
#
# **Ecosystem Support**
# Locations with high startup densities and significant average funding typically signify strong and supportive entrepreneurial ecosystems. **Bangalore** exemplifies this with its high average funding and large number of startups, indicating a well-developed ecosystem offering resources tailored to startups’ needs, facilitating their growth and sustainability. **Mumbai** and **Gurugram** also demonstrate robust ecosystems with significant average funding, underscoring the presence of established support structures, resources, and networks that can aid startup growth.
#
# Even regions like **Pune** and **New Delhi** show strong average funding, suggesting a supportive environment conducive to entrepreneurial activities, albeit with slightly lower startup density compared to top hubs like Bangalore. Startups in these locations can take advantage of the existing infrastructure and support mechanisms designed to foster innovation and growth.
#
# **Conclusion**
# The comprehensive analysis indicates that stakeholders—whether investors or entrepreneurs—should focus on cities like Bangalore, Mumbai, and Gurugram for better funding opportunities, access to resources, and networking advantages. These cities not only offer substantial financial support but also boast well-developed ecosystems that are conducive to startup growth. Emerging markets like Pune and Chennai present opportunities for growth with possibly less competition, making them viable alternatives for startups looking to establish a foothold in India's dynamic startup landscape.
#
# By strategically choosing locations with high funding averages and startup densities, startups can maximize their chances of securing funding, gaining market visibility, and leveraging ecosystem benefits, thereby setting the stage for sustained growth and success in India's burgeoning startup ecosystem.

# %% [markdown]
# #### 3. Are there any annual trends in start-up funding in India from 2018 to 2021?
#
# Understanding the annual trends in start-up funding helps to assess the growth and dynamics of the start-up ecosystem over time. This information is crucial for strategic planning and forecasting future trends, providing insights into how the investment climate has evolved.
#
# i. Trend Analysis: Use line charts to visualize the year-over-year changes in total and average funding amounts.
# ii. Statistical Analysis: Calculate the annual growth rates and perform a trend analysis to identify any significant upward or downward patterns.

# %% [markdown]
# ##### a. Total Annual Start-up Funding in India (2018-2021) with Trend Line Analysis
#
# - Growth Analysis
# - Strategic Planning
# - Long-term Trends
# - Investment Strategies
# - Performance Evaluation

# %%
# Copying the DataFrame
cl_lp1df3 = cl_lp1df.copy()

# Group by year and calculate the total funding amount for each year
total_annual_funding = cl_lp1df3.groupby('Funding_Year')['Amount'].sum().reset_index()

# Sort the DataFrame by total funding amount in descending order
total_annual_funding = total_annual_funding.sort_values(by='Funding_Year', ascending=True)

# Format the 'Amount' column to display funding amounts in currency format
total_annual_funding_formatted = total_annual_funding.copy()
total_annual_funding_formatted["Amount"] = total_annual_funding_formatted["Amount"].apply(lambda x: "${:,.2f}".format(x))

# Copying the Dataframe for trend analysis
total_annual_funding_trend = total_annual_funding.copy()

# Calculate the annual growth rates
total_annual_funding_trend['Growth_Rate'] = total_annual_funding_trend['Amount'].pct_change()
total_annual_funding_formatted['Growth_Rate'] = total_annual_funding_trend['Growth_Rate']

# Drop the first row as it will have NaN growth rate
total_annual_funding_trend = total_annual_funding_trend.dropna()

# Prepare data for linear regression
X = total_annual_funding_trend['Funding_Year'].values.reshape(-1, 1)
y = total_annual_funding_trend['Amount'].values

# Perform linear regression
regressor = LinearRegression()
regressor.fit(X, y)

# Get the slope (trend) and intercept
slope = regressor.coef_[0]
intercept = regressor.intercept_

# Create the equation of the line
line_eq = f"y = {slope/1e9:.2f}Bx - {abs(intercept/1e9):.2f}B"

# Predict total funding amounts using the linear model
total_annual_funding_trend['Predicted_Amount'] = regressor.predict(X)

# Format the 'Predicted_Amount' column to display funding amounts in currency format
total_annual_funding_formatted["Predicted_Amount"] = total_annual_funding_trend["Predicted_Amount"].apply(lambda x: "${:,.2f}".format(x))

# Plotting the annual funding trends and the trend line
plt.figure(figsize=(12, 8))
plt.plot(total_annual_funding['Funding_Year'], total_annual_funding['Amount'], marker='o', color='skyblue', label='Total Funding')
plt.plot(total_annual_funding_trend['Funding_Year'], total_annual_funding_trend['Predicted_Amount'], color='orange', linestyle='--', label='Trend Line')

# Set the title and labels for the plot
plt.suptitle('Total annual Start-up Funding in India (2018-2021)', y=0.95)
plt.xlabel('Year')
plt.ylabel('Total Funding Amount (USD)')
plt.legend()
plt.gca().yaxis.set_major_formatter(billions_formatter)
plt.xticks(total_annual_funding['Funding_Year'])

# Adding data points
for i, txt in enumerate(total_annual_funding['Amount']):
    plt.annotate(f'${txt / 1e9:.2f}B', (total_annual_funding['Funding_Year'].iloc[i], txt),
                  textcoords="offset points", xytext=(0,10), ha='center', fontsize=14)
    
# Add the equation as text on the plot
plt.text(
    total_annual_funding_trend["Funding_Year"].median(),
    total_annual_funding_trend["Predicted_Amount"].min(),
    line_eq,
    fontsize=14,
    color="yellow"
)

# Display plot
plt.show()

# Display the total annual funding with growth rates and predicted amounts
print("Total annual Start-up Funding, with growth rates and predicated amounts, in India (2018-2021):")
total_annual_funding_formatted
# Out:
# Total annual Start-up Funding, with growth rates and predicated amounts, in India (2018-2021):
#    Funding_Year              Amount  Growth_Rate    Predicted_Amount
# 0          2018   $9,215,331,848.84          NaN                 NaN
# 1          2019   $3,616,613,512.99    -0.607544   $3,418,210,282.19
# 2          2020  $17,391,978,248.86     3.808913  $17,788,784,710.46
# 3          2021  $32,357,762,369.54     0.860499  $32,159,359,138.75

# %% [markdown]
# `Comment`
#
# **Growth Analysis**
#
# From 2018 to 2019, there was a decrease of approximately 60.75%.
# From 2019 to 2020, there was an increase of approximately 380.89%.
# From 2020 to 2021, there was an increase of approximately 86.05%.
#
# - ***Identification of Significant Growth Years***:
#   - The graph shows a noticeable dip in funding in 2019, followed by a sharp increase in 2020 and an even more substantial rise in 2021.
#   - Funding grew from $3.62 billion in 2019 to $17.39 billion in 2020, and then to $32.36 billion in 2021, indicating a significant growth trend.
# - ***Market Confidence and Investor Interest***:
#   - The steep rise in funding from 2020 onwards indicates increased market confidence and higher investor interest during these years.
#
# **Strategic Planning**
#
# - ***Planning Funding Rounds***:
#   - Startups can use this information to plan their funding rounds during high-growth years (e.g., 2020 and 2021), maximizing their chances of securing investments.
#
# **Long-term Trends**
#
# - ***Predicting Future Funding Climates***:
#   - The trend line (orange dashed line) provides a visual representation of the long-term funding trend.
#   - The equation \( y = 14.37Bx - 29010.77B \) shows the trend of increasing annual funding, helping startups predict future funding climates and prepare accordingly.
#
# **Investment Strategies**
#
# - ***Adapting Investment Strategies***:
#   - By understanding the funding trends, startups can focus their efforts on years projected to have higher funding availability. For example, given the upward trend, startups might expect continued growth in funding availability in subsequent years.
#
# **Performance Evaluation**
#
# - ***Assessing Performance Relative to Market Expectations***:
#   - Startups can compare their actual funding data against the trend line to assess their performance relative to market expectations. The predicted amounts align closely with the actual funding amounts, showing the model's accuracy in capturing the trend.
#   - If a startup's funding aligns with or exceeds the trend line, it may indicate strong market performance. Conversely, if funding falls short of the trend, it might highlight areas for improvement or adjustment.
#
# Overall, this graph provides actionable insights for startups to understand funding dynamics, plan strategically, adapt investment strategies, and evaluate performance relative to market trends.

# %% [markdown]
# ##### b. Average annual Start-up Funding in India (2018-2021) with Trend Line Analysis
#
# - Investment Expectations
# - Benchmarking
# - Future Projections
# - Resource Allocation

# %%
# Group by year and calculate the average funding amount for each year
avg_annual_funding = cl_lp1df3.groupby('Funding_Year')['Amount'].mean().sort_index()

# Copying Dataframe for trend analysis
avg_annual_funding_trend = avg_annual_funding.reset_index()

# Calculate the annual growth rates
avg_annual_funding_trend['Growth_Rate'] = avg_annual_funding_trend['Amount'].pct_change()

# Copying Dataframe for formatting purposes
avg_annual_funding_formatted = avg_annual_funding_trend.copy()

# Drop the first row as it will have NaN growth rate
avg_annual_funding_trend = avg_annual_funding_trend.dropna()

# Prepare data for linear regression
X = avg_annual_funding_trend['Funding_Year'].values.reshape(-1, 1)
y = avg_annual_funding_trend['Amount'].values

# Perform linear regression
regressor = LinearRegression()
regressor.fit(X, y)

# Get the slope (trend) and intercept
slope = regressor.coef_[0]
intercept = regressor.intercept_

# Create the equation of the line
line_eq = f"y = {slope/1e6:.2f}Mx + {intercept/1e6:.2f}M"

# # Predict average funding amounts using the linear model
avg_annual_funding_trend['Predicted_Amount'] = regressor.predict(X)

# Format the 'Amount' and 'Predicted_Amount' column to display funding amounts in currency format
avg_annual_funding_formatted["Amount"] = avg_annual_funding_formatted["Amount"].apply(lambda x: "${:,.2f}".format(x))
avg_annual_funding_formatted["Predicted_Amount"] = avg_annual_funding_trend["Predicted_Amount"].apply(lambda x: "${:,.2f}".format(x))

# Plotting the annual funding trends and the trend line
plt.figure(figsize=(12, 8))
plt.plot(avg_annual_funding.index, avg_annual_funding.values, marker='o', color='skyblue', label='Average Funding')
plt.plot(avg_annual_funding_trend['Funding_Year'], avg_annual_funding_trend['Predicted_Amount'], color='orange', linestyle='--', label='Trend Line')

# Set the title and labels for the plot
plt.suptitle('Average annual Start-up Funding in India (2018-2021)', y=0.95)
plt.xlabel('Year')
plt.ylabel('Average Funding Amount (USD)')
plt.legend()
plt.xticks(avg_annual_funding.index)
plt.gca().yaxis.set_major_formatter(millions_formatter)

# Adding data points
for i, txt in enumerate(avg_annual_funding.values):
    plt.annotate(f'${txt / 1e6:.2f}M', (avg_annual_funding.index[i], txt),
                  textcoords="offset points", xytext=(0,10), ha='center', fontsize=14)
    
# Add the equation as text on the plot
plt.text(
    avg_annual_funding_trend["Funding_Year"].median(),
    avg_annual_funding_trend["Predicted_Amount"].max(),
    line_eq,
    fontsize=14,
    color="yellow"
)

# Display plot
plt.show()

# # Display the average annual funding DataFrame with growth rates and predicted amounts
print("Average annual Start-up Funding, with growth rates and predicated amounts, in India (2018-2021):")
avg_annual_funding_formatted
# Out:
# Average annual Start-up Funding, with growth rates and predicated amounts, in India (2018-2021):
#    Funding_Year          Amount  Growth_Rate Predicted_Amount
# 0          2018  $17,653,892.43          NaN              NaN
# 1          2019  $46,969,006.66     1.660547   $40,633,468.78
# 2          2020  $18,365,341.34    -0.608990   $31,036,417.11
# 3          2021  $27,774,903.32     0.512354   $21,439,365.44

# %% [markdown]
# `Comment`
#
# **Investment Expectations**
# The graph provides insights into the average funding amounts startups can expect to secure. For example, in 2018, the average funding was approximately $17.65 million, peaking at around $46.97 million in 2019, and then fluctuating in the subsequent years. This data helps startups set realistic expectations for their investment targets.
#
# **Benchmarking**
# Startups can use the average funding data as a benchmark to evaluate their own funding goals and performance. By comparing their funding achievements to the industry averages shown in the graph, startups can identify areas for improvement and set more informed targets.
#
# **Future Projections**
# The trend line, represented by the equation \( y = -9.60Mx + 19417.08M \), indicates a declining trend in average annual funding over the years. This trend line helps startups anticipate potential decreases in average investment sizes, allowing them to adjust their funding strategies and target amounts accordingly.
#
# **Resource Allocation**
# Understanding the projected trends in funding can guide startups in better allocating their resources. For example, knowing that the trend suggests a decrease in average funding, startups might focus more on activities that enhance their appeal to investors or seek to diversify their funding sources to maintain financial stability.
#
# **Graph Interpretation**
# - **2018**: The average funding amount was $17.65 million.
# - **2019**: There was a significant increase, with the average funding amount reaching $46.97 million.
# - **2020**: The average funding amount dropped to $18.37 million.
# - **2021**: There was a recovery, with the average funding amount rising to $27.77 million.
#
# **Trend Analysis**
# The trend line, depicted in orange, suggests that despite the fluctuations, there is an overall declining trend in average annual funding amounts. This is important for startups to consider when planning long-term financial strategies and setting realistic funding goals.
#
# **Detailed Annual Insights**
# - **2018**: The funding amount was $17,653,892.43. Since this is the base year, the growth rate is not applicable.
# - **2019**: The funding amount increased to $46,969,006.66, with a growth rate of 166.05%. The predicted amount for this year, based on the trend line, was $40,633,468.78.
# - **2020**: The funding amount decreased to $18,365,341.34, with a negative growth rate of -60.90%. The predicted amount for this year was $31,036,417.11.
# - **2021**: The funding amount recovered to $27,774,903.32, with a growth rate of 51.24%. The predicted amount for this year was $21,439,365.44.
#
# **Actionable Insights**
# - **Growth Rates**: The significant growth rate of 166.05% in 2019 followed by a steep decline of -60.90% in 2020 indicates volatility in funding amounts. Startups should prepare for such fluctuations by building flexible financial plans.
# - **Predicted Amounts**: The predicted amounts show a consistent downward trend, reinforcing the need for startups to strategize for potentially lower funding in the future. This may involve seeking alternative funding sources or optimizing operations for cost-efficiency.
# - **Recovery**: The recovery in 2021, with a 51.24% growth rate, suggests that while the market can rebound, it is still essential for startups to be cautious and resilient in their financial planning.
#
# By leveraging these insights, startups can improve their financial planning, align their expectations with industry trends, and make informed decisions about resource allocation and fundraising strategies.

# %% [markdown]
# ##### c. Number of Funding Rounds within Each Year
#
# - Market Activity
# - Timing of Funding Efforts
# - Networking Opportunities

# %%
# Count the number of funding rounds in each year
funding_count_year = cl_lp1df3['Funding_Year'].value_counts().reset_index()
funding_count_year.columns = ['Funding_Year', 'Number_of_Funding_Rounds']

# Sort the DataFrame by 'Startup_Count' in descending order
funding_count_year = funding_count_year.sort_values(by='Number_of_Funding_Rounds', ascending=False).reset_index(drop=True)

# Plotting the number of funding rounds within each year
plt.figure(figsize=(12, 8))
colors = plt.cm.viridis(np.linspace(0, 1, len(funding_count_year)))
bars = plt.barh(funding_count_year['Funding_Year'], funding_count_year['Number_of_Funding_Rounds'], color=colors)

# Set the title and labels for the plot
plt.suptitle('Number of Funding Rounds within Each Year', y=0.95)
plt.xlabel('Number of Funding Rounds')
plt.ylabel('Year')
plt.yticks(funding_count_year['Funding_Year'])
plt.gca().invert_yaxis()

# Adding data labels
for bar in bars:
    width = bar.get_width()
    plt.text(width + 7.5, bar.get_y() + bar.get_height() / 2,
              f'{int(width)}', va='center', ha='left')

# Display plot
plt.show()

# Display the number of funding rounds for each year
print("Number of Funding Rounds for Each Year:")
funding_count_year
# Out:
# Number of Funding Rounds for Each Year:
#    Funding_Year  Number_of_Funding_Rounds
# 0          2021                      1165
# 1          2020                       947
# 2          2018                       522
# 3          2019                        77

# %% [markdown]
# `Comment`
#
# **Market Activity**
# - **2018**: There were 522 funding rounds, indicating a moderate level of investor activity.
# - **2019**: The number of funding rounds dropped significantly to 77, suggesting a dip in market activity or investor interest.
# - **2020**: The market rebounded with 947 funding rounds, showing a substantial increase in investor activity and competition among startups.
# - **2021**: The number of funding rounds further increased to 1165, indicating a highly active investment environment.
#
# Understanding the number of funding rounds per year helps gauge the level of investor activity and competition among startups. A higher number of rounds indicates a more active investment environment, which can be beneficial for startups looking to secure funding.
#
# **Timing of Funding Efforts**
# - Startups can time their funding efforts to align with periods of high investor activity, increasing the likelihood of attracting attention from potential investors. For example, given the high number of funding rounds in 2020 and 2021, startups might consider targeting these periods for their fundraising activities.
#
# **Networking Opportunities**
# - Increased funding rounds signify vibrant networking opportunities with investors and peers, facilitating collaborations and knowledge sharing within the startup community. The high numbers in 2020 and 2021 suggest these years were particularly good for networking and finding potential partners.
#
# **Additional Data**
# - The graph data can be summarized as:
#   - **2021**: 1165 funding rounds
#   - **2020**: 947 funding rounds
#   - **2018**: 522 funding rounds
#   - **2019**: 77 funding rounds
#
# These insights can help startups plan their funding strategies more effectively, taking advantage of periods with higher investor activity and leveraging networking opportunities during peak times.

# %% [markdown]
# ##### Comprehensive Analysis and Actionable Insights for Stakeholders on Startup Funding Dynamics in India (2018-2021)

# %% [markdown]
# **Growth Analysis**
#
# Analyzing the funding trends from 2018 to 2021 reveals significant fluctuations, offering crucial insights into the startup investment landscape in India. The data indicates a substantial decrease in funding from 2018 to 2019, with a 60.75% decline. However, this was followed by a remarkable recovery with a 380.89% increase in 2020 and an additional 86.05% increase in 2021. Specifically, funding grew from $3.62 billion in 2019 to $17.39 billion in 2020, and further to $32.36 billion in 2021, marking a period of substantial growth.
#
# This significant rise in funding from 2020 onwards signals increased market confidence and heightened investor interest during these years. Startups can capitalize on this trend by planning their funding rounds during high-growth periods, such as 2020 and 2021, to maximize their chances of securing investments.
#
# **Strategic Planning**
#
# The sharp increase in funding during 2020 and 2021 highlights the importance of strategic timing for funding efforts. Startups should consider these high-growth years when planning their fundraising activities. The trend line, represented by the equation \( y = 14.37Bx - 29010.77B \), demonstrates an overall upward trajectory in annual funding. This predictive model helps startups anticipate future funding climates and prepare accordingly, ensuring they align their strategies with periods of higher investor interest.
#
# **Investment Strategies**
#
# Understanding the annual funding trends enables startups to adapt their investment strategies effectively. By focusing on years projected to have higher funding availability, startups can optimize their efforts to attract investments. The upward trend in funding from 2020 onwards suggests that continued growth in funding availability is likely in subsequent years, providing startups with a roadmap for strategic planning and investment.
#
# **Performance Evaluation**
#
# Startups can utilize the trend line to assess their performance relative to market expectations. Comparing actual funding data against the predicted amounts helps identify whether a startup is performing in line with industry trends. If a startup's funding aligns with or exceeds the trend line, it indicates strong market performance. Conversely, falling short of the trend highlights areas needing improvement or adjustment.
#
# **Investment Expectations**
#
# The analysis of average funding amounts reveals that startups can set realistic expectations based on historical data. In 2018, the average funding was approximately $17.65 million, peaking at around $46.97 million in 2019, and fluctuating in subsequent years. This information helps startups benchmark their funding goals and performance against industry averages, identifying areas for improvement and setting informed targets.
#
# The trend line, represented by the equation \( y = -9.60Mx + 19417.08M \), indicates a declining trend in average annual funding over the years. This trend aids startups in predicting potential decreases in average investment sizes, allowing them to adjust their funding strategies and target amounts accordingly.
#
# **Resource Allocation**
#
# Projected trends in funding guide startups in better allocating their resources. With the trend suggesting a decrease in average funding, startups might focus more on activities that enhance their appeal to investors or seek to diversify their funding sources to maintain financial stability. For example, understanding that the average funding amount was $17.65 million in 2018, peaked at $46.97 million in 2019, dropped to $18.37 million in 2020, and recovered to $27.77 million in 2021 provides a comprehensive view for strategic resource planning.
#
# **Market Activity**
#
# Examining the number of funding rounds per year offers insights into the level of investor activity and competition among startups. In 2018, there were 522 funding rounds, indicating a moderate level of investor activity. The number dropped significantly to 77 in 2019, suggesting a dip in market activity or investor interest. However, the market rebounded with 947 funding rounds in 2020, showing a substantial increase in investor activity and competition among startups, further rising to 1165 funding rounds in 2021.
#
# **Timing of Funding Efforts**
#
# Startups can strategically time their funding efforts to align with periods of high investor activity, increasing the likelihood of attracting potential investors. For example, the high number of funding rounds in 2020 and 2021 suggests these periods were particularly favorable for fundraising activities.
#
# **Networking Opportunities**
#
# Increased funding rounds signify vibrant networking opportunities with investors and peers, facilitating collaborations and knowledge sharing within the startup community. The high numbers in 2020 and 2021 indicate that these years were especially conducive to networking and finding potential partners.
#
# **Conclusion**
#
# This comprehensive analysis provides actionable insights for startups to understand funding dynamics, plan strategically, adapt investment strategies, and evaluate performance relative to market trends. By leveraging these insights, startups can improve their financial planning, align their expectations with industry trends, and make informed decisions about resource allocation and fundraising strategies. The data underscores the importance of timing, strategic planning, and adapting to market conditions to maximize funding opportunities and drive growth.

# %% [markdown]
# #### 4. Which sectors received the most funding each year?

# %% [markdown]
# ##### a. Sectors that received the most funding each year

# %%
# Copying the DataFrame
cl_lp1df4 = cl_lp1df.copy()

# Grouping by Year and Sector to find the total funding amount for each sector in each year
sector_funding_by_year = cl_lp1df4.groupby(['Funding_Year', 'Sector'])['Amount'].sum().reset_index()

# Finding the sector with the highest funding amount for each year
max_funding_by_year = sector_funding_by_year.loc[sector_funding_by_year.groupby('Funding_Year')['Amount'].idxmax()]
max_funding_by_year_formatted = max_funding_by_year.copy()
max_funding_by_year_formatted["Amount"] = max_funding_by_year_formatted["Amount"].apply(lambda x: "${:,.2f}".format(x))

# Get unique sectors and assign colors
unique_sectors = max_funding_by_year['Sector'].unique()
colors = plt.cm.tab10(np.linspace(0, 1, len(unique_sectors)))

# Plotting the graph
fig, ax = plt.subplots(figsize=(12, 8))
for i, sector in enumerate(unique_sectors):
    sector_data = max_funding_by_year[max_funding_by_year['Sector'] == sector]
    ax.bar(sector_data['Funding_Year'], sector_data['Amount'], color=colors[i], label=sector)

# Formatting y-axis labels as currency in billion
formatter = ticker.FuncFormatter(lambda x, pos: f'${x/1e9:.1f}B')
ax.yaxis.set_major_formatter(formatter)

# Adding data labels on top of the bars
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 10, f'${height/1e9:.2f}B', ha='center', va='bottom', color='white')

plt.xlabel('Funding Year')
plt.ylabel('Total Funding Amount')
plt.suptitle('Maximum Funding by Year and Sector', y=0.95)
plt.xticks(max_funding_by_year['Funding_Year'].unique())
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

print('Sectors that received the most funding each year:')
max_funding_by_year_formatted
# Out:
# Sectors that received the most funding each year:
#     Funding_Year                   Sector             Amount
# 11          2018   Finance and Technology  $2,083,553,806.93
# 44          2019  Technology and Software  $1,144,451,506.49
# 67          2020  Technology and Software  $3,600,972,287.94
# 80          2021   Finance and Technology  $6,640,700,290.01

# %% [markdown]
# ##### b. Top three funded sectors for each year

# %%
# Sorting the sector_funding_by_year DataFrame by 'Funding_Year' and 'Amount' in descending order
sorted_sector_funding = sector_funding_by_year.sort_values(by=['Funding_Year', 'Amount'], ascending=[True, False])

# Creating an empty list to store the top three funded sectors for each year
top_three_sectors = []

# Iterating over each year and selecting the top three funded sectors
for year in sorted_sector_funding['Funding_Year'].unique():
    top_sectors_year = sorted_sector_funding[sorted_sector_funding['Funding_Year'] == year].head(3)
    top_three_sectors.extend(top_sectors_year.values.tolist())

# Creating a DataFrame from the list of top three sectors
top_three_sectors_df = pd.DataFrame(top_three_sectors, columns=['Funding_Year', 'Sector', 'Amount'])
top_three_sectors_formatted = top_three_sectors_df.copy()
top_three_sectors_formatted["Amount"] = top_three_sectors_formatted["Amount"].apply(lambda x: "${:,.2f}".format(x))

# Create a pivot table for plotting, filling missing values with 0
pivot_df = top_three_sectors_df.pivot(index='Funding_Year', columns='Sector', values='Amount').fillna(0)

# Plot
ax = pivot_df.plot(kind='bar', figsize=(24, 10), colormap='tab10', width=0.5)

# Set y-axis formatter
ax.yaxis.set_major_formatter(FuncFormatter(billions_formatter))

# Add data labels
for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        ax.annotate(f'${height * 1e-9:.2f}B',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 5),
                    textcoords="offset points",
                    ha='center', va='bottom')

plt.xlabel('Year')
plt.ylabel('Amount')
plt.suptitle('Funding Amount by Sector and Year',y=0.98)
plt.xticks(rotation=0)
plt.legend(title='Sector', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

print('Top three funded sectors for each year:')
top_three_sectors_formatted
# Out:
# Top three funded sectors for each year:
#     Funding_Year                       Sector             Amount
# 0           2018       Finance and Technology  $2,083,553,806.93
# 1           2018  Consumer Goods and Services  $1,740,768,524.53
# 2           2018       Education and Learning    $881,867,315.93
# 3           2019      Technology and Software  $1,144,451,506.49
# 4           2019  Consumer Goods and Services    $929,730,301.30
# 5           2019       Education and Learning    $725,000,000.00
# 6           2020      Technology and Software  $3,600,972,287.94
# 7           2020       Finance and Technology  $3,220,902,916.39
# 8           2020       Education and Learning  $2,401,537,698.68
# 9           2021       Finance and Technology  $6,640,700,290.01
# 10          2021  Consumer Goods and Services  $4,378,861,018.43
# 11          2021      Technology and Software  $3,951,663,493.70

# %% [markdown]
# ##### c. Summary statistics (mean, median, total) for funding amounts in each sector.

# %%
import pandas as pd

# Assuming cl_lp1df4 is already defined and contains the necessary data

# Group by sector to find the total funding amount for each sector
sector_funding = cl_lp1df4.groupby('Sector')['Amount'].sum().reset_index()

# Calculate mean, median, and total funding for each sector
sector_summary = cl_lp1df4.groupby('Sector')['Amount'].agg(['mean', 'median', 'sum']).reset_index()

# Formatting the summary statistics
sector_summary_formatted = sector_summary.copy()
sector_summary_formatted["mean"] = sector_summary_formatted["mean"].apply(lambda x: "${:,.2f}".format(x))
sector_summary_formatted["median"] = sector_summary_formatted["median"].apply(lambda x: "${:,.2f}".format(x))
sector_summary_formatted["sum"] = sector_summary_formatted["sum"].apply(lambda x: "${:,.2f}".format(x))

# Display the summary statistics
sector_summary_formatted
# Out:
#                                       Sector            mean          median  \
# 0                 Agriculture and Technology  $12,438,672.53   $6,000,000.00
# 1                                 Automotive  $37,217,944.42  $10,000,000.00
# 2             Construction and Home Services  $50,031,544.44  $10,000,000.00
# 3                Consumer Goods and Services  $30,769,564.68   $4,500,000.00
# 4                       Cultural and Tourism   $7,096,601.30   $1,200,000.00
# 5                       Defence and Aviation  $65,094,745.78   $3,000,000.00
# 6                      E-commerce and Retail  $27,094,242.35   $8,000,000.00
# 7                     Education and Learning  $22,337,778.70   $4,000,000.00
# 8                     Energy and Environment  $27,677,659.19   $3,000,000.00
# 9   Entrepreneurship and Business Incubation  $21,258,352.29  $21,258,352.29
# 10                       Fashion and Apparel   $6,836,139.95   $1,000,000.00
# 11                    Finance and Technology  $25,703,590.03   $7,000,000.00
# 12          Healthcare and Health Technology  $15,948,061.58   $5,750,000.00
# 13                   Hospitality and Tourism   $9,810,627.77   $9,810,627.77
# 14           Human Resources and Consultancy  $10,535,216.69   $2,412,281.00
# 15                     Insurance and Finance   $1,500,000.00   $1,500,000.00
# 16                 Marketing and Advertising   $6,797,605.51   $2,500,000.00
# 17                   Media and Entertainment  $43,343,799.53   $6,250,000.00
# 18                   Real Estate and Housing  $12,397,931.73   $5,000,000.00
# 19                         Social Networking  $11,009,908.72   $5,200,000.00
# 20         Technology Solutions for Industry  $37,482,910.58  $17,621,255.53
# 21                   Technology and Software  $18,179,703.18   $4,300,000.00
# 22                   Transport and Logistics  $18,238,755.89   $7,000,000.00
#
#                    sum
# 0    $1,069,725,837.39
# 1    $3,051,871,442.78
# 2      $850,536,255.53
# 3    $9,015,482,451.49
# 4       $42,579,607.82
# 5      $325,473,728.90
# 6    $6,340,052,710.28
# 7    $6,321,591,372.52
# 8    $1,494,593,596.05
# 9       $21,258,352.29
# 10     $123,050,519.18
# 11  $12,080,687,314.63
# 12   $3,859,430,902.32
# 13      $19,621,255.53
# 14     $937,634,285.30
# 15       $1,500,000.00
# 16     $190,332,954.25
# 17   $3,380,816,363.53
# 18     $657,090,381.95
# 19     $187,168,448.19
# 20   $1,461,833,512.50
# 21   $9,544,344,169.06
# 22   $1,605,010,518.74

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm

# Function to format x-axis labels in millions
def millions_formatter(x, pos):
    return f'${x*1e-6:.0f}M'

def billions_formatter(x, pos):
    return f'${x*1e-9:.0f}B'

# Create a color map from the Viridis palette
colors = cm.viridis(np.linspace(0, 1, len(sector_summary)))

# Sort the data by 'sum' column in descending order
sector_summary = sector_summary.sort_values(by='mean', ascending=True)

# Plotting the mean funding amounts by sector
plt.figure(figsize=(12, 8))
bars = plt.barh(sector_summary['Sector'], sector_summary['mean'], color=colors)
plt.xlabel('Mean Funding Amount (in USD)')
plt.ylabel('Sector')
plt.title('Mean Funding Amount by Sector')
plt.gca().xaxis.set_major_formatter(millions_formatter)
# Get the maximum value for scaling the distance of the labels
max_value = sector_summary['mean'].max()
for bar in bars:
    width = bar.get_width()
    plt.text(width + max_value * 0.01, bar.get_y() + bar.get_height()/2,
             f'${width*1e-6:.2f}M', va='center', ha='left', fontsize=12)
plt.tight_layout()
plt.show()

# Sort the data by 'median' column in descending order
sector_summary = sector_summary.sort_values(by='median', ascending=True)

# Plotting the median funding amounts by sector
plt.figure(figsize=(12, 8))
bars = plt.barh(sector_summary['Sector'], sector_summary['median'], color=colors)
plt.xlabel('Median Funding Amount (in USD)')
plt.ylabel('Sector')
plt.title('Median Funding Amount by Sector')
plt.gca().xaxis.set_major_formatter(millions_formatter)
max_value = sector_summary['median'].max()
for bar in bars:
    width = bar.get_width()
    plt.text(width + max_value * 0.01, bar.get_y() + bar.get_height()/2,
             f'${width*1e-6:.2f}M', va='center', ha='left', fontsize=12)
plt.tight_layout()
plt.show()

# Sort the data by 'sum' column in descending order
sector_summary = sector_summary.sort_values(by='sum', ascending=True)

# Plotting the total funding amounts by sector
plt.figure(figsize=(12, 8))
bars = plt.barh(sector_summary['Sector'], sector_summary['sum'], color=colors)
plt.xlabel('Total Funding Amount (in USD)')
plt.ylabel('Sector')
plt.title('Total Funding Amount by Sector')
plt.gca().xaxis.set_major_formatter(billions_formatter)
max_value = sector_summary['sum'].max()
for bar in bars:
    width = bar.get_width()
    plt.text(width + max_value * 0.01, bar.get_y() + bar.get_height()/2,
             f'${width*1e-9:.2f}B', va='center', ha='left', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 5. What impact do the years of existence or age of a start-up have on investment opportunities?

# %%
# Copying the DataFrame
cl_lp1df5 = cl_lp1df.copy()

# Function to categorize startups based on their founding year
def categorize_startups(startups):
    categories = {
        'Early Stage': [],
        'Scaling Stage': [],
        'Stable Stage': [],
        'Mature Stage': [],
        'Unknown': []
    }
    
    current_year = 2024 
    
    for index, startup in startups.iterrows():
        founded_year = startup['Founded']
        
        if pd.isnull(founded_year):
            category = 'Unknown'
        else:
            age = current_year - founded_year
            if age <= 5:
                category = 'Early Stage'
            elif age <= 10:
                category = 'Scaling Stage'
            elif age <= 15:
                category = 'Stable Stage'
            else:
                category = 'Mature Stage'
        
        categories[category].append(startup)
    
    return categories

# Function to calculate average investment amount for each category
def calculate_average_investment(categories):
    average_investment = {}
    
    for category, startups in categories.items():
        if startups:
            total_amount = sum(startup['Amount'] for startup in startups)
            average_amount = total_amount / len(startups)
            average_investment[category] = average_amount / 1e6  # Convert to millions
        else:
            average_investment[category] = 0
    
    return average_investment

# Main script
if __name__ == "__main__":
    # Copying the DataFrame
    cl_lp1df5 = cl_lp1df.copy()

    # Categorize startups
    startup_categories = categorize_startups(cl_lp1df5)

    # Calculate average investment for each category
    average_investment_by_category = calculate_average_investment(startup_categories)

    # Sort categories by average investment amount (from highest to lowest)
    sorted_categories = sorted(average_investment_by_category.items(), key=lambda x: x[1], reverse=True)
    categories = [cat[0] for cat in sorted_categories]
    avg_investments = [cat[1] for cat in sorted_categories]

    # Plotting the bar chart
    plt.figure(figsize=(12, 8))
    bar_colors = plt.cm.viridis(np.linspace(0.2, 1, len(categories)))  # Using Viridis color palette

    bars = plt.barh(categories, avg_investments, color=bar_colors)

    # Adding data labels
    for bar, investment in zip(bars, avg_investments):
        plt.text(bar.get_width() + 1.5, bar.get_y() + bar.get_height()/2, 
                 '${:.2f} M'.format(investment), 
                 ha='left', va='center')

    # Formatting currency on y-axis (in millions)
    plt.gca().xaxis.set_major_formatter(mtick.StrMethodFormatter('${x:,.0f} M'))

    plt.xlabel('Average Investment Amount ($ millions)')
    plt.ylabel('Start-up Age Category')
    plt.suptitle('Average Investment by Start-up Age Category', y=0.95)
    plt.gca().invert_yaxis()  # Invert y-axis to have 'Early Stage' at the top
    plt.show()

    # Print startup count and average investment for each category
    print("\nStartup Count and Average Investment by Start-up Age Category:")
    print()
    for category, startups in startup_categories.items():
        avg_amount = average_investment_by_category[category]
        print(f"{category}: {len(startups)} startups, Average Investment: ${avg_amount:.2f} M")
# Out:
# Startup Count and Average Investment by Start-up Age Category:
#
# Early Stage: 629 startups, Average Investment: $10.88 M
# Scaling Stage: 1192 startups, Average Investment: $24.63 M
# Stable Stage: 259 startups, Average Investment: $45.16 M
# Mature Stage: 89 startups, Average Investment: $81.31 M
# Unknown: 542 startups, Average Investment: $13.74 M

# %% [markdown]
# `Comment`
#
# **1. Validation Stage (Early Years)**
#
# Early-stage start-ups, typically within their first 5 years, are often considered high-risk investments due to uncertainties in their business model, market acceptance, and revenue generation. Despite this risk, investors see significant potential for disruptive innovation and substantial growth, which can yield substantial rewards if successful. Reflecting this, there are 629 early-stage start-ups with an average investment of $10.88 million each, indicating a strong willingness among investors to take risks on potentially groundbreaking ventures.
#
# **2. Scaling Stage (Growth Years)**
#
# As start-ups mature and validate their business model, typically within 6 to 10 years, they move into a stage where they have proven their product or service in the market. Investors are more inclined to invest in these start-ups due to demonstrated market traction, which increases the likelihood of a return on investment. Established start-ups may use this investment to scale operations, enter new markets, or diversify their product offerings. There are 1192 scaling stage start-ups with an average investment of $24.63 million each, reflecting increased investor confidence due to proven market traction and growth potential.
#
# **3. Stable Stage (Later Years)**
#
# Older start-ups, typically within 11 to 15 years, that have achieved stability and consistent growth often attract investment for further expansion or strategic acquisitions. These market leaders benefit from an established brand, customer base, and competitive advantage, making them attractive to investors. There are 259 such stable stage start-ups, with an average investment of $45.16 million each, reflecting the reduced risk and higher stability perceived by investors.
#
# **4. Exit Stage (Maturity)**
#
# Investors seeking exit opportunities often focus on start-ups older than 15 years that have potential strategies like IPOs or acquisitions by larger companies, which can yield significant returns. At this mature stage, investment decisions aim to minimize risk while maximizing returns through careful evaluation of financial performance and market position. Reflecting this approach, there are 89 mature-stage start-ups with an average investment of $81.31 million each, indicating the high potential returns from established companies with clear exit strategies.
#
# **5. Unknown Stage**
#
# Start-ups with unknown founding years present uncertain prospects, as their development stage and potential can vary widely, leading investors to approach them with caution. There are 542 such start-ups, with an average investment of $13.74 million, indicating a balanced approach by investors who weigh potential opportunities against the risks of uncertainty.
#
# **Summary**
#
# The age of a start-up impacts investment opportunities by influencing perceived risk, potential for growth, market traction, and exit strategies. Early-stage start-ups offer high-risk, high-reward opportunities, while mature start-ups may attract investment for expansion or exit strategies. Each stage requires careful consideration of the start-up's business model, market conditions, and growth potential to make informed investment decisions.
#
# The provided statistics illustrate the trend: as start-ups mature, the average investment amount increases, reflecting greater investor confidence in more established companies. This data-driven insight helps investors tailor their strategies to the specific risks and rewards associated with each stage of a start-up's lifecycle.

# %% [markdown]
# #### 6. What are the funding stages and types that received the highest investments?

# %% [markdown]
# ##### a. Total Investment by Funding Stage

# %%
# Copying the DataFrame
cl_lp1df6 = cl_lp1df.copy()

# Grouping by funding stage and summing the investments
investment_by_stage = cl_lp1df6.groupby('Stage_and_Type')['Amount'].sum().sort_values(ascending=False)
investment_by_stage_formatted = investment_by_stage.copy()
investment_by_stage_formatted = investment_by_stage_formatted.apply(lambda x: "${:,.2f}".format(x))

# Plotting the results with horizontal bars, viridis palette, data labels in currency, amount axis in currency, billion formatter
plt.figure(figsize=(12, 8))
bars = plt.barh(investment_by_stage.index, investment_by_stage, color=plt.cm.viridis(np.linspace(0.2, 1, (len(investment_by_stage)))))

# Formatting the x-axis as currency in billions
formatter = ticker.FuncFormatter(lambda x, pos: f'${x*1e-9:.0f}B')
plt.gca().xaxis.set_major_formatter(formatter)

# Adding data labels in currency with 2 decimal places in billions
for bar in bars:
    plt.gca().text(
        bar.get_width() + max(investment_by_stage) * 0.01,  # Significant offset from the bars
        bar.get_y() + bar.get_height()/2, 
        f'${bar.get_width()*1e-9:.2f}B', 
        va='center', 
        ha='left'
    )

plt.suptitle('Total Investment by Funding Stage', y=0.95)
plt.xlabel('Total Investment Amount')
plt.ylabel('Funding Stage and Type')
plt.gca().invert_yaxis()

# Display the plot
plt.show()

investment_by_stage_formatted
# Out:
# Stage_and_Type
# Scaling                $43,266,442,242.19
# Equity                  $6,983,702,036.51
# Validation              $6,760,314,969.79
# Early Traction          $3,209,994,652.43
# Debt                    $1,306,380,376.00
# Ideation                  $628,934,485.39
# Market Transactions       $294,141,723.53
# Bridge                    $112,588,156.87
# Non-Equity                 $19,187,337.53
# Name: Amount, dtype: object

# %% [markdown]
# ##### b. Average Investment by Funding Stage

# %%
# Grouping by funding stage and summing the investments
avg_investment_by_stage = cl_lp1df6.groupby('Stage_and_Type')['Amount'].mean().sort_values(ascending=False)
avg_investment_by_stage_formatted = avg_investment_by_stage.copy()
avg_investment_by_stage_formatted = avg_investment_by_stage_formatted.apply(lambda x: "${:,.2f}".format(x))

# Plotting the results with horizontal bars, viridis palette, data labels in currency, amount axis in currency, billion formatter
plt.figure(figsize=(12, 8))
bars = plt.barh(avg_investment_by_stage.index, avg_investment_by_stage, color=plt.cm.viridis(np.linspace(0.2, 1, (len(avg_investment_by_stage)))))

# Formatting the x-axis as currency in billions
formatter = ticker.FuncFormatter(lambda x, pos: f'${x*1e-6:.0f}M')
plt.gca().xaxis.set_major_formatter(formatter)

# Adding data labels in currency with 2 decimal places in billions
for bar in bars:
    plt.gca().text(
        bar.get_width() + max(avg_investment_by_stage) * 0.01,  
        bar.get_y() + bar.get_height()/2, 
        f'${bar.get_width()*1e-6:.2f}M', 
        va='center', 
        ha='left'
    )

plt.suptitle('Average Investment by Funding Stage', y=0.95)
plt.xlabel('Average Investment Amount')
plt.ylabel('Funding Stage and Type')
plt.gca().invert_yaxis()

# Display the plot
plt.show()

avg_investment_by_stage_formatted
# Out:
# Stage_and_Type
# Market Transactions    $73,535,430.88
# Scaling                $61,986,306.94
# Equity                 $33,737,691.00
# Early Traction          $9,786,569.06
# Ideation                $8,385,793.14
# Validation              $7,131,133.93
# Debt                    $4,255,310.67
# Non-Equity              $3,837,467.51
# Bridge                    $809,986.74
# Name: Amount, dtype: object

# %% [markdown]
# ##### c. Investment Trends by Funding Stage Over the Years

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.ticker as ticker

# Copying the DataFrame
cl_lp1df6 = cl_lp1df.copy()

# Grouping by funding stage and year, and summing the investments
investment_by_stage_year = cl_lp1df6.groupby(['Funding_Year', 'Stage_and_Type'])['Amount'].sum().unstack().fillna(0)

# Formatting the amounts in billions for easier visualization
investment_by_stage_year_billion = investment_by_stage_year.applymap(lambda x: x / 1e9)

# %%
# Plotting the trends for each funding stage over the years
plt.figure(figsize=(14, 10))

# Using a color palette for better distinction
colors = plt.cm.viridis(np.linspace(0, 1, len(investment_by_stage_year_billion.columns)))

# Plotting each funding stage
for i, column in enumerate(investment_by_stage_year_billion.columns):
    plt.plot(investment_by_stage_year_billion.index, investment_by_stage_year_billion[column], marker='o', color=colors[i], label=column)

# Formatting the y-axis as currency in billions
formatter = ticker.FuncFormatter(lambda x, pos: f'${x:.0f}B')
plt.gca().yaxis.set_major_formatter(formatter)

# Ensuring x-axis labels for years are whole integers
plt.xticks(investment_by_stage_year_billion.index, investment_by_stage_year_billion.index.astype(int))

# Adding labels and title
plt.title('Investment Trends by Funding Stage Over the Years', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Total Investment Amount (in USD)', fontsize=14)
plt.legend(title='Funding Stage and Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# #### Hypothesis Testing

# %%
# cl_lp1dfH = cl_lp1df.copy()

# Group by 'Founded' and 'Stage_and_Type', and sum the 'Amount' for each group
grouped = cl_lp1df.groupby(['Funding_Year', 'Stage_and_Type'])['Amount'].sum().reset_index()

# Calculate the total funding for each year
total_funding_per_year = grouped.groupby('Funding_Year')['Amount'].sum().reset_index()
total_funding_per_year = total_funding_per_year.rename(columns={'Amount': 'Total_Funding'})

# Merge the total funding back to the grouped dataframe to calculate proportions
cl_lp1dfH = pd.merge(grouped, total_funding_per_year, on='Funding_Year')
cl_lp1dfH['Proportion'] = cl_lp1dfH['Amount'] / cl_lp1dfH['Total_Funding']

# Display the final dataframe with proportions
cl_lp1dfH
# Out:
#     Funding_Year       Stage_and_Type        Amount  Total_Funding  Proportion
# 0           2018               Bridge  0.000000e+00   9.215332e+09    0.000000
# 1           2018                 Debt  1.986412e+08   9.215332e+09    0.021556
# 2           2018       Early Traction  4.438070e+08   9.215332e+09    0.048160
# 3           2018               Equity  3.612821e+09   9.215332e+09    0.392045
# 4           2018             Ideation  3.547751e+07   9.215332e+09    0.003850
# 5           2018  Market Transactions  2.941417e+08   9.215332e+09    0.031919
# 6           2018           Non-Equity  1.918734e+07   9.215332e+09    0.002082
# 7           2018              Scaling  2.615442e+09   9.215332e+09    0.283814
# 8           2018           Validation  1.995814e+09   9.215332e+09    0.216575
# 9           2019               Bridge  0.000000e+00   3.616614e+09    0.000000
# 10          2019                 Debt  0.000000e+00   3.616614e+09    0.000000
# 11          2019       Early Traction  1.012605e+08   3.616614e+09    0.027999
# 12          2019               Equity  0.000000e+00   3.616614e+09    0.000000
# 13          2019             Ideation  2.500000e+06   3.616614e+09    0.000691
# 14          2019  Market Transactions  0.000000e+00   3.616614e+09    0.000000
# 15          2019           Non-Equity  0.000000e+00   3.616614e+09    0.000000
# 16          2019              Scaling  3.410373e+09   3.616614e+09    0.942974
# 17          2019           Validation  1.024803e+08   3.616614e+09    0.028336
# 18          2020               Bridge  9.225816e+07   1.739198e+10    0.005305
# 19          2020                 Debt  4.201391e+08   1.739198e+10    0.024157
# 20          2020       Early Traction  9.622011e+08   1.739198e+10    0.055324
# 21          2020               Equity  4.278070e+07   1.739198e+10    0.002460
# 22          2020             Ideation  2.594802e+08   1.739198e+10    0.014920
# 23          2020  Market Transactions  0.000000e+00   1.739198e+10    0.000000
# 24          2020           Non-Equity  0.000000e+00   1.739198e+10    0.000000
# 25          2020              Scaling  1.362451e+10   1.739198e+10    0.783379
# 26          2020           Validation  1.990612e+09   1.739198e+10    0.114456
# 27          2021               Bridge  2.033000e+07   3.235776e+10    0.000628
# 28          2021                 Debt  6.876000e+08   3.235776e+10    0.021250
# 29          2021       Early Traction  1.702726e+09   3.235776e+10    0.052622
# 30          2021               Equity  3.328100e+09   3.235776e+10    0.102853
# 31          2021             Ideation  3.314767e+08   3.235776e+10    0.010244
# 32          2021  Market Transactions  0.000000e+00   3.235776e+10    0.000000
# 33          2021           Non-Equity  0.000000e+00   3.235776e+10    0.000000
# 34          2021              Scaling  2.361612e+10   3.235776e+10    0.729844
# 35          2021           Validation  2.671409e+09   3.235776e+10    0.082559

# %%
# Pivot the dataframe for plotting
pivot_df = cl_lp1dfH.pivot(index='Funding_Year', columns='Stage_and_Type', values='Proportion')

# Plotting
ax = pivot_df.plot(kind='bar', stacked=True, figsize=(12, 8))

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Proportion of Total Funding')
plt.title('Funding Distribution Across Stages Annually')

# Plot legend outside the plot
ax.legend(title='Stage and Type', bbox_to_anchor=(1.05, 1), loc='upper left')

# Ensure x labels are horizontal
ax.set_xticklabels(ax.get_xticklabels(), rotation=0)

# Adjust layout to make room for the legend
plt.tight_layout(rect=[0, 0, 0.85, 1])

# Display the plot
plt.show()

# %%
# Create a contingency table
contingency_table = cl_lp1dfH.pivot(index='Funding_Year', columns='Stage_and_Type', values='Amount').fillna(0)

# Apply chi-square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Display the results
print("Chi-square statistic:", chi2)
print("p-value:", p)
print("Degrees of freedom:", dof)
print("Expected frequencies:\n", expected)
# Out:
# Chi-square statistic: 15243738689.52947
# p-value: 0.0
# Degrees of freedom: 24
# Expected frequencies:
#  [[1.65789274e+07 1.92368238e+08 4.72680873e+08 1.02837005e+09
#   9.26123978e+07 4.33132082e+07 2.82539021e+06 6.37110709e+09
#   9.95475671e+08]
#  [6.50650175e+06 7.54960952e+07 1.85506508e+08 4.03590136e+08
#   3.63463036e+07 1.69985342e+07 1.10884172e+06 2.50038006e+09
#   3.90680534e+08]
#  [3.12891982e+07 3.63054122e+08 8.92084582e+08 1.94082969e+09
#   1.74786197e+08 8.17444653e+07 5.33232290e+06 1.20241091e+10
#   1.87874854e+09]
#  [5.82135295e+07 6.75461920e+08 1.65972269e+09 3.61091216e+09
#   3.25189587e+08 1.52085516e+08 9.92078271e+06 2.23708460e+10
#   3.49541023e+09]]

# %% [markdown]
# #### Conclusion

# %% [markdown]
# Given the extremely high chi-square statistic and the p-value of 0.0:
#
# Reject the Null Hypothesis (H0):
#
# The data provide strong evidence that the proportion of funding received by early-stage start-ups (seed and series A) is significantly different from the proportion received by later-stage start-ups (series B and beyond) from 2018 to 2021.
#
# Support for the Alternative Hypothesis (H1):
#
# The results suggest that early-stage start-ups (seed and series A) do indeed receive a significantly different (likely larger, as per the hypothesis rationale) proportion of the total funding compared to later-stage start-ups from 2018 to 2021.
#
# This conclusion can help new start-ups understand that there may be greater funding opportunities at early stages, influencing their strategies for seeking investment.

# %% [markdown]
# ## References

# %% [markdown]
# ***Adebayo, O. P., Worlu, R. E., Moses, C. L., & Ogunnaike, O. O. (2020). An integrated organisational culture for sustainable environmental performance in the Nigerian Context. Sustainability, 12(20), 8323.***
#
# ***David, D., S. Gopalan, and S. Ramachandran. 2020. The Startup Environment and Funding Activity in India. ADBI Working Paper 1145. Tokyo: Asian Development Bank Institute.***
#
# ***James Broughel and Adam Thierer. “Technological Innovation and Economic Growth: A Brief Report on the Evidence.” Mercatus Research, Mercatus Center at George Mason University, Arlington, VA, February 2019.***
#
# ***Vickers, Chris, and Nicolas L. Ziebarth. "Lessons for Today from Past Periods of Rapid Technological Change." United Nations, Department of Economic and Social Affairs, DESA Working Paper No. 158, March 2019.***

# %% [markdown]
# [Back to Top](#Table-of-Contents)
